# %%
import os
import gc
import re
import time
import random
import numpy as np
import csv
import copy
import glob
import math
import joblib
import torch
import torch.nn as nn
from torch.optim import AdamW
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from transformers import BertTokenizer, VisualBertForQuestionAnswering, VisualBertConfig
import scipy
from scipy.stats import mannwhitneyu
from scipy.signal import savgol_filter
from scipy.ndimage import gaussian_filter
from scipy.interpolate import CubicSpline, interp1d
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, RocCurveDisplay, roc_curve, classification_report, top_k_accuracy_score, coverage_error
import warnings
warnings.filterwarnings("ignore")

def scherrer_fwhm(crystal_size, theta, wavelength=1.5406, shape_factor=0.9):
    theta_rad = np.deg2rad(theta/2)
    fwhm = (shape_factor*wavelength)/(crystal_size*np.cos(theta_rad))
    return fwhm

def load_plt_setting():
    plt.style.use('seaborn-white')
    mpl.rcParams['font.sans-serif'] = "Arial"
    mpl.rcParams['font.family'] = "sans-serif"
    mpl.rcParams['axes.linewidth'] = 2
    font = {'size': 32}
    mpl.rc('font', **font)
    mpl.rcParams['xtick.major.pad']='8'
    mpl.rcParams['ytick.major.pad']='8'
    plt.rcParams["font.weight"] = "normal"
    plt.rcParams["axes.labelweight"] = "normal"
    plt.rcParams['svg.fonttype'] = 'none'
    mpl.rcParams['axes.linewidth'] = 2

tokenizer = BertTokenizer.from_pretrained("google-bert/bert-base-uncased")
_ = tokenizer.add_tokens('pb')

# %% [markdown]
# # 0 Training loss plot

# %%
folder = os.getcwd()
model_folder = '20241022 three phase orientation full prompt 50 dynamic lr'

# with open(os.path.join(folder, 'models', model_folder, 'train_result.npy'), 'rb') as handle:
#     train_loss = np.array(joblib.load(handle)['loss'])
    
train_loss = np.genfromtxt(os.path.join(folder, 'models', model_folder, 'train_loss.csv'), delimiter=',')
    
smoothed = savgol_filter(train_loss,window_length=201,polyorder=3)

# %%
load_plt_setting()

fig, ax = plt.subplots(figsize=(12, 10))
data_size_list = np.linspace(20,len(train_loss)*20,len(train_loss))

ax.plot(data_size_list, train_loss, zorder=-10, alpha=0.7, label='Raw')
ax.plot(data_size_list, smoothed, label='Smoothed')

ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=5, steps=[1, 2, 5, 10]))
ax.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=5, steps=[1, 2, 5, 10]))
ax.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
# ax.axes.set_xlim([100,100000])
ax.axes.set_xlim([100,30000000])
ax.axes.set_ylim([0,4.5])
# ax.axes.set_ylim([0,2])
ax.set_xscale('log')

ax.set_xlabel(r'Data size', labelpad=20, fontsize=34)
ax.set_ylabel(r'KL divergence', labelpad=20, fontsize=34)
# plt.legend(loc="upper right",fontsize=28)
plt.legend(loc="lower left",fontsize=28)

plt.savefig(os.path.join(folder, 'models', model_folder, 'train_loss.png'), format='png', dpi=300, transparent=True, bbox_inches='tight')

# %%
del train_dic

# %% [markdown]
# # 1 Dataloader

# %%
class DataLoader():
    '''
    [Input]
    dataset_path:      Path to dataset generated from preprocess.py
                       dataset: 'formula', 'element_list', 'space_group', 'xrd_list'
                                'xrd_list': list of (X,Y), len(xrd_list) depends on the strain setting
    
    batch_size:        Batch size n.
    n_mix:             List of n compounds coexisting in one XRD.
    
    [Output]
    Xs:                Array of intensity in (n,Y,1), n = batch_size
    Ys:                Array of classification labels in (n, len(dataset))
    element_list:      List of elements for each sample, n = len(element_list) 
    formula_list:      Human labels, n = len(formula_list)
    '''
    def __init__(self, dataset_path):
        
        try:
            with open(dataset_path, 'rb') as handle:
                self.dataset = joblib.load(handle)
                print('Loading dataset successful.')
        except:
            print("Missing dataset.")
        
        self.sample_list, self.sample_formula_list, self.combination_list = [], [], []
        self.multiphase = {}
        self.len = len(self.dataset)
        
        for sample, self.data in self.dataset.items():
            self.sample_list.append(sample)
            formula = self.data['formula']
            if '-' in formula:
                formula = formula.split('-')
                formula = formula[-1] + '-' + formula[0]
            self.sample_formula_list.append(re.findall(r'\D+', formula) + re.findall(r'\d+', formula))
            
        self.sample_list = [x for _, x in sorted(zip(self.sample_formula_list, self.sample_list))]
        for i,sample in enumerate(self.sample_list):
            self.elements = self.dataset[sample]['element_list']
            self.multiphase[''.join(set(self.elements))] = {'elements':self.elements,'samples':[]}
            print(i,self.dataset[sample]['formula'],self.elements)
            
        for sample in self.sample_list:
            self.elements = self.dataset[sample]['element_list']
            for combination in self.multiphase.keys():
                if set(self.elements).issubset(set(self.multiphase[combination]['elements'])):
                    self.multiphase[combination]['samples'].append(sample)    
        
        self.multiphase = {k: v for k, v in self.multiphase.items() if len(v.get('samples', [])) >= 2}
        print(self.multiphase)
        
    def load_data(self, batch_size=10, twotheta=np.arange(5.00, 60.01, 0.01), 
                  n_mix=[1,2,3], resonable_mixing=False, min_mixing_ratio=0.05, 
                  high_orientation_probability=0.2, crystal_size_range=(5, 20), intensity_variation_range=(0.2, 1), 
                  noise_sigma_list=np.logspace(-4,-2,num=101)):
        
        self.n_mix_list = np.random.choice(n_mix, batch_size, replace=True)
        
        self.Xs = np.zeros((batch_size,len(twotheta),1))
        self.Ys = np.zeros((batch_size,self.len))
        self.element_list, self.formula_list = [], []
        
        i = 0
        while i < batch_size:
            if resonable_mixing and self.n_mix_list[i]!=1:
                self.sample_idxs = []
                samples = []
                while len(samples) < self.n_mix_list[i]:
                    samples = self.multiphase[np.random.choice(list(self.multiphase.keys()))]['samples']
                self.n_mix_list[i] = min(self.n_mix_list[i],len(samples))
                samples = np.random.choice(samples, self.n_mix_list[i], replace=False)
                for sample in samples:
                    self.sample_idxs.append(self.sample_list.index(sample))
            else:
                self.sample_idxs = np.random.choice(self.len, size=self.n_mix_list[i], replace=False)
            self.formulas, self.elements = [], []
            
            self.mixing_ratio = np.random.uniform(min_mixing_ratio,1,len(self.sample_idxs))
            self.mixing_ratio = self.mixing_ratio/np.sum(self.mixing_ratio)
            
            for j, sample_idx in enumerate(self.sample_idxs):
                self.data = self.dataset[self.sample_list[sample_idx]]
                self.formulas.append(self.data['formula'])
                for element in self.data['element_list']:
                    if element not in self.elements:
                        self.elements.append(element)
                self.Ys[i, sample_idx] += 1
                
                self.twotheta_short, self.X_short = self.data['xrd_list'][np.random.randint(0,len(self.data['xrd_list']))]
                if np.random.binomial(1, high_orientation_probability) == 1:
                    high_orientation_peak_index = np.random.choice(np.argpartition(dataloader.X_short,-3)[-3:],1)[0]
                    self.X_short = np.array([self.X_short[high_orientation_peak_index]])
                    self.twotheta_short = np.array([self.twotheta_short[high_orientation_peak_index]])
                
                self.X = np.zeros(twotheta.shape)
                self.X[np.searchsorted(twotheta,self.twotheta_short)] = self.X_short
                
                # Intensity variation
                self.X = self.X * np.random.uniform(*intensity_variation_range, self.X.shape[0])
                # Crystal size broadening
                fwhm = scherrer_fwhm(np.random.uniform(*crystal_size_range), twotheta)
                sigma = np.mean(fwhm)/(2*np.sqrt(2*np.log(2)))
                self.X = gaussian_filter(self.X, sigma=sigma*100)
                
                self.Xs[i,:,0] += self.X/np.max(self.X)*self.mixing_ratio[j]
            
            if np.max(self.Xs[i,:,0]) == 0:
                self.Ys[i, :] = np.zeros(self.Ys[i, :].shape)
                pass
            else:
                self.Xs[i,:,0] = self.Xs[i,:,0]/np.max(self.Xs[i,:,0]) + np.random.normal(0, np.random.choice(noise_sigma_list), len(twotheta))
                self.Xs[i,:,0] = (self.Xs[i,:,0]-np.min(self.Xs[i,:,0]))/(np.max(self.Xs[i,:,0])-np.min(self.Xs[i,:,0]))
                self.formula_list.append(self.formulas)
                self.element_list.append(list(set(np.array(self.elements).flatten())))
                i += 1
            
        return self.Xs, self.Ys, self.element_list, self.formula_list, self.n_mix_list
    
    def load_ref(self, sample_idx=0, twotheta=np.arange(5.00, 60.01, 0.01),):
        
        self.data = self.dataset[self.sample_list[sample_idx]]
        self.twotheta_short, self.X_short = self.data['xrd_list'][int(len(dataloader.data['xrd_list'])/2+0.5)]
        self.X = np.zeros(twotheta.shape)
        self.X[np.searchsorted(twotheta,self.twotheta_short)] = self.X_short
        self.X = self.X/np.max(self.X)
        return self.X

# %%
cif_folder = os.path.join(folder, 'cif')
dataloader = DataLoader(os.path.join(cif_folder, 'dataset.npy'))
# Out:
# Loading dataset successful.
# 0 Cs0.2FA0.8PbBr3 ['Cs', 'FA', 'Pb', 'Br']
# 1 Cs0.4FA0.6PbBr3 ['Cs', 'FA', 'Pb', 'Br']
# 2 Cs0.6FA0.4PbBr3 ['Cs', 'FA', 'Pb', 'Br']
# 3 Cs0.8FA0.2PbBr3 ['Cs', 'FA', 'Pb', 'Br']
# 4 Cs0.2FA0.8PbI3 ['Cs', 'FA', 'Pb', 'I']
# 5 Cs0.4FA0.6PbI3 ['Cs', 'FA', 'Pb', 'I']
# 6 Cs0.6FA0.4PbI3 ['Cs', 'FA', 'Pb', 'I']
# 7 Cs0.8FA0.2PbI3 ['Cs', 'FA', 'Pb', 'I']
# 8 Cs0.2MA0.8PbBr3 ['Cs', 'MA', 'Pb', 'Br']
# 9 Cs0.4MA0.6PbBr3 ['Cs', 'MA', 'Pb', 'Br']
# 10 Cs0.6MA0.4PbBr3 ['Cs', 'MA', 'Pb', 'Br']
# 11 Cs0.8MA0.2PbBr3 ['Cs', 'MA', 'Pb', 'Br']
# 12 Cs0.2MA0.8PbI3 ['Cs', 'MA', 'Pb', 'I']
# 13 Cs0.4MA0.6PbI3 ['Cs', 'MA', 'Pb', 'I']
# 14 Cs0.6MA0.4PbI3 ['Cs', 'MA', 'Pb', 'I']
# 15 Cs0.8MA0.2PbI3 ['Cs', 'MA', 'Pb', 'I']
# 16 Cs4PbBr6 ['Cs', 'Pb', 'Br']
# 17 CsBr ['Cs', 'Br']
# 18 CsI ['Cs', 'I']
# 19 CsPb2Br5 ['Cs', 'Pb', 'Br']
# 20 CsPb(Cl0.2Br0.8)3 ['Cs', 'Pb', 'Br', 'Cl']
# 21 CsPb(Cl0.4Br0.6)3 ['Cs', 'Pb', 'Br', 'Cl']
# 22 CsPb(Cl0.6Br0.4)3 ['Cs', 'Pb', 'Br', 'Cl']
# 23 CsPb(Cl0.8Br0.2)3 ['Cs', 'Pb', 'Br', 'Cl']
# 24 CsPb(I0.2Br0.8)3 ['Cs', 'Pb', 'I', 'Br']
# 25 CsPb(I0.4Br0.6)3 ['Cs', 'Pb', 'I', 'Br']
# 26 CsPb(I0.6Br0.4)3 ['Cs', 'Pb', 'I', 'Br']
# 27 CsPb(I0.8Br0.2)3 ['Cs', 'Pb', 'I', 'Br']
# 28 CsPb(I0.2Cl0.8)3 ['Cs', 'Pb', 'I', 'Cl']
# 29 CsPb(I0.4Cl0.6)3 ['Cs', 'Pb', 'I', 'Cl']
# 30 CsPb(I0.6Cl0.4)3 ['Cs', 'Pb', 'I', 'Cl']
# 31 CsPb(I0.8Cl0.2)3 ['Cs', 'Pb', 'I', 'Cl']
# 32 cubic-CsPbBr3 ['Cs', 'Pb', 'Br']
# 33 orthorhombic-CsPbBr3 ['Cs', 'Pb', 'Br']
# 34 Pnma-CsPbCl3 ['Cs', 'Pb', 'Cl']
# 35 cubic-CsPbCl3 ['Cs', 'Pb', 'Cl']
# 36 alpha-CsPbI3 ['Cs', 'Pb', 'I']
# 37 delta-CsPbI3 ['Cs', 'Pb', 'I']
# 38 gamma-CsPbI3 ['Cs', 'Pb', 'I']
# 39 FAPb(Br0.2I0.8)3 ['FA', 'Pb', 'I', 'Br']
# 40 FAPb(Br0.4I0.6)3 ['FA', 'Pb', 'I', 'Br']
# 41 FAPb(Br0.6I0.4)3 ['FA', 'Pb', 'I', 'Br']
# 42 FAPb(Br0.8I0.2)3 ['FA', 'Pb', 'I', 'Br']
# 43 cubic-FAPbBr3 ['FA', 'Pb', 'Br']
# 44 alpha-FAPbI3 ['FA', 'Pb', 'I']
# 45 beta-FAPbI3 ['FA', 'Pb', 'I']
# 46 delta-FAPbI3 ['FA', 'Pb', 'I']
# 47 MA0.2FA0.8PbBr3 ['FA', 'MA', 'Pb', 'Br']
# 48 MA0.4FA0.6PbBr3 ['FA', 'MA', 'Pb', 'Br']
# 49 MA0.6FA0.4PbBr3 ['FA', 'MA', 'Pb', 'Br']
# 50 MA0.8FA0.2PbBr3 ['FA', 'MA', 'Pb', 'Br']
# 51 MA0.2FA0.8PbI3 ['FA', 'MA', 'Pb', 'I']
# 52 MA0.4FA0.6PbI3 ['FA', 'MA', 'Pb', 'I']
# 53 MA0.6FA0.4PbI3 ['FA', 'MA', 'Pb', 'I']
# 54 MA0.8FA0.2PbI3 ['FA', 'MA', 'Pb', 'I']
# 55 MAPb(Br0.2I0.8)3 ['MA', 'Pb', 'I', 'Br']
# 56 MAPb(Br0.4I0.6)3 ['MA', 'Pb', 'I', 'Br']
# 57 MAPb(Br0.6I0.4)3 ['MA', 'Pb', 'I', 'Br']
# 58 MAPb(Br0.8I0.2)3 ['MA', 'Pb', 'I', 'Br']
# 59 cubic-MAPbBr3 ['MA', 'Pb', 'Br']
# 60 tetragonal-MAPbBr3 ['MA', 'Pb', 'Br']
# 61 Pnma-MAPbCl3 ['MA', 'Pb', 'Cl']
# 62 alpha-MAPbI3 ['MA', 'Pb', 'I']
# 63 tetragonal-MAPbI3 ['MA', 'Pb', 'I']
# 64 PbBr2 ['Pb', 'Br']
# 65 PbI2 ['Pb', 'I']
# {'PbBrFACs': {'elements': ['Cs', 'FA', 'Pb', 'Br'], 'samples': ['Cs0.2FA0.8PbBr', 'Cs0.4FA0.6PbBr', 'Cs0.6FA0.4PbBr', 'Cs0.8FA0.2PbBr', '44540', '236387', '48997', '231017', '84525', '235795', '239760']}, 'IPbFACs': {'elements': ['Cs', 'FA', 'Pb', 'I'], 'samples': ['Cs0.2FA0.8PbI', 'Cs0.4FA0.6PbI', 'Cs0.6FA0.4PbI', 'Cs0.8FA0.2PbI', '56522', '161481', '32306', '21955', '250736', '230492', '230491', '42013']}, 'PbBrMACs': {'elements': ['Cs', 'MA', 'Pb', 'Br'], 'samples': ['Cs0.2MA0.8PbBr', 'Cs0.4MA0.6PbBr', 'Cs0.6MA0.4PbBr', 'Cs0.8MA0.2PbBr', '44540', '236387', '48997', '231017', '84525', '235794', '33037', '239760']}, 'IPbMACs': {'elements': ['Cs', 'MA', 'Pb', 'I'], 'samples': ['Cs0.2MA0.8PbI', 'Cs0.4MA0.6PbI', 'Cs0.6MA0.4PbI', 'Cs0.8MA0.2PbI', '56522', '161481', '32306', '21955', '250735', '238610', '42013']}, 'PbBrCs': {'elements': ['Cs', 'Pb', 'Br'], 'samples': ['44540', '236387', '48997', '231017', '84525', '239760']}, 'ClPbBrCs': {'elements': ['Cs', 'Pb', 'Br', 'Cl'], 'samples': ['44540', '236387', '48997', 'CsPbCl0.2Br0.8', 'CsPbCl0.4Br0.6', 'CsPbCl0.6Br0.4', 'CsPbCl0.8Br0.2', '231017', '84525', '243734', '201251', '239760']}, 'IPbBrCs': {'elements': ['Cs', 'Pb', 'I', 'Br'], 'samples': ['44540', '236387', '56522', '48997', 'CsPbI0.2Br0.8', 'CsPbI0.4Br0.6', 'CsPbI0.6Br0.4', 'CsPbI0.8Br0.2', '231017', '84525', '161481', '32306', '21955', '239760', '42013']}, 'ClIPbCs': {'elements': ['Cs', 'Pb', 'I', 'Cl'], 'samples': ['56522', 'CsPbI0.2Cl0.8', 'CsPbI0.4Cl0.6', 'CsPbI0.6Cl0.4', 'CsPbI0.8Cl0.2', '243734', '201251', '161481', '32306', '21955', '42013']}, 'ClPbCs': {'elements': ['Cs', 'Pb', 'Cl'], 'samples': ['243734', '201251']}, 'IPbCs': {'elements': ['Cs', 'Pb', 'I'], 'samples': ['56522', '161481', '32306', '21955', '42013']}, 'IPbBrFA': {'elements': ['FA', 'Pb', 'I', 'Br'], 'samples': ['FAPbBr0.2I0.8', 'FAPbBr0.4I0.6', 'FAPbBr0.6I0.4', 'FAPbBr0.8I0.2', '235795', '250736', '230492', '230491', '239760', '42013']}, 'PbBrFA': {'elements': ['FA', 'Pb', 'Br'], 'samples': ['235795', '239760']}, 'IPbFA': {'elements': ['FA', 'Pb', 'I'], 'samples': ['250736', '230492', '230491', '42013']}, 'PbMAFABr': {'elements': ['FA', 'MA', 'Pb', 'Br'], 'samples': ['235795', 'MA0.2FA0.8PbBr', 'MA0.4FA0.6PbBr', 'MA0.6FA0.4PbBr', 'MA0.8FA0.2PbBr', '235794', '33037', '239760']}, 'IPbMAFA': {'elements': ['FA', 'MA', 'Pb', 'I'], 'samples': ['250736', '230492', '230491', 'MA0.2FA0.8PbI', 'MA0.4FA0.6PbI', 'MA0.6FA0.4PbI', 'MA0.8FA0.2PbI', '250735', '238610', '42013']}, 'IPbBrMA': {'elements': ['MA', 'Pb', 'I', 'Br'], 'samples': ['MAPbBr0.2I0.8', 'MAPbBr0.4I0.6', 'MAPbBr0.6I0.4', 'MAPbBr0.8I0.2', '235794', '33037', '250735', '238610', '239760', '42013']}, 'PbBrMA': {'elements': ['MA', 'Pb', 'Br'], 'samples': ['235794', '33037', '239760']}, 'IPbMA': {'elements': ['MA', 'Pb', 'I'], 'samples': ['250735', '238610', '42013']}}

# %% [markdown]
# # 2.1 single phase classification (none / EDS / Precursor)

# %%
model_folder = '20241012 single phase orientation full prompt 20'
num_of_epochs = 10000000
cif_folder = os.path.join(folder, 'cif')
visual_embedding_dim = 20
model = VisualBertForQuestionAnswering.from_pretrained(os.path.join(folder, 'models', 
                                                                    model_folder, '{}'.format(num_of_epochs))).to('cuda')

# %%
n = 1
file_name = 'test_dataset_{}phase_orientation.npy'.format(n)

try:
    with open(os.path.join(cif_folder, file_name), 'rb') as handle:
        test_dataset = joblib.load(handle)

    Xs, Ys, element_list, formula_list = test_dataset['Xs'], test_dataset['Ys'], test_dataset['element_list'], test_dataset['formula_list']
    print('test dataset loaded.')

except:
    Xs, Ys, element_list, formula_list, _ = dataloader.load_data(batch_size=2000, n_mix=[n], resonable_mixing=True,
                                                              high_orientation_probability=0.2, crystal_size_range=(5, 20), 
                                                              intensity_variation_range=(0.01, 1))
    test_dataset = {'Xs':Xs, 'Ys':Ys, 'element_list':element_list, 'formula_list':formula_list}

    with open(os.path.join(cif_folder, file_name), 'wb') as handle:
        joblib.dump(test_dataset, handle)
    print('test dataset generated.')
    
print(np.sum(Ys,axis=0))
# Out:
# test dataset loaded.
# [33. 28. 24. 31. 36. 15. 29. 33. 28. 31. 34. 34. 31. 36. 34. 49. 35. 27.
#  30. 33. 29. 32. 35. 35. 28. 25. 27. 25. 39. 33. 24. 30. 31. 37. 23. 28.
#  36. 38. 21. 31. 22. 27. 39. 26. 34. 32. 28. 34. 31. 26. 24. 33. 31. 29.
#  32. 25. 34. 30. 32. 30. 31. 22. 27. 22. 27. 34.]

# %%
y_true, y_pred, y_formula, y_pred_full = [], [], [], []
prompt_type_list = [None,'eds','full']
prompt_type = prompt_type_list[0]

for i in range(len(element_list)):

    Xs_test = Xs[i:i+1,:-1,:].reshape((1,int(Xs.shape[1]/visual_embedding_dim),visual_embedding_dim))
    X_prompts = []
    random.shuffle(element_list[i])
    if prompt_type == None:
        X_prompts.append('')
    elif prompt_type == 'eds':
        X_prompts.append(' '.join([element for element in element_list[i] if element not in ['FA', 'MA']]))
    elif prompt_type == 'full':
        X_prompts.append(' '.join(element_list[i]))
#         X_prompts.append('Cs Pb I Br')

    visual_embeds = torch.from_numpy(Xs_test).to(dtype=torch.float32)
    visual_attention_mask = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)
    visual_token_type_ids = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)

    inputs = tokenizer(X_prompts, return_tensors="pt", padding=True)
    inputs.update(
        {
            "visual_embeds": visual_embeds,
            "visual_token_type_ids": visual_token_type_ids,
            "visual_attention_mask": visual_attention_mask,
        }
    )

    labels = torch.from_numpy(np.array(Ys[i:i+1])).to(dtype=torch.float32)

    outputs = model(**inputs.to('cuda'), output_attentions=True, labels=labels.to('cuda'))
    logits = outputs.logits
    y_true.append(np.array(labels).argmax(-1)[0])
    y_pred.append(np.array(logits.argmax(-1).detach().cpu())[0])
    y_pred_full.append(np.array(logits.detach().cpu()[0]))
    y_formula.append(formula_list[i])
    
    print(X_prompts,y_formula[-1],y_true[-1],y_pred[-1])
    
y_pred_full = np.array(y_pred_full)
# Out:
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 23
# [''] ['MA0.6FA0.4PbBr3'] 49 48
# [''] ['CsPb2Br5'] 19 19
# [''] ['Cs0.2FA0.8PbBr3'] 0 26
# [''] ['CsPb(I0.2Cl0.8)3'] 28 28
# [''] ['CsPb(I0.8Cl0.2)3'] 31 31
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['CsPb(I0.4Cl0.6)3'] 29 29
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['CsI'] 18 18
# [''] ['MAPb(Br0.2I0.8)3'] 55 55
# [''] ['Cs0.4MA0.6PbI3'] 13 13
# [''] ['CsPb(I0.4Br0.6)3'] 25 25
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['CsPb(I0.8Cl0.2)3'] 31 36
# [''] ['PbBr2'] 64 64
# [''] ['Cs0.6FA0.4PbI3'] 6 6
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['Cs0.4FA0.6PbI3'] 5 16
# [''] ['tetragonal-MAPbBr3'] 60 60
# [''] ['cubic-CsPbCl3'] 35 22
# [''] ['cubic-CsPbBr3'] 32 25
# [''] ['Cs0.8MA0.2PbI3'] 15 36
# [''] ['Cs0.4FA0.6PbI3'] 5 5
# [''] ['MA0.4FA0.6PbBr3'] 48 48
# [''] ['cubic-MAPbBr3'] 59 55
# [''] ['CsPb(I0.4Cl0.6)3'] 29 27
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['cubic-MAPbBr3'] 59 59
# [''] ['MA0.6FA0.4PbBr3'] 49 49
# [''] ['alpha-FAPbI3'] 44 44
# [''] ['delta-CsPbI3'] 37 37
# [''] ['MA0.4FA0.6PbBr3'] 48 10
# [''] ['Cs0.4MA0.6PbI3'] 13 13
# [''] ['CsPb(I0.8Cl0.2)3'] 31 31
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['Cs0.6MA0.4PbBr3'] 10 3
# [''] ['MAPb(Br0.4I0.6)3'] 56 55
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['CsPb2Br5'] 19 19
# [''] ['Cs0.6MA0.4PbBr3'] 10 10
# [''] ['cubic-MAPbBr3'] 59 59
# [''] ['Cs0.6MA0.4PbBr3'] 10 3
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['cubic-CsPbBr3'] 32 26
# [''] ['Cs0.6FA0.4PbBr3'] 2 2
# [''] ['Cs0.4MA0.6PbI3'] 13 15
# [''] ['Cs0.8FA0.2PbBr3'] 3 27
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 23
# [''] ['Cs0.8MA0.2PbI3'] 15 36
# [''] ['Cs0.2MA0.8PbI3'] 12 12
# [''] ['CsPb(Cl0.4Br0.6)3'] 21 21
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['Cs0.6MA0.4PbBr3'] 10 25
# [''] ['MA0.4FA0.6PbBr3'] 48 10
# [''] ['MAPb(Br0.4I0.6)3'] 56 31
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['Cs0.4MA0.6PbBr3'] 9 15
# [''] ['MAPb(Br0.4I0.6)3'] 56 55
# [''] ['Pnma-MAPbCl3'] 61 61
# [''] ['FAPb(Br0.8I0.2)3'] 42 42
# [''] ['cubic-CsPbBr3'] 32 15
# [''] ['Cs4PbBr6'] 16 16
# [''] ['CsPb(I0.6Cl0.4)3'] 30 26
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 20
# [''] ['Cs0.2MA0.8PbBr3'] 8 2
# [''] ['Pnma-CsPbCl3'] 34 34
# [''] ['FAPb(Br0.6I0.4)3'] 41 41
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 2
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['Cs0.6MA0.4PbI3'] 14 15
# [''] ['MA0.4FA0.6PbBr3'] 48 48
# [''] ['Pnma-MAPbCl3'] 61 61
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 20
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['cubic-CsPbCl3'] 35 35
# [''] ['FAPb(Br0.8I0.2)3'] 42 42
# [''] ['Cs0.6MA0.4PbBr3'] 10 10
# [''] ['Cs0.2MA0.8PbBr3'] 8 55
# [''] ['delta-CsPbI3'] 37 37
# [''] ['Cs0.6MA0.4PbI3'] 14 14
# [''] ['Cs4PbBr6'] 16 16
# [''] ['MA0.2FA0.8PbBr3'] 47 47
# [''] ['Cs4PbBr6'] 16 16
# [''] ['cubic-MAPbBr3'] 59 50
# [''] ['CsPb(I0.4Cl0.6)3'] 29 27
# [''] ['FAPb(Br0.8I0.2)3'] 42 42
# [''] ['Pnma-MAPbCl3'] 61 33
# [''] ['Cs0.6MA0.4PbBr3'] 10 29
# [''] ['MAPb(Br0.4I0.6)3'] 56 55
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['CsPb(I0.6Br0.4)3'] 26 36
# [''] ['Pnma-MAPbCl3'] 61 64
# [''] ['Cs0.2MA0.8PbBr3'] 8 2
# [''] ['CsPb(I0.4Cl0.6)3'] 29 3
# [''] ['CsPb(I0.2Br0.8)3'] 24 24
# [''] ['MAPb(Br0.8I0.2)3'] 58 58
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['MAPb(Br0.2I0.8)3'] 55 55
# [''] ['MA0.8FA0.2PbBr3'] 50 49
# [''] ['CsPb(Cl0.6Br0.4)3'] 22 22
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 20
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['Cs0.4MA0.6PbI3'] 13 12
# [''] ['CsPb(Cl0.4Br0.6)3'] 21 21
# [''] ['MA0.6FA0.4PbBr3'] 49 49
# [''] ['CsPb(I0.6Br0.4)3'] 26 36
# [''] ['MA0.2FA0.8PbBr3'] 47 11
# [''] ['MAPb(Br0.8I0.2)3'] 58 43
# [''] ['Cs0.8MA0.2PbI3'] 15 36
# [''] ['MAPb(Br0.2I0.8)3'] 55 27
# [''] ['PbBr2'] 64 64
# [''] ['Cs0.4MA0.6PbBr3'] 9 9
# [''] ['MA0.6FA0.4PbBr3'] 49 49
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['Cs4PbBr6'] 16 51
# [''] ['Cs0.4MA0.6PbI3'] 13 15
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['beta-FAPbI3'] 45 64
# [''] ['Cs0.2MA0.8PbBr3'] 8 15
# [''] ['Cs0.6MA0.4PbBr3'] 10 10
# [''] ['beta-FAPbI3'] 45 41
# [''] ['beta-FAPbI3'] 45 45
# [''] ['PbBr2'] 64 6
# [''] ['MA0.4FA0.6PbBr3'] 48 48
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 55
# [''] ['beta-FAPbI3'] 45 45
# [''] ['cubic-MAPbBr3'] 59 55
# [''] ['PbBr2'] 64 64
# [''] ['CsPb(I0.8Br0.2)3'] 27 27
# [''] ['Cs0.8MA0.2PbI3'] 15 13
# [''] ['PbI2'] 65 65
# [''] ['MAPb(Br0.8I0.2)3'] 58 58
# [''] ['Pnma-MAPbCl3'] 61 61
# [''] ['Cs0.2MA0.8PbI3'] 12 12
# [''] ['CsPb(I0.4Br0.6)3'] 25 26
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 20
# [''] ['MA0.6FA0.4PbBr3'] 49 49
# [''] ['CsPb(I0.2Br0.8)3'] 24 24
# [''] ['FAPb(Br0.8I0.2)3'] 42 42
# [''] ['MA0.6FA0.4PbBr3'] 49 50
# [''] ['PbI2'] 65 65
# [''] ['CsPb(I0.4Br0.6)3'] 25 25
# [''] ['Cs0.6MA0.4PbI3'] 14 14
# [''] ['CsPb(I0.2Br0.8)3'] 24 24
# [''] ['Cs0.6MA0.4PbI3'] 14 14
# [''] ['MAPb(Br0.2I0.8)3'] 55 31
# [''] ['MA0.2FA0.8PbBr3'] 47 55
# [''] ['tetragonal-MAPbBr3'] 60 50
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['alpha-FAPbI3'] 44 44
# [''] ['CsPb(I0.8Br0.2)3'] 27 27
# [''] ['MA0.2FA0.8PbBr3'] 47 62
# [''] ['CsPb(I0.6Cl0.4)3'] 30 26
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['CsPb(I0.2Br0.8)3'] 24 32
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 48
# [''] ['tetragonal-MAPbBr3'] 60 60
# [''] ['CsPb(I0.4Br0.6)3'] 25 25
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['Cs0.6MA0.4PbI3'] 14 14
# [''] ['CsPb(I0.8Cl0.2)3'] 31 31
# [''] ['Cs0.6FA0.4PbI3'] 6 6
# [''] ['Cs0.8FA0.2PbI3'] 7 41
# [''] ['Cs0.4FA0.6PbI3'] 5 5
# [''] ['cubic-CsPbBr3'] 32 32
# [''] ['Cs0.6FA0.4PbBr3'] 2 8
# [''] ['Cs0.4MA0.6PbBr3'] 9 9
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['Cs0.6MA0.4PbI3'] 14 36
# [''] ['delta-FAPbI3'] 46 63
# [''] ['CsPb2Br5'] 19 19
# [''] ['CsPb2Br5'] 19 19
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['tetragonal-MAPbBr3'] 60 50
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['CsPb(I0.2Br0.8)3'] 24 24
# [''] ['MA0.2FA0.8PbBr3'] 47 0
# [''] ['alpha-FAPbI3'] 44 44
# [''] ['Cs0.8FA0.2PbBr3'] 3 10
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['Cs0.4MA0.6PbI3'] 13 12
# [''] ['delta-CsPbI3'] 37 37
# [''] ['MAPb(Br0.8I0.2)3'] 58 58
# [''] ['Cs0.4FA0.6PbBr3'] 1 32
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 23
# [''] ['alpha-FAPbI3'] 44 44
# [''] ['Cs0.4FA0.6PbBr3'] 1 24
# [''] ['Pnma-MAPbCl3'] 61 61
# [''] ['MA0.8FA0.2PbI3'] 54 54
# [''] ['Cs0.8FA0.2PbI3'] 7 7
# [''] ['Cs0.8MA0.2PbI3'] 15 36
# [''] ['CsPb(I0.2Br0.8)3'] 24 24
# [''] ['alpha-FAPbI3'] 44 1
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['MAPb(Br0.2I0.8)3'] 55 55
# [''] ['CsPb(I0.4Br0.6)3'] 25 12
# [''] ['CsPb(I0.4Br0.6)3'] 25 25
# [''] ['Cs0.8FA0.2PbBr3'] 3 3
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['Cs0.6MA0.4PbBr3'] 10 3
# [''] ['CsPb(Cl0.4Br0.6)3'] 21 21
# [''] ['cubic-CsPbCl3'] 35 62
# [''] ['PbI2'] 65 15
# [''] ['FAPb(Br0.8I0.2)3'] 42 42
# [''] ['MAPb(Br0.2I0.8)3'] 55 55
# [''] ['CsPb(Cl0.6Br0.4)3'] 22 22
# [''] ['CsPb(I0.8Cl0.2)3'] 31 31
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['Cs0.4MA0.6PbBr3'] 9 9
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 23
# [''] ['MAPb(Br0.2I0.8)3'] 55 55
# [''] ['Cs0.8MA0.2PbI3'] 15 36
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 23
# [''] ['CsPb(Cl0.4Br0.6)3'] 21 21
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['Cs0.2MA0.8PbBr3'] 8 8
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['MAPb(Br0.8I0.2)3'] 58 0
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['Cs0.6MA0.4PbBr3'] 10 25
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['PbBr2'] 64 64
# [''] ['CsI'] 18 18
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 55
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 23
# [''] ['Cs0.8FA0.2PbI3'] 7 64
# [''] ['MAPb(Br0.4I0.6)3'] 56 56
# [''] ['Pnma-CsPbCl3'] 34 35
# [''] ['beta-FAPbI3'] 45 64
# [''] ['Cs0.2FA0.8PbI3'] 4 4
# [''] ['MA0.2FA0.8PbBr3'] 47 47
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 23
# [''] ['CsPb(I0.2Br0.8)3'] 24 24
# [''] ['MA0.6FA0.4PbI3'] 53 53
# [''] ['CsPb(I0.4Cl0.6)3'] 29 0
# [''] ['MAPb(Br0.6I0.4)3'] 57 43
# [''] ['CsPb2Br5'] 19 19
# [''] ['Cs0.6MA0.4PbBr3'] 10 10
# [''] ['Cs0.6FA0.4PbBr3'] 2 8
# [''] ['MA0.6FA0.4PbBr3'] 49 49
# [''] ['CsPb(Cl0.6Br0.4)3'] 22 48
# [''] ['CsI'] 18 18
# [''] ['CsPb(Cl0.4Br0.6)3'] 21 21
# [''] ['cubic-MAPbBr3'] 59 31
# [''] ['cubic-MAPbBr3'] 59 59
# [''] ['tetragonal-MAPbBr3'] 60 60
# [''] ['MA0.8FA0.2PbI3'] 54 41
# [''] ['CsPb(I0.4Br0.6)3'] 25 12
# [''] ['CsPb(I0.2Br0.8)3'] 24 31
# [''] ['MAPb(Br0.6I0.4)3'] 57 43
# [''] ['MA0.4FA0.6PbBr3'] 48 10
# [''] ['Cs0.8MA0.2PbBr3'] 11 25
# [''] ['MA0.8FA0.2PbBr3'] 50 50
# [''] ['cubic-MAPbBr3'] 59 59
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 20
# [''] ['MA0.8FA0.2PbBr3'] 50 50
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['MA0.6FA0.4PbI3'] 53 64
# [''] ['CsPb(Cl0.4Br0.6)3'] 21 21
# [''] ['CsPb(Cl0.6Br0.4)3'] 22 22
# [''] ['MAPb(Br0.8I0.2)3'] 58 58
# [''] ['Cs0.8FA0.2PbI3'] 7 40
# [''] ['cubic-MAPbBr3'] 59 55
# [''] ['Cs0.4FA0.6PbI3'] 5 5
# [''] ['Cs0.8FA0.2PbI3'] 7 7
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['Cs0.8FA0.2PbBr3'] 3 29
# [''] ['CsPb2Br5'] 19 63
# [''] ['PbBr2'] 64 5
# [''] ['Cs0.6MA0.4PbBr3'] 10 10
# [''] ['Cs0.4MA0.6PbBr3'] 9 9
# [''] ['delta-FAPbI3'] 46 46
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['MAPb(Br0.4I0.6)3'] 56 56
# [''] ['MA0.2FA0.8PbI3'] 51 39
# [''] ['CsPb(Cl0.6Br0.4)3'] 22 22
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['CsPb(I0.4Cl0.6)3'] 29 3
# [''] ['MA0.8FA0.2PbI3'] 54 54
# [''] ['CsPb(I0.4Br0.6)3'] 25 25
# [''] ['CsPb(I0.4Cl0.6)3'] 29 36
# [''] ['Cs0.4MA0.6PbBr3'] 9 15
# [''] ['CsPb(I0.8Br0.2)3'] 27 27
# [''] ['MAPb(Br0.8I0.2)3'] 58 58
# [''] ['MAPb(Br0.2I0.8)3'] 55 31
# [''] ['MAPb(Br0.6I0.4)3'] 57 57
# [''] ['MA0.2FA0.8PbBr3'] 47 47
# [''] ['Cs0.8FA0.2PbBr3'] 3 10
# [''] ['Cs0.6MA0.4PbBr3'] 10 25
# [''] ['Cs0.6FA0.4PbBr3'] 2 8
# [''] ['Cs0.8MA0.2PbI3'] 15 36
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 20
# [''] ['alpha-CsPbI3'] 36 36
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['Pnma-CsPbCl3'] 34 47
# [''] ['beta-FAPbI3'] 45 41
# [''] ['CsPb(I0.6Br0.4)3'] 26 26
# [''] ['delta-CsPbI3'] 37 38
# [''] ['Pnma-CsPbCl3'] 34 34
# [''] ['CsPb(I0.4Br0.6)3'] 25 31
# [''] ['Cs0.4MA0.6PbI3'] 13 14
# [''] ['PbI2'] 65 65
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 34
# [''] ['MA0.6FA0.4PbBr3'] 49 49
# [''] ['Cs0.6FA0.4PbBr3'] 2 8
# [''] ['CsPb(I0.2Cl0.8)3'] 28 3
# [''] ['Cs0.2FA0.8PbBr3'] 0 27
# [''] ['Cs0.6FA0.4PbI3'] 6 6
# [''] ['CsPb(I0.4Cl0.6)3'] 29 12
# [''] ['MA0.4FA0.6PbI3'] 52 53
# [''] ['alpha-FAPbI3'] 44 44
# [''] ['beta-FAPbI3'] 45 41
# [''] ['tetragonal-MAPbBr3'] 60 60
# [''] ['Cs0.8FA0.2PbBr3'] 3 26
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 23
# [''] ['Pnma-CsPbCl3'] 34 34
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['cubic-FAPbBr3'] 43 25
# [''] ['FAPb(Br0.6I0.4)3'] 41 41
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 43
# [''] ['cubic-CsPbCl3'] 35 48
# [''] ['alpha-MAPbI3'] 62 62
# [''] ['Cs0.8FA0.2PbBr3'] 3 10
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['CsPb(I0.4Cl0.6)3'] 29 3
# [''] ['CsPb(Cl0.4Br0.6)3'] 21 21
# [''] ['Cs4PbBr6'] 16 16
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 43
# [''] ['alpha-CsPbI3'] 36 15
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['CsPb(Cl0.4Br0.6)3'] 21 43
# [''] ['FAPb(Br0.4I0.6)3'] 40 16
# [''] ['PbBr2'] 64 64
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 55
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['Cs0.8MA0.2PbI3'] 15 15
# [''] ['alpha-FAPbI3'] 44 44
# [''] ['FAPb(Br0.6I0.4)3'] 41 41
# [''] ['Pnma-MAPbCl3'] 61 61
# [''] ['Cs0.4FA0.6PbBr3'] 1 1
# [''] ['CsPb(I0.4Br0.6)3'] 25 25
# [''] ['Cs0.4FA0.6PbBr3'] 1 3
# [''] ['CsPb(I0.6Cl0.4)3'] 30 2
# [''] ['MAPb(Br0.6I0.4)3'] 57 57
# [''] ['delta-CsPbI3'] 37 37
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['CsPb(I0.2Cl0.8)3'] 28 28
# [''] ['Cs0.2FA0.8PbI3'] 4 4
# [''] ['alpha-MAPbI3'] 62 62
# [''] ['FAPb(Br0.4I0.6)3'] 40 6
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['MAPb(Br0.2I0.8)3'] 55 55
# [''] ['CsBr'] 17 17
# [''] ['MA0.8FA0.2PbBr3'] 50 55
# [''] ['CsPb(I0.4Br0.6)3'] 25 12
# [''] ['MAPb(Br0.2I0.8)3'] 55 55
# [''] ['CsPb2Br5'] 19 19
# [''] ['CsPb(Cl0.6Br0.4)3'] 22 20
# [''] ['cubic-MAPbBr3'] 59 59
# [''] ['FAPb(Br0.6I0.4)3'] 41 41
# [''] ['CsPb(Cl0.6Br0.4)3'] 22 20
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['alpha-FAPbI3'] 44 44
# [''] ['Cs0.6MA0.4PbBr3'] 10 36
# [''] ['beta-FAPbI3'] 45 53
# [''] ['tetragonal-MAPbBr3'] 60 50
# [''] ['alpha-FAPbI3'] 44 44
# [''] ['MA0.6FA0.4PbBr3'] 49 8
# [''] ['Cs0.6FA0.4PbI3'] 6 40
# [''] ['CsBr'] 17 17
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['Cs0.4FA0.6PbBr3'] 1 1
# [''] ['Cs0.8FA0.2PbI3'] 7 41
# [''] ['Cs0.2MA0.8PbI3'] 12 13
# [''] ['Cs0.2FA0.8PbBr3'] 0 0
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['Cs0.2MA0.8PbI3'] 12 14
# [''] ['cubic-MAPbBr3'] 59 59
# [''] ['Cs0.6FA0.4PbBr3'] 2 2
# [''] ['MA0.6FA0.4PbBr3'] 49 49
# [''] ['Cs0.4MA0.6PbI3'] 13 12
# [''] ['MA0.6FA0.4PbI3'] 53 53
# [''] ['Cs0.4MA0.6PbI3'] 13 12
# [''] ['Cs0.8MA0.2PbI3'] 15 13
# [''] ['CsBr'] 17 17
# [''] ['delta-CsPbI3'] 37 39
# [''] ['Cs0.4MA0.6PbBr3'] 9 9
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['MAPb(Br0.8I0.2)3'] 58 58
# [''] ['Cs0.4MA0.6PbBr3'] 9 9
# [''] ['CsPb(I0.4Cl0.6)3'] 29 29
# [''] ['Cs0.6MA0.4PbI3'] 14 14
# [''] ['tetragonal-MAPbBr3'] 60 50
# [''] ['MA0.2FA0.8PbBr3'] 47 47
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['cubic-CsPbBr3'] 32 11
# [''] ['Cs0.6MA0.4PbBr3'] 10 27
# [''] ['Cs0.8FA0.2PbBr3'] 3 26
# [''] ['MAPb(Br0.4I0.6)3'] 56 59
# [''] ['Cs0.6FA0.4PbI3'] 6 6
# [''] ['MA0.6FA0.4PbBr3'] 49 2
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 20
# [''] ['CsPb2Br5'] 19 19
# [''] ['Cs0.8FA0.2PbBr3'] 3 26
# [''] ['delta-CsPbI3'] 37 37
# [''] ['PbI2'] 65 65
# [''] ['Cs0.4MA0.6PbBr3'] 9 9
# [''] ['beta-FAPbI3'] 45 45
# [''] ['Pnma-CsPbCl3'] 34 34
# [''] ['cubic-CsPbCl3'] 35 59
# [''] ['CsPb(Cl0.4Br0.6)3'] 21 21
# [''] ['MA0.8FA0.2PbBr3'] 50 50
# [''] ['Cs0.6FA0.4PbBr3'] 2 8
# [''] ['Cs0.4FA0.6PbBr3'] 1 1
# [''] ['FAPb(Br0.8I0.2)3'] 42 42
# [''] ['Cs0.6MA0.4PbI3'] 14 15
# [''] ['CsI'] 18 18
# [''] ['MA0.8FA0.2PbBr3'] 50 50
# [''] ['MAPb(Br0.2I0.8)3'] 55 55
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['cubic-CsPbBr3'] 32 13
# [''] ['MA0.8FA0.2PbBr3'] 50 50
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['MA0.2FA0.8PbI3'] 51 51
# [''] ['FAPb(Br0.4I0.6)3'] 40 53
# [''] ['Cs0.2MA0.8PbBr3'] 8 55
# [''] ['Cs4PbBr6'] 16 16
# [''] ['CsPb(I0.2Br0.8)3'] 24 24
# [''] ['Cs0.4FA0.6PbI3'] 5 5
# [''] ['CsPb(I0.6Br0.4)3'] 26 26
# [''] ['CsBr'] 17 17
# [''] ['CsI'] 18 18
# [''] ['alpha-CsPbI3'] 36 27
# [''] ['MA0.8FA0.2PbI3'] 54 54
# [''] ['Cs0.4MA0.6PbI3'] 13 13
# [''] ['CsPb(Cl0.6Br0.4)3'] 22 43
# [''] ['alpha-CsPbI3'] 36 15
# [''] ['Cs0.6MA0.4PbI3'] 14 15
# [''] ['alpha-FAPbI3'] 44 44
# [''] ['CsPb(I0.2Br0.8)3'] 24 24
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['beta-FAPbI3'] 45 64
# [''] ['delta-CsPbI3'] 37 37
# [''] ['beta-FAPbI3'] 45 45
# [''] ['CsPb(I0.8Br0.2)3'] 27 27
# [''] ['CsI'] 18 18
# [''] ['MA0.4FA0.6PbBr3'] 48 48
# [''] ['Cs0.6MA0.4PbBr3'] 10 3
# [''] ['Cs0.2MA0.8PbBr3'] 8 8
# [''] ['delta-CsPbI3'] 37 37
# [''] ['CsPb(I0.2Br0.8)3'] 24 24
# [''] ['Cs0.4MA0.6PbBr3'] 9 9
# [''] ['MA0.4FA0.6PbBr3'] 48 3
# [''] ['CsBr'] 17 17
# [''] ['MA0.6FA0.4PbBr3'] 49 32
# [''] ['CsPb(I0.2Br0.8)3'] 24 11
# [''] ['Cs0.8MA0.2PbI3'] 15 15
# [''] ['Pnma-MAPbCl3'] 61 61
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['Cs0.2MA0.8PbI3'] 12 13
# [''] ['FAPb(Br0.6I0.4)3'] 41 41
# [''] ['CsPb(I0.2Br0.8)3'] 24 26
# [''] ['Cs0.6FA0.4PbI3'] 6 6
# [''] ['Cs0.2FA0.8PbBr3'] 0 0
# [''] ['Cs0.6MA0.4PbI3'] 14 13
# [''] ['cubic-CsPbBr3'] 32 36
# [''] ['CsPb2Br5'] 19 19
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['MA0.2FA0.8PbBr3'] 47 11
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 65
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 43
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['Pnma-CsPbCl3'] 34 34
# [''] ['delta-FAPbI3'] 46 46
# [''] ['Pnma-MAPbCl3'] 61 61
# [''] ['CsPb(I0.6Cl0.4)3'] 30 12
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['CsPb(I0.8Br0.2)3'] 27 27
# [''] ['PbI2'] 65 15
# [''] ['CsPb(I0.2Cl0.8)3'] 28 29
# [''] ['Cs0.2FA0.8PbI3'] 4 4
# [''] ['delta-CsPbI3'] 37 37
# [''] ['Cs4PbBr6'] 16 16
# [''] ['CsPb(Cl0.6Br0.4)3'] 22 55
# [''] ['beta-FAPbI3'] 45 45
# [''] ['cubic-CsPbBr3'] 32 32
# [''] ['MAPb(Br0.2I0.8)3'] 55 55
# [''] ['Cs0.6MA0.4PbBr3'] 10 3
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['CsPb2Br5'] 19 19
# [''] ['Cs0.6FA0.4PbI3'] 6 6
# [''] ['MAPb(Br0.2I0.8)3'] 55 55
# [''] ['Cs0.4MA0.6PbBr3'] 9 3
# [''] ['cubic-MAPbBr3'] 59 59
# [''] ['tetragonal-MAPbBr3'] 60 59
# [''] ['CsPb(I0.2Cl0.8)3'] 28 3
# [''] ['Cs0.4MA0.6PbI3'] 13 13
# [''] ['MA0.2FA0.8PbBr3'] 47 48
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['CsPb(I0.2Cl0.8)3'] 28 32
# [''] ['Cs0.2MA0.8PbBr3'] 8 8
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 20
# [''] ['Cs0.2MA0.8PbI3'] 12 12
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['CsI'] 18 18
# [''] ['delta-FAPbI3'] 46 46
# [''] ['Cs0.2FA0.8PbI3'] 4 4
# [''] ['CsPb2Br5'] 19 19
# [''] ['cubic-MAPbBr3'] 59 59
# [''] ['CsPb(I0.4Br0.6)3'] 25 31
# [''] ['CsPb2Br5'] 19 19
# [''] ['delta-CsPbI3'] 37 37
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 48
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['MA0.2FA0.8PbBr3'] 47 47
# [''] ['Cs4PbBr6'] 16 16
# [''] ['alpha-FAPbI3'] 44 44
# [''] ['CsPb(I0.4Cl0.6)3'] 29 9
# [''] ['FAPb(Br0.8I0.2)3'] 42 42
# [''] ['MA0.2FA0.8PbBr3'] 47 11
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 23
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 48
# [''] ['cubic-CsPbCl3'] 35 35
# [''] ['Cs0.6FA0.4PbI3'] 6 6
# [''] ['PbBr2'] 64 64
# [''] ['cubic-FAPbBr3'] 43 11
# [''] ['CsPb2Br5'] 19 19
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['tetragonal-MAPbBr3'] 60 60
# [''] ['CsPb(I0.8Br0.2)3'] 27 27
# [''] ['CsPb(I0.4Cl0.6)3'] 29 3
# [''] ['Pnma-MAPbCl3'] 61 33
# [''] ['CsPb(I0.4Cl0.6)3'] 29 27
# [''] ['MA0.8FA0.2PbI3'] 54 54
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['CsPb2Br5'] 19 19
# [''] ['Cs0.2FA0.8PbI3'] 4 4
# [''] ['beta-FAPbI3'] 45 45
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['Cs0.6MA0.4PbBr3'] 10 10
# [''] ['MA0.4FA0.6PbBr3'] 48 3
# [''] ['CsBr'] 17 17
# [''] ['CsI'] 18 18
# [''] ['Pnma-CsPbCl3'] 34 34
# [''] ['Cs0.2FA0.8PbI3'] 4 4
# [''] ['Cs0.6MA0.4PbI3'] 14 15
# [''] ['Cs0.6FA0.4PbBr3'] 2 2
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['Cs0.8FA0.2PbI3'] 7 40
# [''] ['Cs0.2MA0.8PbBr3'] 8 13
# [''] ['Cs0.2FA0.8PbBr3'] 0 0
# [''] ['Cs0.6FA0.4PbI3'] 6 5
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 34
# [''] ['MAPb(Br0.2I0.8)3'] 55 55
# [''] ['CsPb2Br5'] 19 19
# [''] ['MAPb(Br0.2I0.8)3'] 55 55
# [''] ['CsPb(I0.8Cl0.2)3'] 31 31
# [''] ['CsBr'] 17 17
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['MA0.2FA0.8PbBr3'] 47 62
# [''] ['cubic-FAPbBr3'] 43 12
# [''] ['MAPb(Br0.2I0.8)3'] 55 55
# [''] ['CsPb(Cl0.6Br0.4)3'] 22 62
# [''] ['MA0.8FA0.2PbBr3'] 50 44
# [''] ['CsPb2Br5'] 19 63
# [''] ['CsPb(I0.4Br0.6)3'] 25 11
# [''] ['Cs0.8MA0.2PbI3'] 15 15
# [''] ['delta-CsPbI3'] 37 37
# [''] ['MAPb(Br0.2I0.8)3'] 55 27
# [''] ['alpha-CsPbI3'] 36 15
# [''] ['MA0.6FA0.4PbI3'] 53 53
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 23
# [''] ['Cs0.8FA0.2PbI3'] 7 41
# [''] ['Cs0.2MA0.8PbI3'] 12 12
# [''] ['Cs0.4FA0.6PbBr3'] 1 15
# [''] ['Cs0.2MA0.8PbI3'] 12 12
# [''] ['CsPb(I0.8Br0.2)3'] 27 27
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['FAPb(Br0.6I0.4)3'] 41 41
# [''] ['cubic-CsPbCl3'] 35 35
# [''] ['delta-CsPbI3'] 37 37
# [''] ['Pnma-MAPbCl3'] 61 61
# [''] ['MA0.4FA0.6PbBr3'] 48 49
# [''] ['delta-FAPbI3'] 46 46
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['Pnma-CsPbCl3'] 34 34
# [''] ['CsPb(I0.8Br0.2)3'] 27 8
# [''] ['CsPb(I0.6Br0.4)3'] 26 0
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['delta-CsPbI3'] 37 37
# [''] ['Pnma-CsPbCl3'] 34 34
# [''] ['MAPb(Br0.8I0.2)3'] 58 58
# [''] ['cubic-FAPbBr3'] 43 26
# [''] ['Cs0.4MA0.6PbI3'] 13 12
# [''] ['Cs0.2MA0.8PbI3'] 12 12
# [''] ['MA0.6FA0.4PbI3'] 53 53
# [''] ['gamma-CsPbI3'] 38 4
# [''] ['cubic-MAPbBr3'] 59 59
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['MAPb(Br0.2I0.8)3'] 55 55
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['CsPb2Br5'] 19 19
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 55
# [''] ['CsPb(I0.8Cl0.2)3'] 31 60
# [''] ['MAPb(Br0.6I0.4)3'] 57 57
# [''] ['FAPb(Br0.6I0.4)3'] 41 41
# [''] ['PbBr2'] 64 64
# [''] ['Cs0.4FA0.6PbBr3'] 1 1
# [''] ['CsPb(I0.2Br0.8)3'] 24 12
# [''] ['CsPb(I0.6Br0.4)3'] 26 26
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 34
# [''] ['MAPb(Br0.4I0.6)3'] 56 56
# [''] ['Cs0.6MA0.4PbI3'] 14 13
# [''] ['CsPb(I0.8Cl0.2)3'] 31 31
# [''] ['MA0.8FA0.2PbBr3'] 50 50
# [''] ['Cs0.4MA0.6PbBr3'] 9 26
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['MA0.8FA0.2PbBr3'] 50 50
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['MA0.6FA0.4PbI3'] 53 53
# [''] ['Cs0.2FA0.8PbI3'] 4 4
# [''] ['Cs0.2FA0.8PbBr3'] 0 0
# [''] ['Cs0.8MA0.2PbI3'] 15 36
# [''] ['beta-FAPbI3'] 45 40
# [''] ['Cs0.4MA0.6PbI3'] 13 27
# [''] ['CsBr'] 17 17
# [''] ['Cs0.4FA0.6PbI3'] 5 5
# [''] ['CsBr'] 17 17
# [''] ['cubic-FAPbBr3'] 43 12
# [''] ['CsPb(I0.4Br0.6)3'] 25 3
# [''] ['Cs0.4MA0.6PbBr3'] 9 9
# [''] ['MA0.2FA0.8PbI3'] 51 51
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 55
# [''] ['cubic-MAPbBr3'] 59 59
# [''] ['gamma-CsPbI3'] 38 39
# [''] ['CsPb(Cl0.6Br0.4)3'] 22 22
# [''] ['cubic-CsPbCl3'] 35 35
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 20
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 26
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['FAPb(Br0.4I0.6)3'] 40 41
# [''] ['Pnma-MAPbCl3'] 61 61
# [''] ['Cs0.4FA0.6PbBr3'] 1 9
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 23
# [''] ['MA0.2FA0.8PbI3'] 51 51
# [''] ['CsBr'] 17 17
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['Cs0.4MA0.6PbBr3'] 9 2
# [''] ['cubic-CsPbCl3'] 35 35
# [''] ['CsPb(I0.6Br0.4)3'] 26 25
# [''] ['PbBr2'] 64 64
# [''] ['CsPb(I0.6Br0.4)3'] 26 65
# [''] ['MA0.8FA0.2PbBr3'] 50 30
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 20
# [''] ['MA0.2FA0.8PbBr3'] 47 47
# [''] ['PbI2'] 65 65
# [''] ['CsPb(I0.8Cl0.2)3'] 31 31
# [''] ['Cs0.6FA0.4PbBr3'] 2 62
# [''] ['delta-FAPbI3'] 46 46
# [''] ['CsPb(I0.8Cl0.2)3'] 31 31
# [''] ['Cs0.4MA0.6PbBr3'] 9 9
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['Pnma-CsPbCl3'] 34 35
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 23
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['alpha-CsPbI3'] 36 36
# [''] ['Cs0.4MA0.6PbBr3'] 9 32
# [''] ['Cs0.6FA0.4PbI3'] 6 6
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['Cs0.6FA0.4PbBr3'] 2 2
# [''] ['CsPb(I0.4Cl0.6)3'] 29 3
# [''] ['Cs0.2MA0.8PbI3'] 12 12
# [''] ['MA0.2FA0.8PbI3'] 51 4
# [''] ['MA0.6FA0.4PbI3'] 53 53
# [''] ['Cs0.8FA0.2PbBr3'] 3 3
# [''] ['Cs0.2FA0.8PbBr3'] 0 27
# [''] ['PbI2'] 65 65
# [''] ['Cs0.8FA0.2PbBr3'] 3 3
# [''] ['cubic-MAPbBr3'] 59 59
# [''] ['MAPb(Br0.8I0.2)3'] 58 43
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['Cs0.4MA0.6PbBr3'] 9 9
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['Cs0.4MA0.6PbBr3'] 9 9
# [''] ['MAPb(Br0.6I0.4)3'] 57 43
# [''] ['Cs0.8FA0.2PbBr3'] 3 11
# [''] ['Cs4PbBr6'] 16 16
# [''] ['CsPb(I0.4Cl0.6)3'] 29 25
# [''] ['CsPb(I0.6Cl0.4)3'] 30 30
# [''] ['CsPb2Br5'] 19 19
# [''] ['PbBr2'] 64 6
# [''] ['Cs4PbBr6'] 16 16
# [''] ['Cs4PbBr6'] 16 16
# [''] ['Cs0.6MA0.4PbBr3'] 10 25
# [''] ['CsPb(I0.6Br0.4)3'] 26 26
# [''] ['CsPb(I0.8Cl0.2)3'] 31 36
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['Cs4PbBr6'] 16 16
# [''] ['Cs0.6FA0.4PbI3'] 6 6
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['CsPb(I0.8Cl0.2)3'] 31 31
# [''] ['MAPb(Br0.6I0.4)3'] 57 57
# [''] ['CsI'] 18 18
# [''] ['MAPb(Br0.4I0.6)3'] 56 56
# [''] ['Cs0.4FA0.6PbBr3'] 1 11
# [''] ['CsPb(I0.8Cl0.2)3'] 31 12
# [''] ['Cs0.6MA0.4PbI3'] 14 14
# [''] ['Cs0.4FA0.6PbI3'] 5 5
# [''] ['MAPb(Br0.6I0.4)3'] 57 43
# [''] ['PbBr2'] 64 64
# [''] ['Cs0.8MA0.2PbBr3'] 11 11
# [''] ['Cs0.2MA0.8PbI3'] 12 12
# [''] ['Cs0.6MA0.4PbBr3'] 10 10
# [''] ['CsI'] 18 18
# [''] ['Cs0.4FA0.6PbBr3'] 1 1
# [''] ['Cs0.8MA0.2PbBr3'] 11 11
# [''] ['CsPb(I0.4Cl0.6)3'] 29 25
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['FAPb(Br0.6I0.4)3'] 41 41
# [''] ['Cs0.8FA0.2PbBr3'] 3 3
# [''] ['CsPb(I0.8Cl0.2)3'] 31 31
# [''] ['Cs0.6MA0.4PbBr3'] 10 3
# [''] ['CsPb(I0.6Br0.4)3'] 26 15
# [''] ['CsPb(Cl0.6Br0.4)3'] 22 22
# [''] ['Cs0.2MA0.8PbBr3'] 8 11
# [''] ['CsI'] 18 18
# [''] ['CsPb(I0.4Br0.6)3'] 25 12
# [''] ['cubic-MAPbBr3'] 59 59
# [''] ['Cs0.2FA0.8PbI3'] 4 4
# [''] ['Cs0.6FA0.4PbI3'] 6 6
# [''] ['CsPb(I0.2Br0.8)3'] 24 26
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['cubic-CsPbCl3'] 35 22
# [''] ['MA0.2FA0.8PbI3'] 51 4
# [''] ['MAPb(Br0.8I0.2)3'] 58 58
# [''] ['Cs0.8MA0.2PbI3'] 15 36
# [''] ['MA0.6FA0.4PbBr3'] 49 55
# [''] ['CsPb(I0.6Br0.4)3'] 26 26
# [''] ['MAPb(Br0.8I0.2)3'] 58 58
# [''] ['CsBr'] 17 17
# [''] ['CsPb(I0.4Br0.6)3'] 25 25
# [''] ['alpha-FAPbI3'] 44 44
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['Cs0.6MA0.4PbI3'] 14 14
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['CsPb(Cl0.6Br0.4)3'] 22 22
# [''] ['MAPb(Br0.4I0.6)3'] 56 56
# [''] ['MA0.6FA0.4PbI3'] 53 53
# [''] ['PbBr2'] 64 64
# [''] ['Cs0.8MA0.2PbI3'] 15 26
# [''] ['Cs0.8MA0.2PbI3'] 15 15
# [''] ['CsPb2Br5'] 19 19
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['delta-FAPbI3'] 46 46
# [''] ['MA0.6FA0.4PbBr3'] 49 10
# [''] ['FAPb(Br0.8I0.2)3'] 42 42
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['CsPb(Cl0.4Br0.6)3'] 21 21
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['CsPb(I0.2Br0.8)3'] 24 31
# [''] ['FAPb(Br0.8I0.2)3'] 42 42
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['CsPb(I0.2Cl0.8)3'] 28 28
# [''] ['FAPb(Br0.8I0.2)3'] 42 42
# [''] ['CsPb(I0.8Br0.2)3'] 27 27
# [''] ['Cs0.6FA0.4PbI3'] 6 6
# [''] ['alpha-CsPbI3'] 36 36
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 59
# [''] ['Cs0.6MA0.4PbI3'] 14 15
# [''] ['PbBr2'] 64 64
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['Cs0.2FA0.8PbI3'] 4 4
# [''] ['CsPb(I0.4Cl0.6)3'] 29 29
# [''] ['delta-FAPbI3'] 46 46
# [''] ['Cs0.2MA0.8PbBr3'] 8 8
# [''] ['CsBr'] 17 17
# [''] ['Cs0.4FA0.6PbI3'] 5 5
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['Cs0.4FA0.6PbBr3'] 1 1
# [''] ['Cs0.4MA0.6PbI3'] 13 12
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['MA0.8FA0.2PbI3'] 54 54
# [''] ['Cs0.6MA0.4PbI3'] 14 14
# [''] ['MA0.6FA0.4PbBr3'] 49 0
# [''] ['CsPb(Cl0.4Br0.6)3'] 21 21
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['CsPb(I0.6Cl0.4)3'] 30 15
# [''] ['Cs4PbBr6'] 16 16
# [''] ['MA0.6FA0.4PbI3'] 53 53
# [''] ['Pnma-CsPbCl3'] 34 34
# [''] ['alpha-MAPbI3'] 62 14
# [''] ['PbBr2'] 64 64
# [''] ['MA0.8FA0.2PbBr3'] 50 50
# [''] ['Cs0.2FA0.8PbI3'] 4 4
# [''] ['Cs0.4MA0.6PbI3'] 13 12
# [''] ['Cs4PbBr6'] 16 51
# [''] ['Cs0.6FA0.4PbI3'] 6 6
# [''] ['CsPb(Cl0.4Br0.6)3'] 21 47
# [''] ['Cs0.4FA0.6PbBr3'] 1 15
# [''] ['MA0.8FA0.2PbI3'] 54 41
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 49
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['MA0.6FA0.4PbBr3'] 49 55
# [''] ['Cs0.8FA0.2PbI3'] 7 41
# [''] ['CsPb(I0.4Br0.6)3'] 25 25
# [''] ['CsPb(I0.8Br0.2)3'] 27 27
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['beta-FAPbI3'] 45 45
# [''] ['CsPb(I0.2Cl0.8)3'] 28 3
# [''] ['FAPb(Br0.6I0.4)3'] 41 41
# [''] ['FAPb(Br0.6I0.4)3'] 41 41
# [''] ['MAPb(Br0.8I0.2)3'] 58 43
# [''] ['CsPb(I0.8Br0.2)3'] 27 27
# [''] ['Cs0.8MA0.2PbBr3'] 11 11
# [''] ['MA0.6FA0.4PbI3'] 53 53
# [''] ['MA0.6FA0.4PbI3'] 53 53
# [''] ['MA0.8FA0.2PbBr3'] 50 50
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['MA0.8FA0.2PbI3'] 54 54
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 35
# [''] ['MAPb(Br0.8I0.2)3'] 58 26
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['MAPb(Br0.8I0.2)3'] 58 58
# [''] ['MA0.4FA0.6PbBr3'] 48 48
# [''] ['CsPb(I0.6Br0.4)3'] 26 26
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['PbI2'] 65 65
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['CsPb(I0.2Cl0.8)3'] 28 25
# [''] ['PbBr2'] 64 64
# [''] ['Cs0.4FA0.6PbBr3'] 1 24
# [''] ['Cs0.2FA0.8PbBr3'] 0 0
# [''] ['Cs0.6MA0.4PbI3'] 14 13
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['Cs0.6FA0.4PbBr3'] 2 9
# [''] ['delta-CsPbI3'] 37 37
# [''] ['beta-FAPbI3'] 45 41
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 62
# [''] ['cubic-MAPbBr3'] 59 59
# [''] ['Pnma-CsPbCl3'] 34 34
# [''] ['Cs0.6MA0.4PbI3'] 14 36
# [''] ['MA0.6FA0.4PbBr3'] 49 49
# [''] ['MA0.2FA0.8PbBr3'] 47 47
# [''] ['Cs4PbBr6'] 16 16
# [''] ['MA0.8FA0.2PbI3'] 54 54
# [''] ['Cs0.8MA0.2PbI3'] 15 15
# [''] ['orthorhombic-CsPbBr3'] 33 33
# [''] ['Cs0.4FA0.6PbBr3'] 1 1
# [''] ['CsPb2Br5'] 19 19
# [''] ['Cs0.2FA0.8PbI3'] 4 4
# [''] ['CsI'] 18 18
# [''] ['Cs0.4FA0.6PbBr3'] 1 1
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['Cs0.4FA0.6PbBr3'] 1 29
# [''] ['MA0.2FA0.8PbI3'] 51 51
# [''] ['PbI2'] 65 65
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['Cs0.6FA0.4PbI3'] 6 6
# [''] ['Cs0.8FA0.2PbI3'] 7 41
# [''] ['CsPb(I0.8Cl0.2)3'] 31 31
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['Cs0.6FA0.4PbBr3'] 2 8
# [''] ['MA0.6FA0.4PbI3'] 53 53
# [''] ['MA0.4FA0.6PbBr3'] 48 55
# [''] ['Cs0.2MA0.8PbBr3'] 8 8
# [''] ['CsI'] 18 18
# [''] ['Cs0.2MA0.8PbBr3'] 8 8
# [''] ['delta-CsPbI3'] 37 37
# [''] ['MAPb(Br0.2I0.8)3'] 55 31
# [''] ['Cs0.4FA0.6PbBr3'] 1 31
# [''] ['Cs0.2MA0.8PbI3'] 12 12
# [''] ['alpha-FAPbI3'] 44 27
# [''] ['MAPb(Br0.8I0.2)3'] 58 58
# [''] ['CsPb(I0.8Br0.2)3'] 27 27
# [''] ['Cs0.8FA0.2PbBr3'] 3 10
# [''] ['alpha-FAPbI3'] 44 44
# [''] ['CsPb(Cl0.2Br0.8)3'] 20 20
# [''] ['CsPb2Br5'] 19 19
# [''] ['tetragonal-MAPbBr3'] 60 50
# [''] ['CsPb(I0.6Cl0.4)3'] 30 30
# [''] ['Pnma-MAPbCl3'] 61 64
# [''] ['Cs0.6FA0.4PbBr3'] 2 8
# [''] ['CsPb(I0.8Br0.2)3'] 27 27
# [''] ['FAPb(Br0.8I0.2)3'] 42 42
# [''] ['PbI2'] 65 65
# [''] ['delta-FAPbI3'] 46 46
# [''] ['CsPb(Cl0.8Br0.2)3'] 23 23
# [''] ['CsPb(I0.4Cl0.6)3'] 29 3
# [''] ['CsPb(I0.8Br0.2)3'] 27 36
# [''] ['CsPb(I0.8Br0.2)3'] 27 27
# [''] ['Cs0.2FA0.8PbBr3'] 0 0
# [''] ['MAPb(Br0.4I0.6)3'] 56 43
# [''] ['CsPb(Cl0.4Br0.6)3'] 21 21
# [''] ['CsPb(I0.2Cl0.8)3'] 28 3
# [''] ['Cs0.6FA0.4PbI3'] 6 6
# [''] ['MA0.2FA0.8PbI3'] 51 51
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['MA0.4FA0.6PbBr3'] 48 48
# [''] ['CsPb(I0.8Br0.2)3'] 27 27
# [''] ['delta-CsPbI3'] 37 37
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['cubic-MAPbBr3'] 59 59
# [''] ['CsPb(I0.4Cl0.6)3'] 29 29
# [''] ['cubic-CsPbCl3'] 35 56
# [''] ['FAPb(Br0.6I0.4)3'] 41 41
# [''] ['gamma-CsPbI3'] 38 38
# [''] ['cubic-FAPbBr3'] 43 26
# [''] ['tetragonal-MAPbBr3'] 60 60
# [''] ['gamma-CsPbI3'] 38 37
# [''] ['delta-FAPbI3'] 46 46
# [''] ['Cs0.2FA0.8PbBr3'] 0 0
# [''] ['PbBr2'] 64 64
# [''] ['CsBr'] 17 17
# [''] ['alpha-MAPbI3'] 62 62
# [''] ['Cs4PbBr6'] 16 51
# [''] ['CsI'] 18 18
# [''] ['MA0.8FA0.2PbBr3'] 50 50
# [''] ['CsBr'] 17 17
# [''] ['FAPb(Br0.4I0.6)3'] 40 40
# [''] ['tetragonal-MAPbBr3'] 60 50
# [''] ['CsPb(I0.4Br0.6)3'] 25 30
# [''] ['MA0.6FA0.4PbBr3'] 49 11
# [''] ['cubic-FAPbBr3'] 43 26
# [''] ['FAPb(Br0.6I0.4)3'] 41 41
# [''] ['Cs0.6MA0.4PbI3'] 14 36
# [''] ['delta-FAPbI3'] 46 46
# [''] ['Cs0.2FA0.8PbBr3'] 0 0
# [''] ['FAPb(Br0.8I0.2)3'] 42 42
# [''] ['cubic-FAPbBr3'] 43 43
# [''] ['beta-FAPbI3'] 45 7
# [''] ['Cs4PbBr6'] 16 16
# [''] ['tetragonal-MAPbI3'] 63 63
# [''] ['CsPb(Cl0.6Br0.4)3'] 22 59
# [''] ['CsI'] 18 18
# [''] ['Cs0.6FA0.4PbBr3'] 2 2
# [''] ['PbBr2'] 64 64
# [''] ['alpha-MAPbI3'] 62 12
# [''] ['Cs0.8FA0.2PbBr3'] 3 10
# [''] ['CsPb(I0.2Br0.8)3'] 24 24
# [''] ['Cs0.6MA0.4PbBr3'] 10 26
# [''] ['MAPb(Br0.8I0.2)3'] 58 58
# [''] ['CsPb(I0.8Cl0.2)3'] 31 31
# [''] ['cubic-CsPbCl3'] 35 62
# [''] ['CsPb(I0.4Cl0.6)3'] 29 10
# [''] ['MAPb(Br0.4I0.6)3'] 56 10
# [''] ['Cs0.2FA0.8PbBr3'] 0 0
# [''] ['alpha-FAPbI3'] 44 44
# [''] ['Cs0.4FA0.6PbI3'] 5 5
# [''] ['CsPb(I0.2Br0.8)3'] 24 24
# [''] ['Cs0.8MA0.2PbI3'] 15 15
# [''] ['Cs0.4FA0.6PbI3'] 5 5
# [''] ['MA0.6FA0.4PbI3'] 53 53
# [''] ['Cs0.4MA0.6PbI3'] 13 13
# [''] ['Cs0.4MA0.6PbI3'] 13 12
# [''] ['Cs0.2FA0.8PbBr3'] 0 0
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['delta-CsPbI3'] 37 37
# [''] ['FAPb(Br0.2I0.8)3'] 39 39
# [''] ['MA0.4FA0.6PbBr3'] 48 48
# [''] ['Cs0.2FA0.8PbBr3'] 0 27
# [''] ['Cs0.6FA0.4PbI3'] 6 6
# [''] ['Cs0.4FA0.6PbBr3'] 1 1
# [''] ['CsPb(I0.4Cl0.6)3'] 29 27
# [''] ['Cs4PbBr6'] 16 16
# [''] ['gamma-CsPbI3'] 38 39
# [''] ['Cs0.4FA0.6PbI3'] 5 5
# [''] ['CsPb(I0.2Cl0.8)3'] 28 31
# [''] ['MA0.4FA0.6PbI3'] 52 52
# [''] ['alpha-FAPbI3'] 44 44
# [''] ['alpha-CsPbI3'] 36 36
# [''] ['Pnma-CsPbCl3'] 34 34
# [''] ['Cs0.4FA0.6PbBr3'] 1 24
# [''] ['CsPb(I0.8Cl0.2)3'] 31 31
# [''] ['Cs0.8FA0.2PbBr3'] 3 3
# [''] ['MA0.6FA0.4PbBr3'] 49 49
# [''] ['CsBr'] 17 17
# [''] ['CsPb2Br5'] 19 19
# [''] ['MA0.6FA0.4PbBr3'] 49 49
# [''] ['MAPb(Br0.6I0.4)3'] 57 58
# [''] ['Cs0.8MA0.2PbBr3'] 11 25
# [''] ['MA0.8FA0.2PbBr3'] 50 59

# %%
for i in range(5):
    print(torch.topk(outputs.logits[0], i+1).indices)
# Out:
# tensor([34], device='cuda:0')
# tensor([34, 43], device='cuda:0')
# tensor([34, 43,  1], device='cuda:0')
# tensor([34, 43,  1, 23], device='cuda:0')
# tensor([34, 43,  1, 23, 35], device='cuda:0')

# %%
for k in range(1,6):
    print('top {}:'.format(k), top_k_accuracy_score(y_true_full, y_pred_full, k=k))

# %% [markdown]
# ## data size

# %%
# visual_embedding_dim = 50
prompt_type_list = ['full']

with open(os.path.join(cif_folder, 'test_dataset_1phase_orientation.npy'), 'rb') as handle:
    test_dataset = joblib.load(handle)
    
Xs, Ys, element_list, formula_list = test_dataset['Xs'], test_dataset['Ys'], test_dataset['element_list'], test_dataset['formula_list']
Ys_int = [np.where(x==1)[0][0] for x in Ys]

for sample_size in [1e2,3e2,1e3,3e3,1e4,3e4,1e5,3e5,1e6,2e6,3e6,4e6,5e6,6e6,7e6,8e6,9e6,1e7,1.5e7,2e7,2.5e7,3e7]:
# for sample_size in [1e6,2e6,3e6,4e6,5e6,6e6,7e6,8e6,9e6,1e7,1.5e7,2e7]:
    for prompt_type in prompt_type_list:
        
        model = VisualBertForQuestionAnswering.from_pretrained(os.path.join(folder, 'models', 
                                                                            model_folder, '{}'.format(int(sample_size)))).to('cuda')

        y_true, y_pred, y_formula, y_pred_full = [], [], [], []

        for i in range(len(element_list)):

            Xs_test = Xs[i:i+1,:-1,:].reshape((1,int(Xs.shape[1]/visual_embedding_dim),visual_embedding_dim))
            X_prompts = []
            random.shuffle(element_list[i])
            if prompt_type == None:
                X_prompts.append('')
            elif prompt_type == 'eds':
                X_prompts.append(' '.join([element for element in element_list[i] if element not in ['FA', 'MA']]))
            elif prompt_type == 'full':
                X_prompts.append(' '.join(element_list[i]))

            visual_embeds = torch.from_numpy(Xs_test).to(dtype=torch.float32)
            visual_attention_mask = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)
            visual_token_type_ids = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)

            inputs = tokenizer(X_prompts, return_tensors="pt", padding=True)
            inputs.update(
                {
                    "visual_embeds": visual_embeds,
                    "visual_token_type_ids": visual_token_type_ids,
                    "visual_attention_mask": visual_attention_mask,
                }
            )

            labels = torch.from_numpy(np.array(Ys[i:i+1])).to(dtype=torch.float32)

            outputs = model(**inputs.to('cuda'), output_attentions=True, labels=labels.to('cuda'))
            logits = outputs.logits
            y_true.append(np.array(labels).argmax(-1)[0])
            y_pred.append(np.array(logits.argmax(-1).detach().cpu())[0])
            y_pred_full.append(np.array(logits.detach().cpu()[0]))
            y_formula.append(formula_list[i])

            print(X_prompts,y_formula[-1],y_true[-1],y_pred[-1])

        y_pred_full = np.array(y_pred_full)

        report = classification_report(y_true, y_pred, target_names=dataloader.sample_list, output_dict=True)
        matrix = confusion_matrix(y_true, y_pred)
        
        load_plt_setting()
        fig, ax = plt.subplots(figsize=(12, 10))

        mat = ax.matshow(matrix, cmap='hot')
        ax.xaxis.set_ticks_position('bottom')
        ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=10, steps=[1, 2, 5, 10]))
        ax.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
        ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=10, steps=[1, 2, 5, 10]))
        ax.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
        ax.tick_params(axis='both',direction='out',length=8,width=2,pad=10,color='black',labelsize=28)
        ax.tick_params(axis='both',which='minor',direction='out',length=4,width=2,pad=10,color='black',labelsize=28)
        # ax.axes.set_xlim([450,950])
        # ax.axes.set_ylim([0,5])
        # # ax.set_xscale('log')

        cbar = plt.colorbar(mat)
        cbar.ax.tick_params(axis='y', direction='out',length=8,width=3,pad=5,labelsize=28)
        cbar.ax.set_ylabel('Number of samples',labelpad=40, rotation=-90)
        cbar.ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=4, integer=True, steps=[1, 2, 5, 10]))
        cbar.ax.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
        cbar.ax.tick_params(axis='both',which='minor',direction='out',length=4,width=3,pad=5)

        ax.set_xlabel(r'Predicted class', labelpad=20, fontsize=34)
        ax.set_ylabel(r'True class', labelpad=20, fontsize=34)

        plt.text(0.95, 0.91, 'Accuracy: {:.1f}%'.format(report['accuracy']*100), fontsize=32, 
                 transform=ax.transAxes, color='#FFFFFF', horizontalalignment='right')
        if sample_size%1000000 == 0:
            data_size = str(int(sample_size//1000000))+'M'
        elif sample_size%1000 == 0:
            data_size = str(int(sample_size//1000))+'k'
        else:
            data_size = int(sample_size)
        plt.text(0.05, 0.06, 'Data size: {}'.format(data_size), fontsize=32, transform=ax.transAxes, color='#FFFFFF', horizontalalignment='left')

        plt.savefig(os.path.join(folder, 'models', model_folder, 'classification_{}_{}.png'.format(str(prompt_type),int(sample_size))), 
                    format='png', dpi=300, transparent=True, bbox_inches='tight')
# Out:
# ['Cl I Pb Cs'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Br Cs Pb'] ['orthorhombic-CsPbBr3'] 33 55
# ['Cl Br Cs Pb'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['Cs Cl Br Pb'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['Cl Pb I Cs'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['I FA Pb'] ['alpha-FAPbI3'] 44 55
# ['Cl Cs Pb I'] ['CsPb(I0.6Cl0.4)3'] 30 41
# ['I Pb Cs Br'] ['CsPb(I0.6Br0.4)3'] 26 24
# ['MA FA Pb I'] ['MA0.6FA0.4PbI3'] 53 41
# ['FA Br Pb MA'] ['MA0.4FA0.6PbBr3'] 48 41
# ['MA FA Br Pb'] ['MA0.2FA0.8PbBr3'] 47 41
# ['MA I Pb'] ['tetragonal-MAPbI3'] 63 55
# ['Pb Br I Cs'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['Cl I Pb Cs'] ['CsPb(I0.8Cl0.2)3'] 31 41
# ['Cs FA I Pb'] ['Cs0.2FA0.8PbI3'] 4 41
# ['MA Pb I FA'] ['MA0.6FA0.4PbI3'] 53 41
# ['Pb Cs FA Br'] ['Cs0.6FA0.4PbBr3'] 2 24
# ['Cs Pb Br FA'] ['Cs0.2FA0.8PbBr3'] 0 41
# ['MA Cs Pb Br'] ['Cs0.6MA0.4PbBr3'] 10 24
# ['Pb Br Cs FA'] ['Cs0.2FA0.8PbBr3'] 0 41
# ['Br Pb Cs'] ['orthorhombic-CsPbBr3'] 33 55
# ['I MA Pb Cs'] ['Cs0.6MA0.4PbI3'] 14 41
# ['Br MA Pb FA'] ['MA0.8FA0.2PbBr3'] 50 41
# ['Br MA FA Pb'] ['MA0.2FA0.8PbBr3'] 47 41
# ['MA Pb Cl'] ['Pnma-MAPbCl3'] 61 55
# ['Cs Pb MA Br'] ['Cs0.4MA0.6PbBr3'] 9 24
# ['Cs Pb Br FA'] ['Cs0.4FA0.6PbBr3'] 1 41
# ['FA Pb I Cs'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Cs Br Pb MA'] ['Cs0.6MA0.4PbBr3'] 10 41
# ['Cs Pb I MA'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Pb MA FA I'] ['MA0.6FA0.4PbI3'] 53 41
# ['Pb Br I MA'] ['MAPb(Br0.8I0.2)3'] 58 41
# ['Pb FA I'] ['delta-FAPbI3'] 46 13
# ['Cl I Pb Cs'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Pb MA FA I'] ['MA0.4FA0.6PbI3'] 52 41
# ['Pb Cl Cs'] ['cubic-CsPbCl3'] 35 55
# ['Cs Pb I'] ['gamma-CsPbI3'] 38 13
# ['Pb MA Br'] ['cubic-MAPbBr3'] 59 24
# ['Cs I Pb FA'] ['Cs0.8FA0.2PbI3'] 7 41
# ['Br MA Pb'] ['tetragonal-MAPbBr3'] 60 55
# ['Cs I Pb'] ['alpha-CsPbI3'] 36 55
# ['Cs Cl Pb I'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Cl Pb Cs Br'] ['CsPb(Cl0.8Br0.2)3'] 23 24
# ['Pb FA Br I'] ['FAPb(Br0.2I0.8)3'] 39 41
# ['I FA Br Pb'] ['FAPb(Br0.2I0.8)3'] 39 41
# ['I Pb Cs Br'] ['CsPb(I0.2Br0.8)3'] 24 24
# ['MA Br FA Pb'] ['MA0.8FA0.2PbBr3'] 50 41
# ['Pb Br I Cs'] ['CsPb(I0.4Br0.6)3'] 25 41
# ['Br MA I Pb'] ['MAPb(Br0.4I0.6)3'] 56 41
# ['Pb Br I MA'] ['MAPb(Br0.4I0.6)3'] 56 41
# ['FA Cs I Pb'] ['Cs0.6FA0.4PbI3'] 6 41
# ['MA Pb Br I'] ['MAPb(Br0.8I0.2)3'] 58 41
# ['Br Pb Cl Cs'] ['CsPb(Cl0.2Br0.8)3'] 20 41
# ['MA I Pb Cs'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Br Pb'] ['PbBr2'] 64 32
# ['I Pb'] ['PbI2'] 65 55
# ['MA I Pb FA'] ['MA0.6FA0.4PbI3'] 53 41
# ['Br Pb MA I'] ['MAPb(Br0.4I0.6)3'] 56 41
# ['Cs MA Pb I'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Pb FA Cs I'] ['Cs0.6FA0.4PbI3'] 6 41
# ['MA Pb I FA'] ['MA0.2FA0.8PbI3'] 51 41
# ['MA Pb FA Br'] ['MA0.2FA0.8PbBr3'] 47 24
# ['FA I Pb'] ['delta-FAPbI3'] 46 55
# ['FA I Br Pb'] ['FAPb(Br0.8I0.2)3'] 42 41
# ['Br Cl Pb Cs'] ['CsPb(Cl0.2Br0.8)3'] 20 41
# ['I Br Cs Pb'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['Pb Br Cl Cs'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['FA Pb I'] ['alpha-FAPbI3'] 44 13
# ['Pb I FA'] ['beta-FAPbI3'] 45 43
# ['Cs MA Pb Br'] ['Cs0.6MA0.4PbBr3'] 10 24
# ['Cs Pb Br'] ['Cs4PbBr6'] 16 24
# ['I Cs Cl Pb'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Br Pb Cs'] ['CsPb2Br5'] 19 55
# ['MA Cs Pb I'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Pb Cs I'] ['delta-CsPbI3'] 37 13
# ['Cl Cs Pb Br'] ['CsPb(Cl0.2Br0.8)3'] 20 24
# ['Br Pb'] ['PbBr2'] 64 32
# ['Pb FA Br'] ['cubic-FAPbBr3'] 43 24
# ['MA Cs Pb I'] ['Cs0.4MA0.6PbI3'] 13 41
# ['Pb Cs I'] ['delta-CsPbI3'] 37 13
# ['MA Br Cs Pb'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['I Pb MA Br'] ['MAPb(Br0.6I0.4)3'] 57 24
# ['Pb Cl Cs I'] ['CsPb(I0.6Cl0.4)3'] 30 41
# ['Br Cs Pb I'] ['CsPb(I0.8Br0.2)3'] 27 41
# ['Br FA Pb MA'] ['MA0.6FA0.4PbBr3'] 49 41
# ['Pb Br MA Cs'] ['Cs0.2MA0.8PbBr3'] 8 41
# ['Br Pb Cs MA'] ['Cs0.4MA0.6PbBr3'] 9 41
# ['MA I Cs Pb'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Br MA I Pb'] ['MAPb(Br0.4I0.6)3'] 56 41
# ['Cs Cl Pb I'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Pb MA FA Br'] ['MA0.8FA0.2PbBr3'] 50 24
# ['Cs FA Pb I'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Pb Cs I'] ['alpha-CsPbI3'] 36 13
# ['I Pb FA'] ['alpha-FAPbI3'] 44 43
# ['Cs FA I Pb'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Pb Cl I Cs'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['I FA Pb MA'] ['MA0.2FA0.8PbI3'] 51 41
# ['I Pb FA'] ['beta-FAPbI3'] 45 43
# ['FA Pb Cs I'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Pb I'] ['PbI2'] 65 14
# ['Pb MA Br I'] ['MAPb(Br0.6I0.4)3'] 57 41
# ['I Pb'] ['PbI2'] 65 32
# ['Pb MA Cl'] ['Pnma-MAPbCl3'] 61 55
# ['Br Cs Pb'] ['cubic-CsPbBr3'] 32 55
# ['Br Pb MA I'] ['MAPb(Br0.8I0.2)3'] 58 41
# ['FA MA I Pb'] ['MA0.2FA0.8PbI3'] 51 41
# ['Pb FA I'] ['beta-FAPbI3'] 45 13
# ['MA Cs Br Pb'] ['Cs0.2MA0.8PbBr3'] 8 41
# ['Cl I Cs Pb'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Cs I Br Pb'] ['CsPb(I0.8Br0.2)3'] 27 41
# ['Cs I Cl Pb'] ['CsPb(I0.6Cl0.4)3'] 30 41
# ['Cl Cs I Pb'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Pb Cs Cl I'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Pb Cs Br'] ['orthorhombic-CsPbBr3'] 33 24
# ['MA Cl Pb'] ['Pnma-MAPbCl3'] 61 55
# ['Pb I Cs Cl'] ['CsPb(I0.8Cl0.2)3'] 31 41
# ['Cs Cl I Pb'] ['CsPb(I0.8Cl0.2)3'] 31 41
# ['Pb FA I Cs'] ['Cs0.4FA0.6PbI3'] 5 41
# ['Br MA Pb FA'] ['MA0.2FA0.8PbBr3'] 47 41
# ['Pb I Br Cs'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['Pb Cs I'] ['delta-CsPbI3'] 37 13
# ['Cs FA Pb Br'] ['Cs0.2FA0.8PbBr3'] 0 24
# ['MA Pb I'] ['tetragonal-MAPbI3'] 63 13
# ['I FA Br Pb'] ['FAPb(Br0.2I0.8)3'] 39 41
# ['Pb Cl Cs'] ['Pnma-CsPbCl3'] 34 55
# ['Pb FA I Br'] ['FAPb(Br0.8I0.2)3'] 42 24
# ['Cs FA I Pb'] ['Cs0.8FA0.2PbI3'] 7 41
# ['FA MA Pb Br'] ['MA0.8FA0.2PbBr3'] 50 24
# ['Pb FA MA Br'] ['MA0.8FA0.2PbBr3'] 50 24
# ['FA Pb I MA'] ['MA0.8FA0.2PbI3'] 54 41
# ['Br Pb Cs'] ['CsPb2Br5'] 19 55
# ['FA I Pb'] ['delta-FAPbI3'] 46 55
# ['I Br Pb FA'] ['FAPb(Br0.4I0.6)3'] 40 41
# ['Cl Cs I Pb'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['Pb Cs Br'] ['Cs4PbBr6'] 16 24
# ['Cs FA Pb I'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Pb I Br MA'] ['MAPb(Br0.4I0.6)3'] 56 41
# ['Pb Br I Cs'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['Pb Cs Cl Br'] ['CsPb(Cl0.8Br0.2)3'] 23 24
# ['Cs Pb Br'] ['orthorhombic-CsPbBr3'] 33 24
# ['Cs Br'] ['CsBr'] 17 24
# ['Pb Br I FA'] ['FAPb(Br0.4I0.6)3'] 40 41
# ['I Pb Br MA'] ['MAPb(Br0.6I0.4)3'] 57 41
# ['Pb I'] ['PbI2'] 65 14
# ['MA Pb Cs I'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Cs Pb Br I'] ['CsPb(I0.4Br0.6)3'] 25 41
# ['Pb Cl Cs'] ['cubic-CsPbCl3'] 35 55
# ['Br Pb I FA'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['Br Pb MA Cs'] ['Cs0.6MA0.4PbBr3'] 10 41
# ['Pb Br I MA'] ['MAPb(Br0.8I0.2)3'] 58 41
# ['Pb I MA'] ['alpha-MAPbI3'] 62 33
# ['Br FA Pb'] ['cubic-FAPbBr3'] 43 55
# ['Cl Pb MA'] ['Pnma-MAPbCl3'] 61 33
# ['I MA Pb Cs'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Cs Pb Cl I'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['MA Pb I FA'] ['MA0.4FA0.6PbI3'] 52 41
# ['Cs I'] ['CsI'] 18 14
# ['Pb Cs MA Br'] ['Cs0.2MA0.8PbBr3'] 8 24
# ['Pb Br MA Cs'] ['Cs0.6MA0.4PbBr3'] 10 41
# ['Cl Pb Cs'] ['Pnma-CsPbCl3'] 34 55
# ['Pb I'] ['PbI2'] 65 14
# ['Br MA Pb'] ['cubic-MAPbBr3'] 59 55
# ['Cs Pb Cl'] ['cubic-CsPbCl3'] 35 55
# ['Pb MA FA Br'] ['MA0.4FA0.6PbBr3'] 48 24
# ['Cl Cs Pb'] ['cubic-CsPbCl3'] 35 55
# ['Br Pb Cs Cl'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['MA Cs I Pb'] ['Cs0.2MA0.8PbI3'] 12 41
# ['I FA MA Pb'] ['MA0.8FA0.2PbI3'] 54 41
# ['I MA Pb Cs'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Br Pb I FA'] ['FAPb(Br0.2I0.8)3'] 39 41
# ['Pb MA I FA'] ['MA0.6FA0.4PbI3'] 53 41
# ['Cs MA Pb Br'] ['Cs0.6MA0.4PbBr3'] 10 24
# ['Pb I Br MA'] ['MAPb(Br0.6I0.4)3'] 57 41
# ['Pb I FA Cs'] ['Cs0.2FA0.8PbI3'] 4 41
# ['I Pb FA'] ['beta-FAPbI3'] 45 43
# ['Pb Br Cs'] ['CsPb2Br5'] 19 55
# ['Cs Br FA Pb'] ['Cs0.2FA0.8PbBr3'] 0 41
# ['Pb I Br Cs'] ['CsPb(I0.4Br0.6)3'] 25 41
# ['Br Pb I Cs'] ['CsPb(I0.2Br0.8)3'] 24 41
# ['Br MA Pb Cs'] ['Cs0.2MA0.8PbBr3'] 8 41
# ['Br Pb'] ['PbBr2'] 64 32
# ['Pb I FA'] ['delta-FAPbI3'] 46 43
# ['Pb MA Cs I'] ['Cs0.2MA0.8PbI3'] 12 41
# ['MA I FA Pb'] ['MA0.4FA0.6PbI3'] 52 41
# ['Pb Br MA FA'] ['MA0.8FA0.2PbBr3'] 50 41
# ['Pb Cl I Cs'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['Pb Cs I FA'] ['Cs0.8FA0.2PbI3'] 7 41
# ['Cs I Pb'] ['delta-CsPbI3'] 37 55
# ['I Br FA Pb'] ['FAPb(Br0.8I0.2)3'] 42 41
# ['Pb Br MA'] ['tetragonal-MAPbBr3'] 60 33
# ['Pb MA I Br'] ['MAPb(Br0.4I0.6)3'] 56 24
# ['Pb I FA'] ['beta-FAPbI3'] 45 43
# ['Pb I MA FA'] ['MA0.8FA0.2PbI3'] 54 41
# ['Pb Br FA I'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['Pb I Cs FA'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Pb I FA Cs'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Pb I FA Cs'] ['Cs0.6FA0.4PbI3'] 6 41
# ['FA I Pb Cs'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Pb Br FA I'] ['FAPb(Br0.2I0.8)3'] 39 41
# ['MA I Pb'] ['alpha-MAPbI3'] 62 55
# ['Cl Br Cs Pb'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['Pb I Cs MA'] ['Cs0.4MA0.6PbI3'] 13 41
# ['FA Pb Br'] ['cubic-FAPbBr3'] 43 24
# ['Br Pb Cs'] ['CsPb2Br5'] 19 55
# ['Cl MA Pb'] ['Pnma-MAPbCl3'] 61 55
# ['I Br Cs Pb'] ['CsPb(I0.2Br0.8)3'] 24 41
# ['Pb Cs MA I'] ['Cs0.8MA0.2PbI3'] 15 41
# ['FA Cs Pb I'] ['Cs0.2FA0.8PbI3'] 4 41
# ['I Pb Br MA'] ['MAPb(Br0.6I0.4)3'] 57 41
# ['I Pb FA'] ['alpha-FAPbI3'] 44 43
# ['MA Pb Br'] ['cubic-MAPbBr3'] 59 24
# ['Cs Pb Cl'] ['cubic-CsPbCl3'] 35 55
# ['Cs Pb I Cl'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Cl Pb Cs Br'] ['CsPb(Cl0.8Br0.2)3'] 23 24
# ['FA Pb Br Cs'] ['Cs0.8FA0.2PbBr3'] 3 41
# ['I MA Pb'] ['alpha-MAPbI3'] 62 55
# ['Pb FA I'] ['alpha-FAPbI3'] 44 13
# ['I MA FA Pb'] ['MA0.2FA0.8PbI3'] 51 41
# ['FA Pb Br Cs'] ['Cs0.4FA0.6PbBr3'] 1 41
# ['FA Br Cs Pb'] ['Cs0.8FA0.2PbBr3'] 3 41
# ['MA Pb Cs I'] ['Cs0.6MA0.4PbI3'] 14 41
# ['Pb Cs Br'] ['Cs4PbBr6'] 16 24
# ['Cs I Pb'] ['gamma-CsPbI3'] 38 55
# ['Pb Cs Cl Br'] ['CsPb(Cl0.2Br0.8)3'] 20 24
# ['Pb I MA'] ['tetragonal-MAPbI3'] 63 33
# ['Br Pb Cs'] ['CsPb2Br5'] 19 55
# ['Pb Cs I'] ['gamma-CsPbI3'] 38 13
# ['Pb Br FA'] ['cubic-FAPbBr3'] 43 43
# ['MA FA Pb Br'] ['MA0.2FA0.8PbBr3'] 47 24
# ['Pb FA MA I'] ['MA0.4FA0.6PbI3'] 52 41
# ['Pb Br MA Cs'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['Br Pb Cs MA'] ['Cs0.6MA0.4PbBr3'] 10 41
# ['I Cs Pb MA'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Pb FA I Cs'] ['Cs0.8FA0.2PbI3'] 7 41
# ['Pb Cs I Br'] ['CsPb(I0.8Br0.2)3'] 27 24
# ['Pb Cs Cl'] ['cubic-CsPbCl3'] 35 55
# ['MA I Pb Cs'] ['Cs0.4MA0.6PbI3'] 13 41
# ['I Pb FA Cs'] ['Cs0.4FA0.6PbI3'] 5 41
# ['Br Cs Cl Pb'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['MA I Pb Br'] ['MAPb(Br0.6I0.4)3'] 57 24
# ['Pb MA I'] ['tetragonal-MAPbI3'] 63 13
# ['Br Cs Pb Cl'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['Br Cs Pb MA'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['Pb Cl Br Cs'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['Cs Pb I'] ['delta-CsPbI3'] 37 13
# ['Cs Br'] ['CsBr'] 17 24
# ['Pb I FA'] ['alpha-FAPbI3'] 44 43
# ['I Pb Cs FA'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Pb FA Br MA'] ['MA0.6FA0.4PbBr3'] 49 41
# ['MA Br Cs Pb'] ['Cs0.6MA0.4PbBr3'] 10 41
# ['MA Pb Br Cs'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['Pb Br I MA'] ['MAPb(Br0.4I0.6)3'] 56 41
# ['Br Pb Cs MA'] ['Cs0.4MA0.6PbBr3'] 9 41
# ['Pb Br I FA'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['FA MA Pb Br'] ['MA0.4FA0.6PbBr3'] 48 24
# ['Pb FA Br I'] ['FAPb(Br0.2I0.8)3'] 39 41
# ['MA Pb I'] ['tetragonal-MAPbI3'] 63 13
# ['Cl Pb I Cs'] ['CsPb(I0.8Cl0.2)3'] 31 41
# ['MA Cs Pb I'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Pb Cs I'] ['gamma-CsPbI3'] 38 13
# ['I Cs Pb'] ['alpha-CsPbI3'] 36 55
# ['I FA Pb'] ['delta-FAPbI3'] 46 55
# ['I Pb'] ['PbI2'] 65 32
# ['Cl MA Pb'] ['Pnma-MAPbCl3'] 61 55
# ['FA Pb I MA'] ['MA0.6FA0.4PbI3'] 53 41
# ['I FA Pb'] ['alpha-FAPbI3'] 44 55
# ['Pb I MA FA'] ['MA0.2FA0.8PbI3'] 51 41
# ['Pb Cl MA'] ['Pnma-MAPbCl3'] 61 33
# ['Pb Br FA'] ['cubic-FAPbBr3'] 43 43
# ['FA Pb MA I'] ['MA0.4FA0.6PbI3'] 52 41
# ['Cs MA Br Pb'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['FA Pb Cs Br'] ['Cs0.4FA0.6PbBr3'] 1 24
# ['FA I Pb'] ['delta-FAPbI3'] 46 55
# ['MA Cs I Pb'] ['Cs0.4MA0.6PbI3'] 13 41
# ['MA Br Cs Pb'] ['Cs0.2MA0.8PbBr3'] 8 41
# ['Br Cs'] ['CsBr'] 17 6
# ['Br Pb MA'] ['tetragonal-MAPbBr3'] 60 33
# ['Cs Pb Br'] ['cubic-CsPbBr3'] 32 24
# ['Br Cs'] ['CsBr'] 17 6
# ['Cs Pb I'] ['alpha-CsPbI3'] 36 13
# ['FA Cs Pb Br'] ['Cs0.6FA0.4PbBr3'] 2 24
# ['Br Pb'] ['PbBr2'] 64 32
# ['Pb I Cs FA'] ['Cs0.8FA0.2PbI3'] 7 41
# ['I Pb'] ['PbI2'] 65 32
# ['Pb MA I'] ['alpha-MAPbI3'] 62 13
# ['Pb Cs FA Br'] ['Cs0.2FA0.8PbBr3'] 0 24
# ['I Pb Cs Br'] ['CsPb(I0.8Br0.2)3'] 27 24
# ['I Cs FA Pb'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Pb MA Cs Br'] ['Cs0.8MA0.2PbBr3'] 11 24
# ['I Pb Cs Cl'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Cs Pb Br'] ['CsPb2Br5'] 19 24
# ['MA Br Pb'] ['tetragonal-MAPbBr3'] 60 55
# ['I Br Cs Pb'] ['CsPb(I0.2Br0.8)3'] 24 41
# ['Br Pb'] ['PbBr2'] 64 32
# ['I Pb Br FA'] ['FAPb(Br0.8I0.2)3'] 42 41
# ['Cs I'] ['CsI'] 18 14
# ['I Cs Pb Br'] ['CsPb(I0.6Br0.4)3'] 26 24
# ['Pb I MA FA'] ['MA0.6FA0.4PbI3'] 53 41
# ['Cs Br Pb Cl'] ['CsPb(Cl0.2Br0.8)3'] 20 41
# ['Cs Br'] ['CsBr'] 17 24
# ['Pb Cs I'] ['gamma-CsPbI3'] 38 13
# ['Pb Cs Br MA'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['Cs I'] ['CsI'] 18 14
# ['FA I Br Pb'] ['FAPb(Br0.4I0.6)3'] 40 41
# ['FA MA Pb I'] ['MA0.8FA0.2PbI3'] 54 41
# ['Pb Cs MA I'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Pb Cs MA I'] ['Cs0.4MA0.6PbI3'] 13 41
# ['Pb Cs Br'] ['Cs4PbBr6'] 16 24
# ['Br Cs Pb'] ['cubic-CsPbBr3'] 32 55
# ['Pb MA Cs I'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Br Pb Cs Cl'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['Pb FA I'] ['beta-FAPbI3'] 45 13
# ['I MA Pb Br'] ['MAPb(Br0.8I0.2)3'] 58 24
# ['Br Pb FA Cs'] ['Cs0.4FA0.6PbBr3'] 1 41
# ['Pb Br Cs Cl'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['Cs Pb Br'] ['orthorhombic-CsPbBr3'] 33 24
# ['Cs Cl I Pb'] ['CsPb(I0.8Cl0.2)3'] 31 41
# ['Cs Pb Br'] ['Cs4PbBr6'] 16 24
# ['Br MA Pb'] ['cubic-MAPbBr3'] 59 55
# ['Br Pb'] ['PbBr2'] 64 32
# ['Br Pb Cs'] ['Cs4PbBr6'] 16 55
# ['FA Pb Br MA'] ['MA0.6FA0.4PbBr3'] 49 41
# ['FA Pb I'] ['delta-FAPbI3'] 46 13
# ['Pb Cs FA I'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Pb Br Cs'] ['orthorhombic-CsPbBr3'] 33 55
# ['MA Cs Pb I'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Cs Br'] ['CsBr'] 17 24
# ['MA FA Pb I'] ['MA0.8FA0.2PbI3'] 54 41
# ['Pb Cs I MA'] ['Cs0.2MA0.8PbI3'] 12 41
# ['FA Pb I Cs'] ['Cs0.6FA0.4PbI3'] 6 41
# ['I MA Pb Cs'] ['Cs0.4MA0.6PbI3'] 13 41
# ['Pb Cs Br'] ['Cs4PbBr6'] 16 24
# ['Pb FA I'] ['alpha-FAPbI3'] 44 13
# ['Pb Cs FA I'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Cs I Pb'] ['gamma-CsPbI3'] 38 55
# ['Br Pb Cs'] ['CsPb2Br5'] 19 55
# ['Pb I Cs FA'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Br Pb Cs'] ['orthorhombic-CsPbBr3'] 33 55
# ['Cs Pb Br Cl'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['Pb I MA Br'] ['MAPb(Br0.6I0.4)3'] 57 24
# ['I Pb FA'] ['alpha-FAPbI3'] 44 43
# ['Pb Br MA'] ['tetragonal-MAPbBr3'] 60 33
# ['MA Pb I Cs'] ['Cs0.6MA0.4PbI3'] 14 41
# ['I Pb FA Cs'] ['Cs0.8FA0.2PbI3'] 7 41
# ['I Cs Pb'] ['delta-CsPbI3'] 37 55
# ['Pb I Cs FA'] ['Cs0.4FA0.6PbI3'] 5 41
# ['Pb Cl Cs Br'] ['CsPb(Cl0.6Br0.4)3'] 22 24
# ['Pb Cs I Cl'] ['CsPb(I0.8Cl0.2)3'] 31 41
# ['Br Cl Cs Pb'] ['CsPb(Cl0.2Br0.8)3'] 20 41
# ['Cs Br MA Pb'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['Cs Pb FA I'] ['Cs0.6FA0.4PbI3'] 6 41
# ['MA Br FA Pb'] ['MA0.2FA0.8PbBr3'] 47 41
# ['Br Cs Pb'] ['CsPb2Br5'] 19 55
# ['Pb Cs MA Br'] ['Cs0.4MA0.6PbBr3'] 9 24
# ['Pb MA FA Br'] ['MA0.2FA0.8PbBr3'] 47 24
# ['Cs MA Pb Br'] ['Cs0.8MA0.2PbBr3'] 11 24
# ['MA Br Pb'] ['tetragonal-MAPbBr3'] 60 55
# ['I MA Cs Pb'] ['Cs0.6MA0.4PbI3'] 14 41
# ['Br Cl Pb Cs'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['Br Pb Cs'] ['orthorhombic-CsPbBr3'] 33 55
# ['Pb MA Br'] ['tetragonal-MAPbBr3'] 60 24
# ['Pb FA Br Cs'] ['Cs0.4FA0.6PbBr3'] 1 41
# ['Cs I Pb Br'] ['CsPb(I0.2Br0.8)3'] 24 24
# ['MA Pb I Cs'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Pb FA MA I'] ['MA0.6FA0.4PbI3'] 53 41
# ['Pb I Cs Cl'] ['CsPb(I0.8Cl0.2)3'] 31 41
# ['Cs MA Br Pb'] ['Cs0.2MA0.8PbBr3'] 8 41
# ['Pb Cs I MA'] ['Cs0.4MA0.6PbI3'] 13 41
# ['Pb Br I FA'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['Br MA FA Pb'] ['MA0.6FA0.4PbBr3'] 49 41
# ['I MA Pb'] ['alpha-MAPbI3'] 62 55
# ['Pb I FA Cs'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Cs Pb Br Cl'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['Pb Cs FA I'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Br Pb Cs Cl'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['Cs Pb MA Br'] ['Cs0.8MA0.2PbBr3'] 11 24
# ['I Pb FA MA'] ['MA0.6FA0.4PbI3'] 53 41
# ['Cs Cl Pb I'] ['CsPb(I0.8Cl0.2)3'] 31 41
# ['Br FA MA Pb'] ['MA0.2FA0.8PbBr3'] 47 41
# ['Br Pb Cs FA'] ['Cs0.6FA0.4PbBr3'] 2 41
# ['Pb FA I MA'] ['MA0.6FA0.4PbI3'] 53 41
# ['Cs FA Pb I'] ['Cs0.4FA0.6PbI3'] 5 41
# ['I FA Pb Br'] ['FAPb(Br0.6I0.4)3'] 41 24
# ['I Pb'] ['PbI2'] 65 32
# ['Pb Cs I MA'] ['Cs0.8MA0.2PbI3'] 15 41
# ['I Br Cs Pb'] ['CsPb(I0.8Br0.2)3'] 27 41
# ['Pb I FA'] ['beta-FAPbI3'] 45 43
# ['I MA Pb Br'] ['MAPb(Br0.4I0.6)3'] 56 24
# ['MA FA Pb I'] ['MA0.2FA0.8PbI3'] 51 41
# ['I Br Pb FA'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['Br MA Pb FA'] ['MA0.4FA0.6PbBr3'] 48 41
# ['Pb Br FA'] ['cubic-FAPbBr3'] 43 43
# ['Pb FA Cs Br'] ['Cs0.8FA0.2PbBr3'] 3 24
# ['Pb Cs FA Br'] ['Cs0.8FA0.2PbBr3'] 3 24
# ['Pb Br'] ['PbBr2'] 64 24
# ['Br MA I Pb'] ['MAPb(Br0.2I0.8)3'] 55 41
# ['I Pb MA'] ['tetragonal-MAPbI3'] 63 33
# ['Cs Pb Br'] ['cubic-CsPbBr3'] 32 24
# ['I Pb FA Br'] ['FAPb(Br0.6I0.4)3'] 41 24
# ['Br I FA Pb'] ['FAPb(Br0.8I0.2)3'] 42 41
# ['Cs I Pb'] ['delta-CsPbI3'] 37 55
# ['Cs Br MA Pb'] ['Cs0.4MA0.6PbBr3'] 9 41
# ['Pb Br MA FA'] ['MA0.8FA0.2PbBr3'] 50 41
# ['MA I Pb'] ['tetragonal-MAPbI3'] 63 55
# ['FA MA Pb I'] ['MA0.2FA0.8PbI3'] 51 41
# ['MA I Br Pb'] ['MAPb(Br0.6I0.4)3'] 57 41
# ['Br Pb I MA'] ['MAPb(Br0.8I0.2)3'] 58 41
# ['I Cs Pb Br'] ['CsPb(I0.4Br0.6)3'] 25 24
# ['FA Pb Br Cs'] ['Cs0.4FA0.6PbBr3'] 1 41
# ['I Cs Pb'] ['delta-CsPbI3'] 37 55
# ['Pb Br Cs'] ['Cs4PbBr6'] 16 55
# ['I Cs MA Pb'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Br I Pb Cs'] ['CsPb(I0.4Br0.6)3'] 25 41
# ['FA Pb I'] ['alpha-FAPbI3'] 44 13
# ['Br Pb FA Cs'] ['Cs0.6FA0.4PbBr3'] 2 41
# ['MA FA Pb I'] ['MA0.4FA0.6PbI3'] 52 41
# ['Pb I FA Br'] ['FAPb(Br0.8I0.2)3'] 42 24
# ['I MA Cs Pb'] ['Cs0.4MA0.6PbI3'] 13 41
# ['Br I Pb MA'] ['MAPb(Br0.8I0.2)3'] 58 41
# ['Pb Cs Br Cl'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['Pb Cl I Cs'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Pb MA Br'] ['tetragonal-MAPbBr3'] 60 24
# ['Pb Br I FA'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['Pb Cs Br Cl'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['Br Pb FA MA'] ['MA0.4FA0.6PbBr3'] 48 41
# ['FA I Pb'] ['alpha-FAPbI3'] 44 55
# ['Pb Br I Cs'] ['CsPb(I0.2Br0.8)3'] 24 41
# ['Br MA FA Pb'] ['MA0.6FA0.4PbBr3'] 49 41
# ['FA Pb Br I'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['FA Br Cs Pb'] ['Cs0.4FA0.6PbBr3'] 1 41
# ['Pb Br'] ['PbBr2'] 64 24
# ['Pb I FA MA'] ['MA0.2FA0.8PbI3'] 51 41
# ['Br I Pb FA'] ['FAPb(Br0.2I0.8)3'] 39 41
# ['I Cs Pb MA'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Br Pb FA MA'] ['MA0.2FA0.8PbBr3'] 47 41
# ['FA MA Pb Br'] ['MA0.4FA0.6PbBr3'] 48 24
# ['Br I Pb Cs'] ['CsPb(I0.2Br0.8)3'] 24 41
# ['FA Br Cs Pb'] ['Cs0.2FA0.8PbBr3'] 0 41
# ['FA Cs Pb Br'] ['Cs0.2FA0.8PbBr3'] 0 24
# ['Cs I Pb FA'] ['Cs0.8FA0.2PbI3'] 7 41
# ['Pb MA Br Cs'] ['Cs0.4MA0.6PbBr3'] 9 41
# ['Pb FA Br I'] ['FAPb(Br0.8I0.2)3'] 42 41
# ['Pb Cs Br'] ['Cs4PbBr6'] 16 24
# ['I Pb MA'] ['tetragonal-MAPbI3'] 63 33
# ['Pb MA Br Cs'] ['Cs0.6MA0.4PbBr3'] 10 41
# ['Cs Pb Br FA'] ['Cs0.4FA0.6PbBr3'] 1 41
# ['Pb Br Cs'] ['cubic-CsPbBr3'] 32 55
# ['I Pb MA Cs'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Cs Pb Br'] ['Cs4PbBr6'] 16 24
# ['MA Pb I'] ['alpha-MAPbI3'] 62 13
# ['Cs Br Pb MA'] ['Cs0.2MA0.8PbBr3'] 8 41
# ['Pb I MA'] ['tetragonal-MAPbI3'] 63 33
# ['FA I Pb Cs'] ['Cs0.6FA0.4PbI3'] 6 41
# ['MA Pb I FA'] ['MA0.2FA0.8PbI3'] 51 41
# ['I MA FA Pb'] ['MA0.8FA0.2PbI3'] 54 41
# ['I Pb Br FA'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['FA Pb I'] ['delta-FAPbI3'] 46 13
# ['Pb MA Br'] ['cubic-MAPbBr3'] 59 24
# ['Pb I Cl Cs'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Pb I FA Br'] ['FAPb(Br0.8I0.2)3'] 42 24
# ['MA Br Pb FA'] ['MA0.2FA0.8PbBr3'] 47 41
# ['Br Cs Pb FA'] ['Cs0.8FA0.2PbBr3'] 3 41
# ['FA Br Pb MA'] ['MA0.4FA0.6PbBr3'] 48 41
# ['FA Pb Cs I'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Cs Pb I MA'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Cl Cs I Pb'] ['CsPb(I0.6Cl0.4)3'] 30 41
# ['Pb I FA Cs'] ['Cs0.8FA0.2PbI3'] 7 41
# ['Br Cs FA Pb'] ['Cs0.8FA0.2PbBr3'] 3 41
# ['Cl Pb Cs Br'] ['CsPb(Cl0.8Br0.2)3'] 23 24
# ['FA MA I Pb'] ['MA0.4FA0.6PbI3'] 52 41
# ['Pb I MA Br'] ['MAPb(Br0.2I0.8)3'] 55 24
# ['Pb MA I Cs'] ['Cs0.2MA0.8PbI3'] 12 41
# ['I Pb Cs'] ['alpha-CsPbI3'] 36 55
# ['I Pb Cs MA'] ['Cs0.6MA0.4PbI3'] 14 41
# ['Cl Cs Pb I'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['I MA Pb'] ['alpha-MAPbI3'] 62 55
# ['Pb FA I'] ['beta-FAPbI3'] 45 13
# ['Pb Br FA Cs'] ['Cs0.8FA0.2PbBr3'] 3 41
# ['MA Cl Pb'] ['Pnma-MAPbCl3'] 61 55
# ['Pb FA MA Br'] ['MA0.2FA0.8PbBr3'] 47 24
# ['Cs Pb MA I'] ['Cs0.4MA0.6PbI3'] 13 41
# ['Pb MA Cs I'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Pb I FA Br'] ['FAPb(Br0.6I0.4)3'] 41 24
# ['Br Pb MA Cs'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['MA Pb I Br'] ['MAPb(Br0.8I0.2)3'] 58 24
# ['MA Br Cs Pb'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['Cs I'] ['CsI'] 18 14
# ['Pb Br Cs FA'] ['Cs0.4FA0.6PbBr3'] 1 41
# ['Pb I MA Cs'] ['Cs0.6MA0.4PbI3'] 14 41
# ['Pb Br Cs'] ['cubic-CsPbBr3'] 32 55
# ['Cs Br FA Pb'] ['Cs0.2FA0.8PbBr3'] 0 41
# ['Cs Cl I Pb'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Pb Cs I'] ['delta-CsPbI3'] 37 13
# ['I Pb FA'] ['beta-FAPbI3'] 45 43
# ['Pb FA I'] ['delta-FAPbI3'] 46 13
# ['Br Pb I MA'] ['MAPb(Br0.8I0.2)3'] 58 41
# ['Cs Pb I'] ['gamma-CsPbI3'] 38 13
# ['Br Pb Cs I'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['I Pb Cs Br'] ['CsPb(I0.2Br0.8)3'] 24 24
# ['MA Br Cs Pb'] ['Cs0.2MA0.8PbBr3'] 8 41
# ['Cs I'] ['CsI'] 18 14
# ['Pb Br'] ['PbBr2'] 64 24
# ['Cs Pb Cl I'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['Br Pb I FA'] ['FAPb(Br0.4I0.6)3'] 40 41
# ['Cs I'] ['CsI'] 18 14
# ['I Pb Br Cs'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['Pb Br Cs I'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['Br I Cs Pb'] ['CsPb(I0.8Br0.2)3'] 27 41
# ['I Br FA Pb'] ['FAPb(Br0.4I0.6)3'] 40 41
# ['Pb MA Br'] ['cubic-MAPbBr3'] 59 24
# ['Pb Br MA I'] ['MAPb(Br0.2I0.8)3'] 55 41
# ['I Pb FA'] ['delta-FAPbI3'] 46 43
# ['Cs FA I Pb'] ['Cs0.8FA0.2PbI3'] 7 41
# ['Br Pb I MA'] ['MAPb(Br0.4I0.6)3'] 56 41
# ['I Br FA Pb'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['Br MA FA Pb'] ['MA0.6FA0.4PbBr3'] 49 41
# ['I Pb Br MA'] ['MAPb(Br0.6I0.4)3'] 57 41
# ['I Cs FA Pb'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Br Pb Cs I'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['Br Pb Cl Cs'] ['CsPb(Cl0.2Br0.8)3'] 20 41
# ['Pb I Cl Cs'] ['CsPb(I0.6Cl0.4)3'] 30 41
# ['Br Pb I FA'] ['FAPb(Br0.8I0.2)3'] 42 41
# ['FA Pb Br'] ['cubic-FAPbBr3'] 43 24
# ['FA MA Br Pb'] ['MA0.4FA0.6PbBr3'] 48 41
# ['Cl Pb Cs'] ['Pnma-CsPbCl3'] 34 55
# ['Pb Br Cs MA'] ['Cs0.6MA0.4PbBr3'] 10 41
# ['Pb Cs Cl I'] ['CsPb(I0.8Cl0.2)3'] 31 41
# ['Cl Br Cs Pb'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['Pb I MA Br'] ['MAPb(Br0.6I0.4)3'] 57 24
# ['I MA Br Pb'] ['MAPb(Br0.6I0.4)3'] 57 41
# ['I Pb FA'] ['beta-FAPbI3'] 45 43
# ['I Pb Br Cs'] ['CsPb(I0.2Br0.8)3'] 24 41
# ['Br FA MA Pb'] ['MA0.8FA0.2PbBr3'] 50 41
# ['Cs Pb Br FA'] ['Cs0.4FA0.6PbBr3'] 1 41
# ['Cl Pb Br Cs'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['FA I Pb'] ['delta-FAPbI3'] 46 55
# ['I Cs Pb Br'] ['CsPb(I0.4Br0.6)3'] 25 24
# ['FA Pb Br MA'] ['MA0.4FA0.6PbBr3'] 48 41
# ['FA Pb Br'] ['cubic-FAPbBr3'] 43 24
# ['Br Pb Cs I'] ['CsPb(I0.2Br0.8)3'] 24 41
# ['I Br Cs Pb'] ['CsPb(I0.2Br0.8)3'] 24 41
# ['Cs I MA Pb'] ['Cs0.6MA0.4PbI3'] 14 41
# ['Br MA I Pb'] ['MAPb(Br0.2I0.8)3'] 55 41
# ['Pb I FA'] ['beta-FAPbI3'] 45 43
# ['MA I FA Pb'] ['MA0.8FA0.2PbI3'] 54 41
# ['Cs I Br Pb'] ['CsPb(I0.2Br0.8)3'] 24 41
# ['Cs I Pb FA'] ['Cs0.4FA0.6PbI3'] 5 41
# ['MA I Pb Br'] ['MAPb(Br0.8I0.2)3'] 58 24
# ['Pb Br FA Cs'] ['Cs0.6FA0.4PbBr3'] 2 41
# ['Pb I MA FA'] ['MA0.4FA0.6PbI3'] 52 41
# ['Cs Pb I MA'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Br Cs Pb'] ['Cs4PbBr6'] 16 55
# ['Br MA Pb I'] ['MAPb(Br0.6I0.4)3'] 57 41
# ['Br FA Pb MA'] ['MA0.2FA0.8PbBr3'] 47 41
# ['I Pb Cs MA'] ['Cs0.6MA0.4PbI3'] 14 41
# ['Br I Pb Cs'] ['CsPb(I0.2Br0.8)3'] 24 41
# ['Pb I Cs'] ['gamma-CsPbI3'] 38 55
# ['Cs FA Pb I'] ['Cs0.8FA0.2PbI3'] 7 41
# ['I FA Pb Br'] ['FAPb(Br0.2I0.8)3'] 39 24
# ['Pb Br Cs'] ['orthorhombic-CsPbBr3'] 33 55
# ['FA Cs Pb I'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Pb FA I Cs'] ['Cs0.2FA0.8PbI3'] 4 41
# ['FA Br MA Pb'] ['MA0.6FA0.4PbBr3'] 49 41
# ['Pb Br Cl Cs'] ['CsPb(Cl0.2Br0.8)3'] 20 41
# ['Pb Br Cs Cl'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['I Cs Pb'] ['gamma-CsPbI3'] 38 55
# ['Pb FA MA I'] ['MA0.4FA0.6PbI3'] 52 41
# ['Pb Br MA'] ['tetragonal-MAPbBr3'] 60 33
# ['MA Pb Cs I'] ['Cs0.6MA0.4PbI3'] 14 41
# ['Pb MA I'] ['tetragonal-MAPbI3'] 63 13
# ['FA Pb Cs I'] ['Cs0.6FA0.4PbI3'] 6 41
# ['MA Cs Pb Br'] ['Cs0.2MA0.8PbBr3'] 8 24
# ['FA Pb Cs I'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Br Pb Cs'] ['CsPb2Br5'] 19 55
# ['Br Cs'] ['CsBr'] 17 6
# ['Br Cs Pb MA'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['I Pb MA FA'] ['MA0.4FA0.6PbI3'] 52 41
# ['MA Cs Br Pb'] ['Cs0.2MA0.8PbBr3'] 8 41
# ['I FA MA Pb'] ['MA0.4FA0.6PbI3'] 52 41
# ['MA Cs I Pb'] ['Cs0.4MA0.6PbI3'] 13 41
# ['Pb MA FA Br'] ['MA0.2FA0.8PbBr3'] 47 24
# ['Br FA I Pb'] ['FAPb(Br0.2I0.8)3'] 39 41
# ['Pb I FA'] ['alpha-FAPbI3'] 44 43
# ['Cs Cl Pb'] ['cubic-CsPbCl3'] 35 55
# ['Pb Cs I MA'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Pb I Cs Cl'] ['CsPb(I0.6Cl0.4)3'] 30 41
# ['FA Br Pb I'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['FA Br Pb Cs'] ['Cs0.4FA0.6PbBr3'] 1 41
# ['Br Cs'] ['CsBr'] 17 6
# ['Br MA Pb FA'] ['MA0.2FA0.8PbBr3'] 47 41
# ['FA Br MA Pb'] ['MA0.4FA0.6PbBr3'] 48 41
# ['Br Cl Pb Cs'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['Cs MA Pb I'] ['Cs0.4MA0.6PbI3'] 13 41
# ['MA Br Pb'] ['cubic-MAPbBr3'] 59 55
# ['Br Cs FA Pb'] ['Cs0.2FA0.8PbBr3'] 0 41
# ['Pb I Cs'] ['alpha-CsPbI3'] 36 55
# ['I Pb MA Cs'] ['Cs0.4MA0.6PbI3'] 13 41
# ['Br Pb FA'] ['cubic-FAPbBr3'] 43 43
# ['MA Cs Pb Br'] ['Cs0.8MA0.2PbBr3'] 11 24
# ['I Pb MA FA'] ['MA0.2FA0.8PbI3'] 51 41
# ['Pb FA I'] ['delta-FAPbI3'] 46 13
# ['Br MA Pb'] ['cubic-MAPbBr3'] 59 55
# ['MA Cs Br Pb'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['Br Pb I MA'] ['MAPb(Br0.6I0.4)3'] 57 41
# ['Cs MA Pb Br'] ['Cs0.6MA0.4PbBr3'] 10 24
# ['Pb I FA Cs'] ['Cs0.8FA0.2PbI3'] 7 41
# ['FA Cs Pb I'] ['Cs0.8FA0.2PbI3'] 7 41
# ['I Pb FA'] ['beta-FAPbI3'] 45 43
# ['Pb MA Cs Br'] ['Cs0.6MA0.4PbBr3'] 10 24
# ['Br Pb MA I'] ['MAPb(Br0.8I0.2)3'] 58 41
# ['Pb Cs Br'] ['Cs4PbBr6'] 16 24
# ['MA FA I Pb'] ['MA0.8FA0.2PbI3'] 54 41
# ['Cs I Pb'] ['alpha-CsPbI3'] 36 55
# ['Cl Pb Cs I'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['Pb Br Cs'] ['orthorhombic-CsPbBr3'] 33 55
# ['I Pb Cs MA'] ['Cs0.4MA0.6PbI3'] 13 41
# ['Pb Br Cs I'] ['CsPb(I0.2Br0.8)3'] 24 41
# ['Pb I'] ['PbI2'] 65 14
# ['Br MA Cs Pb'] ['Cs0.6MA0.4PbBr3'] 10 41
# ['Pb Cs Br'] ['orthorhombic-CsPbBr3'] 33 24
# ['Br Pb'] ['PbBr2'] 64 32
# ['Cs FA Pb Br'] ['Cs0.8FA0.2PbBr3'] 3 24
# ['Pb Br Cs'] ['Cs4PbBr6'] 16 55
# ['FA Pb Br'] ['cubic-FAPbBr3'] 43 24
# ['Cl I Pb Cs'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['I Pb MA FA'] ['MA0.2FA0.8PbI3'] 51 41
# ['I MA Cs Pb'] ['Cs0.6MA0.4PbI3'] 14 41
# ['Br Pb MA'] ['cubic-MAPbBr3'] 59 33
# ['I Pb FA MA'] ['MA0.2FA0.8PbI3'] 51 41
# ['Cs Pb Br'] ['CsPb2Br5'] 19 24
# ['FA MA Br Pb'] ['MA0.6FA0.4PbBr3'] 49 41
# ['MA Pb Br'] ['cubic-MAPbBr3'] 59 24
# ['Br MA Pb'] ['tetragonal-MAPbBr3'] 60 55
# ['Br Pb MA I'] ['MAPb(Br0.6I0.4)3'] 57 41
# ['Cs Pb I'] ['delta-CsPbI3'] 37 13
# ['Pb Cl Br Cs'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['Pb I MA Cs'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Pb Cs FA Br'] ['Cs0.2FA0.8PbBr3'] 0 24
# ['FA I Pb'] ['beta-FAPbI3'] 45 55
# ['I Pb FA MA'] ['MA0.8FA0.2PbI3'] 54 41
# ['Pb FA Br MA'] ['MA0.4FA0.6PbBr3'] 48 41
# ['I FA Pb'] ['beta-FAPbI3'] 45 55
# ['Pb I FA Cs'] ['Cs0.4FA0.6PbI3'] 5 41
# ['Br FA Pb'] ['cubic-FAPbBr3'] 43 55
# ['FA MA Pb I'] ['MA0.2FA0.8PbI3'] 51 41
# ['Pb FA Br MA'] ['MA0.6FA0.4PbBr3'] 49 41
# ['Pb Cs Br I'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['Pb Br Cs'] ['CsPb2Br5'] 19 55
# ['Br Pb Cs'] ['cubic-CsPbBr3'] 32 55
# ['FA Pb Br Cs'] ['Cs0.6FA0.4PbBr3'] 2 41
# ['FA Pb Cs Br'] ['Cs0.4FA0.6PbBr3'] 1 24
# ['MA Br Cs Pb'] ['Cs0.2MA0.8PbBr3'] 8 41
# ['Br Pb Cs I'] ['CsPb(I0.2Br0.8)3'] 24 41
# ['I FA Br Pb'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['Pb Cs FA Br'] ['Cs0.4FA0.6PbBr3'] 1 24
# ['Cs FA I Pb'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Br Cs I Pb'] ['CsPb(I0.2Br0.8)3'] 24 41
# ['Cl I Cs Pb'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['Cl Pb Cs I'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['Pb Br Cl Cs'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['I Cs Pb MA'] ['Cs0.4MA0.6PbI3'] 13 41
# ['Pb FA I Cs'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Pb Br'] ['PbBr2'] 64 24
# ['Br Pb Cs MA'] ['Cs0.2MA0.8PbBr3'] 8 41
# ['Pb I Cs MA'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Cs Pb MA Br'] ['Cs0.4MA0.6PbBr3'] 9 24
# ['Pb Cl Cs I'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['FA Pb I'] ['alpha-FAPbI3'] 44 13
# ['Pb Cl Cs Br'] ['CsPb(Cl0.4Br0.6)3'] 21 24
# ['Pb I Cs Cl'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['I Cs Pb FA'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Cl Cs Pb'] ['Pnma-CsPbCl3'] 34 55
# ['MA I Pb'] ['alpha-MAPbI3'] 62 55
# ['I MA Br Pb'] ['MAPb(Br0.8I0.2)3'] 58 41
# ['Cs Pb I MA'] ['Cs0.6MA0.4PbI3'] 14 41
# ['Cl Pb Cs I'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Cs Cl Pb'] ['Pnma-CsPbCl3'] 34 55
# ['Pb Cs Cl I'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['I FA Pb Cs'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Br FA Pb'] ['cubic-FAPbBr3'] 43 55
# ['Pb Cs I Br'] ['CsPb(I0.8Br0.2)3'] 27 24
# ['I Cs MA Pb'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Pb FA MA Br'] ['MA0.8FA0.2PbBr3'] 50 24
# ['MA I Pb Br'] ['MAPb(Br0.4I0.6)3'] 56 24
# ['Cs Cl Br Pb'] ['CsPb(Cl0.2Br0.8)3'] 20 41
# ['I Pb MA'] ['alpha-MAPbI3'] 62 33
# ['Br Cs FA Pb'] ['Cs0.6FA0.4PbBr3'] 2 41
# ['Pb Cl Br Cs'] ['CsPb(Cl0.2Br0.8)3'] 20 41
# ['FA Pb I Br'] ['FAPb(Br0.6I0.4)3'] 41 24
# ['Br Pb FA MA'] ['MA0.8FA0.2PbBr3'] 50 41
# ['Br Pb Cs FA'] ['Cs0.6FA0.4PbBr3'] 2 41
# ['MA FA Pb Br'] ['MA0.4FA0.6PbBr3'] 48 24
# ['Br Cs I Pb'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['FA I Pb'] ['alpha-FAPbI3'] 44 55
# ['FA Pb Br'] ['cubic-FAPbBr3'] 43 24
# ['I Cs Pb'] ['alpha-CsPbI3'] 36 55
# ['Pb I FA MA'] ['MA0.4FA0.6PbI3'] 52 41
# ['Br MA Cs Pb'] ['Cs0.4MA0.6PbBr3'] 9 41
# ['I Cs Pb'] ['gamma-CsPbI3'] 38 55
# ['I MA Pb FA'] ['MA0.4FA0.6PbI3'] 52 41
# ['FA MA Pb I'] ['MA0.8FA0.2PbI3'] 54 41
# ['Cs Pb I MA'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Pb I Cl Cs'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['I Pb FA Cs'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Pb Cs Cl'] ['Pnma-CsPbCl3'] 34 55
# ['Br I FA Pb'] ['FAPb(Br0.4I0.6)3'] 40 41
# ['I Br MA Pb'] ['MAPb(Br0.2I0.8)3'] 55 41
# ['Pb Cl Br Cs'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['Cl Pb Br Cs'] ['CsPb(Cl0.2Br0.8)3'] 20 41
# ['Pb MA FA I'] ['MA0.8FA0.2PbI3'] 54 41
# ['Cs I MA Pb'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Br Cs Pb'] ['orthorhombic-CsPbBr3'] 33 55
# ['MA Br Pb'] ['cubic-MAPbBr3'] 59 55
# ['Br MA I Pb'] ['MAPb(Br0.2I0.8)3'] 55 41
# ['Cs Pb Br'] ['Cs4PbBr6'] 16 24
# ['Br Pb Cs'] ['Cs4PbBr6'] 16 55
# ['FA Pb Cs Br'] ['Cs0.2FA0.8PbBr3'] 0 24
# ['Br MA Pb I'] ['MAPb(Br0.4I0.6)3'] 56 41
# ['I Br Pb MA'] ['MAPb(Br0.2I0.8)3'] 55 41
# ['Cs I Pb'] ['alpha-CsPbI3'] 36 55
# ['I Br Pb MA'] ['MAPb(Br0.8I0.2)3'] 58 41
# ['Br Pb Cs'] ['CsPb2Br5'] 19 55
# ['FA I Br Pb'] ['FAPb(Br0.2I0.8)3'] 39 41
# ['I Cs'] ['CsI'] 18 6
# ['Cs Cl Br Pb'] ['CsPb(Cl0.2Br0.8)3'] 20 41
# ['I Pb FA'] ['alpha-FAPbI3'] 44 43
# ['Pb Cl Cs I'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Pb Br FA MA'] ['MA0.4FA0.6PbBr3'] 48 41
# ['Cl Cs Pb I'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Br Cs Pb'] ['cubic-CsPbBr3'] 32 55
# ['FA Pb MA Br'] ['MA0.4FA0.6PbBr3'] 48 24
# ['Cs I Pb'] ['delta-CsPbI3'] 37 55
# ['Cs Br FA Pb'] ['Cs0.2FA0.8PbBr3'] 0 41
# ['I Cs Pb MA'] ['Cs0.8MA0.2PbI3'] 15 41
# ['FA Br Cs Pb'] ['Cs0.6FA0.4PbBr3'] 2 41
# ['MA Pb Cl'] ['Pnma-MAPbCl3'] 61 55
# ['Cs Pb I MA'] ['Cs0.4MA0.6PbI3'] 13 41
# ['Br Cs Pb Cl'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['FA Pb Cs I'] ['Cs0.8FA0.2PbI3'] 7 41
# ['I MA FA Pb'] ['MA0.8FA0.2PbI3'] 54 41
# ['Pb Cl Cs Br'] ['CsPb(Cl0.4Br0.6)3'] 21 24
# ['Cs Br Pb FA'] ['Cs0.8FA0.2PbBr3'] 3 41
# ['Cs Cl Pb I'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['MA Pb I FA'] ['MA0.2FA0.8PbI3'] 51 41
# ['Cl Br Pb Cs'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['Pb Cs I Br'] ['CsPb(I0.8Br0.2)3'] 27 24
# ['Br Pb'] ['PbBr2'] 64 55
# ['Br FA Pb Cs'] ['Cs0.8FA0.2PbBr3'] 3 41
# ['Br Pb Cs'] ['cubic-CsPbBr3'] 32 55
# ['Cs Pb Cl I'] ['CsPb(I0.6Cl0.4)3'] 30 41
# ['Pb Cs Br'] ['cubic-CsPbBr3'] 32 24
# ['I Pb MA Br'] ['MAPb(Br0.6I0.4)3'] 57 24
# ['Cs I Pb'] ['delta-CsPbI3'] 37 55
# ['I FA Pb'] ['delta-FAPbI3'] 46 55
# ['Cl Cs Br Pb'] ['CsPb(Cl0.2Br0.8)3'] 20 41
# ['Cs Pb Br'] ['orthorhombic-CsPbBr3'] 33 24
# ['MA I FA Pb'] ['MA0.6FA0.4PbI3'] 53 41
# ['Cl Br Pb Cs'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['FA Pb Br I'] ['FAPb(Br0.8I0.2)3'] 42 41
# ['Br Pb Cs'] ['orthorhombic-CsPbBr3'] 33 55
# ['Cs Pb Br FA'] ['Cs0.4FA0.6PbBr3'] 1 41
# ['Pb MA Br'] ['cubic-MAPbBr3'] 59 24
# ['Br Cs MA Pb'] ['Cs0.6MA0.4PbBr3'] 10 41
# ['I Pb'] ['PbI2'] 65 55
# ['Cs I'] ['CsI'] 18 14
# ['I Cs Pb Br'] ['CsPb(I0.2Br0.8)3'] 24 24
# ['MA Br Pb'] ['cubic-MAPbBr3'] 59 55
# ['Pb Cs I Cl'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['I Cs Pb'] ['delta-CsPbI3'] 37 55
# ['I Cs Pb Br'] ['CsPb(I0.2Br0.8)3'] 24 24
# ['MA Cl Pb'] ['Pnma-MAPbCl3'] 61 55
# ['Pb MA Br Cs'] ['Cs0.4MA0.6PbBr3'] 9 41
# ['Pb FA I MA'] ['MA0.4FA0.6PbI3'] 52 41
# ['Br MA FA Pb'] ['MA0.2FA0.8PbBr3'] 47 41
# ['Pb I Cs'] ['alpha-CsPbI3'] 36 55
# ['Pb I Br FA'] ['FAPb(Br0.2I0.8)3'] 39 41
# ['Pb Br MA'] ['cubic-MAPbBr3'] 59 33
# ['Pb MA I'] ['tetragonal-MAPbI3'] 63 13
# ['Cs MA Pb I'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Br Pb I FA'] ['FAPb(Br0.4I0.6)3'] 40 41
# ['Pb I Br MA'] ['MAPb(Br0.4I0.6)3'] 56 41
# ['I Cs Br Pb'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['Pb I Cs'] ['alpha-CsPbI3'] 36 55
# ['Pb Br Cs I'] ['CsPb(I0.4Br0.6)3'] 25 41
# ['Cs Br'] ['CsBr'] 17 24
# ['MA Br Pb'] ['cubic-MAPbBr3'] 59 55
# ['FA Pb I'] ['alpha-FAPbI3'] 44 13
# ['Cs Br Pb FA'] ['Cs0.8FA0.2PbBr3'] 3 41
# ['Br FA I Pb'] ['FAPb(Br0.2I0.8)3'] 39 41
# ['I Cl Pb Cs'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['MA Pb Br'] ['tetragonal-MAPbBr3'] 60 24
# ['Pb Br Cs'] ['Cs4PbBr6'] 16 55
# ['Br MA Pb'] ['cubic-MAPbBr3'] 59 55
# ['Pb Cs FA Br'] ['Cs0.4FA0.6PbBr3'] 1 24
# ['I Cs Cl Pb'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Pb I FA'] ['beta-FAPbI3'] 45 43
# ['I Pb FA'] ['delta-FAPbI3'] 46 43
# ['Cs FA Pb I'] ['Cs0.2FA0.8PbI3'] 4 41
# ['I Pb Cl Cs'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['Pb I Cs'] ['delta-CsPbI3'] 37 55
# ['Cs Pb Br Cl'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['Cs Br Pb'] ['orthorhombic-CsPbBr3'] 33 55
# ['I Cs Cl Pb'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['Pb I FA Cs'] ['Cs0.8FA0.2PbI3'] 7 41
# ['Pb Cs I MA'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Br Pb FA Cs'] ['Cs0.4FA0.6PbBr3'] 1 41
# ['FA Pb I'] ['alpha-FAPbI3'] 44 13
# ['I Cs'] ['CsI'] 18 6
# ['Cs Cl Pb Br'] ['CsPb(Cl0.8Br0.2)3'] 23 24
# ['Pb Cs I FA'] ['Cs0.4FA0.6PbI3'] 5 41
# ['Cs Br FA Pb'] ['Cs0.4FA0.6PbBr3'] 1 41
# ['MA Pb Cs I'] ['Cs0.4MA0.6PbI3'] 13 41
# ['Br Pb I MA'] ['MAPb(Br0.4I0.6)3'] 56 41
# ['FA Pb I Cs'] ['Cs0.4FA0.6PbI3'] 5 41
# ['Br Cs Cl Pb'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['Cs Pb I Cl'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['I Cs FA Pb'] ['Cs0.2FA0.8PbI3'] 4 41
# ['MA I Pb'] ['alpha-MAPbI3'] 62 55
# ['FA I Pb Cs'] ['Cs0.4FA0.6PbI3'] 5 41
# ['I MA Pb Cs'] ['Cs0.8MA0.2PbI3'] 15 41
# ['I MA Pb'] ['alpha-MAPbI3'] 62 55
# ['I Pb MA Cs'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Pb MA I Br'] ['MAPb(Br0.2I0.8)3'] 55 24
# ['I Pb MA'] ['alpha-MAPbI3'] 62 33
# ['Cl Pb Cs'] ['Pnma-CsPbCl3'] 34 55
# ['FA Pb I Br'] ['FAPb(Br0.8I0.2)3'] 42 24
# ['MA I Pb'] ['alpha-MAPbI3'] 62 55
# ['Cl Br Pb Cs'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['Cs Pb I Cl'] ['CsPb(I0.6Cl0.4)3'] 30 41
# ['Br Pb Cs I'] ['CsPb(I0.8Br0.2)3'] 27 41
# ['Br Pb I Cs'] ['CsPb(I0.4Br0.6)3'] 25 41
# ['Pb Br MA FA'] ['MA0.6FA0.4PbBr3'] 49 41
# ['Pb I Cs'] ['alpha-CsPbI3'] 36 55
# ['Cs Pb I'] ['alpha-CsPbI3'] 36 13
# ['Br Cs Pb'] ['orthorhombic-CsPbBr3'] 33 55
# ['MA Pb I Br'] ['MAPb(Br0.6I0.4)3'] 57 24
# ['FA I MA Pb'] ['MA0.2FA0.8PbI3'] 51 41
# ['Pb I MA'] ['alpha-MAPbI3'] 62 33
# ['Cs Pb I'] ['alpha-CsPbI3'] 36 13
# ['MA Cs Br Pb'] ['Cs0.6MA0.4PbBr3'] 10 41
# ['Cs Pb Br I'] ['CsPb(I0.8Br0.2)3'] 27 41
# ['Cs I Pb'] ['gamma-CsPbI3'] 38 55
# ['Pb Cs MA I'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Cs Pb MA I'] ['Cs0.8MA0.2PbI3'] 15 41
# ['I Pb FA'] ['beta-FAPbI3'] 45 43
# ['Pb Cl I Cs'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['Cs I Pb'] ['delta-CsPbI3'] 37 55
# ['Pb MA Br I'] ['MAPb(Br0.2I0.8)3'] 55 41
# ['MA FA Pb Br'] ['MA0.6FA0.4PbBr3'] 49 24
# ['Pb I Cs'] ['gamma-CsPbI3'] 38 55
# ['Pb Cl Br Cs'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['Br Cs Pb'] ['orthorhombic-CsPbBr3'] 33 55
# ['I MA Br Pb'] ['MAPb(Br0.6I0.4)3'] 57 41
# ['Pb I MA FA'] ['MA0.6FA0.4PbI3'] 53 41
# ['Cs Pb Br'] ['orthorhombic-CsPbBr3'] 33 24
# ['Cl Br Cs Pb'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['MA Br FA Pb'] ['MA0.6FA0.4PbBr3'] 49 41
# ['Cl Pb Br Cs'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['I Pb'] ['PbI2'] 65 32
# ['MA Cs Br Pb'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['FA Br Pb Cs'] ['Cs0.2FA0.8PbBr3'] 0 41
# ['Pb MA Br'] ['cubic-MAPbBr3'] 59 24
# ['MA Pb Br Cs'] ['Cs0.2MA0.8PbBr3'] 8 41
# ['I Cs Pb'] ['alpha-CsPbI3'] 36 55
# ['FA MA Br Pb'] ['MA0.4FA0.6PbBr3'] 48 41
# ['Br Pb Cs MA'] ['Cs0.6MA0.4PbBr3'] 10 41
# ['MA I Cs Pb'] ['Cs0.6MA0.4PbI3'] 14 41
# ['Cs Pb MA I'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Cs I Pb Cl'] ['CsPb(I0.8Cl0.2)3'] 31 41
# ['I Pb'] ['PbI2'] 65 55
# ['I Pb MA'] ['alpha-MAPbI3'] 62 33
# ['Cs Pb Br'] ['cubic-CsPbBr3'] 32 24
# ['Cl I Pb Cs'] ['CsPb(I0.8Cl0.2)3'] 31 41
# ['Cs Cl Pb'] ['Pnma-CsPbCl3'] 34 55
# ['I Pb FA MA'] ['MA0.2FA0.8PbI3'] 51 41
# ['I Cs FA Pb'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Cl Cs Pb'] ['cubic-CsPbCl3'] 35 55
# ['I Cs MA Pb'] ['Cs0.6MA0.4PbI3'] 14 41
# ['I FA Pb Cs'] ['Cs0.4FA0.6PbI3'] 5 41
# ['Br FA Pb I'] ['FAPb(Br0.2I0.8)3'] 39 41
# ['I Br Pb FA'] ['FAPb(Br0.4I0.6)3'] 40 41
# ['Br Pb MA'] ['tetragonal-MAPbBr3'] 60 33
# ['FA I MA Pb'] ['MA0.2FA0.8PbI3'] 51 41
# ['MA I Cs Pb'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Pb Cl Cs'] ['Pnma-CsPbCl3'] 34 55
# ['Cs Br Pb'] ['cubic-CsPbBr3'] 32 55
# ['FA I Br Pb'] ['FAPb(Br0.4I0.6)3'] 40 41
# ['Pb Br FA Cs'] ['Cs0.2FA0.8PbBr3'] 0 41
# ['Pb FA I'] ['alpha-FAPbI3'] 44 13
# ['MA Pb I'] ['alpha-MAPbI3'] 62 13
# ['Cs I FA Pb'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Pb Br I MA'] ['MAPb(Br0.2I0.8)3'] 55 41
# ['Pb I Cl Cs'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Cs Cl Br Pb'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['Pb Cs MA I'] ['Cs0.6MA0.4PbI3'] 14 41
# ['MA I Cs Pb'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Cs MA Pb I'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Br Pb I FA'] ['FAPb(Br0.8I0.2)3'] 42 41
# ['Pb I FA MA'] ['MA0.4FA0.6PbI3'] 52 41
# ['Cs Br'] ['CsBr'] 17 24
# ['MA Br Pb'] ['tetragonal-MAPbBr3'] 60 55
# ['Pb FA Br'] ['cubic-FAPbBr3'] 43 24
# ['Cs I'] ['CsI'] 18 14
# ['Cs I'] ['CsI'] 18 14
# ['Pb I FA'] ['alpha-FAPbI3'] 44 43
# ['Cs I'] ['CsI'] 18 14
# ['I FA Pb'] ['alpha-FAPbI3'] 44 55
# ['Br Cs'] ['CsBr'] 17 6
# ['Pb Cl Cs Br'] ['CsPb(Cl0.2Br0.8)3'] 20 24
# ['I FA Pb Br'] ['FAPb(Br0.4I0.6)3'] 40 24
# ['Br I Pb FA'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['I Cs MA Pb'] ['Cs0.4MA0.6PbI3'] 13 41
# ['I MA FA Pb'] ['MA0.4FA0.6PbI3'] 52 41
# ['Pb I MA'] ['alpha-MAPbI3'] 62 33
# ['FA Cs Pb I'] ['Cs0.8FA0.2PbI3'] 7 41
# ['Cl Cs Pb'] ['Pnma-CsPbCl3'] 34 55
# ['Pb Br MA I'] ['MAPb(Br0.4I0.6)3'] 56 41
# ['FA I Pb MA'] ['MA0.4FA0.6PbI3'] 52 41
# ['Br FA Cs Pb'] ['Cs0.4FA0.6PbBr3'] 1 41
# ['I Pb FA Cs'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Pb Cs Br Cl'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['Pb FA Br Cs'] ['Cs0.8FA0.2PbBr3'] 3 41
# ['MA Br Pb'] ['tetragonal-MAPbBr3'] 60 55
# ['Br FA Pb MA'] ['MA0.2FA0.8PbBr3'] 47 41
# ['Cs I Br Pb'] ['CsPb(I0.8Br0.2)3'] 27 41
# ['Cs Cl Br Pb'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['Cs I Pb FA'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Br Cs Pb Cl'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['Pb Br Cs I'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['Pb MA Br'] ['tetragonal-MAPbBr3'] 60 24
# ['Cs Br Pb I'] ['CsPb(I0.8Br0.2)3'] 27 41
# ['I Cs'] ['CsI'] 18 6
# ['Br Pb MA Cs'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['Pb MA Br'] ['cubic-MAPbBr3'] 59 24
# ['Pb Cs Cl'] ['cubic-CsPbCl3'] 35 55
# ['Pb I FA MA'] ['MA0.2FA0.8PbI3'] 51 41
# ['Cl Cs Pb Br'] ['CsPb(Cl0.4Br0.6)3'] 21 24
# ['FA Br I Pb'] ['FAPb(Br0.2I0.8)3'] 39 41
# ['Pb Cs Cl Br'] ['CsPb(Cl0.8Br0.2)3'] 23 24
# ['I FA Pb'] ['alpha-FAPbI3'] 44 55
# ['I Pb MA FA'] ['MA0.6FA0.4PbI3'] 53 41
# ['Cs Cl Pb Br'] ['CsPb(Cl0.4Br0.6)3'] 21 24
# ['FA MA Pb I'] ['MA0.8FA0.2PbI3'] 54 41
# ['Pb Cs Br'] ['cubic-CsPbBr3'] 32 24
# ['I Pb Cs Br'] ['CsPb(I0.2Br0.8)3'] 24 24
# ['Cs I Cl Pb'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['Pb MA Cs I'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Cs Pb Br MA'] ['Cs0.4MA0.6PbBr3'] 9 41
# ['Cl I Cs Pb'] ['CsPb(I0.6Cl0.4)3'] 30 41
# ['Cs Br'] ['CsBr'] 17 24
# ['Pb MA Br'] ['tetragonal-MAPbBr3'] 60 24
# ['FA Pb Br MA'] ['MA0.4FA0.6PbBr3'] 48 41
# ['MA Br Pb FA'] ['MA0.8FA0.2PbBr3'] 50 41
# ['MA Br Pb I'] ['MAPb(Br0.2I0.8)3'] 55 41
# ['Cs I FA Pb'] ['Cs0.8FA0.2PbI3'] 7 41
# ['FA MA Br Pb'] ['MA0.6FA0.4PbBr3'] 49 41
# ['MA I Pb Cs'] ['Cs0.8MA0.2PbI3'] 15 41
# ['MA Pb Cs I'] ['Cs0.8MA0.2PbI3'] 15 41
# ['MA Pb I FA'] ['MA0.8FA0.2PbI3'] 54 41
# ['I Pb MA Br'] ['MAPb(Br0.2I0.8)3'] 55 24
# ['MA Br Pb Cs'] ['Cs0.4MA0.6PbBr3'] 9 41
# ['Pb MA Br FA'] ['MA0.8FA0.2PbBr3'] 50 41
# ['Pb Cs Cl Br'] ['CsPb(Cl0.8Br0.2)3'] 23 24
# ['Pb FA Br I'] ['FAPb(Br0.2I0.8)3'] 39 41
# ['Br I Pb MA'] ['MAPb(Br0.6I0.4)3'] 57 41
# ['Cs Pb Br MA'] ['Cs0.2MA0.8PbBr3'] 8 41
# ['MA FA Br Pb'] ['MA0.2FA0.8PbBr3'] 47 41
# ['Cs I'] ['CsI'] 18 14
# ['Cs I Pb'] ['delta-CsPbI3'] 37 55
# ['Cs MA Pb I'] ['Cs0.8MA0.2PbI3'] 15 41
# ['I Pb MA'] ['tetragonal-MAPbI3'] 63 33
# ['FA Cs Pb Br'] ['Cs0.6FA0.4PbBr3'] 2 24
# ['Pb Br'] ['PbBr2'] 64 24
# ['MA Br FA Pb'] ['MA0.6FA0.4PbBr3'] 49 41
# ['Cl Pb MA'] ['Pnma-MAPbCl3'] 61 33
# ['Pb Br Cs'] ['cubic-CsPbBr3'] 32 55
# ['I MA Pb Br'] ['MAPb(Br0.8I0.2)3'] 58 24
# ['MA Pb Cs I'] ['Cs0.6MA0.4PbI3'] 14 41
# ['Pb Cs Br FA'] ['Cs0.8FA0.2PbBr3'] 3 41
# ['Pb Br'] ['PbBr2'] 64 24
# ['Pb Cl Cs I'] ['CsPb(I0.8Cl0.2)3'] 31 41
# ['Cs Cl I Pb'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['Pb Cs I'] ['delta-CsPbI3'] 37 13
# ['Br I MA Pb'] ['MAPb(Br0.8I0.2)3'] 58 41
# ['Cs FA Pb I'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Pb FA I MA'] ['MA0.8FA0.2PbI3'] 54 41
# ['Pb Cs I'] ['alpha-CsPbI3'] 36 13
# ['Cl Br Pb Cs'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['I Pb MA'] ['alpha-MAPbI3'] 62 33
# ['Pb Br I FA'] ['FAPb(Br0.8I0.2)3'] 42 41
# ['Pb Cl Br Cs'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['FA MA I Pb'] ['MA0.6FA0.4PbI3'] 53 41
# ['Br Pb Cl Cs'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['Cs I Pb'] ['delta-CsPbI3'] 37 55
# ['Pb Cs Cl'] ['cubic-CsPbCl3'] 35 55
# ['I FA Pb Cs'] ['Cs0.4FA0.6PbI3'] 5 41
# ['Pb Cs Br Cl'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['Cs MA Pb Br'] ['Cs0.8MA0.2PbBr3'] 11 24
# ['Br Pb Cs Cl'] ['CsPb(Cl0.2Br0.8)3'] 20 41
# ['I MA FA Pb'] ['MA0.8FA0.2PbI3'] 54 41
# ['Br Pb MA Cs'] ['Cs0.6MA0.4PbBr3'] 10 41
# ['Cs Br Pb MA'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['MA Cs I Pb'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Cs Br Pb Cl'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['Pb Cs Cl I'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['I Pb'] ['PbI2'] 65 55
# ['Cs FA Br Pb'] ['Cs0.6FA0.4PbBr3'] 2 41
# ['FA Pb I Cs'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Cs Pb I MA'] ['Cs0.6MA0.4PbI3'] 14 41
# ['MA Pb Br'] ['tetragonal-MAPbBr3'] 60 24
# ['Cs Cl Br Pb'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['I Pb Cs'] ['gamma-CsPbI3'] 38 55
# ['Cs Br MA Pb'] ['Cs0.6MA0.4PbBr3'] 10 41
# ['Cs Br Pb I'] ['CsPb(I0.2Br0.8)3'] 24 41
# ['Pb I Br Cs'] ['CsPb(I0.8Br0.2)3'] 27 41
# ['Pb MA Br FA'] ['MA0.6FA0.4PbBr3'] 49 41
# ['MA Br FA Pb'] ['MA0.2FA0.8PbBr3'] 47 41
# ['Br Pb MA Cs'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['Pb FA MA I'] ['MA0.4FA0.6PbI3'] 52 41
# ['Cl Br Cs Pb'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['Pb Br MA FA'] ['MA0.4FA0.6PbBr3'] 48 41
# ['I Cl Pb Cs'] ['CsPb(I0.6Cl0.4)3'] 30 41
# ['Cs MA Pb I'] ['Cs0.6MA0.4PbI3'] 14 41
# ['Pb I Cs MA'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Br Pb Cl Cs'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['I FA Br Pb'] ['FAPb(Br0.4I0.6)3'] 40 41
# ['Pb Cl Cs I'] ['CsPb(I0.6Cl0.4)3'] 30 41
# ['Pb Cs Br I'] ['CsPb(I0.4Br0.6)3'] 25 41
# ['I FA Cs Pb'] ['Cs0.4FA0.6PbI3'] 5 41
# ['MA Pb I Cs'] ['Cs0.8MA0.2PbI3'] 15 41
# ['I Br MA Pb'] ['MAPb(Br0.4I0.6)3'] 56 41
# ['Pb MA FA Br'] ['MA0.6FA0.4PbBr3'] 49 24
# ['Pb MA Cs I'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Cl Cs I Pb'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['Cs Br Pb FA'] ['Cs0.6FA0.4PbBr3'] 2 41
# ['MA Cs Pb Br'] ['Cs0.2MA0.8PbBr3'] 8 24
# ['Cs Br'] ['CsBr'] 17 24
# ['I FA Pb Br'] ['FAPb(Br0.4I0.6)3'] 40 24
# ['I MA Pb FA'] ['MA0.4FA0.6PbI3'] 52 41
# ['FA Pb Cs I'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Br Cs I Pb'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['I Pb'] ['PbI2'] 65 32
# ['Pb FA I'] ['beta-FAPbI3'] 45 13
# ['Br Cl Cs Pb'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['Pb I Cs'] ['delta-CsPbI3'] 37 55
# ['Cs Br Cl Pb'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['MA Pb I Br'] ['MAPb(Br0.8I0.2)3'] 58 24
# ['Br Cs Cl Pb'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['Cs Pb Br'] ['orthorhombic-CsPbBr3'] 33 24
# ['Cl Cs I Pb'] ['CsPb(I0.8Cl0.2)3'] 31 41
# ['I Cs FA Pb'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Pb MA I'] ['tetragonal-MAPbI3'] 63 13
# ['Pb Br FA I'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['I Br MA Pb'] ['MAPb(Br0.2I0.8)3'] 55 41
# ['FA Pb Br I'] ['FAPb(Br0.8I0.2)3'] 42 41
# ['Pb Cl Cs'] ['Pnma-CsPbCl3'] 34 55
# ['Pb Cs I FA'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Br Cs Pb'] ['Cs4PbBr6'] 16 55
# ['I Pb Cl Cs'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['FA Cs I Pb'] ['Cs0.8FA0.2PbI3'] 7 41
# ['Cs Br FA Pb'] ['Cs0.2FA0.8PbBr3'] 0 41
# ['I Pb MA FA'] ['MA0.4FA0.6PbI3'] 52 41
# ['I Cs Cl Pb'] ['CsPb(I0.8Cl0.2)3'] 31 41
# ['Br Cs Pb'] ['cubic-CsPbBr3'] 32 55
# ['Cl Br Pb Cs'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['Pb Cs I'] ['delta-CsPbI3'] 37 13
# ['I Cs MA Pb'] ['Cs0.6MA0.4PbI3'] 14 41
# ['Br Cs'] ['CsBr'] 17 6
# ['Pb Cs Br'] ['CsPb2Br5'] 19 24
# ['Pb I MA Br'] ['MAPb(Br0.6I0.4)3'] 57 24
# ['Br FA Pb'] ['cubic-FAPbBr3'] 43 55
# ['Pb Cs Cl'] ['Pnma-CsPbCl3'] 34 55
# ['Br Cs FA Pb'] ['Cs0.8FA0.2PbBr3'] 3 41
# ['Cs Cl Pb'] ['Pnma-CsPbCl3'] 34 55
# ['Br I Pb FA'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['Pb Br Cs'] ['CsPb2Br5'] 19 55
# ['Cs Pb FA Br'] ['Cs0.8FA0.2PbBr3'] 3 24
# ['Cs Pb Cl'] ['cubic-CsPbCl3'] 35 55
# ['I Cs FA Pb'] ['Cs0.8FA0.2PbI3'] 7 41
# ['I Pb FA MA'] ['MA0.8FA0.2PbI3'] 54 41
# ['MA I FA Pb'] ['MA0.2FA0.8PbI3'] 51 41
# ['I MA Cs Pb'] ['Cs0.8MA0.2PbI3'] 15 41
# ['FA I Pb MA'] ['MA0.2FA0.8PbI3'] 51 41
# ['FA Br Pb Cs'] ['Cs0.2FA0.8PbBr3'] 0 41
# ['Pb Br MA'] ['cubic-MAPbBr3'] 59 33
# ['I Pb Cs'] ['delta-CsPbI3'] 37 55
# ['MA I Cs Pb'] ['Cs0.6MA0.4PbI3'] 14 41
# ['I Cs Pb'] ['alpha-CsPbI3'] 36 55
# ['Br MA Cs Pb'] ['Cs0.4MA0.6PbBr3'] 9 41
# ['Br MA Pb FA'] ['MA0.6FA0.4PbBr3'] 49 41
# ['MA Cl Pb'] ['Pnma-MAPbCl3'] 61 55
# ['MA I Pb FA'] ['MA0.6FA0.4PbI3'] 53 41
# ['Pb I Cs Br'] ['CsPb(I0.2Br0.8)3'] 24 24
# ['I Cs MA Pb'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Pb Br Cs MA'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['Pb Br MA'] ['tetragonal-MAPbBr3'] 60 33
# ['MA I FA Pb'] ['MA0.8FA0.2PbI3'] 54 41
# ['Cs Pb Br'] ['orthorhombic-CsPbBr3'] 33 24
# ['Br Pb'] ['PbBr2'] 64 32
# ['Pb Br FA I'] ['FAPb(Br0.2I0.8)3'] 39 41
# ['Pb FA MA Br'] ['MA0.6FA0.4PbBr3'] 49 24
# ['Pb Cs Br'] ['Cs4PbBr6'] 16 24
# ['Pb I Cs MA'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Br Pb I MA'] ['MAPb(Br0.8I0.2)3'] 58 41
# ['Pb Br FA I'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['MA Pb Br'] ['tetragonal-MAPbBr3'] 60 24
# ['Br Cs Pb'] ['cubic-CsPbBr3'] 32 55
# ['Br Cs MA Pb'] ['Cs0.4MA0.6PbBr3'] 9 41
# ['Pb Cs Br'] ['CsPb2Br5'] 19 24
# ['Br FA MA Pb'] ['MA0.4FA0.6PbBr3'] 48 41
# ['FA I Pb MA'] ['MA0.8FA0.2PbI3'] 54 41
# ['I Br Cs Pb'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['MA FA Pb Br'] ['MA0.6FA0.4PbBr3'] 49 24
# ['Pb Cs I'] ['alpha-CsPbI3'] 36 13
# ['FA I Pb Br'] ['FAPb(Br0.4I0.6)3'] 40 24
# ['Pb Br Cl Cs'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['MA Pb I FA'] ['MA0.8FA0.2PbI3'] 54 41
# ['Cs MA Pb Br'] ['Cs0.4MA0.6PbBr3'] 9 24
# ['Pb Br I Cs'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['Cs Br Pb MA'] ['Cs0.6MA0.4PbBr3'] 10 41
# ['Pb FA I MA'] ['MA0.2FA0.8PbI3'] 51 41
# ['I Cs MA Pb'] ['Cs0.6MA0.4PbI3'] 14 41
# ['Cs FA I Pb'] ['Cs0.6FA0.4PbI3'] 6 41
# ['Pb FA I'] ['delta-FAPbI3'] 46 13
# ['Cs I'] ['CsI'] 18 14
# ['Pb Br Cs'] ['orthorhombic-CsPbBr3'] 33 55
# ['Pb FA I'] ['delta-FAPbI3'] 46 13
# ['Pb MA Cs I'] ['Cs0.4MA0.6PbI3'] 13 41
# ['Pb I Cs'] ['alpha-CsPbI3'] 36 55
# ['Br Cl Cs Pb'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['Pb Cs Br Cl'] ['CsPb(Cl0.2Br0.8)3'] 20 41
# ['FA Br Pb'] ['cubic-FAPbBr3'] 43 55
# ['I Pb'] ['PbI2'] 65 55
# ['Cl Br Cs Pb'] ['CsPb(Cl0.2Br0.8)3'] 20 41
# ['Pb Cs Br Cl'] ['CsPb(Cl0.2Br0.8)3'] 20 41
# ['Br FA Cs Pb'] ['Cs0.2FA0.8PbBr3'] 0 41
# ['Pb FA Br I'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['Cs FA I Pb'] ['Cs0.8FA0.2PbI3'] 7 41
# ['FA Pb MA I'] ['MA0.2FA0.8PbI3'] 51 41
# ['Pb Cl Cs'] ['Pnma-CsPbCl3'] 34 55
# ['Pb I Br Cs'] ['CsPb(I0.2Br0.8)3'] 24 41
# ['Br MA Pb I'] ['MAPb(Br0.6I0.4)3'] 57 41
# ['Cs Br'] ['CsBr'] 17 24
# ['Cl I Pb Cs'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['Pb MA FA Br'] ['MA0.2FA0.8PbBr3'] 47 24
# ['I Pb'] ['PbI2'] 65 32
# ['MA Pb Cl'] ['Pnma-MAPbCl3'] 61 55
# ['I FA Pb'] ['alpha-FAPbI3'] 44 55
# ['Br Pb MA FA'] ['MA0.8FA0.2PbBr3'] 50 41
# ['Pb Br Cs'] ['CsPb2Br5'] 19 55
# ['Cs I'] ['CsI'] 18 14
# ['FA Pb I Cs'] ['Cs0.8FA0.2PbI3'] 7 41
# ['I Pb FA Cs'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Br MA Pb'] ['cubic-MAPbBr3'] 59 55
# ['FA Br Pb Cs'] ['Cs0.8FA0.2PbBr3'] 3 41
# ['FA I MA Pb'] ['MA0.4FA0.6PbI3'] 52 41
# ['Br FA Cs Pb'] ['Cs0.4FA0.6PbBr3'] 1 41
# ['I Pb FA'] ['beta-FAPbI3'] 45 43
# ['Pb FA I'] ['delta-FAPbI3'] 46 13
# ['Br Pb FA'] ['cubic-FAPbBr3'] 43 43
# ['Cs Cl I Pb'] ['CsPb(I0.6Cl0.4)3'] 30 41
# ['Cl I Pb Cs'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['Br MA Pb'] ['cubic-MAPbBr3'] 59 55
# ['Pb I Cs'] ['alpha-CsPbI3'] 36 55
# ['MA Pb Br FA'] ['MA0.6FA0.4PbBr3'] 49 41
# ['Cl Pb Cs'] ['Pnma-CsPbCl3'] 34 55
# ['Br Pb Cs'] ['CsPb2Br5'] 19 55
# ['I Cs'] ['CsI'] 18 6
# ['I FA Cs Pb'] ['Cs0.4FA0.6PbI3'] 5 41
# ['Pb I Cs'] ['delta-CsPbI3'] 37 55
# ['Cs Pb I MA'] ['Cs0.8MA0.2PbI3'] 15 41
# ['Br FA Pb I'] ['FAPb(Br0.4I0.6)3'] 40 41
# ['Cs Br Pb'] ['Cs4PbBr6'] 16 55
# ['Pb Cl Cs I'] ['CsPb(I0.6Cl0.4)3'] 30 41
# ['Br MA Cs Pb'] ['Cs0.4MA0.6PbBr3'] 9 41
# ['I Br MA Pb'] ['MAPb(Br0.6I0.4)3'] 57 41
# ['MA I Pb Cs'] ['Cs0.4MA0.6PbI3'] 13 41
# ['Cs FA Pb I'] ['Cs0.2FA0.8PbI3'] 4 41
# ['Br I Cs Pb'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['Br Cs Pb'] ['cubic-CsPbBr3'] 32 55
# ['FA I MA Pb'] ['MA0.2FA0.8PbI3'] 51 41
# ['Pb FA I'] ['beta-FAPbI3'] 45 13
# ['Br Pb Cs'] ['Cs4PbBr6'] 16 55
# ['Cs Cl I Pb'] ['CsPb(I0.6Cl0.4)3'] 30 41
# ['I Cs MA Pb'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Pb MA Cs I'] ['Cs0.6MA0.4PbI3'] 14 41
# ['Cs I Pb'] ['delta-CsPbI3'] 37 55
# ['Cs MA Pb Br'] ['Cs0.6MA0.4PbBr3'] 10 24
# ['Cs Pb Br Cl'] ['CsPb(Cl0.8Br0.2)3'] 23 41
# ['Cl I Pb Cs'] ['CsPb(I0.8Cl0.2)3'] 31 41
# ['Br Cs Pb I'] ['CsPb(I0.4Br0.6)3'] 25 41
# ['MA Pb Cl'] ['Pnma-MAPbCl3'] 61 55
# ['Br Cs I Pb'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['Pb I Br FA'] ['FAPb(Br0.2I0.8)3'] 39 41
# ['Br MA Pb'] ['cubic-MAPbBr3'] 59 55
# ['Br Pb MA I'] ['MAPb(Br0.6I0.4)3'] 57 41
# ['MA FA Pb Br'] ['MA0.2FA0.8PbBr3'] 47 24
# ['Cs Br I Pb'] ['CsPb(I0.6Br0.4)3'] 26 41
# ['Pb MA I'] ['tetragonal-MAPbI3'] 63 13
# ['Pb Br Cs'] ['CsPb2Br5'] 19 55
# ['Cl Br Pb Cs'] ['CsPb(Cl0.6Br0.4)3'] 22 41
# ['Pb Br MA I'] ['MAPb(Br0.4I0.6)3'] 56 41
# ['MA Cs Pb I'] ['Cs0.2MA0.8PbI3'] 12 41
# ['MA Pb Br'] ['tetragonal-MAPbBr3'] 60 24
# ['Cl Pb I Cs'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['Cl I Cs Pb'] ['CsPb(I0.8Cl0.2)3'] 31 41
# ['Pb Br Cs'] ['Cs4PbBr6'] 16 55
# ['Br Cl Pb Cs'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['Pb Cs I'] ['gamma-CsPbI3'] 38 13
# ['I Cs'] ['CsI'] 18 6
# ['FA MA Pb I'] ['MA0.4FA0.6PbI3'] 52 41
# ['I Cs Pb MA'] ['Cs0.2MA0.8PbI3'] 12 41
# ['Pb Cs I'] ['delta-CsPbI3'] 37 13
# ['Cl I Pb Cs'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['Pb Br FA I'] ['FAPb(Br0.4I0.6)3'] 40 41
# ['Br Cs Pb Cl'] ['CsPb(Cl0.2Br0.8)3'] 20 41
# ['Cs Pb I'] ['alpha-CsPbI3'] 36 13
# ['Cl Br Pb Cs'] ['CsPb(Cl0.4Br0.6)3'] 21 41
# ['Pb MA Cl'] ['Pnma-MAPbCl3'] 61 55
# ['Cs Pb Br MA'] ['Cs0.8MA0.2PbBr3'] 11 41
# ['Cs I Pb Cl'] ['CsPb(I0.4Cl0.6)3'] 29 41
# ['Pb I'] ['PbI2'] 65 14
# ['Pb MA FA I'] ['MA0.2FA0.8PbI3'] 51 41
# ['I Pb MA Br'] ['MAPb(Br0.4I0.6)3'] 56 24
# ['Pb Cs MA Br'] ['Cs0.6MA0.4PbBr3'] 10 24
# ['Cl Pb I Cs'] ['CsPb(I0.2Cl0.8)3'] 28 41
# ['FA MA Pb Br'] ['MA0.8FA0.2PbBr3'] 50 24
# ...
# ['I Br Pb FA'] ['FAPb(Br0.8I0.2)3'] 42 42
# ['Br Pb MA FA'] ['MA0.8FA0.2PbBr3'] 50 50
# ['Cs MA Pb Br'] ['Cs0.8MA0.2PbBr3'] 11 11
# ['Pb Br Cs'] ['Cs4PbBr6'] 16 16
# ['Pb I FA Br'] ['FAPb(Br0.4I0.6)3'] 40 40
# ['FA Br I Pb'] ['FAPb(Br0.2I0.8)3'] 39 39
# ['FA Br Pb I'] ['FAPb(Br0.8I0.2)3'] 42 42
# ['Pb Cs Cl I'] ['CsPb(I0.6Cl0.4)3'] 30 30
# ['Cs I'] ['CsI'] 18 18
# ['Pb FA Br MA'] ['MA0.4FA0.6PbBr3'] 48 49
# ['Cs I MA Pb'] ['Cs0.2MA0.8PbI3'] 12 12
# ['FA Pb Br'] ['cubic-FAPbBr3'] 43 43
# ['Br Pb'] ['PbBr2'] 64 64
# ['Pb MA Cs Br'] ['Cs0.8MA0.2PbBr3'] 11 11
# ['Pb Cs I FA'] ['Cs0.6FA0.4PbI3'] 6 6
# ['FA MA I Pb'] ['MA0.8FA0.2PbI3'] 54 54
# ['Cs Cl Pb I'] ['CsPb(I0.2Cl0.8)3'] 28 28
# ['FA Pb I'] ['beta-FAPbI3'] 45 45
# ['I Br MA Pb'] ['MAPb(Br0.8I0.2)3'] 58 58
# ['Cs Pb Br'] ['cubic-CsPbBr3'] 32 32
# ['Pb MA Br Cs'] ['Cs0.8MA0.2PbBr3'] 11 11
# ['Cl Cs Pb I'] ['CsPb(I0.8Cl0.2)3'] 31 31
# ['I Pb Br MA'] ['MAPb(Br0.4I0.6)3'] 56 56
# ['FA Pb I'] ['beta-FAPbI3'] 45 45
# ['Cs Pb Br Cl'] ['CsPb(Cl0.4Br0.6)3'] 21 21
# ['I Pb'] ['PbI2'] 65 65
# ['FA Pb I Cs'] ['Cs0.6FA0.4PbI3'] 6 6
# ['Cs FA Pb Br'] ['Cs0.2FA0.8PbBr3'] 0 0
# ['Pb Br MA'] ['cubic-MAPbBr3'] 59 59
# ['I Pb Br MA'] ['MAPb(Br0.2I0.8)3'] 55 58
# ['I Pb'] ['PbI2'] 65 65
# ['Cs Br Pb Cl'] ['CsPb(Cl0.4Br0.6)3'] 21 20
# ['Br Pb MA'] ['tetragonal-MAPbBr3'] 60 60
# ['MA Pb Cs I'] ['Cs0.8MA0.2PbI3'] 15 15
# ['Cs Pb MA I'] ['Cs0.6MA0.4PbI3'] 14 13
# ['MA FA Pb Br'] ['MA0.4FA0.6PbBr3'] 48 49
# ['Pb FA Br'] ['cubic-FAPbBr3'] 43 43
# ['Cs Br Pb'] ['CsPb2Br5'] 19 19
# ['I Br Cs Pb'] ['CsPb(I0.6Br0.4)3'] 26 26
# ['Br Pb I FA'] ['FAPb(Br0.2I0.8)3'] 39 39
# ['FA I Pb'] ['delta-FAPbI3'] 46 46
# ['I Pb Br MA'] ['MAPb(Br0.2I0.8)3'] 55 55
# ['Pb MA Br FA'] ['MA0.2FA0.8PbBr3'] 47 47
# ['Br FA I Pb'] ['FAPb(Br0.2I0.8)3'] 39 39
# ['Pb I Br FA'] ['FAPb(Br0.8I0.2)3'] 42 42
# ['I Pb FA'] ['alpha-FAPbI3'] 44 44
# ['Pb Cs I'] ['alpha-CsPbI3'] 36 36
# ['Cs Pb FA Br'] ['Cs0.8FA0.2PbBr3'] 3 3
# ['Pb Cs I'] ['delta-CsPbI3'] 37 37
# ['Br I Pb FA'] ['FAPb(Br0.8I0.2)3'] 42 42
# ['Br Cs Pb Cl'] ['CsPb(Cl0.4Br0.6)3'] 21 20
# ['Cs Pb FA I'] ['Cs0.2FA0.8PbI3'] 4 4
# ['FA I Pb'] ['beta-FAPbI3'] 45 45
# ['Cs Br Pb'] ['orthorhombic-CsPbBr3'] 33 33
# ['Cs I Pb'] ['delta-CsPbI3'] 37 37
# ['Pb Cs I MA'] ['Cs0.4MA0.6PbI3'] 13 12
# ['I Pb'] ['PbI2'] 65 65
# ['Cs Cl Br Pb'] ['CsPb(Cl0.4Br0.6)3'] 21 21
# ['I Pb FA MA'] ['MA0.4FA0.6PbI3'] 52 52
# ['Pb I MA'] ['alpha-MAPbI3'] 62 62
# ['Pb Cl Cs'] ['cubic-CsPbCl3'] 35 35
# ['I Cs Pb'] ['delta-CsPbI3'] 37 37
# ['Cl Pb I Cs'] ['CsPb(I0.6Cl0.4)3'] 30 30
# ['I Pb MA'] ['tetragonal-MAPbI3'] 63 63
# ['Pb I Cs Br'] ['CsPb(I0.8Br0.2)3'] 27 27
# ['Cs MA Pb Br'] ['Cs0.2MA0.8PbBr3'] 8 11
# ['Br Cs'] ['CsBr'] 17 17
# ['Cl I Cs Pb'] ['CsPb(I0.4Cl0.6)3'] 29 29
# ['Pb FA I'] ['alpha-FAPbI3'] 44 44
# ['Cl Cs Br Pb'] ['CsPb(Cl0.8Br0.2)3'] 23 23
# ['Cs Pb FA Br'] ['Cs0.8FA0.2PbBr3'] 3 3
# ['I Pb Br MA'] ['MAPb(Br0.8I0.2)3'] 58 58
# ['MA I Pb FA'] ['MA0.4FA0.6PbI3'] 52 52
# ['I Pb Cs MA'] ['Cs0.8MA0.2PbI3'] 15 14
# ['Cs Br MA Pb'] ['Cs0.6MA0.4PbBr3'] 10 10
# ['I Cs Pb Br'] ['CsPb(I0.4Br0.6)3'] 25 25
# ['Cs Cl Pb Br'] ['CsPb(Cl0.8Br0.2)3'] 23 23
# ['Cs I Pb Br'] ['CsPb(I0.8Br0.2)3'] 27 27
# ['FA Cs Br Pb'] ['Cs0.8FA0.2PbBr3'] 3 3
# ['Pb Br Cs Cl'] ['CsPb(Cl0.2Br0.8)3'] 20 20
# ['Cs Pb Br'] ['Cs4PbBr6'] 16 16
# ['Cs FA Pb Br'] ['Cs0.8FA0.2PbBr3'] 3 3
# ['Br Pb Cl Cs'] ['CsPb(Cl0.2Br0.8)3'] 20 20
# ['I Cs Br Pb'] ['CsPb(I0.4Br0.6)3'] 25 25
# ['Cs I Pb'] ['alpha-CsPbI3'] 36 36
# ['Br Pb MA Cs'] ['Cs0.2MA0.8PbBr3'] 8 8
# ['Cs I MA Pb'] ['Cs0.4MA0.6PbI3'] 13 14
# ['Pb I'] ['PbI2'] 65 65
# ['Cl Cs I Pb'] ['CsPb(I0.8Cl0.2)3'] 31 31
# ['Pb I Br Cs'] ['CsPb(I0.6Br0.4)3'] 26 25
# ['Cs Br I Pb'] ['CsPb(I0.2Br0.8)3'] 24 24
# ['Br Cs I Pb'] ['CsPb(I0.8Br0.2)3'] 27 27
# ['I Cs Pb'] ['gamma-CsPbI3'] 38 38
# ['Br Cs Cl Pb'] ['CsPb(Cl0.6Br0.4)3'] 22 22
# ['Br Pb Cs'] ['orthorhombic-CsPbBr3'] 33 33
# ['I Br MA Pb'] ['MAPb(Br0.4I0.6)3'] 56 56
# ['FA Pb I'] ['delta-FAPbI3'] 46 46
# ['Br Cs I Pb'] ['CsPb(I0.8Br0.2)3'] 27 27
# ['I Cs'] ['CsI'] 18 18
# ['Br I Cs Pb'] ['CsPb(I0.6Br0.4)3'] 26 26
# ['Pb Cs Br'] ['CsPb2Br5'] 19 19
# ['MA Pb I Br'] ['MAPb(Br0.8I0.2)3'] 58 58
# ['I FA Br Pb'] ['FAPb(Br0.8I0.2)3'] 42 41
# ['Cs Pb I Cl'] ['CsPb(I0.2Cl0.8)3'] 28 28
# ['MA Pb Br Cs'] ['Cs0.6MA0.4PbBr3'] 10 8
# ['Pb Br Cs'] ['cubic-CsPbBr3'] 32 32
# ['Cs Pb Br'] ['CsPb2Br5'] 19 19
# ['Pb MA I Br'] ['MAPb(Br0.2I0.8)3'] 55 55
# ['MA Cs Br Pb'] ['Cs0.8MA0.2PbBr3'] 11 11
# ['FA I Cs Pb'] ['Cs0.8FA0.2PbI3'] 7 7
# ['MA Br Pb'] ['tetragonal-MAPbBr3'] 60 60
# ['Cs Br'] ['CsBr'] 17 17
# ['MA Br Pb'] ['cubic-MAPbBr3'] 59 59
# ['Pb Cs Br'] ['CsPb2Br5'] 19 19
# ['FA I Pb Cs'] ['Cs0.2FA0.8PbI3'] 4 4
# ['MA Cs I Pb'] ['Cs0.4MA0.6PbI3'] 13 14
# ['I Cs'] ['CsI'] 18 18
# ['Br Cl Cs Pb'] ['CsPb(Cl0.4Br0.6)3'] 21 21
# ['Cl Pb MA'] ['Pnma-MAPbCl3'] 61 61
# ['Cl Cs Pb'] ['cubic-CsPbCl3'] 35 34
# ['Pb Br Cs'] ['Cs4PbBr6'] 16 16
# ['FA Br Cs Pb'] ['Cs0.6FA0.4PbBr3'] 2 2
# ['Pb Br Cs Cl'] ['CsPb(Cl0.6Br0.4)3'] 22 22
# ['Cs I Pb Cl'] ['CsPb(I0.4Cl0.6)3'] 29 29
# ['Pb I MA FA'] ['MA0.6FA0.4PbI3'] 53 53
# ['FA I MA Pb'] ['MA0.6FA0.4PbI3'] 53 53
# ['Br Cs FA Pb'] ['Cs0.6FA0.4PbBr3'] 2 2
# ['FA I Pb Br'] ['FAPb(Br0.8I0.2)3'] 42 42
# ['I Pb Cs MA'] ['Cs0.8MA0.2PbI3'] 15 12
# ['Br Pb I MA'] ['MAPb(Br0.6I0.4)3'] 57 57
# ['Br I Pb MA'] ['MAPb(Br0.4I0.6)3'] 56 56
# ['I Cs'] ['CsI'] 18 18
# ['MA FA Br Pb'] ['MA0.2FA0.8PbBr3'] 47 47
# ['Cs Br Pb'] ['cubic-CsPbBr3'] 32 32
# ['Cl Cs Pb'] ['cubic-CsPbCl3'] 35 35
# ['Pb Cs I MA'] ['Cs0.8MA0.2PbI3'] 15 15
# ['Br I Pb FA'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['Pb Br I FA'] ['FAPb(Br0.2I0.8)3'] 39 39
# ['Br Cs Cl Pb'] ['CsPb(Cl0.6Br0.4)3'] 22 22
# ['Pb Cs Br FA'] ['Cs0.8FA0.2PbBr3'] 3 3
# ['Pb FA I Br'] ['FAPb(Br0.4I0.6)3'] 40 40
# ['Pb MA I Br'] ['MAPb(Br0.4I0.6)3'] 56 56
# ['MA I FA Pb'] ['MA0.6FA0.4PbI3'] 53 53
# ['Br FA MA Pb'] ['MA0.8FA0.2PbBr3'] 50 48
# ['Cs I'] ['CsI'] 18 18
# ['I Pb Cl Cs'] ['CsPb(I0.6Cl0.4)3'] 30 30
# ['Pb Br MA I'] ['MAPb(Br0.8I0.2)3'] 58 58
# ['Pb FA I'] ['alpha-FAPbI3'] 44 44
# ['MA Br Cs Pb'] ['Cs0.2MA0.8PbBr3'] 8 8
# ['Pb I Cs'] ['delta-CsPbI3'] 37 36
# ['Pb I'] ['PbI2'] 65 65
# ['Pb FA Cs Br'] ['Cs0.8FA0.2PbBr3'] 3 3
# ['Cs Cl Pb'] ['cubic-CsPbCl3'] 35 35
# ['Pb I FA'] ['beta-FAPbI3'] 45 45
# ['Pb Br FA I'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['MA Cs I Pb'] ['Cs0.2MA0.8PbI3'] 12 12
# ['I Pb FA'] ['beta-FAPbI3'] 45 46
# ['Br Pb'] ['PbBr2'] 64 64
# ['Br I Cs Pb'] ['CsPb(I0.4Br0.6)3'] 25 27
# ['Pb FA I'] ['beta-FAPbI3'] 45 45
# ['Pb Cs I Br'] ['CsPb(I0.2Br0.8)3'] 24 24
# ['Cs Br'] ['CsBr'] 17 17
# ['I MA FA Pb'] ['MA0.2FA0.8PbI3'] 51 51
# ['Cl Pb Br Cs'] ['CsPb(Cl0.4Br0.6)3'] 21 23
# ['Pb I FA Br'] ['FAPb(Br0.8I0.2)3'] 42 42
# ['I Cs Pb MA'] ['Cs0.6MA0.4PbI3'] 14 15
# ['FA Br Pb Cs'] ['Cs0.6FA0.4PbBr3'] 2 2
# ['Pb MA Br'] ['tetragonal-MAPbBr3'] 60 60
# ['MA Pb Cs I'] ['Cs0.8MA0.2PbI3'] 15 13
# ['Pb Br FA'] ['cubic-FAPbBr3'] 43 43
# ['I Cs Pb'] ['alpha-CsPbI3'] 36 36
# ['Br Pb Cs'] ['CsPb2Br5'] 19 19
# ['I Pb Cs Cl'] ['CsPb(I0.6Cl0.4)3'] 30 30
# ['MA FA Pb Br'] ['MA0.2FA0.8PbBr3'] 47 47
# ['Pb Br'] ['PbBr2'] 64 64
# ['Pb FA Br'] ['cubic-FAPbBr3'] 43 43
# ['Cl MA Pb'] ['Pnma-MAPbCl3'] 61 61
# ['Pb Br MA'] ['tetragonal-MAPbBr3'] 60 60
# ['Pb Br Cs'] ['cubic-CsPbBr3'] 32 32
# ['FA I Pb Cs'] ['Cs0.8FA0.2PbI3'] 7 7
# ['Pb FA I Br'] ['FAPb(Br0.4I0.6)3'] 40 40
# ['Pb FA I'] ['delta-FAPbI3'] 46 46
# ['MA FA Pb I'] ['MA0.6FA0.4PbI3'] 53 53
# ['I Pb FA'] ['delta-FAPbI3'] 46 45
# ['Cs Pb Cl'] ['cubic-CsPbCl3'] 35 35
# ['Cs MA Pb Br'] ['Cs0.4MA0.6PbBr3'] 9 9
# ['Pb FA Br I'] ['FAPb(Br0.8I0.2)3'] 42 42
# ['Cs I Pb'] ['alpha-CsPbI3'] 36 36
# ['FA Pb MA Br'] ['MA0.2FA0.8PbBr3'] 47 47
# ['I Pb Cl Cs'] ['CsPb(I0.8Cl0.2)3'] 31 31
# ['Pb Br FA MA'] ['MA0.8FA0.2PbBr3'] 50 50
# ['I Cs Pb MA'] ['Cs0.4MA0.6PbI3'] 13 13
# ['FA Br Pb MA'] ['MA0.8FA0.2PbBr3'] 50 50
# ['Pb I'] ['PbI2'] 65 65
# ['MA I Pb Br'] ['MAPb(Br0.6I0.4)3'] 57 57
# ['Cs I Br Pb'] ['CsPb(I0.4Br0.6)3'] 25 25
# ['MA Pb I'] ['alpha-MAPbI3'] 62 62
# ['Cl Br Pb Cs'] ['CsPb(Cl0.2Br0.8)3'] 20 23
# ['I Pb FA'] ['beta-FAPbI3'] 45 46
# ['Pb FA I MA'] ['MA0.2FA0.8PbI3'] 51 51
# ['Cs Cl Pb'] ['Pnma-CsPbCl3'] 34 34
# ['MA Pb I Cs'] ['Cs0.8MA0.2PbI3'] 15 15
# ['Pb Br Cs'] ['Cs4PbBr6'] 16 16
# ['FA MA I Pb'] ['MA0.8FA0.2PbI3'] 54 54
# ['Br I FA Pb'] ['FAPb(Br0.8I0.2)3'] 42 42
# ['Br Pb FA'] ['cubic-FAPbBr3'] 43 43
# ['Cs Br Pb Cl'] ['CsPb(Cl0.2Br0.8)3'] 20 20
# ['Pb Br FA I'] ['FAPb(Br0.8I0.2)3'] 42 42
# ['Cs Pb I'] ['alpha-CsPbI3'] 36 36
# ['Cs MA Br Pb'] ['Cs0.2MA0.8PbBr3'] 8 8
# ['Pb Br'] ['PbBr2'] 64 64
# ['Br Pb Cs'] ['cubic-CsPbBr3'] 32 32
# ['Br Pb MA I'] ['MAPb(Br0.4I0.6)3'] 56 56
# ['Cs Pb Br'] ['orthorhombic-CsPbBr3'] 33 33
# ['Br Pb I Cs'] ['CsPb(I0.4Br0.6)3'] 25 25
# ['Cs Pb I'] ['alpha-CsPbI3'] 36 36
# ['Cs Br Pb'] ['orthorhombic-CsPbBr3'] 33 33
# ['Br Pb I Cs'] ['CsPb(I0.8Br0.2)3'] 27 27
# ['MA Br Cs Pb'] ['Cs0.4MA0.6PbBr3'] 9 9
# ['Pb Cs Cl Br'] ['CsPb(Cl0.6Br0.4)3'] 22 22
# ['Pb MA Br Cs'] ['Cs0.8MA0.2PbBr3'] 11 11
# ['I FA Cs Pb'] ['Cs0.8FA0.2PbI3'] 7 7
# ['FA I Pb'] ['delta-FAPbI3'] 46 46
# ['Pb Cs FA I'] ['Cs0.8FA0.2PbI3'] 7 7
# ['Cs Br Pb'] ['cubic-CsPbBr3'] 32 32
# ['MA Cs Pb I'] ['Cs0.6MA0.4PbI3'] 14 12
# ['I FA Pb MA'] ['MA0.2FA0.8PbI3'] 51 51
# ['Cs Br Pb MA'] ['Cs0.4MA0.6PbBr3'] 9 9
# ['MA Pb Br Cs'] ['Cs0.8MA0.2PbBr3'] 11 11
# ['Pb I'] ['PbI2'] 65 65
# ['Pb Cs I MA'] ['Cs0.6MA0.4PbI3'] 14 14
# ['FA I MA Pb'] ['MA0.8FA0.2PbI3'] 54 52
# ['Pb FA I MA'] ['MA0.2FA0.8PbI3'] 51 51
# ['FA Pb Br MA'] ['MA0.2FA0.8PbBr3'] 47 47
# ['I Pb FA'] ['alpha-FAPbI3'] 44 44
# ['Cs Pb Cl I'] ['CsPb(I0.2Cl0.8)3'] 28 28
# ['MA Br Pb I'] ['MAPb(Br0.2I0.8)3'] 55 55
# ['Cs I Pb'] ['gamma-CsPbI3'] 38 38
# ['I Pb Cs Br'] ['CsPb(I0.6Br0.4)3'] 26 25
# ['Pb Cs MA I'] ['Cs0.8MA0.2PbI3'] 15 14
# ['Pb I FA Br'] ['FAPb(Br0.8I0.2)3'] 42 42
# ['Cs Pb I MA'] ['Cs0.4MA0.6PbI3'] 13 13
# ['Cs Br'] ['CsBr'] 17 17
# ['Br Pb Cs'] ['orthorhombic-CsPbBr3'] 33 33
# ['Pb MA Br I'] ['MAPb(Br0.8I0.2)3'] 58 58
# ['MA Pb FA I'] ['MA0.8FA0.2PbI3'] 54 54
# ['I Pb Cl Cs'] ['CsPb(I0.4Cl0.6)3'] 29 29
# ['FA MA I Pb'] ['MA0.4FA0.6PbI3'] 52 52
# ['Br Pb FA MA'] ['MA0.4FA0.6PbBr3'] 48 48
# ['Pb Cl Cs Br'] ['CsPb(Cl0.8Br0.2)3'] 23 23
# ['Br FA Pb I'] ['FAPb(Br0.8I0.2)3'] 42 42
# ['Pb MA Cl'] ['Pnma-MAPbCl3'] 61 61
# ['I Cs Pb Cl'] ['CsPb(I0.4Cl0.6)3'] 29 29
# ['FA I Pb'] ['alpha-FAPbI3'] 44 44
# ['MA I Br Pb'] ['MAPb(Br0.6I0.4)3'] 57 58
# ['Pb FA MA Br'] ['MA0.4FA0.6PbBr3'] 48 48
# ['MA Cs Br Pb'] ['Cs0.8MA0.2PbBr3'] 11 11
# ['Br I Pb FA'] ['FAPb(Br0.2I0.8)3'] 39 39
# ['I FA Pb'] ['alpha-FAPbI3'] 44 44
# ['Br Cs Pb Cl'] ['CsPb(Cl0.6Br0.4)3'] 22 22
# ['I Pb Cl Cs'] ['CsPb(I0.2Cl0.8)3'] 28 28
# ['Cs Cl Pb I'] ['CsPb(I0.2Cl0.8)3'] 28 28
# ['Br Pb FA Cs'] ['Cs0.2FA0.8PbBr3'] 0 0
# ['Br Pb MA'] ['tetragonal-MAPbBr3'] 60 60
# ['MA I Cs Pb'] ['Cs0.4MA0.6PbI3'] 13 13
# ['I MA FA Pb'] ['MA0.6FA0.4PbI3'] 53 51
# ['Pb I FA Cs'] ['Cs0.2FA0.8PbI3'] 4 5
# ['Cs Br Pb MA'] ['Cs0.6MA0.4PbBr3'] 10 10
# ['Br Cs Pb'] ['Cs4PbBr6'] 16 16
# ['Cl Cs Pb Br'] ['CsPb(Cl0.6Br0.4)3'] 22 22
# ['Cl Cs Br Pb'] ['CsPb(Cl0.2Br0.8)3'] 20 20
# ['I Cs Pb'] ['gamma-CsPbI3'] 38 36
# ['Pb MA Cs I'] ['Cs0.6MA0.4PbI3'] 14 15
# ['Pb Br Cs'] ['orthorhombic-CsPbBr3'] 33 33
# ['Cs MA Br Pb'] ['Cs0.6MA0.4PbBr3'] 10 10
# ['Cl Pb Cs'] ['Pnma-CsPbCl3'] 34 34
# ['Br Cs Pb'] ['orthorhombic-CsPbBr3'] 33 33
# ['Br Pb Cs Cl'] ['CsPb(Cl0.4Br0.6)3'] 21 21
# ['I Pb FA'] ['delta-FAPbI3'] 46 46
# ['Br MA I Pb'] ['MAPb(Br0.2I0.8)3'] 55 55
# ['Pb FA Cs Br'] ['Cs0.4FA0.6PbBr3'] 1 1
# ['Cs Pb Cl'] ['cubic-CsPbCl3'] 35 35
# ['MA Br Pb I'] ['MAPb(Br0.8I0.2)3'] 58 58
# ['Pb Br MA Cs'] ['Cs0.2MA0.8PbBr3'] 8 8
# ['Cs FA Pb I'] ['Cs0.6FA0.4PbI3'] 6 6
# ['Pb Cs I'] ['gamma-CsPbI3'] 38 38
# ['Br MA Pb I'] ['MAPb(Br0.6I0.4)3'] 57 57
# ['Cs Pb I MA'] ['Cs0.8MA0.2PbI3'] 15 15
# ['MA Br Cs Pb'] ['Cs0.8MA0.2PbBr3'] 11 11
# ['Br MA Pb I'] ['MAPb(Br0.8I0.2)3'] 58 58
# ['Pb I Cs'] ['gamma-CsPbI3'] 38 38
# ['I Pb MA Cs'] ['Cs0.2MA0.8PbI3'] 12 12
# ['Cl Cs Pb'] ['cubic-CsPbCl3'] 35 35
# ['Cs Cl Pb I'] ['CsPb(I0.6Cl0.4)3'] 30 30
# ['I FA Br Pb'] ['FAPb(Br0.4I0.6)3'] 40 40
# ['Br Cs'] ['CsBr'] 17 17
# ['Pb Cs MA I'] ['Cs0.2MA0.8PbI3'] 12 13
# ['Pb Br Cs FA'] ['Cs0.8FA0.2PbBr3'] 3 3
# ['I Br FA Pb'] ['FAPb(Br0.8I0.2)3'] 42 42
# ['Pb Cs Br Cl'] ['CsPb(Cl0.8Br0.2)3'] 23 23
# ['Pb MA I Br'] ['MAPb(Br0.4I0.6)3'] 56 56
# ['MA Pb Cs Br'] ['Cs0.2MA0.8PbBr3'] 8 8
# ['Pb Cs Br Cl'] ['CsPb(Cl0.8Br0.2)3'] 23 23
# ['Cs I Pb'] ['delta-CsPbI3'] 37 37
# ['Cs Pb Br FA'] ['Cs0.4FA0.6PbBr3'] 1 1
# ['Cs I'] ['CsI'] 18 18
# ['Br Pb MA'] ['tetragonal-MAPbBr3'] 60 60
# ['FA Pb MA I'] ['MA0.4FA0.6PbI3'] 52 52
# ['Cl Pb MA'] ['Pnma-MAPbCl3'] 61 61
# ['I Pb MA Cs'] ['Cs0.4MA0.6PbI3'] 13 14
# ['Pb Br FA Cs'] ['Cs0.4FA0.6PbBr3'] 1 1
# ['Br Pb MA I'] ['MAPb(Br0.4I0.6)3'] 56 58
# ['Pb Cs Br MA'] ['Cs0.4MA0.6PbBr3'] 9 9
# ['Cs Cl Pb'] ['Pnma-CsPbCl3'] 34 34
# ['FA Pb I'] ['delta-FAPbI3'] 46 46
# ['FA Br Cs Pb'] ['Cs0.6FA0.4PbBr3'] 2 2
# ['Pb Cs I FA'] ['Cs0.4FA0.6PbI3'] 5 5
# ['Br MA Pb'] ['tetragonal-MAPbBr3'] 60 60
# ['I Pb Br MA'] ['MAPb(Br0.4I0.6)3'] 56 56
# ['Pb Cs I FA'] ['Cs0.6FA0.4PbI3'] 6 6
# ['I Pb FA MA'] ['MA0.8FA0.2PbI3'] 54 54
# ['MA Pb FA I'] ['MA0.8FA0.2PbI3'] 54 54
# ['Pb I Cl Cs'] ['CsPb(I0.4Cl0.6)3'] 29 29
# ['Pb Cs Cl'] ['Pnma-CsPbCl3'] 34 34
# ['I Pb Br MA'] ['MAPb(Br0.6I0.4)3'] 57 57
# ['I Cs Pb MA'] ['Cs0.4MA0.6PbI3'] 13 13
# ['Cs I'] ['CsI'] 18 18
# ['Cs Br Cl Pb'] ['CsPb(Cl0.4Br0.6)3'] 21 21
# ['I MA Pb'] ['alpha-MAPbI3'] 62 62
# ['I Pb MA'] ['tetragonal-MAPbI3'] 63 63
# ['Pb Cs Cl'] ['cubic-CsPbCl3'] 35 35
# ['FA Pb Br I'] ['FAPb(Br0.8I0.2)3'] 42 42
# ['I MA Br Pb'] ['MAPb(Br0.2I0.8)3'] 55 55
# ['Pb Br'] ['PbBr2'] 64 64
# ['FA I Pb'] ['alpha-FAPbI3'] 44 44
# ['Pb Cs Br'] ['Cs4PbBr6'] 16 16
# ['Cs Br Pb'] ['Cs4PbBr6'] 16 16
# ['Pb Br MA I'] ['MAPb(Br0.8I0.2)3'] 58 57
# ['Cs Cl I Pb'] ['CsPb(I0.8Cl0.2)3'] 31 31
# ['Pb I MA'] ['tetragonal-MAPbI3'] 63 63
# ['Pb Br FA MA'] ['MA0.2FA0.8PbBr3'] 47 47
# ['Pb Cs I'] ['delta-CsPbI3'] 37 37
# ['FA Cs Pb Br'] ['Cs0.8FA0.2PbBr3'] 3 3
# ['Cl Pb MA'] ['Pnma-MAPbCl3'] 61 61
# ['Pb Cs Br I'] ['CsPb(I0.8Br0.2)3'] 27 27
# ['I FA Pb'] ['alpha-FAPbI3'] 44 44
# ['Cs Br Pb Cl'] ['CsPb(Cl0.6Br0.4)3'] 22 22
# ['Cs Br'] ['CsBr'] 17 17
# ['I MA Pb Br'] ['MAPb(Br0.6I0.4)3'] 57 57
# ['Cs I MA Pb'] ['Cs0.6MA0.4PbI3'] 14 15
# ['I Pb Br MA'] ['MAPb(Br0.4I0.6)3'] 56 58
# ['Br MA Pb Cs'] ['Cs0.4MA0.6PbBr3'] 9 9
# ['Br Pb Cs'] ['orthorhombic-CsPbBr3'] 33 16
# ['Pb FA MA Br'] ['MA0.6FA0.4PbBr3'] 49 49
# ['Br FA Pb MA'] ['MA0.2FA0.8PbBr3'] 47 47
# ['Pb MA FA Br'] ['MA0.4FA0.6PbBr3'] 48 48
# ['I Pb Cl Cs'] ['CsPb(I0.6Cl0.4)3'] 30 30
# ['Pb MA I'] ['alpha-MAPbI3'] 62 62
# ['Cs Cl Pb Br'] ['CsPb(Cl0.6Br0.4)3'] 22 22
# ['Pb MA I FA'] ['MA0.2FA0.8PbI3'] 51 51
# ['Br Cs Pb MA'] ['Cs0.4MA0.6PbBr3'] 9 8
# ['Br Pb MA'] ['cubic-MAPbBr3'] 59 59
# ['Cs Cl Pb'] ['cubic-CsPbCl3'] 35 35
# ['Pb Br'] ['PbBr2'] 64 64
# ['Cs Br Pb'] ['Cs4PbBr6'] 16 16
# ['MA Pb Cs Br'] ['Cs0.8MA0.2PbBr3'] 11 11
# ['Br FA I Pb'] ['FAPb(Br0.6I0.4)3'] 41 40
# ['Pb Br MA FA'] ['MA0.2FA0.8PbBr3'] 47 47
# ['Pb Cl I Cs'] ['CsPb(I0.4Cl0.6)3'] 29 29
# ['Cs Cl I Pb'] ['CsPb(I0.8Cl0.2)3'] 31 28
# ['MA Cs Pb Br'] ['Cs0.4MA0.6PbBr3'] 9 9
# ['I Cs Pb Br'] ['CsPb(I0.2Br0.8)3'] 24 24
# ['MA Pb Br I'] ['MAPb(Br0.8I0.2)3'] 58 58
# ['Pb Cs I Br'] ['CsPb(I0.4Br0.6)3'] 25 25
# ['Cl I Cs Pb'] ['CsPb(I0.8Cl0.2)3'] 31 31
# ['Pb MA Cl'] ['Pnma-MAPbCl3'] 61 61
# ['I Br FA Pb'] ['FAPb(Br0.2I0.8)3'] 39 39
# ['Pb I FA'] ['beta-FAPbI3'] 45 45
# ['I FA Pb MA'] ['MA0.6FA0.4PbI3'] 53 51
# ['Pb Cs Cl'] ['Pnma-CsPbCl3'] 34 34
# ['I Pb Cs FA'] ['Cs0.8FA0.2PbI3'] 7 7
# ['Pb Br Cs Cl'] ['CsPb(Cl0.6Br0.4)3'] 22 22
# ['Pb MA Cs Br'] ['Cs0.4MA0.6PbBr3'] 9 9
# ['I FA Pb MA'] ['MA0.2FA0.8PbI3'] 51 51
# ['Pb I MA'] ['tetragonal-MAPbI3'] 63 63
# ['I Pb'] ['PbI2'] 65 65
# ['Pb I Cs'] ['alpha-CsPbI3'] 36 36
# ['Pb MA FA I'] ['MA0.6FA0.4PbI3'] 53 54
# ['Br Cl Cs Pb'] ['CsPb(Cl0.8Br0.2)3'] 23 23
# ['I FA Pb Br'] ['FAPb(Br0.6I0.4)3'] 41 41
# ['FA Cs Pb Br'] ['Cs0.6FA0.4PbBr3'] 2 2
# ['Cs FA I Pb'] ['Cs0.8FA0.2PbI3'] 7 7
# ['Cs Br FA Pb'] ['Cs0.4FA0.6PbBr3'] 1 1
# ['Pb FA Br MA'] ['MA0.8FA0.2PbBr3'] 50 50
# ['I Pb FA'] ['beta-FAPbI3'] 45 45
# ['Cs Br Pb I'] ['CsPb(I0.4Br0.6)3'] 25 25
# ['MA Br Cs Pb'] ['Cs0.2MA0.8PbBr3'] 8 8
# ['FA Br MA Pb'] ['MA0.4FA0.6PbBr3'] 48 48
# ['I MA FA Pb'] ['MA0.8FA0.2PbI3'] 54 54
# ['Cs I Pb Br'] ['CsPb(I0.6Br0.4)3'] 26 24
# ['Pb FA Cs Br'] ['Cs0.2FA0.8PbBr3'] 0 1
# ['FA Pb MA I'] ['MA0.8FA0.2PbI3'] 54 54
# ['Br FA Pb Cs'] ['Cs0.6FA0.4PbBr3'] 2 2
# ['MA FA Pb I'] ['MA0.4FA0.6PbI3'] 52 52
# ['FA Pb Br I'] ['FAPb(Br0.2I0.8)3'] 39 39
# ['Cl Cs Pb'] ['cubic-CsPbCl3'] 35 35
# ['MA Cs Pb I'] ['Cs0.6MA0.4PbI3'] 14 14
# ['Pb Cs Br I'] ['CsPb(I0.6Br0.4)3'] 26 26
# ['Pb I Cs Cl'] ['CsPb(I0.8Cl0.2)3'] 31 31
# ['Pb Br FA I'] ['FAPb(Br0.8I0.2)3'] 42 42
# ['Pb Cs I FA'] ['Cs0.8FA0.2PbI3'] 7 7

# %% [markdown]
# ## Fig 2a-c

# %%
load_plt_setting()

report = classification_report(y_true, y_pred, target_names=dataloader.sample_list, output_dict=True)
matrix = confusion_matrix(y_true, y_pred)

fig, ax = plt.subplots(figsize=(12, 10))

mat = ax.matshow(matrix, cmap='hot')
ax.xaxis.set_ticks_position('bottom')
ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=10, steps=[1, 2, 5, 10]))
ax.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=10, steps=[1, 2, 5, 10]))
ax.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax.tick_params(axis='both',direction='out',length=8,width=2,pad=10,color='black',labelsize=28)
ax.tick_params(axis='both',which='minor',direction='out',length=4,width=2,pad=10,color='black',labelsize=28)
# ax.axes.set_xlim([450,950])
# ax.axes.set_ylim([0,5])
# # ax.set_xscale('log')

cbar = plt.colorbar(mat)
cbar.ax.tick_params(axis='y', direction='out',length=8,width=3,pad=5,labelsize=28)
cbar.ax.set_ylabel('Number of samples',labelpad=40, rotation=-90)
cbar.ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=4, integer=True, steps=[1, 2, 5, 10]))
cbar.ax.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
cbar.ax.tick_params(axis='both',which='minor',direction='out',length=4,width=3,pad=5)

ax.set_xlabel(r'Predicted class', labelpad=20, fontsize=34)
ax.set_ylabel(r'True class', labelpad=20, fontsize=34)

plt.text(0.95, 0.91, 'Accuracy: {:.1f}%'.format(report['accuracy']*100), fontsize=32, 
         transform=ax.transAxes, color='#FFFFFF', horizontalalignment='right')
plt.text(0.05, 0.06, 'Precursor label', fontsize=32, transform=ax.transAxes, color='#FFFFFF', horizontalalignment='left')

plt.savefig(os.path.join(folder, 'models', model_folder, 'classification_Precursor.png'), 
            format='png', dpi=300, transparent=True, bbox_inches='tight')

# %% [markdown]
# ## Fig 2e

# %%
for i in range(len(y_true)):
    if y_true[i] != y_pred[i]:
        print(i,'\t',str(y_true[i])+'\t'+dataloader.dataset[dataloader.sample_list[y_true[i]]]['formula']+'\t\t'+str(y_pred[i])+'\t'+
             dataloader.dataset[dataloader.sample_list[y_pred[i]]]['formula'])
# Out:
# 1 	 49	MA0.6FA0.4PbBr3		48	MA0.4FA0.6PbBr3
# 3 	 0	Cs0.2FA0.8PbBr3		26	CsPb(I0.6Br0.4)3
# 16 	 31	CsPb(I0.8Cl0.2)3		36	alpha-CsPbI3
# 20 	 5	Cs0.4FA0.6PbI3		16	Cs4PbBr6
# 22 	 35	cubic-CsPbCl3		22	CsPb(Cl0.6Br0.4)3
# 23 	 32	cubic-CsPbBr3		25	CsPb(I0.4Br0.6)3
# 24 	 15	Cs0.8MA0.2PbI3		36	alpha-CsPbI3
# 27 	 59	cubic-MAPbBr3		55	MAPb(Br0.2I0.8)3
# 28 	 29	CsPb(I0.4Cl0.6)3		27	CsPb(I0.8Br0.2)3
# 34 	 48	MA0.4FA0.6PbBr3		10	Cs0.6MA0.4PbBr3
# 38 	 10	Cs0.6MA0.4PbBr3		3	Cs0.8FA0.2PbBr3
# 39 	 56	MAPb(Br0.4I0.6)3		55	MAPb(Br0.2I0.8)3
# 44 	 10	Cs0.6MA0.4PbBr3		3	Cs0.8FA0.2PbBr3
# 46 	 32	cubic-CsPbBr3		26	CsPb(I0.6Br0.4)3
# 48 	 13	Cs0.4MA0.6PbI3		15	Cs0.8MA0.2PbI3
# 49 	 3	Cs0.8FA0.2PbBr3		27	CsPb(I0.8Br0.2)3
# 51 	 15	Cs0.8MA0.2PbI3		36	alpha-CsPbI3
# 55 	 10	Cs0.6MA0.4PbBr3		25	CsPb(I0.4Br0.6)3
# 56 	 48	MA0.4FA0.6PbBr3		10	Cs0.6MA0.4PbBr3
# 57 	 56	MAPb(Br0.4I0.6)3		31	CsPb(I0.8Cl0.2)3
# 59 	 9	Cs0.4MA0.6PbBr3		15	Cs0.8MA0.2PbI3
# 60 	 56	MAPb(Br0.4I0.6)3		55	MAPb(Br0.2I0.8)3
# 63 	 32	cubic-CsPbBr3		15	Cs0.8MA0.2PbI3
# 65 	 30	CsPb(I0.6Cl0.4)3		26	CsPb(I0.6Br0.4)3
# 67 	 8	Cs0.2MA0.8PbBr3		2	Cs0.6FA0.4PbBr3
# 70 	 20	CsPb(Cl0.2Br0.8)3		2	Cs0.6FA0.4PbBr3
# 72 	 14	Cs0.6MA0.4PbI3		15	Cs0.8MA0.2PbI3
# 80 	 8	Cs0.2MA0.8PbBr3		55	MAPb(Br0.2I0.8)3
# 86 	 59	cubic-MAPbBr3		50	MA0.8FA0.2PbBr3
# 87 	 29	CsPb(I0.4Cl0.6)3		27	CsPb(I0.8Br0.2)3
# 89 	 61	Pnma-MAPbCl3		33	orthorhombic-CsPbBr3
# 90 	 10	Cs0.6MA0.4PbBr3		29	CsPb(I0.4Cl0.6)3
# 91 	 56	MAPb(Br0.4I0.6)3		55	MAPb(Br0.2I0.8)3
# 93 	 26	CsPb(I0.6Br0.4)3		36	alpha-CsPbI3
# 94 	 61	Pnma-MAPbCl3		64	PbBr2
# 95 	 8	Cs0.2MA0.8PbBr3		2	Cs0.6FA0.4PbBr3
# 96 	 29	CsPb(I0.4Cl0.6)3		3	Cs0.8FA0.2PbBr3
# 101 	 50	MA0.8FA0.2PbBr3		49	MA0.6FA0.4PbBr3
# 105 	 13	Cs0.4MA0.6PbI3		12	Cs0.2MA0.8PbI3
# 108 	 26	CsPb(I0.6Br0.4)3		36	alpha-CsPbI3
# 109 	 47	MA0.2FA0.8PbBr3		11	Cs0.8MA0.2PbBr3
# 110 	 58	MAPb(Br0.8I0.2)3		43	cubic-FAPbBr3
# 111 	 15	Cs0.8MA0.2PbI3		36	alpha-CsPbI3
# 112 	 55	MAPb(Br0.2I0.8)3		27	CsPb(I0.8Br0.2)3
# 117 	 16	Cs4PbBr6		51	MA0.2FA0.8PbI3
# 118 	 13	Cs0.4MA0.6PbI3		15	Cs0.8MA0.2PbI3
# 120 	 45	beta-FAPbI3		64	PbBr2
# 121 	 8	Cs0.2MA0.8PbBr3		15	Cs0.8MA0.2PbI3
# 123 	 45	beta-FAPbI3		41	FAPb(Br0.6I0.4)3
# 125 	 64	PbBr2		6	Cs0.6FA0.4PbI3
# 127 	 23	CsPb(Cl0.8Br0.2)3		55	MAPb(Br0.2I0.8)3
# 129 	 59	cubic-MAPbBr3		55	MAPb(Br0.2I0.8)3
# 132 	 15	Cs0.8MA0.2PbI3		13	Cs0.4MA0.6PbI3
# 137 	 25	CsPb(I0.4Br0.6)3		26	CsPb(I0.6Br0.4)3
# 142 	 49	MA0.6FA0.4PbBr3		50	MA0.8FA0.2PbBr3
# 148 	 55	MAPb(Br0.2I0.8)3		31	CsPb(I0.8Cl0.2)3
# 149 	 47	MA0.2FA0.8PbBr3		55	MAPb(Br0.2I0.8)3
# 150 	 60	tetragonal-MAPbBr3		50	MA0.8FA0.2PbBr3
# 154 	 47	MA0.2FA0.8PbBr3		62	alpha-MAPbI3
# 155 	 30	CsPb(I0.6Cl0.4)3		26	CsPb(I0.6Br0.4)3
# 157 	 24	CsPb(I0.2Br0.8)3		32	cubic-CsPbBr3
# 158 	 20	CsPb(Cl0.2Br0.8)3		48	MA0.4FA0.6PbBr3
# 165 	 7	Cs0.8FA0.2PbI3		41	FAPb(Br0.6I0.4)3
# 168 	 2	Cs0.6FA0.4PbBr3		8	Cs0.2MA0.8PbBr3
# 171 	 14	Cs0.6MA0.4PbI3		36	alpha-CsPbI3
# 172 	 46	delta-FAPbI3		63	tetragonal-MAPbI3
# 176 	 60	tetragonal-MAPbBr3		50	MA0.8FA0.2PbBr3
# 179 	 47	MA0.2FA0.8PbBr3		0	Cs0.2FA0.8PbBr3
# 181 	 3	Cs0.8FA0.2PbBr3		10	Cs0.6MA0.4PbBr3
# 183 	 13	Cs0.4MA0.6PbI3		12	Cs0.2MA0.8PbI3
# 186 	 1	Cs0.4FA0.6PbBr3		32	cubic-CsPbBr3
# 189 	 1	Cs0.4FA0.6PbBr3		24	CsPb(I0.2Br0.8)3
# 193 	 15	Cs0.8MA0.2PbI3		36	alpha-CsPbI3
# 195 	 44	alpha-FAPbI3		1	Cs0.4FA0.6PbBr3
# 198 	 25	CsPb(I0.4Br0.6)3		12	Cs0.2MA0.8PbI3
# 202 	 10	Cs0.6MA0.4PbBr3		3	Cs0.8FA0.2PbBr3
# 204 	 35	cubic-CsPbCl3		62	alpha-MAPbI3
# 205 	 65	PbI2		15	Cs0.8MA0.2PbI3
# 214 	 15	Cs0.8MA0.2PbI3		36	alpha-CsPbI3
# 222 	 58	MAPb(Br0.8I0.2)3		0	Cs0.2FA0.8PbBr3
# 224 	 10	Cs0.6MA0.4PbBr3		25	CsPb(I0.4Br0.6)3
# 228 	 20	CsPb(Cl0.2Br0.8)3		55	MAPb(Br0.2I0.8)3
# 230 	 7	Cs0.8FA0.2PbI3		64	PbBr2
# 232 	 34	Pnma-CsPbCl3		35	cubic-CsPbCl3
# 233 	 45	beta-FAPbI3		64	PbBr2
# 239 	 29	CsPb(I0.4Cl0.6)3		0	Cs0.2FA0.8PbBr3
# 240 	 57	MAPb(Br0.6I0.4)3		43	cubic-FAPbBr3
# 243 	 2	Cs0.6FA0.4PbBr3		8	Cs0.2MA0.8PbBr3
# 245 	 22	CsPb(Cl0.6Br0.4)3		48	MA0.4FA0.6PbBr3
# 248 	 59	cubic-MAPbBr3		31	CsPb(I0.8Cl0.2)3
# 251 	 54	MA0.8FA0.2PbI3		41	FAPb(Br0.6I0.4)3
# 252 	 25	CsPb(I0.4Br0.6)3		12	Cs0.2MA0.8PbI3
# 253 	 24	CsPb(I0.2Br0.8)3		31	CsPb(I0.8Cl0.2)3
# 254 	 57	MAPb(Br0.6I0.4)3		43	cubic-FAPbBr3
# 255 	 48	MA0.4FA0.6PbBr3		10	Cs0.6MA0.4PbBr3
# 256 	 11	Cs0.8MA0.2PbBr3		25	CsPb(I0.4Br0.6)3
# 262 	 53	MA0.6FA0.4PbI3		64	PbBr2
# 266 	 7	Cs0.8FA0.2PbI3		40	FAPb(Br0.4I0.6)3
# 267 	 59	cubic-MAPbBr3		55	MAPb(Br0.2I0.8)3
# 272 	 3	Cs0.8FA0.2PbBr3		29	CsPb(I0.4Cl0.6)3
# 273 	 19	CsPb2Br5		63	tetragonal-MAPbI3
# 274 	 64	PbBr2		5	Cs0.4FA0.6PbI3
# 280 	 51	MA0.2FA0.8PbI3		39	FAPb(Br0.2I0.8)3
# 283 	 29	CsPb(I0.4Cl0.6)3		3	Cs0.8FA0.2PbBr3
# 286 	 29	CsPb(I0.4Cl0.6)3		36	alpha-CsPbI3
# 287 	 9	Cs0.4MA0.6PbBr3		15	Cs0.8MA0.2PbI3
# 290 	 55	MAPb(Br0.2I0.8)3		31	CsPb(I0.8Cl0.2)3
# 293 	 3	Cs0.8FA0.2PbBr3		10	Cs0.6MA0.4PbBr3
# 294 	 10	Cs0.6MA0.4PbBr3		25	CsPb(I0.4Br0.6)3
# 295 	 2	Cs0.6FA0.4PbBr3		8	Cs0.2MA0.8PbBr3
# 296 	 15	Cs0.8MA0.2PbI3		36	alpha-CsPbI3
# 300 	 34	Pnma-CsPbCl3		47	MA0.2FA0.8PbBr3
# 301 	 45	beta-FAPbI3		41	FAPb(Br0.6I0.4)3
# 303 	 37	delta-CsPbI3		38	gamma-CsPbI3
# 305 	 25	CsPb(I0.4Br0.6)3		31	CsPb(I0.8Cl0.2)3
# 306 	 13	Cs0.4MA0.6PbI3		14	Cs0.6MA0.4PbI3
# 308 	 23	CsPb(Cl0.8Br0.2)3		34	Pnma-CsPbCl3
# 310 	 2	Cs0.6FA0.4PbBr3		8	Cs0.2MA0.8PbBr3
# 311 	 28	CsPb(I0.2Cl0.8)3		3	Cs0.8FA0.2PbBr3
# 312 	 0	Cs0.2FA0.8PbBr3		27	CsPb(I0.8Br0.2)3
# 314 	 29	CsPb(I0.4Cl0.6)3		12	Cs0.2MA0.8PbI3
# 315 	 52	MA0.4FA0.6PbI3		53	MA0.6FA0.4PbI3
# 317 	 45	beta-FAPbI3		41	FAPb(Br0.6I0.4)3
# 319 	 3	Cs0.8FA0.2PbBr3		26	CsPb(I0.6Br0.4)3
# 324 	 43	cubic-FAPbBr3		25	CsPb(I0.4Br0.6)3
# 326 	 23	CsPb(Cl0.8Br0.2)3		43	cubic-FAPbBr3
# 327 	 35	cubic-CsPbCl3		48	MA0.4FA0.6PbBr3
# 329 	 3	Cs0.8FA0.2PbBr3		10	Cs0.6MA0.4PbBr3
# 331 	 29	CsPb(I0.4Cl0.6)3		3	Cs0.8FA0.2PbBr3
# 334 	 20	CsPb(Cl0.2Br0.8)3		43	cubic-FAPbBr3
# 335 	 36	alpha-CsPbI3		15	Cs0.8MA0.2PbI3
# 337 	 21	CsPb(Cl0.4Br0.6)3		43	cubic-FAPbBr3
# 338 	 40	FAPb(Br0.4I0.6)3		16	Cs4PbBr6
# 340 	 20	CsPb(Cl0.2Br0.8)3		55	MAPb(Br0.2I0.8)3
# 348 	 1	Cs0.4FA0.6PbBr3		3	Cs0.8FA0.2PbBr3
# 349 	 30	CsPb(I0.6Cl0.4)3		2	Cs0.6FA0.4PbBr3
# 356 	 40	FAPb(Br0.4I0.6)3		6	Cs0.6FA0.4PbI3
# 360 	 50	MA0.8FA0.2PbBr3		55	MAPb(Br0.2I0.8)3
# 361 	 25	CsPb(I0.4Br0.6)3		12	Cs0.2MA0.8PbI3
# 364 	 22	CsPb(Cl0.6Br0.4)3		20	CsPb(Cl0.2Br0.8)3
# 367 	 22	CsPb(Cl0.6Br0.4)3		20	CsPb(Cl0.2Br0.8)3
# 371 	 10	Cs0.6MA0.4PbBr3		36	alpha-CsPbI3
# 372 	 45	beta-FAPbI3		53	MA0.6FA0.4PbI3
# 373 	 60	tetragonal-MAPbBr3		50	MA0.8FA0.2PbBr3
# 375 	 49	MA0.6FA0.4PbBr3		8	Cs0.2MA0.8PbBr3
# 376 	 6	Cs0.6FA0.4PbI3		40	FAPb(Br0.4I0.6)3
# 380 	 7	Cs0.8FA0.2PbI3		41	FAPb(Br0.6I0.4)3
# 381 	 12	Cs0.2MA0.8PbI3		13	Cs0.4MA0.6PbI3
# 384 	 12	Cs0.2MA0.8PbI3		14	Cs0.6MA0.4PbI3
# 388 	 13	Cs0.4MA0.6PbI3		12	Cs0.2MA0.8PbI3
# 390 	 13	Cs0.4MA0.6PbI3		12	Cs0.2MA0.8PbI3
# 391 	 15	Cs0.8MA0.2PbI3		13	Cs0.4MA0.6PbI3
# 393 	 37	delta-CsPbI3		39	FAPb(Br0.2I0.8)3
# 400 	 60	tetragonal-MAPbBr3		50	MA0.8FA0.2PbBr3
# 403 	 32	cubic-CsPbBr3		11	Cs0.8MA0.2PbBr3
# 404 	 10	Cs0.6MA0.4PbBr3		27	CsPb(I0.8Br0.2)3
# 405 	 3	Cs0.8FA0.2PbBr3		26	CsPb(I0.6Br0.4)3
# 406 	 56	MAPb(Br0.4I0.6)3		59	cubic-MAPbBr3
# 408 	 49	MA0.6FA0.4PbBr3		2	Cs0.6FA0.4PbBr3
# 411 	 3	Cs0.8FA0.2PbBr3		26	CsPb(I0.6Br0.4)3
# 417 	 35	cubic-CsPbCl3		59	cubic-MAPbBr3
# 420 	 2	Cs0.6FA0.4PbBr3		8	Cs0.2MA0.8PbBr3
# 423 	 14	Cs0.6MA0.4PbI3		15	Cs0.8MA0.2PbI3
# 428 	 32	cubic-CsPbBr3		13	Cs0.4MA0.6PbI3
# 432 	 40	FAPb(Br0.4I0.6)3		53	MA0.6FA0.4PbI3
# 433 	 8	Cs0.2MA0.8PbBr3		55	MAPb(Br0.2I0.8)3
# 440 	 36	alpha-CsPbI3		27	CsPb(I0.8Br0.2)3
# 443 	 22	CsPb(Cl0.6Br0.4)3		43	cubic-FAPbBr3
# 444 	 36	alpha-CsPbI3		15	Cs0.8MA0.2PbI3
# 445 	 14	Cs0.6MA0.4PbI3		15	Cs0.8MA0.2PbI3
# 449 	 45	beta-FAPbI3		64	PbBr2
# 455 	 10	Cs0.6MA0.4PbBr3		3	Cs0.8FA0.2PbBr3
# 460 	 48	MA0.4FA0.6PbBr3		3	Cs0.8FA0.2PbBr3
# 462 	 49	MA0.6FA0.4PbBr3		32	cubic-CsPbBr3
# 463 	 24	CsPb(I0.2Br0.8)3		11	Cs0.8MA0.2PbBr3
# 467 	 12	Cs0.2MA0.8PbI3		13	Cs0.4MA0.6PbI3
# 469 	 24	CsPb(I0.2Br0.8)3		26	CsPb(I0.6Br0.4)3
# 472 	 14	Cs0.6MA0.4PbI3		13	Cs0.4MA0.6PbI3
# 473 	 32	cubic-CsPbBr3		36	alpha-CsPbI3
# 476 	 47	MA0.2FA0.8PbBr3		11	Cs0.8MA0.2PbBr3
# 477 	 20	CsPb(Cl0.2Br0.8)3		65	PbI2
# 478 	 20	CsPb(Cl0.2Br0.8)3		43	cubic-FAPbBr3
# 485 	 30	CsPb(I0.6Cl0.4)3		12	Cs0.2MA0.8PbI3
# 488 	 65	PbI2		15	Cs0.8MA0.2PbI3
# 489 	 28	CsPb(I0.2Cl0.8)3		29	CsPb(I0.4Cl0.6)3
# 493 	 22	CsPb(Cl0.6Br0.4)3		55	MAPb(Br0.2I0.8)3
# 497 	 10	Cs0.6MA0.4PbBr3		3	Cs0.8FA0.2PbBr3
# 503 	 9	Cs0.4MA0.6PbBr3		3	Cs0.8FA0.2PbBr3
# 505 	 60	tetragonal-MAPbBr3		59	cubic-MAPbBr3
# 506 	 28	CsPb(I0.2Cl0.8)3		3	Cs0.8FA0.2PbBr3
# 508 	 47	MA0.2FA0.8PbBr3		48	MA0.4FA0.6PbBr3
# 511 	 28	CsPb(I0.2Cl0.8)3		32	cubic-CsPbBr3
# 521 	 25	CsPb(I0.4Br0.6)3		31	CsPb(I0.8Cl0.2)3
# 524 	 20	CsPb(Cl0.2Br0.8)3		48	MA0.4FA0.6PbBr3
# 529 	 29	CsPb(I0.4Cl0.6)3		9	Cs0.4MA0.6PbBr3
# 531 	 47	MA0.2FA0.8PbBr3		11	Cs0.8MA0.2PbBr3
# 533 	 20	CsPb(Cl0.2Br0.8)3		48	MA0.4FA0.6PbBr3
# 537 	 43	cubic-FAPbBr3		11	Cs0.8MA0.2PbBr3
# 542 	 29	CsPb(I0.4Cl0.6)3		3	Cs0.8FA0.2PbBr3
# 543 	 61	Pnma-MAPbCl3		33	orthorhombic-CsPbBr3
# 544 	 29	CsPb(I0.4Cl0.6)3		27	CsPb(I0.8Br0.2)3
# 552 	 48	MA0.4FA0.6PbBr3		3	Cs0.8FA0.2PbBr3
# 557 	 14	Cs0.6MA0.4PbI3		15	Cs0.8MA0.2PbI3
# 560 	 7	Cs0.8FA0.2PbI3		40	FAPb(Br0.4I0.6)3
# 561 	 8	Cs0.2MA0.8PbBr3		13	Cs0.4MA0.6PbI3
# 563 	 6	Cs0.6FA0.4PbI3		5	Cs0.4FA0.6PbI3
# 564 	 23	CsPb(Cl0.8Br0.2)3		34	Pnma-CsPbCl3
# 571 	 47	MA0.2FA0.8PbBr3		62	alpha-MAPbI3
# 572 	 43	cubic-FAPbBr3		12	Cs0.2MA0.8PbI3
# 574 	 22	CsPb(Cl0.6Br0.4)3		62	alpha-MAPbI3
# 575 	 50	MA0.8FA0.2PbBr3		44	alpha-FAPbI3
# 576 	 19	CsPb2Br5		63	tetragonal-MAPbI3
# 577 	 25	CsPb(I0.4Br0.6)3		11	Cs0.8MA0.2PbBr3
# 580 	 55	MAPb(Br0.2I0.8)3		27	CsPb(I0.8Br0.2)3
# 581 	 36	alpha-CsPbI3		15	Cs0.8MA0.2PbI3
# 584 	 7	Cs0.8FA0.2PbI3		41	FAPb(Br0.6I0.4)3
# 586 	 1	Cs0.4FA0.6PbBr3		15	Cs0.8MA0.2PbI3
# 594 	 48	MA0.4FA0.6PbBr3		49	MA0.6FA0.4PbBr3
# 598 	 27	CsPb(I0.8Br0.2)3		8	Cs0.2MA0.8PbBr3
# 599 	 26	CsPb(I0.6Br0.4)3		0	Cs0.2FA0.8PbBr3
# 604 	 43	cubic-FAPbBr3		26	CsPb(I0.6Br0.4)3
# 605 	 13	Cs0.4MA0.6PbI3		12	Cs0.2MA0.8PbI3
# 608 	 38	gamma-CsPbI3		4	Cs0.2FA0.8PbI3
# 615 	 20	CsPb(Cl0.2Br0.8)3		55	MAPb(Br0.2I0.8)3
# 616 	 31	CsPb(I0.8Cl0.2)3		60	tetragonal-MAPbBr3
# 621 	 24	CsPb(I0.2Br0.8)3		12	Cs0.2MA0.8PbI3
# 623 	 23	CsPb(Cl0.8Br0.2)3		34	Pnma-CsPbCl3
# 625 	 14	Cs0.6MA0.4PbI3		13	Cs0.4MA0.6PbI3
# 628 	 9	Cs0.4MA0.6PbBr3		26	CsPb(I0.6Br0.4)3
# 635 	 15	Cs0.8MA0.2PbI3		36	alpha-CsPbI3
# 636 	 45	beta-FAPbI3		40	FAPb(Br0.4I0.6)3
# 637 	 13	Cs0.4MA0.6PbI3		27	CsPb(I0.8Br0.2)3
# 641 	 43	cubic-FAPbBr3		12	Cs0.2MA0.8PbI3
# 642 	 25	CsPb(I0.4Br0.6)3		3	Cs0.8FA0.2PbBr3
# 645 	 20	CsPb(Cl0.2Br0.8)3		55	MAPb(Br0.2I0.8)3
# 647 	 38	gamma-CsPbI3		39	FAPb(Br0.2I0.8)3
# 652 	 20	CsPb(Cl0.2Br0.8)3		26	CsPb(I0.6Br0.4)3
# 654 	 40	FAPb(Br0.4I0.6)3		41	FAPb(Br0.6I0.4)3
# 656 	 1	Cs0.4FA0.6PbBr3		9	Cs0.4MA0.6PbBr3
# 661 	 9	Cs0.4MA0.6PbBr3		2	Cs0.6FA0.4PbBr3
# 663 	 26	CsPb(I0.6Br0.4)3		25	CsPb(I0.4Br0.6)3
# 665 	 26	CsPb(I0.6Br0.4)3		65	PbI2
# 666 	 50	MA0.8FA0.2PbBr3		30	CsPb(I0.6Cl0.4)3
# 668 	 23	CsPb(Cl0.8Br0.2)3		20	CsPb(Cl0.2Br0.8)3
# 672 	 2	Cs0.6FA0.4PbBr3		62	alpha-MAPbI3
# 677 	 34	Pnma-CsPbCl3		35	cubic-CsPbCl3
# 682 	 9	Cs0.4MA0.6PbBr3		32	cubic-CsPbBr3
# 686 	 29	CsPb(I0.4Cl0.6)3		3	Cs0.8FA0.2PbBr3
# 688 	 51	MA0.2FA0.8PbI3		4	Cs0.2FA0.8PbI3
# 691 	 0	Cs0.2FA0.8PbBr3		27	CsPb(I0.8Br0.2)3
# 695 	 58	MAPb(Br0.8I0.2)3		43	cubic-FAPbBr3
# 700 	 57	MAPb(Br0.6I0.4)3		43	cubic-FAPbBr3
# 701 	 3	Cs0.8FA0.2PbBr3		11	Cs0.8MA0.2PbBr3
# 703 	 29	CsPb(I0.4Cl0.6)3		25	CsPb(I0.4Br0.6)3
# 706 	 64	PbBr2		6	Cs0.6FA0.4PbI3
# 709 	 10	Cs0.6MA0.4PbBr3		25	CsPb(I0.4Br0.6)3
# 711 	 31	CsPb(I0.8Cl0.2)3		36	alpha-CsPbI3
# 720 	 1	Cs0.4FA0.6PbBr3		11	Cs0.8MA0.2PbBr3
# 721 	 31	CsPb(I0.8Cl0.2)3		12	Cs0.2MA0.8PbI3
# 724 	 57	MAPb(Br0.6I0.4)3		43	cubic-FAPbBr3
# 732 	 29	CsPb(I0.4Cl0.6)3		25	CsPb(I0.4Br0.6)3
# 737 	 10	Cs0.6MA0.4PbBr3		3	Cs0.8FA0.2PbBr3
# 738 	 26	CsPb(I0.6Br0.4)3		15	Cs0.8MA0.2PbI3
# 740 	 8	Cs0.2MA0.8PbBr3		11	Cs0.8MA0.2PbBr3
# 742 	 25	CsPb(I0.4Br0.6)3		12	Cs0.2MA0.8PbI3
# 746 	 24	CsPb(I0.2Br0.8)3		26	CsPb(I0.6Br0.4)3
# 748 	 35	cubic-CsPbCl3		22	CsPb(Cl0.6Br0.4)3
# 749 	 51	MA0.2FA0.8PbI3		4	Cs0.2FA0.8PbI3
# 751 	 15	Cs0.8MA0.2PbI3		36	alpha-CsPbI3
# 752 	 49	MA0.6FA0.4PbBr3		55	MAPb(Br0.2I0.8)3
# 765 	 15	Cs0.8MA0.2PbI3		26	CsPb(I0.6Br0.4)3
# 770 	 49	MA0.6FA0.4PbBr3		10	Cs0.6MA0.4PbBr3
# 775 	 24	CsPb(I0.2Br0.8)3		31	CsPb(I0.8Cl0.2)3
# 783 	 23	CsPb(Cl0.8Br0.2)3		59	cubic-MAPbBr3
# 784 	 14	Cs0.6MA0.4PbI3		15	Cs0.8MA0.2PbI3
# 795 	 13	Cs0.4MA0.6PbI3		12	Cs0.2MA0.8PbI3
# 800 	 49	MA0.6FA0.4PbBr3		0	Cs0.2FA0.8PbBr3
# 803 	 30	CsPb(I0.6Cl0.4)3		15	Cs0.8MA0.2PbI3
# 807 	 62	alpha-MAPbI3		14	Cs0.6MA0.4PbI3
# 811 	 13	Cs0.4MA0.6PbI3		12	Cs0.2MA0.8PbI3
# 812 	 16	Cs4PbBr6		51	MA0.2FA0.8PbI3
# 814 	 21	CsPb(Cl0.4Br0.6)3		47	MA0.2FA0.8PbBr3
# 815 	 1	Cs0.4FA0.6PbBr3		15	Cs0.8MA0.2PbI3
# 816 	 54	MA0.8FA0.2PbI3		41	FAPb(Br0.6I0.4)3
# 817 	 23	CsPb(Cl0.8Br0.2)3		49	MA0.6FA0.4PbBr3
# 819 	 49	MA0.6FA0.4PbBr3		55	MAPb(Br0.2I0.8)3
# 820 	 7	Cs0.8FA0.2PbI3		41	FAPb(Br0.6I0.4)3
# 825 	 28	CsPb(I0.2Cl0.8)3		3	Cs0.8FA0.2PbBr3
# 828 	 58	MAPb(Br0.8I0.2)3		43	cubic-FAPbBr3
# 837 	 23	CsPb(Cl0.8Br0.2)3		35	cubic-CsPbCl3
# 838 	 58	MAPb(Br0.8I0.2)3		26	CsPb(I0.6Br0.4)3
# 847 	 28	CsPb(I0.2Cl0.8)3		25	CsPb(I0.4Br0.6)3
# 849 	 1	Cs0.4FA0.6PbBr3		24	CsPb(I0.2Br0.8)3
# 851 	 14	Cs0.6MA0.4PbI3		13	Cs0.4MA0.6PbI3
# 853 	 2	Cs0.6FA0.4PbBr3		9	Cs0.4MA0.6PbBr3
# 855 	 45	beta-FAPbI3		41	FAPb(Br0.6I0.4)3
# 856 	 20	CsPb(Cl0.2Br0.8)3		62	alpha-MAPbI3
# 859 	 14	Cs0.6MA0.4PbI3		36	alpha-CsPbI3
# 872 	 1	Cs0.4FA0.6PbBr3		29	CsPb(I0.4Cl0.6)3
# 877 	 7	Cs0.8FA0.2PbI3		41	FAPb(Br0.6I0.4)3
# 880 	 2	Cs0.6FA0.4PbBr3		8	Cs0.2MA0.8PbBr3
# 882 	 48	MA0.4FA0.6PbBr3		55	MAPb(Br0.2I0.8)3
# 887 	 55	MAPb(Br0.2I0.8)3		31	CsPb(I0.8Cl0.2)3
# 888 	 1	Cs0.4FA0.6PbBr3		31	CsPb(I0.8Cl0.2)3
# 890 	 44	alpha-FAPbI3		27	CsPb(I0.8Br0.2)3
# 893 	 3	Cs0.8FA0.2PbBr3		10	Cs0.6MA0.4PbBr3
# 897 	 60	tetragonal-MAPbBr3		50	MA0.8FA0.2PbBr3
# 899 	 61	Pnma-MAPbCl3		64	PbBr2
# 900 	 2	Cs0.6FA0.4PbBr3		8	Cs0.2MA0.8PbBr3
# 906 	 29	CsPb(I0.4Cl0.6)3		3	Cs0.8FA0.2PbBr3
# 907 	 27	CsPb(I0.8Br0.2)3		36	alpha-CsPbI3
# 910 	 56	MAPb(Br0.4I0.6)3		43	cubic-FAPbBr3
# 912 	 28	CsPb(I0.2Cl0.8)3		3	Cs0.8FA0.2PbBr3
# 922 	 35	cubic-CsPbCl3		56	MAPb(Br0.4I0.6)3
# 925 	 43	cubic-FAPbBr3		26	CsPb(I0.6Br0.4)3
# 927 	 38	gamma-CsPbI3		37	delta-CsPbI3
# 933 	 16	Cs4PbBr6		51	MA0.2FA0.8PbI3
# 938 	 60	tetragonal-MAPbBr3		50	MA0.8FA0.2PbBr3
# 939 	 25	CsPb(I0.4Br0.6)3		30	CsPb(I0.6Cl0.4)3
# 940 	 49	MA0.6FA0.4PbBr3		11	Cs0.8MA0.2PbBr3
# 941 	 43	cubic-FAPbBr3		26	CsPb(I0.6Br0.4)3
# 943 	 14	Cs0.6MA0.4PbI3		36	alpha-CsPbI3
# 948 	 45	beta-FAPbI3		7	Cs0.8FA0.2PbI3
# 951 	 22	CsPb(Cl0.6Br0.4)3		59	cubic-MAPbBr3
# 955 	 62	alpha-MAPbI3		12	Cs0.2MA0.8PbI3
# 956 	 3	Cs0.8FA0.2PbBr3		10	Cs0.6MA0.4PbBr3
# 958 	 10	Cs0.6MA0.4PbBr3		26	CsPb(I0.6Br0.4)3
# 961 	 35	cubic-CsPbCl3		62	alpha-MAPbI3
# 962 	 29	CsPb(I0.4Cl0.6)3		10	Cs0.6MA0.4PbBr3
# 963 	 56	MAPb(Br0.4I0.6)3		10	Cs0.6MA0.4PbBr3
# 972 	 13	Cs0.4MA0.6PbI3		12	Cs0.2MA0.8PbI3
# 978 	 0	Cs0.2FA0.8PbBr3		27	CsPb(I0.8Br0.2)3
# 981 	 29	CsPb(I0.4Cl0.6)3		27	CsPb(I0.8Br0.2)3
# 983 	 38	gamma-CsPbI3		39	FAPb(Br0.2I0.8)3
# 985 	 28	CsPb(I0.2Cl0.8)3		31	CsPb(I0.8Cl0.2)3
# 990 	 1	Cs0.4FA0.6PbBr3		24	CsPb(I0.2Br0.8)3
# 997 	 57	MAPb(Br0.6I0.4)3		58	MAPb(Br0.8I0.2)3
# 998 	 11	Cs0.8MA0.2PbBr3		25	CsPb(I0.4Br0.6)3
# 999 	 50	MA0.8FA0.2PbBr3		59	cubic-MAPbBr3

# %%
load_plt_setting()

twotheta = np.arange(5.00, 60.01, 0.01)
data1 = Xs[604,:,0]
data2 = dataloader.load_ref(26)
data3 = dataloader.load_ref(43)

alpha = 0.7

fig, (ax0, ax1, ax2) = plt.subplots(3,1, sharex=True, gridspec_kw=dict(height_ratios=[3, 1, 1]),figsize=(12, 10))
mat1 = ax0.plot(twotheta, data1, linewidth=1, color=colors.to_rgba('#118ab2'))
ax0.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
ax0.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax0.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
ax0.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax0.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax0.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax0.axes.set_ylim([-0.05,1.05])

mat2 = ax1.plot(twotheta, data2, linewidth=2, color=colors.to_rgba('#ffd166'))
ax1.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
ax1.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax1.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
ax1.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax1.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax1.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax1.axes.set_ylim([0,1.3])

mat2 = ax2.plot(twotheta, data3, linewidth=2, color=colors.to_rgba('#ef476f'))
ax2.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
ax2.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax2.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
ax2.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax2.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax2.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax2.axes.set_ylim([0,1.3])
# ax2.axes.set_xlim([22.5,30])
ax2.axes.set_xlim([twotheta[0],twotheta[-1]])

plt.text(0.03, 0.85, 'Input', fontsize=30, transform=ax0.transAxes, horizontalalignment='left')
plt.text(0.95, 0.85, r'$\alpha$'+'-'+r'$\mathrm{FAPbBr_{3}}$', fontsize=30, transform=ax0.transAxes, horizontalalignment='right')
plt.text(0.03, 0.65, 'No label', fontsize=30, transform=ax1.transAxes, horizontalalignment='left')
plt.text(0.95, 0.65, r'$\mathrm{CsPb(I_{0.6}Br_{0.4})_{3}}$', fontsize=30, transform=ax1.transAxes, horizontalalignment='right')

plt.text(0.03, 0.65, '"FA Pb Br" label', fontsize=30, transform=ax2.transAxes, horizontalalignment='left')
plt.text(0.95, 0.65, r'$\alpha$'+'-'+r'$\mathrm{FAPbBr_{3}}$', fontsize=30, transform=ax2.transAxes, horizontalalignment='right')

# plt.text(0.96, 0.75, 'n = 1000', fontsize=30, transform=ax0.transAxes, horizontalalignment='right')

plt.subplots_adjust(hspace=.0)

ax2.set_xlabel(r'2$\Theta$ (degree)', labelpad=10, fontsize=34)
ax0.set_ylabel(r'Normalized intensity                      ', labelpad=20, fontsize=34)
plt.savefig(os.path.join(folder, 'models', model_folder, 'Wrong_prediction.png'), 
            format='png', dpi=300, transparent=True, bbox_inches='tight')

# %% [markdown]
# ## Fig 2d

# %%
default_label_pred = y_pred

# %%
FAPbI_pred = y_pred

# %%
CsPbIBr_pred = y_pred

# %%
np.savetxt(os.path.join(folder, 'models', model_folder, 'Probability_vs_prompt.csv'),  
               np.swapaxes(np.asarray([default_label_pred,FAPbI_pred,CsPbIBr_pred]),0,1), 
               header='Default prompt / FA-Pb-I prompt / Cs-Pb-I-Br prompt',)

# %%
load_plt_setting()

sample_names = ['Default label','"FA Pb I" label','"Cs Pb I Br" label']

data1 = default_label_pred
data2 = FAPbI_pred
data3 = CsPbIBr_pred
# samples = [r'TiO$_{2}$ 0 mol% K$^{+}$',r'TiO$_{2}$ 10 mol% K$^{+}$',r'SnO$_{2}$ 0 mol% K$^{+}$',r'SnO$_{2}$ 10 mol% K$^{+}$']

wav_range = (-0.5,65.5)
bins = round((wav_range[1]-wav_range[0])*1)
alpha = 0.7

kwargs1 = dict(histtype='stepfilled', density=True, bins=bins, ec="black", range=wav_range, fc=colors.to_rgba('#118ab2')[:-1]+(alpha,))
kwargs2 = dict(histtype='stepfilled', density=True, bins=bins, ec="black", range=wav_range, fc=colors.to_rgba('#ffd166')[:-1]+(alpha,))
kwargs3 = dict(histtype='stepfilled', density=True, bins=bins, ec="black", range=wav_range, fc=colors.to_rgba('#ef476f')[:-1]+(alpha,))
# kwargs4 = dict(histtype='stepfilled', density=False, bins=bins, ec="black", range=wav_range, fc = colors.to_rgba('#118ab2')[:-1]+(alpha,))

fig, (ax0, ax1, ax2) = plt.subplots(3,1, sharex=True, gridspec_kw=dict(height_ratios=[1, 1, 1]),figsize=(12, 10))
mat1 = ax0.hist(data1, **kwargs1, label=sample_names[0], linewidth=1)
ax0.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
ax0.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax0.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
ax0.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax0.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax0.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax0.axes.set_ylim([0,0.11])

mat2 = ax1.hist(data2, **kwargs2, label=sample_names[1], linewidth=1)
ax1.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
ax1.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax1.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
ax1.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax1.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax1.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax1.axes.set_ylim([0,0.49])

mat2 = ax2.hist(data3, **kwargs3, label=sample_names[2], linewidth=1)
ax2.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
ax2.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax2.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
ax2.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax2.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax2.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax2.axes.set_ylim([0,0.28])

plt.text(0.03, 0.75, sample_names[0], fontsize=30, transform=ax0.transAxes, horizontalalignment='left')
plt.text(0.03, 0.75, sample_names[1], fontsize=30, transform=ax1.transAxes, horizontalalignment='left')
plt.text(0.03, 0.75, sample_names[2], fontsize=30, transform=ax2.transAxes, horizontalalignment='left')

plt.text(0.96, 0.75, 'n = 1000', fontsize=30, transform=ax0.transAxes, horizontalalignment='right')

plt.subplots_adjust(hspace=.0)

ax2.set_xlabel(r'Class index', labelpad=10, fontsize=34)
ax1.set_ylabel(r'Prediction probability', labelpad=30, fontsize=34)
plt.savefig(os.path.join(folder, 'models', model_folder, 'Probability_vs_prompt.png'), 
            format='png', dpi=300, transparent=True, bbox_inches='tight')

# %% [markdown]
# # 2.2 Multi label classification

# %%
model_folder = '20241020 random phase orientation full prompt 50 dynamic lr'
num_of_epochs = 30000000
cif_folder = os.path.join(folder, 'cif')
visual_embedding_dim = 50
model = VisualBertForQuestionAnswering.from_pretrained(os.path.join(folder, 'models', 
                                                                    model_folder, '{}'.format(num_of_epochs))).to('cuda')

# %%
full_result = {}
# prompt_type_list = ['none','eds','full']
prompt_type_list = ['full']
n_mix = [1,2,3]
random_phase = True

for prompt_type in prompt_type_list:
    full_result[prompt_type] = {}
    if random_phase:
        for n in n_mix:
            full_result[prompt_type]['{}'.format(n)] = {'y_true':[], 'y_pred':[], 'y_acc':[], 'n_true':[], 'n_pred':[], 'n_acc':[]}
    else:
        full_result[prompt_type]['{}'.format(n)] = {'y_true':[], 'y_pred':[], 'y_acc':[]}
# Out:
# test dataset loaded.

# %%
for n in n_mix:
    
    file_name = 'test_dataset_{}phase_orientation.npy'.format(n)
    
    try:
        with open(os.path.join(cif_folder, file_name), 'rb') as handle:
            test_dataset = joblib.load(handle)

        Xs, Ys, element_list, formula_list = test_dataset['Xs'], test_dataset['Ys'], test_dataset['element_list'], test_dataset['formula_list']
        print('test dataset loaded.')

    except:
        Xs, Ys, element_list, formula_list, _ = dataloader.load_data(batch_size=2000, n_mix=[n], resonable_mixing=True,
                                                                  high_orientation_probability=0.2, crystal_size_range=(5, 20), 
                                                                  intensity_variation_range=(0.01, 1))
        test_dataset = {'Xs':Xs, 'Ys':Ys, 'element_list':element_list, 'formula_list':formula_list}

        with open(os.path.join(cif_folder, file_name), 'wb') as handle:
            joblib.dump(test_dataset, handle)
        print('test dataset generated.')

    print(np.sum(Ys,axis=0))

    if random_phase:
        n_mix_list_onehot = np.zeros((Ys.shape[0], len(n_mix)))
        n_mix_list_onehot[np.arange(Ys.shape[0]), n_mix.index(n)] = 1
        Ys = np.concatenate((Ys,n_mix_list_onehot),axis=1)

    for prompt_type in prompt_type_list:

        for i in range(len(element_list)):

            Xs_test = Xs[i:i+1,:-1,:].reshape((1,int(Xs.shape[1]/visual_embedding_dim),visual_embedding_dim))

            X_prompts = []
            random.shuffle(element_list[i])
            if prompt_type == 'none':
                X_prompts.append('')
            elif prompt_type == 'eds':
                X_prompts.append(' '.join([element for element in element_list[i] if element not in ['FA', 'MA']]))
            elif prompt_type == 'full':
                X_prompts.append(' '.join(element_list[i]))

            visual_embeds = torch.from_numpy(Xs_test).to(dtype=torch.float32)
            visual_attention_mask = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)
            visual_token_type_ids = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)

            inputs = tokenizer(X_prompts, return_tensors="pt", padding=True)
            inputs.update(
                {
                    "visual_embeds": visual_embeds,
                    "visual_token_type_ids": visual_token_type_ids,
                    "visual_attention_mask": visual_attention_mask,
                }
            )

            labels = torch.from_numpy(Ys[i:i+1]).to(dtype=torch.float32)
            outputs = model(**inputs.to('cuda'), output_attentions=True)
            
            if random_phase:
                y_true = np.array(Ys[i:i+1])[0,:-len(n_mix)]
                y_pred = np.array(outputs.logits.detach().cpu())[0,:-len(n_mix)]
                n_true = np.array(Ys[i:i+1])[0,-len(n_mix):]
                n_pred = np.array(outputs.logits.detach().cpu())[0,-len(n_mix):]
                n_true_idx = np.where(n_true!=0)[0]
                n_pred_idx = np.argpartition(n_pred,-1)[-1:]
                
                if set(list(n_true_idx)) == set(list(n_pred_idx)):
                    full_result[prompt_type]['{}'.format(n)]['n_acc'].append(0)
                else:
                    full_result[prompt_type]['{}'.format(n)]['n_acc'].append(1)
                    
                full_result[prompt_type]['{}'.format(n)]['n_true'].append(n_true)
                full_result[prompt_type]['{}'.format(n)]['n_pred'].append(n_pred)
            else:
                y_true = np.array(Ys[i:i+1])[0]
                y_pred = np.array(outputs.logits.detach().cpu())[0]
            
            y_true_idx = np.where(y_true!=0)[0]
            y_pred_idx = np.argpartition(y_pred,-n)[-n:]
            
            if set(list(y_true_idx)) == set(list(y_pred_idx)):
                full_result[prompt_type]['{}'.format(n)]['y_acc'].append(0)
            else:
                full_result[prompt_type]['{}'.format(n)]['y_acc'].append(1)
                
            full_result[prompt_type]['{}'.format(n)]['y_true'].append(y_true)
            full_result[prompt_type]['{}'.format(n)]['y_pred'].append(y_pred)
            
            if random_phase:
                print(i,formula_list[i],y_true_idx,y_pred_idx,n_true_idx,n_pred_idx)
            else:
                print(i,formula_list[i],y_true_idx,y_pred_idx)
# Out:
# 0 ['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'MA0.4FA0.6PbBr3'] [48, 59, 60] [59, 43, 49]
# 1 ['tetragonal-MAPbBr3', 'PbBr2', 'cubic-MAPbBr3'] [59, 60, 64] [60, 64, 59]
# 2 ['Cs4PbBr6', 'CsPb2Br5', 'CsBr'] [16, 17, 19] [19, 16, 17]
# 3 ['alpha-CsPbI3', 'delta-CsPbI3', 'PbI2'] [36, 37, 65] [65, 37, 36]
# 4 ['cubic-CsPbBr3', 'CsPb(I0.8Br0.2)3', 'PbI2'] [27, 32, 65] [27, 32, 65]
# 5 ['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3'] [59, 60, 64] [64, 59, 60]
# 6 ['MA0.4FA0.6PbI3', 'MA0.2FA0.8PbI3', 'delta-FAPbI3'] [46, 51, 52] [51, 44, 52]
# 7 ['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'PbBr2'] [59, 60, 64] [64, 59, 60]
# 8 ['PbI2', 'MAPb(Br0.8I0.2)3', 'tetragonal-MAPbBr3'] [58, 60, 65] [65, 34, 58]
# 9 ['beta-FAPbI3', 'PbI2', 'MA0.4FA0.6PbI3'] [45, 52, 65] [45, 52, 65]
# 10 ['CsPb(Cl0.8Br0.2)3', 'cubic-CsPbBr3', 'CsPb(Cl0.2Br0.8)3'] [20, 23, 32] [0, 3, 32]
# 11 ['cubic-CsPbBr3', 'Cs0.6MA0.4PbBr3', 'orthorhombic-CsPbBr3'] [10, 32, 33] [33, 32, 9]
# 12 ['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3'] [59, 60, 64] [64, 60, 59]
# 13 ['gamma-CsPbI3', 'Cs0.4MA0.6PbI3', 'PbI2'] [13, 38, 65] [38, 44, 36]
# 14 ['beta-FAPbI3', 'PbI2', 'alpha-FAPbI3'] [44, 45, 65] [65, 44, 45]
# 15 ['beta-FAPbI3', 'PbI2', 'alpha-FAPbI3'] [44, 45, 65] [45, 65, 44]
# 16 ['beta-FAPbI3', 'cubic-FAPbBr3', 'PbI2'] [43, 45, 65] [45, 65, 62]
# 17 ['Cs4PbBr6', 'CsBr', 'Cs0.8MA0.2PbBr3'] [11, 16, 17] [16, 17, 11]
# 18 ['alpha-CsPbI3', 'Cs0.6FA0.4PbI3', 'delta-CsPbI3'] [6, 36, 37] [36, 6, 37]
# 19 ['alpha-CsPbI3', 'Cs4PbBr6', 'PbBr2'] [16, 36, 64] [16, 64, 17]
# 20 ['Cs0.2MA0.8PbI3', 'Cs0.4MA0.6PbI3', 'alpha-MAPbI3'] [12, 13, 62] [13, 14, 12]
# 21 ['Cs0.2FA0.8PbBr3', 'Cs0.4FA0.6PbBr3', 'PbBr2'] [0, 1, 64] [1, 2, 64]
# 22 ['tetragonal-MAPbBr3', 'PbI2', 'MAPb(Br0.2I0.8)3'] [55, 60, 65] [65, 60, 36]
# 23 ['PbI2', 'beta-FAPbI3', 'delta-FAPbI3'] [45, 46, 65] [65, 46, 45]
# 24 ['alpha-FAPbI3', 'CsI', 'Cs0.6FA0.4PbI3'] [6, 18, 44] [44, 6, 65]
# 25 ['FAPb(Br0.4I0.6)3', 'PbI2', 'cubic-FAPbBr3'] [40, 43, 65] [36, 40, 46]
# 26 ['CsPb(Cl0.2Br0.8)3', 'CsPb(Cl0.6Br0.4)3', 'Pnma-CsPbCl3'] [20, 22, 34] [20, 34, 22]
# 27 ['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'PbBr2'] [59, 60, 64] [60, 64, 59]
# 28 ['gamma-CsPbI3', 'alpha-CsPbI3', 'Cs0.4FA0.6PbI3'] [5, 36, 38] [64, 39, 38]
# 29 ['cubic-CsPbBr3', 'Cs0.2FA0.8PbBr3', 'Cs0.8FA0.2PbBr3'] [0, 3, 32] [36, 25, 24]
# 30 ['alpha-CsPbI3', 'Cs0.8MA0.2PbI3', 'delta-CsPbI3'] [15, 36, 37] [37, 36, 15]
# 31 ['Cs0.2MA0.8PbI3', 'gamma-CsPbI3', 'Cs0.4MA0.6PbI3'] [12, 13, 38] [38, 12, 13]
# 32 ['cubic-MAPbBr3', 'MA0.8FA0.2PbBr3', 'cubic-FAPbBr3'] [43, 50, 59] [43, 59, 47]
# 33 ['FAPb(Br0.4I0.6)3', 'delta-FAPbI3', 'beta-FAPbI3'] [40, 45, 46] [40, 45, 46]
# 34 ['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2'] [62, 63, 65] [65, 63, 62]
# 35 ['cubic-CsPbBr3', 'CsPb(I0.4Br0.6)3', 'delta-CsPbI3'] [25, 32, 37] [37, 65, 18]
# 36 ['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3'] [59, 60, 64] [60, 59, 64]
# 37 ['Pnma-CsPbCl3', 'CsBr', 'CsPb(Cl0.2Br0.8)3'] [17, 20, 34] [20, 34, 22]
# 38 ['orthorhombic-CsPbBr3', 'CsPb(Cl0.8Br0.2)3', 'Cs4PbBr6'] [16, 23, 33] [33, 16, 32]
# 39 ['CsBr', 'PbBr2', 'cubic-CsPbBr3'] [17, 32, 64] [64, 17, 32]
# 40 ['Cs4PbBr6', 'PbBr2', 'orthorhombic-CsPbBr3'] [16, 33, 64] [33, 16, 19]
# 41 ['CsPb2Br5', 'PbI2', 'gamma-CsPbI3'] [19, 38, 65] [38, 65, 46]
# 42 ['PbI2', 'delta-CsPbI3', 'CsI'] [18, 37, 65] [37, 65, 18]
# 43 ['Cs4PbBr6', 'orthorhombic-CsPbBr3', 'Cs0.2MA0.8PbBr3'] [8, 16, 33] [33, 16, 8]
# 44 ['Cs4PbBr6', 'CsPb2Br5', 'CsPb(Cl0.6Br0.4)3'] [16, 19, 22] [19, 16, 32]
# 45 ['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2'] [59, 60, 64] [64, 60, 59]
# 46 ['PbBr2', 'CsBr', 'Cs4PbBr6'] [16, 17, 64] [64, 19, 37]
# 47 ['alpha-FAPbI3', 'delta-FAPbI3', 'PbI2'] [44, 46, 65] [46, 44, 65]
# 48 ['PbI2', 'tetragonal-MAPbI3', 'alpha-MAPbI3'] [62, 63, 65] [62, 63, 65]
# 49 ['cubic-FAPbBr3', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3'] [43, 59, 60] [43, 60, 50]
# 50 ['Cs0.2FA0.8PbBr3', 'CsBr', 'CsPb2Br5'] [0, 17, 19] [19, 17, 0]
# 51 ['PbI2', 'CsPb(I0.4Cl0.6)3', 'CsI'] [18, 29, 65] [18, 65, 29]
# 52 ['PbBr2', 'cubic-CsPbBr3', 'orthorhombic-CsPbBr3'] [32, 33, 64] [64, 33, 32]
# 53 ['orthorhombic-CsPbBr3', 'alpha-CsPbI3', 'delta-CsPbI3'] [33, 36, 37] [33, 38, 27]
# 54 ['orthorhombic-CsPbBr3', 'Cs0.8MA0.2PbBr3', 'tetragonal-MAPbBr3'] [11, 33, 60] [33, 32, 2]
# 55 ['delta-FAPbI3', 'beta-FAPbI3', 'PbI2'] [45, 46, 65] [65, 45, 46]
# 56 ['CsPb(Cl0.8Br0.2)3', 'CsPb2Br5', 'cubic-CsPbBr3'] [19, 23, 32] [32, 19, 27]
# 57 ['CsBr', 'cubic-CsPbBr3', 'CsPb2Br5'] [17, 19, 32] [19, 17, 32]
# 58 ['gamma-CsPbI3', 'Cs0.8MA0.2PbI3', 'CsI'] [15, 18, 38] [65, 38, 36]
# 59 ['MAPb(Br0.2I0.8)3', 'MAPb(Br0.4I0.6)3', 'cubic-MAPbBr3'] [55, 56, 59] [59, 62, 56]
# 60 ['Cs0.2FA0.8PbI3', 'alpha-CsPbI3', 'delta-FAPbI3'] [4, 36, 46] [4, 18, 45]
# 61 ['alpha-CsPbI3', 'cubic-CsPbCl3', 'delta-CsPbI3'] [35, 36, 37] [37, 36, 18]
# 62 ['CsPb2Br5', 'Cs4PbBr6', 'PbBr2'] [16, 19, 64] [19, 16, 64]
# 63 ['MA0.8FA0.2PbI3', 'MA0.2FA0.8PbI3', 'tetragonal-MAPbI3'] [51, 54, 63] [63, 51, 54]
# 64 ['Cs4PbBr6', 'Cs0.4FA0.6PbBr3', 'Cs0.8FA0.2PbBr3'] [1, 3, 16] [3, 10, 1]
# 65 ['PbI2', 'delta-CsPbI3', 'gamma-CsPbI3'] [37, 38, 65] [33, 64, 16]
# 66 ['Cs0.6MA0.4PbBr3', 'Cs0.2MA0.8PbBr3', 'tetragonal-MAPbBr3'] [8, 10, 60] [8, 10, 2]
# 67 ['CsPb(Cl0.2Br0.8)3', 'PbBr2', 'Cs4PbBr6'] [16, 20, 64] [16, 33, 19]
# 68 ['PbBr2', 'Cs4PbBr6', 'CsBr'] [16, 17, 64] [17, 64, 16]
# 69 ['PbBr2', 'CsBr', 'cubic-CsPbBr3'] [17, 32, 64] [64, 62, 65]
# 70 ['cubic-FAPbBr3', 'PbBr2', 'FAPb(Br0.4I0.6)3'] [40, 43, 64] [43, 65, 4]
# 71 ['alpha-MAPbI3', 'PbI2', 'tetragonal-MAPbI3'] [62, 63, 65] [62, 65, 63]
# 72 ['orthorhombic-CsPbBr3', 'Cs4PbBr6', 'cubic-CsPbBr3'] [16, 32, 33] [16, 33, 32]
# 73 ['beta-FAPbI3', 'alpha-FAPbI3', 'delta-FAPbI3'] [44, 45, 46] [44, 46, 45]
# 74 ['tetragonal-MAPbBr3', 'Cs0.6MA0.4PbBr3', 'cubic-MAPbBr3'] [10, 59, 60] [59, 10, 9]
# 75 ['delta-CsPbI3', 'CsI', 'Cs0.8MA0.2PbI3'] [15, 18, 37] [37, 65, 18]
# 76 ['CsPb(Cl0.2Br0.8)3', 'orthorhombic-CsPbBr3', 'CsPb(Cl0.6Br0.4)3'] [20, 22, 33] [33, 22, 23]
# 77 ['PbI2', 'alpha-MAPbI3', 'tetragonal-MAPbI3'] [62, 63, 65] [65, 63, 62]
# 78 ['MA0.8FA0.2PbI3', 'beta-FAPbI3', 'tetragonal-MAPbI3'] [45, 54, 63] [54, 46, 63]
# 79 ['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2'] [62, 63, 65] [65, 62, 63]
# 80 ['PbI2', 'orthorhombic-CsPbBr3', 'PbBr2'] [33, 64, 65] [33, 64, 16]
# 81 ['CsPb(I0.8Br0.2)3', 'CsPb2Br5', 'CsBr'] [17, 19, 27] [17, 19, 27]
# 82 ['Pnma-CsPbCl3', 'alpha-CsPbI3', 'CsPb(I0.6Cl0.4)3'] [30, 34, 36] [36, 30, 25]
# 83 ['PbI2', 'delta-FAPbI3', 'FAPb(Br0.8I0.2)3'] [42, 46, 65] [46, 42, 41]
# 84 ['alpha-CsPbI3', 'Cs0.8MA0.2PbI3', 'tetragonal-MAPbI3'] [15, 36, 63] [36, 15, 34]
# 85 ['CsPb(I0.4Cl0.6)3', 'CsPb(I0.2Cl0.8)3', 'alpha-CsPbI3'] [28, 29, 36] [29, 36, 28]
# 86 ['beta-FAPbI3', 'delta-FAPbI3', 'alpha-FAPbI3'] [44, 45, 46] [45, 46, 44]
# 87 ['Cs4PbBr6', 'Cs0.2FA0.8PbBr3', 'PbBr2'] [0, 16, 64] [64, 16, 1]
# 88 ['FAPb(Br0.6I0.4)3', 'PbI2', 'PbBr2'] [41, 64, 65] [41, 44, 65]
# 89 ['PbI2', 'CsPb(I0.8Cl0.2)3', 'Pnma-CsPbCl3'] [31, 34, 65] [34, 65, 30]
# 90 ['beta-FAPbI3', 'PbI2', 'delta-FAPbI3'] [45, 46, 65] [65, 45, 46]
# 91 ['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2'] [59, 60, 64] [60, 64, 59]
# 92 ['Cs0.4FA0.6PbBr3', 'cubic-FAPbBr3', 'Cs0.2FA0.8PbBr3'] [0, 1, 43] [0, 1, 3]
# 93 ['alpha-CsPbI3', 'CsPb(I0.4Cl0.6)3', 'CsPb(I0.2Cl0.8)3'] [28, 29, 36] [36, 27, 25]
# 94 ['tetragonal-MAPbBr3', 'MA0.2FA0.8PbBr3', 'MA0.8FA0.2PbBr3'] [47, 50, 60] [50, 47, 60]
# 95 ['delta-FAPbI3', 'alpha-FAPbI3', 'FAPb(Br0.8I0.2)3'] [42, 44, 46] [44, 42, 46]
# 96 ['delta-CsPbI3', 'gamma-CsPbI3', 'PbI2'] [37, 38, 65] [37, 38, 34]
# 97 ['PbI2', 'alpha-CsPbI3', 'beta-FAPbI3'] [36, 45, 65] [45, 36, 44]
# 98 ['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2'] [62, 63, 65] [62, 63, 65]
# 99 ['CsBr', 'cubic-CsPbBr3', 'orthorhombic-CsPbBr3'] [17, 32, 33] [33, 17, 18]
# 100 ['CsPb(I0.6Cl0.4)3', 'delta-CsPbI3', 'CsPb(I0.2Cl0.8)3'] [28, 30, 37] [29, 37, 18]
# 101 ['delta-FAPbI3', 'alpha-FAPbI3', 'PbI2'] [44, 46, 65] [46, 44, 65]
# 102 ['alpha-FAPbI3', 'delta-FAPbI3', 'cubic-FAPbBr3'] [43, 44, 46] [46, 44, 65]
# 103 ['alpha-MAPbI3', 'alpha-FAPbI3', 'MA0.6FA0.4PbI3'] [44, 53, 62] [44, 62, 53]
# 104 ['MAPb(Br0.4I0.6)3', 'PbBr2', 'alpha-MAPbI3'] [56, 62, 64] [64, 62, 56]
# 105 ['CsI', 'alpha-CsPbI3', 'gamma-CsPbI3'] [18, 36, 38] [38, 36, 18]
# 106 ['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3'] [59, 60, 64] [64, 60, 59]
# 107 ['beta-FAPbI3', 'FAPb(Br0.6I0.4)3', 'delta-FAPbI3'] [41, 45, 46] [46, 41, 45]
# 108 ['CsPb(I0.8Cl0.2)3', 'Pnma-CsPbCl3', 'CsPb(I0.2Cl0.8)3'] [28, 31, 34] [31, 34, 29]
# 109 ['delta-FAPbI3', 'beta-FAPbI3', 'alpha-FAPbI3'] [44, 45, 46] [44, 46, 45]
# 110 ['MA0.6FA0.4PbI3', 'alpha-MAPbI3', 'PbI2'] [53, 62, 65] [62, 52, 53]
# 111 ['cubic-CsPbBr3', 'CsBr', 'Cs0.8FA0.2PbBr3'] [3, 17, 32] [17, 32, 11]
# 112 ['MA0.2FA0.8PbBr3', 'MA0.6FA0.4PbBr3', 'PbBr2'] [47, 49, 64] [64, 49, 0]
# 113 ['PbI2', 'CsI', 'Cs0.6FA0.4PbI3'] [6, 18, 65] [6, 65, 18]
# 114 ['Cs4PbBr6', 'orthorhombic-CsPbBr3', 'CsBr'] [16, 17, 33] [16, 17, 19]
# 115 ['CsPb(Cl0.8Br0.2)3', 'orthorhombic-CsPbBr3', 'CsPb(Cl0.6Br0.4)3'] [22, 23, 33] [33, 43, 19]
# 116 ['beta-FAPbI3', 'delta-FAPbI3', 'alpha-FAPbI3'] [44, 45, 46] [45, 46, 44]
# 117 ['PbBr2', 'CsBr', 'orthorhombic-CsPbBr3'] [17, 33, 64] [33, 17, 19]
# 118 ['alpha-FAPbI3', 'beta-FAPbI3', 'delta-FAPbI3'] [44, 45, 46] [44, 45, 46]
# 119 ['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2'] [59, 60, 64] [64, 60, 59]
# 120 ['FAPb(Br0.8I0.2)3', 'FAPb(Br0.4I0.6)3', 'beta-FAPbI3'] [40, 42, 45] [45, 51, 46]
# 121 ['tetragonal-MAPbI3', 'PbI2', 'beta-FAPbI3'] [45, 63, 65] [63, 64, 17]
# 122 ['PbI2', 'alpha-CsPbI3', 'delta-CsPbI3'] [36, 37, 65] [36, 65, 37]
# 123 ['tetragonal-MAPbBr3', 'PbBr2', 'cubic-MAPbBr3'] [59, 60, 64] [60, 59, 64]
# 124 ['PbI2', 'beta-FAPbI3', 'alpha-FAPbI3'] [44, 45, 65] [65, 45, 44]
# 125 ['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2'] [59, 60, 64] [59, 64, 60]
# 126 ['alpha-CsPbI3', 'cubic-CsPbCl3', 'gamma-CsPbI3'] [35, 36, 38] [38, 36, 15]
# 127 ['orthorhombic-CsPbBr3', 'Cs4PbBr6', 'CsBr'] [16, 17, 33] [38, 37, 33]
# 128 ['CsBr', 'orthorhombic-CsPbBr3', 'PbBr2'] [17, 33, 64] [64, 33, 17]
# 129 ['Cs0.6FA0.4PbI3', 'beta-FAPbI3', 'delta-CsPbI3'] [6, 37, 45] [7, 37, 45]
# 130 ['alpha-MAPbI3', 'MAPb(Br0.8I0.2)3', 'cubic-MAPbBr3'] [58, 59, 62] [65, 59, 58]
# 131 ['alpha-CsPbI3', 'PbI2', 'delta-CsPbI3'] [36, 37, 65] [36, 37, 65]
# 132 ['gamma-CsPbI3', 'alpha-CsPbI3', 'PbI2'] [36, 38, 65] [38, 65, 30]
# 133 ['cubic-CsPbBr3', 'CsPb2Br5', 'cubic-CsPbCl3'] [19, 32, 35] [32, 19, 16]
# 134 ['delta-CsPbI3', 'Cs0.6FA0.4PbI3', 'Cs0.2FA0.8PbI3'] [4, 6, 37] [4, 37, 6]
# 135 ['MA0.8FA0.2PbI3', 'delta-FAPbI3', 'PbI2'] [46, 54, 65] [65, 46, 45]
# 136 ['alpha-FAPbI3', 'beta-FAPbI3', 'PbI2'] [44, 45, 65] [44, 65, 46]
# 137 ['delta-FAPbI3', 'Cs0.8FA0.2PbI3', 'delta-CsPbI3'] [7, 37, 46] [37, 46, 33]
# 138 ['Pnma-CsPbCl3', 'cubic-CsPbBr3', 'CsPb2Br5'] [19, 32, 34] [32, 34, 19]
# 139 ['beta-FAPbI3', 'FAPb(Br0.4I0.6)3', 'delta-FAPbI3'] [40, 45, 46] [45, 7, 40]
# 140 ['alpha-MAPbI3', 'MAPb(Br0.4I0.6)3', 'MAPb(Br0.6I0.4)3'] [56, 57, 62] [55, 56, 57]
# 141 ['Cs0.8MA0.2PbBr3', 'CsPb2Br5', 'orthorhombic-CsPbBr3'] [11, 19, 33] [33, 17, 32]
# 142 ['Cs4PbBr6', 'cubic-CsPbBr3', 'CsPb2Br5'] [16, 19, 32] [32, 16, 19]
# 143 ['delta-FAPbI3', 'alpha-FAPbI3', 'beta-FAPbI3'] [44, 45, 46] [46, 44, 45]
# 144 ['PbI2', 'alpha-CsPbI3', 'gamma-CsPbI3'] [36, 38, 65] [65, 36, 38]
# 145 ['orthorhombic-CsPbBr3', 'CsBr', 'cubic-CsPbBr3'] [17, 32, 33] [17, 33, 32]
# 146 ['gamma-CsPbI3', 'alpha-CsPbI3', 'delta-CsPbI3'] [36, 37, 38] [37, 63, 38]
# 147 ['Cs0.4MA0.6PbI3', 'alpha-CsPbI3', 'CsI'] [13, 18, 36] [36, 65, 18]
# 148 ['tetragonal-MAPbI3', 'MA0.4FA0.6PbI3', 'MA0.8FA0.2PbI3'] [52, 54, 63] [63, 45, 51]
# 149 ['cubic-CsPbBr3', 'orthorhombic-CsPbBr3', 'PbBr2'] [32, 33, 64] [64, 33, 32]
# 150 ['CsPb2Br5', 'cubic-CsPbCl3', 'PbBr2'] [19, 35, 64] [64, 19, 17]
# 151 ['delta-CsPbI3', 'beta-FAPbI3', 'CsI'] [18, 37, 45] [37, 45, 38]
# 152 ['FAPb(Br0.6I0.4)3', 'FAPb(Br0.8I0.2)3', 'PbBr2'] [41, 42, 64] [41, 45, 42]
# 153 ['alpha-MAPbI3', 'MAPb(Br0.8I0.2)3', 'tetragonal-MAPbBr3'] [58, 60, 62] [58, 60, 57]
# 154 ['Cs4PbBr6', 'CsBr', 'CsPb2Br5'] [16, 17, 19] [16, 19, 32]
# 155 ['delta-FAPbI3', 'beta-FAPbI3', 'alpha-FAPbI3'] [44, 45, 46] [44, 46, 45]
# 156 ['CsBr', 'orthorhombic-CsPbBr3', 'cubic-CsPbBr3'] [17, 32, 33] [32, 17, 33]
# 157 ['beta-FAPbI3', 'alpha-FAPbI3', 'MA0.2FA0.8PbI3'] [44, 45, 51] [51, 44, 65]
# 158 ['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3'] [59, 60, 64] [60, 59, 64]
# 159 ['PbI2', 'Cs4PbBr6', 'CsPb(I0.2Br0.8)3'] [16, 24, 65] [16, 1, 24]
# 160 ['cubic-CsPbCl3', 'CsPb(I0.4Cl0.6)3', 'alpha-CsPbI3'] [29, 35, 36] [36, 65, 46]
# 161 ['Cs0.2FA0.8PbBr3', 'orthorhombic-CsPbBr3', 'CsBr'] [0, 17, 33] [33, 0, 1]
# 162 ['CsPb2Br5', 'CsPb(Cl0.2Br0.8)3', 'CsPb(Cl0.8Br0.2)3'] [19, 20, 23] [19, 8, 2]
# 163 ['CsBr', 'Cs0.8FA0.2PbBr3', 'cubic-FAPbBr3'] [3, 17, 43] [60, 55, 57]
# 164 ['PbI2', 'delta-CsPbI3', 'alpha-CsPbI3'] [36, 37, 65] [65, 37, 36]
# 165 ['CsPb(Cl0.2Br0.8)3', 'PbBr2', 'CsPb(Cl0.4Br0.6)3'] [20, 21, 64] [64, 43, 49]
# 166 ['cubic-MAPbBr3', 'tetragonal-MAPbI3', 'MAPb(Br0.6I0.4)3'] [57, 59, 63] [63, 58, 57]
# 167 ['alpha-MAPbI3', 'PbI2', 'tetragonal-MAPbI3'] [62, 63, 65] [62, 65, 63]
# 168 ['CsPb2Br5', 'cubic-MAPbBr3', 'Cs0.2MA0.8PbBr3'] [8, 19, 59] [19, 59, 8]
# 169 ['Cs4PbBr6', 'cubic-FAPbBr3', 'Cs0.4FA0.6PbBr3'] [1, 16, 43] [16, 1, 32]
# 170 ['CsPb2Br5', 'orthorhombic-CsPbBr3', 'CsBr'] [17, 19, 33] [19, 35, 17]
# 171 ['PbI2', 'gamma-CsPbI3', 'CsI'] [18, 38, 65] [65, 18, 38]
# 172 ['alpha-FAPbI3', 'MA0.8FA0.2PbI3', 'PbI2'] [44, 54, 65] [54, 65, 44]
# 173 ['CsPb(I0.4Br0.6)3', 'CsBr', 'CsPb(I0.2Br0.8)3'] [17, 24, 25] [55, 62, 60]
# 174 ['MAPb(Br0.2I0.8)3', 'MAPb(Br0.6I0.4)3', 'tetragonal-MAPbI3'] [55, 57, 63] [63, 57, 65]
# 175 ['CsPb(Cl0.6Br0.4)3', 'cubic-CsPbBr3', 'orthorhombic-CsPbBr3'] [22, 32, 33] [33, 32, 0]
# 176 ['cubic-FAPbBr3', 'PbBr2', 'Cs0.8FA0.2PbBr3'] [3, 43, 64] [64, 43, 58]
# 177 ['PbBr2', 'CsBr', 'Cs4PbBr6'] [16, 17, 64] [17, 16, 64]
# 178 ['CsI', 'delta-CsPbI3', 'alpha-CsPbI3'] [18, 36, 37] [36, 37, 18]
# 179 ['cubic-MAPbBr3', 'MA0.2FA0.8PbBr3', 'PbBr2'] [47, 59, 64] [64, 59, 43]
# 180 ['PbI2', 'alpha-MAPbI3', 'tetragonal-MAPbI3'] [62, 63, 65] [62, 65, 63]
# 181 ['PbI2', 'cubic-FAPbBr3', 'beta-FAPbI3'] [43, 45, 65] [43, 64, 65]
# 182 ['MAPb(Br0.2I0.8)3', 'PbI2', 'MAPb(Br0.8I0.2)3'] [55, 58, 65] [65, 46, 43]
# 183 ['Cs0.8FA0.2PbI3', 'delta-CsPbI3', 'Cs0.6FA0.4PbI3'] [6, 7, 37] [37, 38, 16]
# 184 ['PbBr2', 'MA0.6FA0.4PbBr3', 'MA0.2FA0.8PbBr3'] [47, 49, 64] [64, 60, 47]
# 185 ['PbI2', 'delta-CsPbI3', 'CsI'] [18, 37, 65] [65, 37, 18]
# 186 ['CsPb(I0.6Cl0.4)3', 'cubic-CsPbCl3', 'PbI2'] [30, 35, 65] [65, 58, 55]
# 187 ['CsPb(I0.2Cl0.8)3', 'CsI', 'gamma-CsPbI3'] [18, 28, 38] [18, 38, 65]
# 188 ['CsI', 'CsPb(I0.2Br0.8)3', 'orthorhombic-CsPbBr3'] [18, 24, 33] [33, 17, 24]
# 189 ['FAPb(Br0.8I0.2)3', 'FAPb(Br0.6I0.4)3', 'PbBr2'] [41, 42, 64] [46, 45, 64]
# 190 ['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'MA0.8FA0.2PbBr3'] [50, 59, 60] [50, 60, 59]
# 191 ['PbBr2', 'orthorhombic-CsPbBr3', 'cubic-CsPbBr3'] [32, 33, 64] [33, 64, 19]
# 192 ['CsPb(Cl0.4Br0.6)3', 'CsPb(Cl0.2Br0.8)3', 'CsPb2Br5'] [19, 20, 21] [20, 19, 33]
# 193 ['gamma-CsPbI3', 'PbI2', 'alpha-CsPbI3'] [36, 38, 65] [38, 65, 36]
# 194 ['CsI', 'Cs0.8FA0.2PbI3', 'Cs0.6FA0.4PbI3'] [6, 7, 18] [6, 7, 18]
# 195 ['Cs0.2FA0.8PbBr3', 'Cs0.6FA0.4PbBr3', 'CsBr'] [0, 2, 17] [17, 0, 3]
# 196 ['alpha-FAPbI3', 'tetragonal-MAPbI3', 'MA0.2FA0.8PbI3'] [44, 51, 63] [65, 63, 64]
# 197 ['Pnma-CsPbCl3', 'gamma-CsPbI3', 'PbI2'] [34, 38, 65] [38, 34, 65]
# 198 ['CsPb2Br5', 'cubic-CsPbBr3', 'Cs4PbBr6'] [16, 19, 32] [46, 19, 36]
# 199 ['beta-FAPbI3', 'alpha-FAPbI3', 'delta-FAPbI3'] [44, 45, 46] [44, 45, 46]
# 200 ['delta-FAPbI3', 'PbI2', 'beta-FAPbI3'] [45, 46, 65] [65, 45, 46]
# 201 ['gamma-CsPbI3', 'Cs0.2MA0.8PbI3', 'Cs0.4MA0.6PbI3'] [12, 13, 38] [38, 14, 13]
# 202 ['tetragonal-MAPbBr3', 'PbBr2', 'cubic-MAPbBr3'] [59, 60, 64] [60, 59, 64]
# 203 ['CsPb(Cl0.2Br0.8)3', 'CsPb(Cl0.4Br0.6)3', 'CsPb2Br5'] [19, 20, 21] [21, 19, 23]
# 204 ['MA0.8FA0.2PbBr3', 'MA0.6FA0.4PbBr3', 'MA0.4FA0.6PbBr3'] [48, 49, 50] [48, 60, 49]
# 205 ['tetragonal-MAPbBr3', 'MA0.6FA0.4PbBr3', 'MA0.4FA0.6PbBr3'] [48, 49, 60] [48, 49, 60]
# 206 ['CsPb(I0.4Cl0.6)3', 'alpha-CsPbI3', 'delta-CsPbI3'] [29, 36, 37] [65, 36, 37]
# 207 ['gamma-CsPbI3', 'PbI2', 'Cs0.4FA0.6PbI3'] [5, 38, 65] [38, 5, 65]
# 208 ['tetragonal-MAPbI3', 'PbI2', 'alpha-MAPbI3'] [62, 63, 65] [62, 63, 65]
# 209 ['gamma-CsPbI3', 'delta-FAPbI3', 'Cs0.2FA0.8PbI3'] [4, 38, 46] [4, 45, 46]
# 210 ['cubic-MAPbBr3', 'MA0.2FA0.8PbBr3', 'cubic-FAPbBr3'] [43, 47, 59] [59, 47, 43]
# 211 ['cubic-MAPbBr3', 'MAPb(Br0.4I0.6)3', 'PbBr2'] [56, 59, 64] [64, 58, 44]
# 212 ['PbI2', 'CsI', 'CsPb(I0.6Br0.4)3'] [18, 26, 65] [18, 36, 65]
# 213 ['alpha-FAPbI3', 'PbI2', 'beta-FAPbI3'] [44, 45, 65] [65, 44, 45]
# 214 ['gamma-CsPbI3', 'Cs0.4MA0.6PbI3', 'tetragonal-MAPbI3'] [13, 38, 63] [63, 38, 13]
# 215 ['PbI2', 'alpha-CsPbI3', 'CsPb(I0.4Cl0.6)3'] [29, 36, 65] [65, 36, 26]
# 216 ['tetragonal-MAPbI3', 'beta-FAPbI3', 'alpha-MAPbI3'] [45, 62, 63] [62, 63, 65]
# 217 ['cubic-FAPbBr3', 'tetragonal-MAPbBr3', 'MA0.8FA0.2PbBr3'] [43, 50, 60] [43, 60, 50]
# 218 ['alpha-MAPbI3', 'MA0.8FA0.2PbI3', 'beta-FAPbI3'] [45, 54, 62] [45, 44, 54]
# 219 ['Cs0.2MA0.8PbI3', 'alpha-CsPbI3', 'gamma-CsPbI3'] [12, 36, 38] [38, 36, 15]
# 220 ['orthorhombic-CsPbBr3', 'PbBr2', 'cubic-CsPbBr3'] [32, 33, 64] [32, 64, 33]
# 221 ['tetragonal-MAPbI3', 'MA0.6FA0.4PbI3', 'MA0.2FA0.8PbI3'] [51, 53, 63] [51, 53, 52]
# 222 ['PbI2', 'alpha-MAPbI3', 'beta-FAPbI3'] [45, 62, 65] [45, 62, 65]
# 223 ['Cs4PbBr6', 'PbBr2', 'Cs0.8MA0.2PbBr3'] [11, 16, 64] [64, 16, 17]
# 224 ['Pnma-CsPbCl3', 'CsBr', 'cubic-CsPbBr3'] [17, 32, 34] [34, 32, 29]
# 225 ['MA0.8FA0.2PbBr3', 'PbBr2', 'MA0.6FA0.4PbBr3'] [49, 50, 64] [64, 60, 50]
# 226 ['Cs0.4FA0.6PbI3', 'CsI', 'PbI2'] [5, 18, 65] [5, 65, 44]
# 227 ['cubic-CsPbBr3', 'CsPb(Cl0.6Br0.4)3', 'CsPb(Cl0.8Br0.2)3'] [22, 23, 32] [32, 17, 43]
# 228 ['cubic-CsPbBr3', 'Cs4PbBr6', 'CsBr'] [16, 17, 32] [17, 16, 32]
# 229 ['alpha-FAPbI3', 'beta-FAPbI3', 'PbI2'] [44, 45, 65] [45, 65, 44]
# 230 ['delta-CsPbI3', 'gamma-CsPbI3', 'CsPb(I0.2Cl0.8)3'] [28, 37, 38] [38, 46, 37]
# 231 ['cubic-CsPbCl3', 'CsPb(Cl0.6Br0.4)3', 'Pnma-CsPbCl3'] [22, 34, 35] [34, 32, 22]
# 232 ['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'Cs0.6MA0.4PbBr3'] [10, 59, 60] [10, 60, 59]
# 233 ['alpha-FAPbI3', 'delta-FAPbI3', 'PbI2'] [44, 46, 65] [65, 44, 46]
# 234 ['cubic-CsPbBr3', 'orthorhombic-CsPbBr3', 'Cs4PbBr6'] [16, 32, 33] [33, 16, 32]
# 235 ['Pnma-CsPbCl3', 'CsPb(Cl0.4Br0.6)3', 'cubic-CsPbCl3'] [21, 34, 35] [34, 35, 22]
# 236 ['Cs0.4MA0.6PbBr3', 'Cs0.6MA0.4PbBr3', 'CsPb2Br5'] [9, 10, 19] [19, 10, 9]
# 237 ['Cs0.2MA0.8PbI3', 'gamma-CsPbI3', 'tetragonal-MAPbI3'] [12, 38, 63] [63, 38, 13]
# 238 ['PbI2', 'delta-FAPbI3', 'beta-FAPbI3'] [45, 46, 65] [65, 45, 46]
# 239 ['cubic-CsPbBr3', 'PbBr2', 'orthorhombic-CsPbBr3'] [32, 33, 64] [32, 33, 64]
# 240 ['CsPb(I0.4Cl0.6)3', 'cubic-CsPbCl3', 'alpha-CsPbI3'] [29, 35, 36] [36, 65, 29]
# 241 ['alpha-FAPbI3', 'FAPb(Br0.4I0.6)3', 'delta-FAPbI3'] [40, 44, 46] [44, 40, 46]
# 242 ['cubic-CsPbBr3', 'PbBr2', 'Cs4PbBr6'] [16, 32, 64] [64, 32, 16]
# 243 ['cubic-CsPbBr3', 'Cs0.4FA0.6PbBr3', 'Cs4PbBr6'] [1, 16, 32] [44, 16, 37]
# 244 ['MA0.8FA0.2PbBr3', 'cubic-MAPbBr3', 'cubic-FAPbBr3'] [43, 50, 59] [43, 59, 1]
# 245 ['PbI2', 'CsI', 'gamma-CsPbI3'] [18, 38, 65] [38, 65, 46]
# 246 ['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3'] [59, 60, 64] [60, 59, 64]
# 247 ['PbBr2', 'MA0.6FA0.4PbBr3', 'cubic-MAPbBr3'] [49, 59, 64] [64, 59, 60]
# 248 ['Cs0.6MA0.4PbBr3', 'PbBr2', 'CsBr'] [10, 17, 64] [64, 57, 17]
# 249 ['cubic-CsPbBr3', 'CsBr', 'orthorhombic-CsPbBr3'] [17, 32, 33] [32, 17, 33]
# 250 ['Cs4PbBr6', 'cubic-FAPbBr3', 'orthorhombic-CsPbBr3'] [16, 33, 43] [36, 37, 43]
# 251 ['PbBr2', 'orthorhombic-CsPbBr3', 'CsBr'] [17, 33, 64] [64, 17, 32]
# 252 ['alpha-CsPbI3', 'delta-CsPbI3', 'gamma-CsPbI3'] [36, 37, 38] [37, 36, 38]
# 253 ['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3'] [59, 60, 64] [64, 59, 60]
# 254 ['MAPb(Br0.4I0.6)3', 'cubic-MAPbBr3', 'MAPb(Br0.8I0.2)3'] [56, 58, 59] [65, 59, 58]
# 255 ['PbI2', 'delta-FAPbI3', 'alpha-FAPbI3'] [44, 46, 65] [65, 44, 46]
# 256 ['MA0.4FA0.6PbBr3', 'MA0.2FA0.8PbBr3', 'tetragonal-MAPbBr3'] [47, 48, 60] [47, 48, 50]
# 257 ['gamma-CsPbI3', 'PbI2', 'delta-CsPbI3'] [37, 38, 65] [38, 37, 18]
# 258 ['alpha-CsPbI3', 'gamma-CsPbI3', 'CsI'] [18, 36, 38] [18, 38, 36]
# 259 ['CsBr', 'Cs4PbBr6', 'orthorhombic-CsPbBr3'] [16, 17, 33] [16, 33, 17]
# 260 ['Cs0.2FA0.8PbBr3', 'Cs4PbBr6', 'Cs0.8FA0.2PbBr3'] [0, 3, 16] [16, 3, 10]
# 261 ['beta-FAPbI3', 'delta-FAPbI3', 'alpha-FAPbI3'] [44, 45, 46] [46, 44, 45]
# 262 ['orthorhombic-CsPbBr3', 'cubic-CsPbCl3', 'cubic-CsPbBr3'] [32, 33, 35] [33, 32, 1]
# 263 ['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3'] [59, 60, 64] [60, 59, 64]
# 264 ['CsPb(Cl0.2Br0.8)3', 'CsBr', 'CsPb2Br5'] [17, 19, 20] [19, 17, 22]
# 265 ['alpha-FAPbI3', 'CsI', 'Cs0.8FA0.2PbI3'] [7, 18, 44] [7, 44, 36]
# 266 ['cubic-CsPbCl3', 'CsPb(I0.6Cl0.4)3', 'PbI2'] [30, 35, 65] [30, 65, 62]
# 267 ['alpha-CsPbI3', 'delta-CsPbI3', 'gamma-CsPbI3'] [36, 37, 38] [38, 36, 37]
# 268 ['orthorhombic-CsPbBr3', 'cubic-CsPbBr3', 'Cs0.2MA0.8PbBr3'] [8, 32, 33] [33, 3, 32]
# 269 ['MA0.2FA0.8PbBr3', 'MA0.8FA0.2PbBr3', 'MA0.6FA0.4PbBr3'] [47, 49, 50] [49, 47, 48]
# 270 ['CsBr', 'Cs0.2MA0.8PbBr3', 'Cs0.6MA0.4PbBr3'] [8, 10, 17] [9, 17, 2]
# 271 ['CsPb(I0.6Cl0.4)3', 'CsI', 'alpha-CsPbI3'] [18, 30, 36] [18, 36, 30]
# 272 ['Cs0.8FA0.2PbBr3', 'cubic-FAPbBr3', 'Cs0.4FA0.6PbBr3'] [1, 3, 43] [1, 43, 32]
# 273 ['cubic-CsPbBr3', 'orthorhombic-CsPbBr3', 'Cs4PbBr6'] [16, 32, 33] [33, 16, 32]
# 274 ['PbBr2', 'cubic-CsPbBr3', 'CsBr'] [17, 32, 64] [32, 64, 17]
# 275 ['Cs4PbBr6', 'Cs0.4FA0.6PbBr3', 'cubic-CsPbBr3'] [1, 16, 32] [16, 32, 1]
# 276 ['alpha-FAPbI3', 'delta-FAPbI3', 'beta-FAPbI3'] [44, 45, 46] [46, 44, 45]
# 277 ['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3'] [59, 60, 64] [59, 64, 60]
# 278 ['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2'] [62, 63, 65] [65, 62, 46]
# 279 ['CsI', 'Pnma-CsPbCl3', 'CsPb(I0.4Cl0.6)3'] [18, 29, 34] [34, 18, 29]
# 280 ['delta-FAPbI3', 'PbI2', 'MA0.2FA0.8PbI3'] [46, 51, 65] [65, 46, 51]
# 281 ['CsPb(Cl0.8Br0.2)3', 'Pnma-CsPbCl3', 'Cs4PbBr6'] [16, 23, 34] [16, 34, 32]
# 282 ['CsPb2Br5', 'cubic-CsPbBr3', 'PbBr2'] [19, 32, 64] [60, 24, 64]
# 283 ['delta-FAPbI3', 'beta-FAPbI3', 'alpha-FAPbI3'] [44, 45, 46] [44, 45, 46]
# 284 ['PbBr2', 'Cs0.6MA0.4PbBr3', 'CsBr'] [10, 17, 64] [64, 10, 3]
# 285 ['alpha-FAPbI3', 'PbI2', 'beta-FAPbI3'] [44, 45, 65] [65, 45, 44]
# 286 ['PbI2', 'Cs0.8FA0.2PbI3', 'Cs0.6FA0.4PbI3'] [6, 7, 65] [45, 44, 53]
# 287 ['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2'] [62, 63, 65] [65, 62, 63]
# 288 ['cubic-CsPbCl3', 'orthorhombic-CsPbBr3', 'Pnma-CsPbCl3'] [33, 34, 35] [35, 33, 34]
# 289 ['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3'] [59, 60, 64] [64, 60, 59]
# 290 ['CsI', 'tetragonal-MAPbI3', 'gamma-CsPbI3'] [18, 38, 63] [63, 38, 37]
# 291 ['cubic-FAPbBr3', 'MA0.8FA0.2PbBr3', 'PbBr2'] [43, 50, 64] [43, 64, 50]
# 292 ['CsPb(I0.8Cl0.2)3', 'cubic-CsPbCl3', 'PbI2'] [31, 35, 65] [65, 62, 56]
# 293 ['CsPb(I0.6Br0.4)3', 'delta-CsPbI3', 'orthorhombic-CsPbBr3'] [26, 33, 37] [63, 51, 37]
# 294 ['CsPb(I0.4Cl0.6)3', 'gamma-CsPbI3', 'Pnma-CsPbCl3'] [29, 34, 38] [38, 34, 29]
# 295 ['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2'] [62, 63, 65] [65, 63, 62]
# 296 ['cubic-CsPbCl3', 'CsPb(I0.8Cl0.2)3', 'CsPb(I0.6Cl0.4)3'] [30, 31, 35] [28, 30, 35]
# 297 ['CsPb(I0.6Br0.4)3', 'PbBr2', 'CsPb(I0.4Br0.6)3'] [25, 26, 64] [25, 36, 64]
# 298 ['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3'] [59, 60, 64] [64, 60, 59]
# 299 ['cubic-CsPbCl3', 'CsI', 'CsPb(I0.2Cl0.8)3'] [18, 28, 35] [18, 22, 32]
# 300 ['Cs0.8MA0.2PbI3', 'alpha-MAPbI3', 'alpha-CsPbI3'] [15, 36, 62] [36, 14, 15]
# 301 ['MA0.8FA0.2PbI3', 'tetragonal-MAPbI3', 'MA0.6FA0.4PbI3'] [53, 54, 63] [53, 54, 63]
# 302 ['CsBr', 'CsPb2Br5', 'Cs4PbBr6'] [16, 17, 19] [17, 19, 16]
# 303 ['Cs0.8FA0.2PbBr3', 'cubic-CsPbBr3', 'CsBr'] [3, 17, 32] [17, 2, 32]
# 304 ['Cs4PbBr6', 'CsBr', 'CsPb2Br5'] [16, 17, 19] [17, 19, 16]
# 305 ['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3'] [59, 60, 64] [60, 64, 59]
# 306 ['Cs4PbBr6', 'Cs0.6FA0.4PbBr3', 'PbBr2'] [2, 16, 64] [64, 16, 19]
# 307 ['PbBr2', 'Cs4PbBr6', 'CsBr'] [16, 17, 64] [17, 64, 16]
# 308 ['PbI2', 'alpha-MAPbI3', 'tetragonal-MAPbI3'] [62, 63, 65] [65, 62, 63]
# 309 ['delta-CsPbI3', 'CsPb(I0.6Br0.4)3', 'alpha-CsPbI3'] [26, 36, 37] [18, 37, 36]
# 310 ['CsI', 'delta-CsPbI3', 'alpha-CsPbI3'] [18, 36, 37] [36, 18, 37]
# 311 ['PbBr2', 'FAPb(Br0.4I0.6)3', 'delta-FAPbI3'] [40, 46, 64] [64, 40, 42]
# 312 ['PbI2', 'beta-FAPbI3', 'delta-FAPbI3'] [45, 46, 65] [45, 46, 65]
# 313 ['CsPb2Br5', 'orthorhombic-CsPbBr3', 'CsBr'] [17, 19, 33] [33, 17, 19]
# 314 ['PbBr2', 'tetragonal-MAPbBr3', 'cubic-FAPbBr3'] [43, 60, 64] [43, 64, 1]
# 315 ['cubic-CsPbBr3', 'Cs0.2FA0.8PbBr3', 'Cs4PbBr6'] [0, 16, 32] [16, 32, 17]
# 316 ['cubic-MAPbBr3', 'cubic-FAPbBr3', 'PbBr2'] [43, 59, 64] [43, 64, 59]
# 317 ['delta-CsPbI3', 'alpha-MAPbI3', 'Cs0.2MA0.8PbI3'] [12, 37, 62] [37, 65, 62]
# 318 ['MA0.8FA0.2PbBr3', 'cubic-FAPbBr3', 'MA0.2FA0.8PbBr3'] [43, 47, 50] [43, 50, 60]
# 319 ['MA0.8FA0.2PbBr3', 'PbBr2', 'cubic-FAPbBr3'] [43, 50, 64] [64, 43, 47]
# 320 ['Cs0.6MA0.4PbBr3', 'Cs0.8MA0.2PbBr3', 'Cs0.4MA0.6PbBr3'] [9, 10, 11] [9, 2, 11]
# 321 ['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3'] [59, 60, 64] [60, 64, 59]
# 322 ['MA0.8FA0.2PbBr3', 'MA0.2FA0.8PbBr3', 'cubic-MAPbBr3'] [47, 50, 59] [48, 47, 50]
# 323 ['orthorhombic-CsPbBr3', 'CsPb2Br5', 'PbBr2'] [19, 33, 64] [19, 33, 64]
# 324 ['CsBr', 'Cs0.8FA0.2PbBr3', 'orthorhombic-CsPbBr3'] [3, 17, 33] [17, 33, 43]
# 325 ['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3'] [59, 60, 64] [64, 60, 59]
# 326 ['PbBr2', 'Cs4PbBr6', 'CsPb(Cl0.6Br0.4)3'] [16, 22, 64] [64, 16, 24]
# 327 ['Cs0.4MA0.6PbBr3', 'Cs0.8MA0.2PbBr3', 'CsBr'] [9, 11, 17] [11, 9, 17]
# 328 ['MA0.8FA0.2PbBr3', 'tetragonal-MAPbBr3', 'MA0.2FA0.8PbBr3'] [47, 50, 60] [47, 60, 59]
# 329 ['alpha-CsPbI3', 'CsPb(I0.4Cl0.6)3', 'PbI2'] [29, 36, 65] [65, 54, 7]
# 330 ['orthorhombic-CsPbBr3', 'CsPb2Br5', 'Cs0.8FA0.2PbBr3'] [3, 19, 33] [19, 33, 9]
# 331 ['CsPb(I0.2Cl0.8)3', 'CsPb(I0.6Cl0.4)3', 'CsI'] [18, 28, 30] [18, 30, 25]
# 332 ['Cs0.4MA0.6PbBr3', 'Cs0.2MA0.8PbBr3', 'CsPb2Br5'] [8, 9, 19] [19, 1, 17]
# 333 ['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3'] [59, 60, 64] [60, 59, 64]
# 334 ['alpha-CsPbI3', 'PbI2', 'gamma-CsPbI3'] [36, 38, 65] [38, 65, 46]
# 335 ['PbI2', 'delta-FAPbI3', 'alpha-FAPbI3'] [44, 46, 65] [46, 44, 65]
# 336 ['CsI', 'gamma-CsPbI3', 'alpha-CsPbI3'] [18, 36, 38] [36, 38, 18]
# 337 ['PbBr2', 'Cs0.8MA0.2PbBr3', 'cubic-MAPbBr3'] [11, 59, 64] [11, 64, 59]
# 338 ['alpha-MAPbI3', 'MA0.4FA0.6PbI3', 'MA0.6FA0.4PbI3'] [52, 53, 62] [53, 52, 62]
# 339 ['tetragonal-MAPbI3', 'PbI2', 'alpha-MAPbI3'] [62, 63, 65] [65, 62, 63]
# 340 ['Cs4PbBr6', 'tetragonal-MAPbBr3', 'CsBr'] [16, 17, 60] [16, 17, 22]
# 341 ['CsPb(I0.8Cl0.2)3', 'PbI2', 'Pnma-CsPbCl3'] [31, 34, 65] [34, 31, 65]
# 342 ['Cs0.4FA0.6PbI3', 'Cs0.8FA0.2PbI3', 'alpha-FAPbI3'] [5, 7, 44] [7, 5, 44]
# 343 ['alpha-CsPbI3', 'gamma-CsPbI3', 'PbI2'] [36, 38, 65] [38, 36, 65]
# 344 ['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'alpha-MAPbI3'] [59, 60, 62] [59, 60, 62]
# 345 ['PbBr2', 'Cs0.8MA0.2PbBr3', 'Cs4PbBr6'] [11, 16, 64] [64, 16, 32]
# 346 ['PbI2', 'beta-FAPbI3', 'alpha-FAPbI3'] [44, 45, 65] [65, 44, 45]
# 347 ['MAPb(Br0.2I0.8)3', 'MAPb(Br0.8I0.2)3', 'MAPb(Br0.6I0.4)3'] [55, 57, 58] [58, 57, 65]
# 348 ['Cs4PbBr6', 'PbI2', 'CsBr'] [16, 17, 65] [16, 21, 17]
# 349 ['PbBr2', 'CsPb2Br5', 'cubic-CsPbCl3'] [19, 35, 64] [64, 19, 17]
# 350 ['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2'] [62, 63, 65] [65, 62, 63]
# 351 ['Cs0.4FA0.6PbBr3', 'orthorhombic-CsPbBr3', 'cubic-CsPbBr3'] [1, 32, 33] [1, 33, 32]
# 352 ['Cs0.4FA0.6PbI3', 'Cs0.8FA0.2PbI3', 'Cs0.6FA0.4PbI3'] [5, 6, 7] [54, 51, 45]
# 353 ['Cs0.4MA0.6PbBr3', 'orthorhombic-CsPbBr3', 'Cs0.2MA0.8PbBr3'] [8, 9, 33] [33, 9, 8]
# 354 ['orthorhombic-CsPbBr3', 'CsBr', 'cubic-CsPbBr3'] [17, 32, 33] [17, 33, 32]
# 355 ['gamma-CsPbI3', 'alpha-CsPbI3', 'PbI2'] [36, 38, 65] [38, 36, 65]
# 356 ['tetragonal-MAPbBr3', 'PbBr2', 'cubic-MAPbBr3'] [59, 60, 64] [64, 59, 60]
# 357 ['PbBr2', 'CsPb(I0.4Br0.6)3', 'CsBr'] [17, 25, 64] [64, 17, 55]
# 358 ['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3'] [59, 60, 64] [59, 64, 60]
# 359 ['PbBr2', 'cubic-CsPbCl3', 'CsPb2Br5'] [19, 35, 64] [19, 64, 17]
# 360 ['alpha-MAPbI3', 'PbI2', 'tetragonal-MAPbI3'] [62, 63, 65] [65, 62, 63]
# 361 ['MA0.6FA0.4PbI3', 'MA0.8FA0.2PbI3', 'MA0.2FA0.8PbI3'] [51, 53, 54] [51, 45, 46]
# 362 ['orthorhombic-CsPbBr3', 'PbBr2', 'alpha-CsPbI3'] [33, 36, 64] [64, 39, 40]
# 363 ['PbI2', 'alpha-FAPbI3', 'beta-FAPbI3'] [44, 45, 65] [65, 45, 44]
# 364 ['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2'] [59, 60, 64] [60, 59, 64]
# 365 ['cubic-CsPbBr3', 'PbI2', 'CsPb(I0.6Br0.4)3'] [26, 32, 65] [65, 24, 36]
# 366 ['CsBr', 'Cs4PbBr6', 'cubic-CsPbBr3'] [16, 17, 32] [17, 16, 64]
# 367 ['beta-FAPbI3', 'FAPb(Br0.4I0.6)3', 'FAPb(Br0.6I0.4)3'] [40, 41, 45] [45, 53, 46]
# 368 ['MA0.8FA0.2PbBr3', 'MA0.4FA0.6PbBr3', 'PbBr2'] [48, 50, 64] [47, 64, 60]
# 369 ['CsI', 'cubic-CsPbBr3', 'gamma-CsPbI3'] [18, 32, 38] [18, 38, 65]
# 370 ['CsPb2Br5', 'PbBr2', 'CsBr'] [17, 19, 64] [64, 17, 19]
# 371 ['CsPb(I0.2Br0.8)3', 'CsBr', 'cubic-CsPbBr3'] [17, 24, 32] [25, 26, 32]
# 372 ['Cs0.2FA0.8PbBr3', 'CsPb2Br5', 'Cs0.6FA0.4PbBr3'] [0, 2, 19] [19, 3, 64]
# 373 ['alpha-MAPbI3', 'tetragonal-MAPbI3', 'MA0.4FA0.6PbI3'] [52, 62, 63] [62, 53, 52]
# 374 ['tetragonal-MAPbBr3', 'PbBr2', 'cubic-MAPbBr3'] [59, 60, 64] [60, 64, 59]
# 375 ['alpha-CsPbI3', 'cubic-CsPbBr3', 'CsPb2Br5'] [19, 32, 36] [45, 44, 65]
# 376 ['alpha-FAPbI3', 'beta-FAPbI3', 'PbI2'] [44, 45, 65] [45, 65, 44]
# 377 ['CsBr', 'cubic-CsPbBr3', 'orthorhombic-CsPbBr3'] [17, 32, 33] [33, 32, 17]
# 378 ['beta-FAPbI3', 'FAPb(Br0.4I0.6)3', 'FAPb(Br0.6I0.4)3'] [40, 41, 45] [45, 41, 53]
# 379 ['CsPb(Cl0.2Br0.8)3', 'CsPb(Cl0.6Br0.4)3', 'PbBr2'] [20, 22, 64] [64, 22, 32]
# 380 ['PbI2', 'CsPb(I0.6Cl0.4)3', 'CsPb(I0.2Cl0.8)3'] [28, 30, 65] [27, 32, 36]
# 381 ['CsBr', 'cubic-CsPbCl3', 'PbBr2'] [17, 35, 64] [64, 17, 19]
# 382 ['cubic-MAPbBr3', 'MA0.4FA0.6PbBr3', 'MA0.2FA0.8PbBr3'] [47, 48, 59] [60, 47, 59]
# 383 ['delta-CsPbI3', 'alpha-CsPbI3', 'PbI2'] [36, 37, 65] [65, 36, 37]
# 384 ['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3'] [59, 60, 64] [59, 60, 64]
# 385 ['alpha-MAPbI3', 'PbBr2', 'tetragonal-MAPbI3'] [62, 63, 64] [64, 63, 55]
# 386 ['CsBr', 'CsPb(Cl0.4Br0.6)3', 'cubic-CsPbCl3'] [17, 21, 35] [21, 17, 35]
# 387 ['beta-FAPbI3', 'delta-FAPbI3', 'alpha-FAPbI3'] [44, 45, 46] [65, 45, 46]
# 388 ['PbI2', 'MAPb(Br0.8I0.2)3', 'MAPb(Br0.6I0.4)3'] [57, 58, 65] [17, 1, 65]
# 389 ['alpha-CsPbI3', 'gamma-CsPbI3', 'delta-CsPbI3'] [36, 37, 38] [38, 37, 36]
# 390 ['CsPb2Br5', 'cubic-CsPbBr3', 'CsPb(Cl0.6Br0.4)3'] [19, 22, 32] [32, 19, 65]
# 391 ['PbI2', 'gamma-CsPbI3', 'Pnma-CsPbCl3'] [34, 38, 65] [38, 65, 34]
# 392 ['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3'] [59, 60, 64] [60, 64, 59]
# 393 ['PbI2', 'PbBr2', 'alpha-MAPbI3'] [62, 64, 65] [65, 64, 62]
# 394 ['MA0.2FA0.8PbI3', 'MA0.6FA0.4PbI3', 'delta-FAPbI3'] [46, 51, 53] [45, 51, 46]
# 395 ['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2'] [59, 60, 64] [64, 59, 60]
# 396 ['delta-FAPbI3', 'alpha-FAPbI3', 'Cs0.6FA0.4PbI3'] [6, 44, 46] [46, 6, 45]
# 397 ['cubic-CsPbBr3', 'orthorhombic-CsPbBr3', 'CsPb2Br5'] [19, 32, 33] [19, 65, 64]
# 398 ['delta-CsPbI3', 'PbI2', 'alpha-CsPbI3'] [36, 37, 65] [65, 37, 36]
# 399 ['Cs0.6FA0.4PbBr3', 'cubic-CsPbBr3', 'CsPb2Br5'] [2, 19, 32] [32, 2, 64]
# 400 ['PbI2', 'Cs0.6MA0.4PbI3', 'gamma-CsPbI3'] [14, 38, 65] [38, 12, 13]
# 401 ['CsI', 'PbI2', 'Cs0.8MA0.2PbI3'] [15, 18, 65] [18, 36, 65]
# 402 ['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3'] [59, 60, 64] [64, 60, 59]
# 403 ['alpha-FAPbI3', 'beta-FAPbI3', 'delta-FAPbI3'] [44, 45, 46] [46, 44, 45]
# 404 ['cubic-FAPbBr3', 'MA0.8FA0.2PbBr3', 'PbBr2'] [43, 50, 64] [43, 64, 50]
# 405 ['MA0.2FA0.8PbBr3', 'cubic-MAPbBr3', 'MA0.8FA0.2PbBr3'] [47, 50, 59] [59, 43, 47]
# 406 ['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2'] [59, 60, 64] [60, 59, 64]
# 407 ['PbBr2', 'orthorhombic-CsPbBr3', 'cubic-CsPbBr3'] [32, 33, 64] [32, 33, 64]
# 408 ['CsBr', 'PbBr2', 'orthorhombic-CsPbBr3'] [17, 33, 64] [64, 33, 17]
# 409 ['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2'] [62, 63, 65] [65, 62, 17]
# 410 ['gamma-CsPbI3', 'PbI2', 'CsI'] [18, 38, 65] [18, 65, 38]
# 411 ['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2'] [62, 63, 65] [62, 65, 63]
# 412 ['delta-FAPbI3', 'beta-FAPbI3', 'CsI'] [18, 45, 46] [46, 45, 41]
# 413 ['alpha-CsPbI3', 'CsI', 'Cs0.8MA0.2PbI3'] [15, 18, 36] [14, 36, 15]
# 414 ['cubic-CsPbCl3', 'CsPb(I0.8Cl0.2)3', 'PbI2'] [31, 35, 65] [35, 36, 30]
# 415 ['cubic-MAPbBr3', 'MAPb(Br0.6I0.4)3', 'alpha-MAPbI3'] [57, 59, 62] [62, 59, 58]
# 416 ['beta-FAPbI3', 'MA0.6FA0.4PbI3', 'MA0.2FA0.8PbI3'] [45, 51, 53] [53, 51, 45]
# 417 ['CsBr', 'cubic-CsPbBr3', 'Cs4PbBr6'] [16, 17, 32] [17, 16, 0]
# 418 ['delta-CsPbI3', 'PbI2', 'Cs0.2FA0.8PbI3'] [4, 37, 65] [4, 65, 37]
# 419 ['Cs0.6MA0.4PbBr3', 'cubic-CsPbBr3', 'CsBr'] [10, 17, 32] [34, 32, 35]
# 420 ['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3'] [59, 60, 64] [64, 60, 59]
# 421 ['Pnma-CsPbCl3', 'delta-CsPbI3', 'gamma-CsPbI3'] [34, 37, 38] [34, 38, 37]
# 422 ['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3'] [59, 60, 64] [59, 60, 64]
# 423 ['PbI2', 'alpha-MAPbI3', 'tetragonal-MAPbI3'] [62, 63, 65] [62, 65, 63]
# 424 ['cubic-CsPbBr3', 'CsPb2Br5', 'Cs4PbBr6'] [16, 19, 32] [16, 19, 32]
# 425 ['PbI2', 'PbBr2', 'tetragonal-MAPbBr3'] [60, 64, 65] [64, 65, 60]
# 426 ['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3'] [59, 60, 64] [60, 64, 59]
# 427 ['tetragonal-MAPbBr3', 'Cs0.8MA0.2PbBr3', 'CsBr'] [11, 17, 60] [65, 17, 18]
# 428 ['tetragonal-MAPbI3', 'PbI2', 'alpha-MAPbI3'] [62, 63, 65] [63, 62, 65]
# 429 ['delta-CsPbI3', 'PbI2', 'gamma-CsPbI3'] [37, 38, 65] [65, 38, 37]
# 430 ['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2'] [59, 60, 64] [59, 64, 60]
# 431 ['cubic-CsPbBr3', 'orthorhombic-CsPbBr3', 'CsPb2Br5'] [19, 32, 33] [33, 19, 32]
# 432 ['PbI2', 'Cs0.6MA0.4PbI3', 'Cs0.8MA0.2PbI3'] [14, 15, 65] [65, 36, 18]
# 433 ['PbI2', 'gamma-CsPbI3', 'CsPb(I0.4Cl0.6)3'] [29, 38, 65] [38, 65, 18]
# 434 ['MA0.6FA0.4PbI3', 'beta-FAPbI3', 'alpha-MAPbI3'] [45, 53, 62] [16, 64, 45]
# 435 ['cubic-CsPbBr3', 'PbBr2', 'CsBr'] [17, 32, 64] [64, 32, 17]
# 436 ['PbI2', 'alpha-MAPbI3', 'PbBr2'] [62, 64, 65] [64, 65, 46]
# 437 ['gamma-CsPbI3', 'PbI2', 'CsI'] [18, 38, 65] [65, 46, 39]
# 438 ['CsI', 'Pnma-CsPbCl3', 'CsPb(I0.8Cl0.2)3'] [18, 31, 34] [34, 31, 29]
# 439 ['PbI2', 'tetragonal-MAPbI3', 'alpha-MAPbI3'] [62, 63, 65] [65, 63, 62]
# 440 ['MAPb(Br0.4I0.6)3', 'tetragonal-MAPbI3', 'cubic-MAPbBr3'] [56, 59, 63] [64, 43, 3]
# 441 ['Cs0.8FA0.2PbBr3', 'Cs4PbBr6', 'CsBr'] [3, 16, 17] [16, 43, 17]
# 442 ['gamma-CsPbI3', 'delta-CsPbI3', 'CsPb(I0.6Cl0.4)3'] [30, 37, 38] [37, 38, 13]
# 443 ['cubic-FAPbBr3', 'delta-FAPbI3', 'FAPb(Br0.4I0.6)3'] [40, 43, 46] [46, 43, 65]
# 444 ['Cs0.8MA0.2PbI3', 'CsI', 'alpha-MAPbI3'] [15, 18, 62] [18, 62, 14]
# 445 ['PbI2', 'gamma-CsPbI3', 'delta-CsPbI3'] [37, 38, 65] [38, 37, 65]
# 446 ['gamma-CsPbI3', 'CsPb(I0.6Br0.4)3', 'Cs4PbBr6'] [16, 26, 38] [16, 26, 64]
# 447 ['delta-FAPbI3', 'beta-FAPbI3', 'PbI2'] [45, 46, 65] [45, 65, 46]
# 448 ['CsPb(I0.4Br0.6)3', 'CsI', 'PbBr2'] [18, 25, 64] [25, 64, 32]
# 449 ['delta-FAPbI3', 'beta-FAPbI3', 'alpha-FAPbI3'] [44, 45, 46] [46, 45, 44]
# 450 ['PbI2', 'delta-FAPbI3', 'beta-FAPbI3'] [45, 46, 65] [65, 45, 46]
# 451 ['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2'] [62, 63, 65] [62, 63, 65]
# 452 ['tetragonal-MAPbBr3', 'Cs0.6MA0.4PbBr3', 'PbBr2'] [10, 60, 64] [64, 60, 10]
# 453 ['PbBr2', 'cubic-CsPbBr3', 'Cs4PbBr6'] [16, 32, 64] [64, 32, 16]
# 454 ['cubic-FAPbBr3', 'delta-FAPbI3', 'PbI2'] [43, 46, 65] [65, 45, 46]
# 455 ['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2'] [62, 63, 65] [65, 63, 62]
# 456 ['MA0.8FA0.2PbBr3', 'MA0.4FA0.6PbBr3', 'MA0.2FA0.8PbBr3'] [47, 48, 50] [59, 43, 48]
# 457 ['CsPb(Cl0.4Br0.6)3', 'PbBr2', 'cubic-CsPbBr3'] [21, 32, 64] [64, 32, 11]
# 458 ['cubic-FAPbBr3', 'Cs0.8FA0.2PbBr3', 'cubic-CsPbBr3'] [3, 32, 43] [43, 32, 3]
# 459 ['MA0.6FA0.4PbBr3', 'MA0.8FA0.2PbBr3', 'tetragonal-MAPbBr3'] [49, 50, 60] [49, 50, 60]
# 460 ['CsPb2Br5', 'CsPb(Cl0.2Br0.8)3', 'Pnma-CsPbCl3'] [19, 20, 34] [19, 34, 20]
# 461 ['alpha-CsPbI3', 'gamma-CsPbI3', 'delta-CsPbI3'] [36, 37, 38] [38, 37, 36]
# 462 ['Cs4PbBr6', 'cubic-CsPbBr3', 'PbBr2'] [16, 32, 64] [64, 16, 45]
# 463 ['gamma-CsPbI3', 'alpha-CsPbI3', 'CsI'] [18, 36, 38] [18, 36, 38]
# 464 ['CsBr', 'orthorhombic-CsPbBr3', 'CsPb(Cl0.8Br0.2)3'] [17, 23, 33] [64, 23, 43]
# 465 ['Cs4PbBr6', 'CsBr', 'orthorhombic-CsPbBr3'] [16, 17, 33] [16, 33, 17]
# 466 ['CsI', 'alpha-CsPbI3', 'delta-CsPbI3'] [18, 36, 37] [33, 17, 23]
# 467 ['orthorhombic-CsPbBr3', 'CsBr', 'PbBr2'] [17, 33, 64] [33, 64, 17]
# 468 ['CsPb(Cl0.6Br0.4)3', 'Pnma-CsPbCl3', 'CsPb(Cl0.8Br0.2)3'] [22, 23, 34] [22, 34, 21]
# 469 ['tetragonal-MAPbI3', 'Cs0.6MA0.4PbI3', 'CsI'] [14, 18, 63] [62, 63, 59]
# 470 ['orthorhombic-CsPbBr3', 'Cs4PbBr6', 'CsPb2Br5'] [16, 19, 33] [16, 33, 19]
# 471 ['PbI2', 'delta-FAPbI3', 'beta-FAPbI3'] [45, 46, 65] [65, 46, 5]
# 472 ['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbI3'] [59, 63, 64] [64, 63, 19]
# 473 ['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3'] [59, 60, 64] [64, 60, 59]
# 474 ['gamma-CsPbI3', 'Cs0.8MA0.2PbI3', 'alpha-MAPbI3'] [15, 38, 62] [38, 14, 13]
# 475 ['MA0.8FA0.2PbI3', 'MA0.2FA0.8PbI3', 'beta-FAPbI3'] [45, 51, 54] [51, 65, 44]
# 476 ['PbBr2', 'orthorhombic-CsPbBr3', 'Cs4PbBr6'] [16, 33, 64] [64, 16, 19]
# 477 ['Cs0.6FA0.4PbI3', 'Cs0.8FA0.2PbI3', 'Cs0.4FA0.6PbI3'] [5, 6, 7] [6, 4, 51]
# 478 ['CsI', 'delta-CsPbI3', 'gamma-CsPbI3'] [18, 37, 38] [37, 18, 33]
# 479 ['tetragonal-MAPbI3', 'Cs0.4MA0.6PbI3', 'Cs0.6MA0.4PbI3'] [13, 14, 63] [63, 62, 14]
# 480 ['alpha-FAPbI3', 'cubic-FAPbBr3', 'FAPb(Br0.6I0.4)3'] [41, 43, 44] [43, 41, 65]
# 481 ['alpha-CsPbI3', 'CsI', 'PbI2'] [18, 36, 65] [65, 36, 18]
# 482 ['CsPb(Cl0.2Br0.8)3', 'PbBr2', 'CsPb(Cl0.8Br0.2)3'] [20, 23, 64] [64, 23, 32]
# 483 ['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3'] [59, 60, 64] [64, 60, 59]
# 484 ['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2'] [59, 60, 64] [64, 59, 60]
# 485 ['beta-FAPbI3', 'delta-FAPbI3', 'alpha-FAPbI3'] [44, 45, 46] [44, 46, 45]
# 486 ['PbI2', 'delta-FAPbI3', 'alpha-FAPbI3'] [44, 46, 65] [44, 65, 46]
# 487 ['orthorhombic-CsPbBr3', 'cubic-CsPbBr3', 'CsBr'] [17, 32, 33] [33, 17, 32]
# 488 ['Pnma-CsPbCl3', 'delta-CsPbI3', 'cubic-CsPbCl3'] [34, 35, 37] [34, 37, 35]
# 489 ['MAPb(Br0.6I0.4)3', 'PbBr2', 'MAPb(Br0.8I0.2)3'] [57, 58, 64] [64, 57, 58]
# 490 ['PbI2', 'CsI', 'Pnma-CsPbCl3'] [18, 34, 65] [34, 65, 18]
# 491 ['PbI2', 'MA0.6FA0.4PbI3', 'alpha-MAPbI3'] [53, 62, 65] [16, 43, 22]
# 492 ['FAPb(Br0.6I0.4)3', 'alpha-FAPbI3', 'FAPb(Br0.4I0.6)3'] [40, 41, 44] [44, 41, 5]
# 493 ['CsPb(I0.2Cl0.8)3', 'CsPb(I0.6Cl0.4)3', 'gamma-CsPbI3'] [28, 30, 38] [38, 30, 65]
# 494 ['cubic-FAPbBr3', 'MA0.4FA0.6PbBr3', 'PbBr2'] [43, 48, 64] [64, 32, 11]
# 495 ['Cs4PbBr6', 'CsBr', 'orthorhombic-CsPbBr3'] [16, 17, 33] [33, 19, 17]
# 496 ['cubic-CsPbBr3', 'PbBr2', 'Cs0.2FA0.8PbBr3'] [0, 32, 64] [64, 32, 19]
# 497 ['Cs0.8FA0.2PbI3', 'delta-FAPbI3', 'alpha-CsPbI3'] [7, 36, 46] [36, 65, 7]
# 498 ['CsPb(I0.8Br0.2)3', 'Cs4PbBr6', 'CsPb(I0.2Br0.8)3'] [16, 24, 27] [16, 19, 24]
# 499 ['cubic-MAPbBr3', 'PbBr2', 'MA0.6FA0.4PbBr3'] [49, 59, 64] [59, 64, 60]
# 500 ['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2'] [62, 63, 65] [62, 63, 65]
# 501 ['CsPb(I0.6Br0.4)3', 'Cs4PbBr6', 'CsPb(I0.2Br0.8)3'] [16, 24, 26] [16, 24, 19]
# 502 ['CsPb(Cl0.4Br0.6)3', 'CsBr', 'Pnma-CsPbCl3'] [17, 21, 34] [21, 34, 17]
# 503 ['MA0.8FA0.2PbI3', 'tetragonal-MAPbI3', 'MA0.6FA0.4PbI3'] [53, 54, 63] [63, 53, 52]
# 504 ['Cs0.6MA0.4PbBr3', 'tetragonal-MAPbBr3', 'CsBr'] [10, 17, 60] [10, 60, 17]
# 505 ['tetragonal-MAPbI3', 'alpha-FAPbI3', 'delta-FAPbI3'] [44, 46, 63] [46, 63, 44]
# 506 ['beta-FAPbI3', 'PbBr2', 'FAPb(Br0.4I0.6)3'] [40, 45, 64] [41, 39, 45]
# 507 ['beta-FAPbI3', 'MA0.8FA0.2PbI3', 'delta-FAPbI3'] [45, 46, 54] [46, 54, 44]
# 508 ['Cs4PbBr6', 'CsPb(Cl0.6Br0.4)3', 'orthorhombic-CsPbBr3'] [16, 22, 33] [33, 16, 17]
# 509 ['gamma-CsPbI3', 'delta-CsPbI3', 'alpha-CsPbI3'] [36, 37, 38] [37, 36, 38]
# 510 ['CsBr', 'CsPb2Br5', 'PbBr2'] [17, 19, 64] [17, 19, 64]
# 511 ['CsBr', 'PbI2', 'PbBr2'] [17, 64, 65] [65, 64, 57]
# 512 ['PbI2', 'FAPb(Br0.2I0.8)3', 'cubic-FAPbBr3'] [39, 43, 65] [39, 43, 65]
# 513 ['Pnma-CsPbCl3', 'CsPb(Cl0.4Br0.6)3', 'CsBr'] [17, 21, 34] [21, 34, 17]
# 514 ['MA0.6FA0.4PbI3', 'MA0.8FA0.2PbI3', 'beta-FAPbI3'] [45, 53, 54] [45, 6, 41]
# 515 ['PbBr2', 'cubic-MAPbBr3', 'MAPb(Br0.4I0.6)3'] [56, 59, 64] [64, 43, 65]
# 516 ['beta-FAPbI3', 'alpha-FAPbI3', 'cubic-FAPbBr3'] [43, 44, 45] [44, 45, 65]
# 517 ['MAPb(Br0.2I0.8)3', 'MAPb(Br0.4I0.6)3', 'cubic-MAPbBr3'] [55, 56, 59] [58, 55, 59]
# 518 ['PbI2', 'delta-FAPbI3', 'alpha-FAPbI3'] [44, 46, 65] [64, 43, 48]
# 519 ['alpha-CsPbI3', 'PbI2', 'delta-CsPbI3'] [36, 37, 65] [37, 36, 65]
# 520 ['Cs0.4FA0.6PbI3', 'gamma-CsPbI3', 'Cs0.2FA0.8PbI3'] [4, 5, 38] [38, 4, 5]
# 521 ['cubic-CsPbBr3', 'PbBr2', 'CsBr'] [17, 32, 64] [64, 32, 17]
# 522 ['PbBr2', 'CsI', 'gamma-CsPbI3'] [18, 38, 64] [38, 19, 45]
# 523 ['delta-FAPbI3', 'beta-FAPbI3', 'alpha-FAPbI3'] [44, 45, 46] [44, 45, 46]
# 524 ['PbBr2', 'MAPb(Br0.2I0.8)3', 'tetragonal-MAPbBr3'] [55, 60, 64] [64, 43, 60]
# 525 ['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2'] [62, 63, 65] [63, 65, 62]
# 526 ['PbI2', 'tetragonal-MAPbBr3', 'alpha-MAPbI3'] [60, 62, 65] [62, 60, 65]
# 527 ['Cs0.2FA0.8PbI3', 'alpha-CsPbI3', 'CsI'] [4, 18, 36] [4, 36, 18]
# 528 ['CsPb(I0.4Cl0.6)3', 'CsPb(I0.8Cl0.2)3', 'PbI2'] [29, 31, 65] [65, 32, 24]
# 529 ['cubic-MAPbBr3', 'MA0.4FA0.6PbBr3', 'MA0.8FA0.2PbBr3'] [48, 50, 59] [59, 48, 50]
# 530 ['beta-FAPbI3', 'delta-FAPbI3', 'Cs0.2FA0.8PbI3'] [4, 45, 46] [39, 46, 41]
# 531 ['Pnma-CsPbCl3', 'delta-CsPbI3', 'alpha-CsPbI3'] [34, 36, 37] [36, 37, 65]
# 532 ['Cs4PbBr6', 'Cs0.2MA0.8PbBr3', 'cubic-MAPbBr3'] [8, 16, 59] [8, 59, 16]
# 533 ['cubic-FAPbBr3', 'beta-FAPbI3', 'PbI2'] [43, 45, 65] [43, 32, 65]
# 534 ['orthorhombic-CsPbBr3', 'Cs4PbBr6', 'CsPb2Br5'] [16, 19, 33] [33, 38, 19]
# 535 ['beta-FAPbI3', 'Cs0.6FA0.4PbI3', 'PbI2'] [6, 45, 65] [5, 45, 6]
# 536 ['CsPb2Br5', 'orthorhombic-CsPbBr3', 'CsBr'] [17, 19, 33] [33, 19, 17]
# 537 ['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2'] [62, 63, 65] [62, 63, 65]
# 538 ['alpha-CsPbI3', 'Cs0.2MA0.8PbI3', 'gamma-CsPbI3'] [12, 36, 38] [38, 36, 15]
# 539 ['FAPb(Br0.8I0.2)3', 'FAPb(Br0.6I0.4)3', 'PbI2'] [41, 42, 65] [42, 65, 46]
# 540 ['gamma-CsPbI3', 'delta-CsPbI3', 'CsI'] [18, 37, 38] [38, 37, 18]
# 541 ['CsPb(Cl0.8Br0.2)3', 'CsPb(Cl0.4Br0.6)3', 'CsPb2Br5'] [19, 21, 23] [19, 21, 23]
# 542 ['tetragonal-MAPbBr3', 'MAPb(Br0.8I0.2)3', 'cubic-MAPbBr3'] [58, 59, 60] [50, 43, 59]
# 543 ['cubic-CsPbBr3', 'Cs0.8FA0.2PbBr3', 'Cs4PbBr6'] [3, 16, 32] [16, 32, 11]
# 544 ['alpha-MAPbI3', 'PbI2', 'tetragonal-MAPbI3'] [62, 63, 65] [65, 63, 62]
# 545 ['alpha-CsPbI3', 'gamma-CsPbI3', 'delta-CsPbI3'] [36, 37, 38] [37, 38, 36]
# 546 ['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2'] [62, 63, 65] [62, 65, 63]
# 547 ['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2'] [59, 60, 64] [60, 59, 64]
# 548 ['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'PbBr2'] [59, 60, 64] [64, 60, 59]
# 549 ['Cs4PbBr6', 'PbBr2', 'Cs0.4MA0.6PbBr3'] [9, 16, 64] [64, 16, 2]
# 550 ['PbBr2', 'Cs0.6FA0.4PbBr3', 'cubic-CsPbBr3'] [2, 32, 64] [8, 2, 32]
# 551 ['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'PbBr2'] [59, 60, 64] [64, 60, 59]
# 552 ['tetragonal-MAPbI3', 'MAPb(Br0.8I0.2)3', 'MAPb(Br0.4I0.6)3'] [56, 58, 63] [56, 63, 58]
# 553 ['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'PbBr2'] [59, 60, 64] [60, 59, 64]
# 554 ['Cs0.6MA0.4PbBr3', 'CsBr', 'cubic-MAPbBr3'] [10, 17, 59] [32, 1, 17]
# 555 ['Cs0.8MA0.2PbBr3', 'Cs0.4MA0.6PbBr3', 'Cs0.6MA0.4PbBr3'] [9, 10, 11] [11, 10, 32]
# 556 ['gamma-CsPbI3', 'delta-CsPbI3', 'alpha-CsPbI3'] [36, 37, 38] [37, 38, 36]
# 557 ['beta-FAPbI3', 'delta-FAPbI3', 'alpha-FAPbI3'] [44, 45, 46] [45, 46, 44]
# 558 ['MA0.8FA0.2PbI3', 'beta-FAPbI3', 'alpha-FAPbI3'] [44, 45, 54] [45, 44, 7]
# 559 ['beta-FAPbI3', 'delta-FAPbI3', 'alpha-FAPbI3'] [44, 45, 46] [44, 46, 45]
# 560 ['Pnma-CsPbCl3', 'CsI', 'CsPb(I0.6Cl0.4)3'] [18, 30, 34] [65, 18, 17]
# 561 ['delta-FAPbI3', 'tetragonal-MAPbI3', 'beta-FAPbI3'] [45, 46, 63] [46, 45, 44]
# 562 ['delta-CsPbI3', 'CsI', 'alpha-CsPbI3'] [18, 36, 37] [18, 36, 37]
# 563 ['MA0.2FA0.8PbBr3', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3'] [47, 59, 60] [47, 59, 60]
# 564 ['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'MAPb(Br0.8I0.2)3'] [58, 59, 60] [59, 58, 60]
# 565 ['Cs0.8MA0.2PbI3', 'PbI2', 'CsI'] [15, 18, 65] [36, 65, 18]
# 566 ['cubic-FAPbBr3', 'PbI2', 'delta-FAPbI3'] [43, 46, 65] [65, 46, 43]
# 567 ['Cs0.2FA0.8PbBr3', 'CsBr', 'Cs0.4FA0.6PbBr3'] [0, 1, 17] [65, 62, 63]
# 568 ['alpha-FAPbI3', 'beta-FAPbI3', 'delta-FAPbI3'] [44, 45, 46] [46, 44, 45]
# 569 ['MA0.6FA0.4PbBr3', 'cubic-FAPbBr3', 'MA0.4FA0.6PbBr3'] [43, 48, 49] [43, 49, 50]
# 570 ['CsPb2Br5', 'orthorhombic-CsPbBr3', 'Cs0.6FA0.4PbBr3'] [2, 19, 33] [19, 33, 2]
# 571 ['tetragonal-MAPbBr3', 'PbBr2', 'cubic-MAPbBr3'] [59, 60, 64] [60, 64, 59]
# 572 ['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3'] [59, 60, 64] [64, 59, 60]
# 573 ['CsI', 'CsPb(I0.2Br0.8)3', 'alpha-CsPbI3'] [18, 24, 36] [17, 18, 36]
# 574 ['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3'] [59, 60, 64] [60, 59, 64]
# 575 ['Cs0.4MA0.6PbI3', 'gamma-CsPbI3', 'CsI'] [13, 18, 38] [18, 38, 65]
# 576 ['CsPb2Br5', 'orthorhombic-CsPbBr3', 'Cs4PbBr6'] [16, 19, 33] [33, 39, 19]
# 577 ['Cs0.2MA0.8PbBr3', 'tetragonal-MAPbBr3', 'Cs0.6MA0.4PbBr3'] [8, 10, 60] [17, 10, 9]
# 578 ['gamma-CsPbI3', 'PbI2', 'alpha-CsPbI3'] [36, 38, 65] [65, 38, 36]
# 579 ['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'PbBr2'] [59, 60, 64] [60, 64, 59]
# 580 ['Cs0.8MA0.2PbI3', 'Cs0.6MA0.4PbI3', 'Cs0.4MA0.6PbI3'] [13, 14, 15] [14, 15, 13]
# 581 ['Cs4PbBr6', 'CsPb2Br5', 'Cs0.4FA0.6PbBr3'] [1, 16, 19] [64, 16, 32]
# 582 ['alpha-MAPbI3', 'PbI2', 'tetragonal-MAPbI3'] [62, 63, 65] [62, 63, 65]
# 583 ['Cs0.4FA0.6PbI3', 'delta-CsPbI3', 'delta-FAPbI3'] [5, 37, 46] [5, 38, 37]
# 584 ['CsPb(Cl0.4Br0.6)3', 'cubic-CsPbCl3', 'Cs4PbBr6'] [16, 21, 35] [35, 16, 34]
# 585 ['orthorhombic-CsPbBr3', 'delta-CsPbI3', 'CsI'] [18, 33, 37] [38, 37, 19]
# 586 ['gamma-CsPbI3', 'tetragonal-MAPbI3', 'CsI'] [18, 38, 63] [38, 63, 36]
# 587 ['tetragonal-MAPbI3', 'PbI2', 'alpha-MAPbI3'] [62, 63, 65] [62, 65, 63]
# 588 ['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3'] [59, 60, 64] [60, 64, 59]
# 589 ['tetragonal-MAPbI3', 'MAPb(Br0.4I0.6)3', 'MAPb(Br0.2I0.8)3'] [55, 56, 63] [63, 55, 56]
# 590 ['CsBr', 'cubic-FAPbBr3', 'cubic-CsPbBr3'] [17, 32, 43] [18, 36, 26]
# 591 ['PbBr2', 'delta-CsPbI3', 'CsPb(I0.8Br0.2)3'] [27, 37, 64] [27, 37, 64]
# 592 ['PbBr2', 'alpha-CsPbI3', 'CsI'] [18, 36, 64] [64, 43, 62]
# 593 ['CsPb(I0.6Cl0.4)3', 'PbI2', 'Pnma-CsPbCl3'] [30, 34, 65] [65, 30, 34]
# 594 ['beta-FAPbI3', 'FAPb(Br0.6I0.4)3', 'delta-FAPbI3'] [41, 45, 46] [46, 45, 41]
# 595 ['gamma-CsPbI3', 'PbI2', 'CsPb(I0.6Cl0.4)3'] [30, 38, 65] [65, 38, 18]
# 596 ['Cs4PbBr6', 'CsBr', 'cubic-MAPbBr3'] [16, 17, 59] [17, 16, 4]
# 597 ['alpha-CsPbI3', 'gamma-CsPbI3', 'delta-CsPbI3'] [36, 37, 38] [38, 37, 36]
# 598 ['delta-CsPbI3', 'CsI', 'Cs0.4MA0.6PbI3'] [13, 18, 37] [37, 46, 18]
# 599 ['Cs4PbBr6', 'Cs0.2MA0.8PbBr3', 'cubic-CsPbBr3'] [8, 16, 32] [16, 8, 11]
# 600 ['CsPb(I0.8Br0.2)3', 'CsI', 'Cs4PbBr6'] [16, 18, 27] [19, 60, 32]
# 601 ['MAPb(Br0.8I0.2)3', 'MAPb(Br0.4I0.6)3', 'MAPb(Br0.6I0.4)3'] [56, 57, 58] [57, 58, 56]
# 602 ['PbI2', 'alpha-MAPbI3', 'tetragonal-MAPbI3'] [62, 63, 65] [62, 65, 63]
# 603 ['Cs0.2FA0.8PbBr3', 'orthorhombic-CsPbBr3', 'CsBr'] [0, 17, 33] [17, 33, 19]
# 604 ['delta-FAPbI3', 'PbI2', 'beta-FAPbI3'] [45, 46, 65] [65, 46, 45]
# 605 ['CsPb2Br5', 'cubic-CsPbBr3', 'orthorhombic-CsPbBr3'] [19, 32, 33] [33, 19, 32]
# 606 ['orthorhombic-CsPbBr3', 'CsPb2Br5', 'PbBr2'] [19, 33, 64] [33, 64, 19]
# 607 ['PbI2', 'alpha-MAPbI3', 'tetragonal-MAPbI3'] [62, 63, 65] [62, 65, 63]
# 608 ['alpha-MAPbI3', 'gamma-CsPbI3', 'tetragonal-MAPbI3'] [38, 62, 63] [63, 62, 38]
# 609 ['cubic-CsPbBr3', 'Cs4PbBr6', 'CsPb2Br5'] [16, 19, 32] [16, 19, 32]
# 610 ['tetragonal-MAPbI3', 'cubic-MAPbBr3', 'alpha-MAPbI3'] [59, 62, 63] [59, 63, 65]
# 611 ['Cs0.8FA0.2PbI3', 'CsI', 'alpha-CsPbI3'] [7, 18, 36] [36, 7, 18]
# 612 ['PbBr2', 'orthorhombic-CsPbBr3', 'CsPb2Br5'] [19, 33, 64] [64, 33, 17]
# 613 ['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2'] [62, 63, 65] [62, 65, 63]
# 614 ['alpha-CsPbI3', 'PbI2', 'tetragonal-MAPbI3'] [36, 63, 65] [63, 65, 62]
# 615 ['alpha-MAPbI3', 'PbBr2', 'PbI2'] [62, 64, 65] [62, 64, 65]
# 616 ['alpha-FAPbI3', 'PbI2', 'delta-FAPbI3'] [44, 46, 65] [65, 46, 44]
# 617 ['gamma-CsPbI3', 'CsPb2Br5', 'cubic-CsPbBr3'] [19, 32, 38] [38, 7, 65]
# 618 ['CsPb(I0.2Br0.8)3', 'gamma-CsPbI3', 'CsBr'] [17, 24, 38] [38, 65, 18]
# 619 ['Cs0.8FA0.2PbBr3', 'Cs0.2FA0.8PbBr3', 'Cs0.6FA0.4PbBr3'] [0, 2, 3] [0, 3, 2]
# 620 ['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3'] [59, 60, 64] [60, 59, 64]
# 621 ['CsI', 'gamma-CsPbI3', 'alpha-CsPbI3'] [18, 36, 38] [38, 36, 18]
# 622 ['Cs0.6MA0.4PbBr3', 'CsPb2Br5', 'tetragonal-MAPbBr3'] [10, 19, 60] [60, 9, 32]
# ...
# 794 ['delta-CsPbI3', 'Cs0.2MA0.8PbI3', 'Cs0.4MA0.6PbI3'] [12, 13, 37] [37, 14, 13]
# 795 ['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2'] [62, 63, 65] [62, 65, 63]
# 796 ['Cs0.6MA0.4PbI3', 'Cs0.2MA0.8PbI3', 'delta-CsPbI3'] [12, 14, 37] [14, 37, 15]
# 797 ['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3'] [59, 60, 64] [60, 64, 59]
# 798 ['MA0.4FA0.6PbBr3', 'MA0.6FA0.4PbBr3', 'cubic-MAPbBr3'] [48, 49, 59] [47, 59, 48]
# 799 ['delta-FAPbI3', 'PbI2', 'beta-FAPbI3'] [45, 46, 65] [65, 46, 45]
# 800 ['cubic-FAPbBr3', 'MA0.6FA0.4PbBr3', 'PbBr2'] [43, 49, 64] [43, 64, 47]
# 801 ['alpha-CsPbI3', 'CsPb(I0.2Cl0.8)3', 'PbI2'] [28, 36, 65] [36, 30, 65]
# 802 ['tetragonal-MAPbI3', 'PbI2', 'alpha-MAPbI3'] [62, 63, 65] [62, 63, 65]
# 803 ['alpha-FAPbI3', 'delta-FAPbI3', 'FAPb(Br0.8I0.2)3'] [42, 44, 46] [42, 46, 44]
# 804 ['beta-FAPbI3', 'MA0.4FA0.6PbI3', 'PbI2'] [45, 52, 65] [45, 65, 52]
# 805 ['PbI2', 'CsPb(I0.6Cl0.4)3', 'gamma-CsPbI3'] [30, 38, 65] [38, 30, 65]
# 806 ['CsI', 'PbI2', 'delta-CsPbI3'] [18, 37, 65] [37, 65, 18]
# 807 ['tetragonal-MAPbI3', 'alpha-MAPbI3', 'delta-FAPbI3'] [46, 62, 63] [63, 62, 46]
# 808 ['CsI', 'Cs0.6MA0.4PbI3', 'Cs0.2MA0.8PbI3'] [12, 14, 18] [18, 13, 12]
# 809 ['MA0.4FA0.6PbBr3', 'cubic-MAPbBr3', 'MA0.2FA0.8PbBr3'] [47, 48, 59] [47, 59, 48]
# 810 ['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2'] [62, 63, 65] [62, 65, 63]
# 811 ['orthorhombic-CsPbBr3', 'Cs4PbBr6', 'CsPb(Cl0.6Br0.4)3'] [16, 22, 33] [33, 16, 20]
# 812 ['beta-FAPbI3', 'alpha-FAPbI3', 'cubic-FAPbBr3'] [43, 44, 45] [45, 43, 44]
# 813 ['Cs4PbBr6', 'CsBr', 'CsPb2Br5'] [16, 17, 19] [16, 19, 17]
# 814 ['PbI2', 'tetragonal-MAPbI3', 'alpha-MAPbI3'] [62, 63, 65] [62, 65, 63]
# 815 ['MA0.8FA0.2PbBr3', 'MA0.6FA0.4PbBr3', 'cubic-MAPbBr3'] [49, 50, 59] [50, 59, 49]
# 816 ['orthorhombic-CsPbBr3', 'cubic-CsPbBr3', 'PbBr2'] [32, 33, 64] [64, 33, 32]
# 817 ['alpha-MAPbI3', 'PbI2', 'tetragonal-MAPbI3'] [62, 63, 65] [62, 65, 63]
# 818 ['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3'] [59, 60, 64] [64, 59, 60]
# 819 ['PbI2', 'CsPb(I0.6Cl0.4)3', 'CsI'] [18, 30, 65] [30, 18, 65]
# 820 ['alpha-FAPbI3', 'beta-FAPbI3', 'delta-FAPbI3'] [44, 45, 46] [44, 46, 45]
# 821 ['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2'] [62, 63, 65] [62, 63, 65]
# 822 ['MAPb(Br0.6I0.4)3', 'PbBr2', 'tetragonal-MAPbBr3'] [57, 60, 64] [60, 64, 63]
# 823 ['delta-FAPbI3', 'Cs0.2FA0.8PbI3', 'CsI'] [4, 18, 46] [4, 46, 65]
# 824 ['delta-CsPbI3', 'CsI', 'alpha-CsPbI3'] [18, 36, 37] [38, 36, 37]
# 825 ['cubic-FAPbBr3', 'delta-FAPbI3', 'FAPb(Br0.2I0.8)3'] [39, 43, 46] [46, 39, 65]
# 826 ['alpha-MAPbI3', 'PbI2', 'tetragonal-MAPbI3'] [62, 63, 65] [62, 63, 65]
# 827 ['PbBr2', 'MA0.4FA0.6PbBr3', 'tetragonal-MAPbBr3'] [48, 60, 64] [64, 48, 50]
# 828 ['alpha-CsPbI3', 'delta-CsPbI3', 'gamma-CsPbI3'] [36, 37, 38] [38, 36, 37]
# 829 ['Cs4PbBr6', 'orthorhombic-CsPbBr3', 'CsBr'] [16, 17, 33] [33, 16, 17]
# 830 ['PbI2', 'Cs0.8FA0.2PbI3', 'Cs0.4FA0.6PbI3'] [5, 7, 65] [5, 65, 7]
# 831 ['cubic-CsPbBr3', 'orthorhombic-CsPbBr3', 'CsBr'] [17, 32, 33] [17, 33, 32]
# 832 ['Cs0.4FA0.6PbBr3', 'cubic-FAPbBr3', 'Cs4PbBr6'] [1, 16, 43] [43, 16, 2]
# 833 ['alpha-FAPbI3', 'CsI', 'alpha-CsPbI3'] [18, 36, 44] [44, 36, 18]
# 834 ['MA0.4FA0.6PbI3', 'PbI2', 'MA0.8FA0.2PbI3'] [52, 54, 65] [52, 65, 45]
# 835 ['CsPb2Br5', 'cubic-CsPbBr3', 'cubic-MAPbBr3'] [19, 32, 59] [60, 19, 32]
# 836 ['PbBr2', 'MA0.4FA0.6PbBr3', 'cubic-FAPbBr3'] [43, 48, 64] [43, 64, 47]
# 837 ['MA0.2FA0.8PbI3', 'MA0.6FA0.4PbI3', 'beta-FAPbI3'] [45, 51, 53] [53, 51, 45]
# 838 ['delta-CsPbI3', 'CsI', 'delta-FAPbI3'] [18, 37, 46] [37, 46, 44]
# 839 ['FAPb(Br0.4I0.6)3', 'PbBr2', 'cubic-FAPbBr3'] [40, 43, 64] [64, 40, 43]
# 840 ['Cs4PbBr6', 'orthorhombic-CsPbBr3', 'cubic-CsPbBr3'] [16, 32, 33] [33, 16, 32]
# 841 ['MA0.4FA0.6PbI3', 'MA0.8FA0.2PbI3', 'beta-FAPbI3'] [45, 52, 54] [52, 45, 54]
# 842 ['CsBr', 'Cs0.2FA0.8PbBr3', 'cubic-CsPbBr3'] [0, 17, 32] [32, 17, 0]
# 843 ['FAPb(Br0.6I0.4)3', 'PbI2', 'PbBr2'] [41, 64, 65] [64, 41, 44]
# 844 ['alpha-CsPbI3', 'delta-CsPbI3', 'PbI2'] [36, 37, 65] [65, 36, 37]
# 845 ['MA0.2FA0.8PbBr3', 'cubic-FAPbBr3', 'PbBr2'] [43, 47, 64] [64, 43, 47]
# 846 ['Cs0.6MA0.4PbBr3', 'PbBr2', 'CsPb2Br5'] [10, 19, 64] [10, 64, 19]
# 847 ['beta-FAPbI3', 'delta-FAPbI3', 'PbBr2'] [45, 46, 64] [45, 46, 64]
# 848 ['delta-CsPbI3', 'CsI', 'gamma-CsPbI3'] [18, 37, 38] [37, 38, 65]
# 849 ['Cs0.6MA0.4PbBr3', 'Cs4PbBr6', 'Cs0.8MA0.2PbBr3'] [10, 11, 16] [16, 11, 10]
# 850 ['Cs4PbBr6', 'orthorhombic-CsPbBr3', 'CsBr'] [16, 17, 33] [17, 33, 19]
# 851 ['orthorhombic-CsPbBr3', 'CsPb(Cl0.8Br0.2)3', 'cubic-CsPbBr3'] [23, 32, 33] [32, 33, 20]
# 852 ['beta-FAPbI3', 'alpha-MAPbI3', 'MA0.8FA0.2PbI3'] [45, 54, 62] [45, 62, 54]
# 853 ['delta-CsPbI3', 'CsPb(I0.6Cl0.4)3', 'alpha-CsPbI3'] [30, 36, 37] [36, 31, 37]
# 854 ['PbI2', 'CsPb(I0.2Cl0.8)3', 'CsI'] [18, 28, 65] [28, 18, 29]
# 855 ['gamma-CsPbI3', 'CsI', 'Pnma-CsPbCl3'] [18, 34, 38] [38, 34, 18]
# 856 ['Cs4PbBr6', 'CsPb2Br5', 'PbBr2'] [16, 19, 64] [16, 19, 64]
# 857 ['MAPb(Br0.4I0.6)3', 'tetragonal-MAPbI3', 'tetragonal-MAPbBr3'] [56, 60, 63] [63, 56, 58]
# 858 ['delta-FAPbI3', 'FAPb(Br0.4I0.6)3', 'PbI2'] [40, 46, 65] [46, 65, 64]
# 859 ['CsI', 'PbI2', 'gamma-CsPbI3'] [18, 38, 65] [65, 38, 18]
# 860 ['CsPb2Br5', 'PbBr2', 'CsBr'] [17, 19, 64] [64, 19, 32]
# 861 ['MA0.4FA0.6PbBr3', 'PbBr2', 'MA0.6FA0.4PbBr3'] [48, 49, 64] [49, 48, 64]
# 862 ['delta-FAPbI3', 'beta-FAPbI3', 'PbI2'] [45, 46, 65] [45, 46, 65]
# 863 ['CsBr', 'Cs4PbBr6', 'cubic-CsPbBr3'] [16, 17, 32] [17, 32, 16]
# 864 ['cubic-CsPbBr3', 'Cs4PbBr6', 'CsBr'] [16, 17, 32] [16, 17, 19]
# 865 ['CsPb(I0.6Cl0.4)3', 'Pnma-CsPbCl3', 'CsI'] [18, 30, 34] [65, 30, 18]
# 866 ['PbBr2', 'CsPb(I0.4Br0.6)3', 'gamma-CsPbI3'] [25, 38, 64] [38, 64, 16]
# 867 ['PbI2', 'delta-CsPbI3', 'CsI'] [18, 37, 65] [18, 37, 65]
# 868 ['alpha-CsPbI3', 'Pnma-CsPbCl3', 'CsI'] [18, 34, 36] [36, 34, 30]
# 869 ['PbI2', 'MA0.2FA0.8PbI3', 'beta-FAPbI3'] [45, 51, 65] [51, 65, 45]
# 870 ['CsBr', 'Cs0.4FA0.6PbBr3', 'CsPb2Br5'] [1, 17, 19] [19, 1, 17]
# 871 ['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2'] [59, 60, 64] [60, 64, 59]
# 872 ['alpha-FAPbI3', 'Cs0.6FA0.4PbI3', 'delta-FAPbI3'] [6, 44, 46] [6, 44, 65]
# 873 ['CsPb2Br5', 'CsPb(Cl0.6Br0.4)3', 'cubic-CsPbBr3'] [19, 22, 32] [19, 32, 34]
# 874 ['alpha-MAPbI3', 'MAPb(Br0.8I0.2)3', 'tetragonal-MAPbI3'] [58, 62, 63] [62, 63, 58]
# 875 ['delta-CsPbI3', 'Cs0.4FA0.6PbI3', 'Cs0.2FA0.8PbI3'] [4, 5, 37] [5, 4, 38]
# 876 ['CsPb(Cl0.6Br0.4)3', 'cubic-CsPbCl3', 'Cs4PbBr6'] [16, 22, 35] [19, 21, 22]
# 877 ['delta-CsPbI3', 'Cs0.8MA0.2PbI3', 'gamma-CsPbI3'] [15, 37, 38] [37, 38, 15]
# 878 ['PbI2', 'delta-FAPbI3', 'beta-FAPbI3'] [45, 46, 65] [65, 45, 46]
# 879 ['CsPb(Cl0.6Br0.4)3', 'PbBr2', 'CsBr'] [17, 22, 64] [19, 21, 17]
# 880 ['delta-FAPbI3', 'alpha-FAPbI3', 'Cs0.6FA0.4PbI3'] [6, 44, 46] [46, 5, 65]
# 881 ['CsPb(I0.8Cl0.2)3', 'CsPb(I0.4Cl0.6)3', 'PbI2'] [29, 31, 65] [65, 31, 29]
# 882 ['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2'] [62, 63, 65] [62, 65, 63]
# 883 ['MA0.6FA0.4PbBr3', 'MA0.8FA0.2PbBr3', 'MA0.2FA0.8PbBr3'] [47, 49, 50] [60, 47, 43]
# 884 ['CsPb2Br5', 'orthorhombic-CsPbBr3', 'CsBr'] [17, 19, 33] [19, 17, 33]
# 885 ['alpha-FAPbI3', 'PbI2', 'beta-FAPbI3'] [44, 45, 65] [44, 65, 45]
# 886 ['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2'] [62, 63, 65] [62, 63, 65]
# 887 ['Pnma-CsPbCl3', 'cubic-CsPbBr3', 'orthorhombic-CsPbBr3'] [32, 33, 34] [32, 33, 1]
# 888 ['delta-CsPbI3', 'gamma-CsPbI3', 'CsPb(I0.6Cl0.4)3'] [30, 37, 38] [37, 30, 38]
# 889 ['delta-FAPbI3', 'beta-FAPbI3', 'PbI2'] [45, 46, 65] [45, 65, 46]
# 890 ['PbBr2', 'Cs4PbBr6', 'CsPb2Br5'] [16, 19, 64] [19, 16, 64]
# 891 ['cubic-CsPbBr3', 'Cs0.6MA0.4PbBr3', 'CsPb2Br5'] [10, 19, 32] [10, 19, 32]
# 892 ['alpha-FAPbI3', 'Cs0.4FA0.6PbI3', 'PbI2'] [5, 44, 65] [65, 5, 44]
# 893 ['tetragonal-MAPbI3', 'PbI2', 'alpha-MAPbI3'] [62, 63, 65] [62, 65, 63]
# 894 ['orthorhombic-CsPbBr3', 'Cs0.4FA0.6PbBr3', 'PbBr2'] [1, 33, 64] [64, 33, 1]
# 895 ['CsPb2Br5', 'CsBr', 'delta-CsPbI3'] [17, 19, 37] [64, 37, 19]
# 896 ['cubic-FAPbBr3', 'alpha-FAPbI3', 'PbI2'] [43, 44, 65] [44, 43, 65]
# 897 ['delta-CsPbI3', 'CsI', 'CsPb(I0.2Cl0.8)3'] [18, 28, 37] [37, 28, 29]
# 898 ['cubic-FAPbBr3', 'Cs0.8FA0.2PbBr3', 'cubic-CsPbBr3'] [3, 32, 43] [32, 3, 0]
# 899 ['beta-FAPbI3', 'delta-FAPbI3', 'FAPb(Br0.4I0.6)3'] [40, 45, 46] [40, 45, 46]
# 900 ['alpha-MAPbI3', 'tetragonal-MAPbI3', 'MA0.2FA0.8PbI3'] [51, 62, 63] [63, 62, 44]
# 901 ['PbBr2', 'CsPb(I0.2Br0.8)3', 'CsPb(I0.6Br0.4)3'] [24, 26, 64] [64, 24, 26]
# 902 ['MA0.6FA0.4PbBr3', 'MA0.8FA0.2PbBr3', 'MA0.4FA0.6PbBr3'] [48, 49, 50] [49, 48, 50]
# 903 ['cubic-CsPbBr3', 'orthorhombic-CsPbBr3', 'CsBr'] [17, 32, 33] [33, 17, 32]
# 904 ['CsPb2Br5', 'tetragonal-MAPbBr3', 'cubic-CsPbBr3'] [19, 32, 60] [19, 32, 60]
# 905 ['Cs0.2FA0.8PbI3', 'delta-CsPbI3', 'delta-FAPbI3'] [4, 37, 46] [4, 37, 38]
# 906 ['MA0.2FA0.8PbI3', 'delta-FAPbI3', 'MA0.6FA0.4PbI3'] [46, 51, 53] [46, 51, 53]
# 907 ['tetragonal-MAPbBr3', 'PbBr2', 'cubic-MAPbBr3'] [59, 60, 64] [60, 64, 59]
# 908 ['Cs0.4MA0.6PbI3', 'CsI', 'Cs0.2MA0.8PbI3'] [12, 13, 18] [12, 13, 62]
# 909 ['Cs0.8FA0.2PbI3', 'Cs0.6FA0.4PbI3', 'Cs0.4FA0.6PbI3'] [5, 6, 7] [7, 6, 5]
# 910 ['CsI', 'CsPb(I0.2Cl0.8)3', 'cubic-CsPbCl3'] [18, 28, 35] [36, 28, 29]
# 911 ['CsBr', 'Cs4PbBr6', 'Cs0.2MA0.8PbBr3'] [8, 16, 17] [8, 16, 17]
# 912 ['Cs4PbBr6', 'PbBr2', 'cubic-CsPbBr3'] [16, 32, 64] [64, 32, 16]
# 913 ['CsPb2Br5', 'orthorhombic-CsPbBr3', 'PbBr2'] [19, 33, 64] [19, 64, 33]
# 914 ['beta-FAPbI3', 'FAPb(Br0.4I0.6)3', 'FAPb(Br0.6I0.4)3'] [40, 41, 45] [45, 41, 40]
# 915 ['Cs4PbBr6', 'cubic-CsPbBr3', 'CsBr'] [16, 17, 32] [17, 16, 32]
# 916 ['CsBr', 'Cs0.6FA0.4PbBr3', 'orthorhombic-CsPbBr3'] [2, 17, 33] [33, 2, 0]
# 917 ['CsPb(Cl0.4Br0.6)3', 'cubic-CsPbCl3', 'PbBr2'] [21, 35, 64] [64, 21, 32]
# 918 ['PbBr2', 'cubic-FAPbBr3', 'Cs0.6FA0.4PbBr3'] [2, 43, 64] [64, 43, 3]
# 919 ['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3'] [59, 60, 64] [60, 64, 59]
# 920 ['beta-FAPbI3', 'PbI2', 'delta-FAPbI3'] [45, 46, 65] [65, 46, 45]
# 921 ['CsBr', 'cubic-CsPbBr3', 'cubic-CsPbCl3'] [17, 32, 35] [17, 32, 35]
# 922 ['CsI', 'delta-CsPbI3', 'alpha-CsPbI3'] [18, 36, 37] [18, 37, 36]
# 923 ['alpha-FAPbI3', 'gamma-CsPbI3', 'beta-FAPbI3'] [38, 44, 45] [44, 38, 65]
# 924 ['PbI2', 'delta-FAPbI3', 'alpha-FAPbI3'] [44, 46, 65] [65, 46, 44]
# 925 ['MAPb(Br0.6I0.4)3', 'PbI2', 'PbBr2'] [57, 64, 65] [65, 64, 57]
# 926 ['Pnma-CsPbCl3', 'CsPb(I0.2Cl0.8)3', 'alpha-CsPbI3'] [28, 34, 36] [36, 31, 28]
# 927 ['gamma-CsPbI3', 'Cs0.2MA0.8PbI3', 'Cs0.4MA0.6PbI3'] [12, 13, 38] [38, 13, 14]
# 928 ['Cs0.2FA0.8PbBr3', 'cubic-CsPbBr3', 'Cs0.8FA0.2PbBr3'] [0, 3, 32] [32, 43, 0]
# 929 ['orthorhombic-CsPbBr3', 'CsPb(Cl0.2Br0.8)3', 'Pnma-CsPbCl3'] [20, 33, 34] [20, 33, 34]
# 930 ['FAPb(Br0.8I0.2)3', 'FAPb(Br0.4I0.6)3', 'delta-FAPbI3'] [40, 42, 46] [46, 41, 42]
# 931 ['CsI', 'gamma-CsPbI3', 'tetragonal-MAPbI3'] [18, 38, 63] [63, 18, 38]
# 932 ['alpha-CsPbI3', 'CsPb(I0.6Cl0.4)3', 'CsPb(I0.4Cl0.6)3'] [29, 30, 36] [29, 36, 30]
# 933 ['PbI2', 'delta-FAPbI3', 'alpha-FAPbI3'] [44, 46, 65] [65, 44, 46]
# 934 ['MA0.4FA0.6PbI3', 'PbI2', 'MA0.8FA0.2PbI3'] [52, 54, 65] [52, 65, 44]
# 935 ['Cs0.6MA0.4PbI3', 'Cs0.2MA0.8PbI3', 'tetragonal-MAPbI3'] [12, 14, 63] [63, 12, 62]
# 936 ['MAPb(Br0.6I0.4)3', 'PbI2', 'tetragonal-MAPbI3'] [57, 63, 65] [65, 63, 57]
# 937 ['cubic-CsPbBr3', 'CsPb(I0.2Br0.8)3', 'CsBr'] [17, 24, 32] [17, 24, 32]
# 938 ['Cs0.8MA0.2PbI3', 'CsI', 'alpha-CsPbI3'] [15, 18, 36] [18, 36, 65]
# 939 ['MA0.4FA0.6PbI3', 'tetragonal-MAPbI3', 'alpha-MAPbI3'] [52, 62, 63] [63, 52, 54]
# 940 ['cubic-FAPbBr3', 'tetragonal-MAPbBr3', 'MA0.2FA0.8PbBr3'] [43, 47, 60] [47, 50, 43]
# 941 ['tetragonal-MAPbBr3', 'PbBr2', 'CsPb2Br5'] [19, 60, 64] [19, 64, 60]
# 942 ['Cs0.2FA0.8PbI3', 'PbI2', 'alpha-FAPbI3'] [4, 44, 65] [65, 4, 36]
# 943 ['PbI2', 'FAPb(Br0.4I0.6)3', 'FAPb(Br0.6I0.4)3'] [40, 41, 65] [41, 46, 42]
# 944 ['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'PbBr2'] [59, 60, 64] [64, 60, 59]
# 945 ['gamma-CsPbI3', 'Cs0.2FA0.8PbI3', 'delta-CsPbI3'] [4, 37, 38] [4, 38, 37]
# 946 ['MAPb(Br0.6I0.4)3', 'tetragonal-MAPbBr3', 'alpha-MAPbI3'] [57, 60, 62] [57, 60, 65]
# 947 ['PbBr2', 'FAPb(Br0.4I0.6)3', 'beta-FAPbI3'] [40, 45, 64] [45, 64, 40]
# 948 ['PbBr2', 'MA0.4FA0.6PbBr3', 'cubic-FAPbBr3'] [43, 48, 64] [47, 64, 43]
# 949 ['FAPb(Br0.6I0.4)3', 'PbBr2', 'beta-FAPbI3'] [41, 45, 64] [64, 39, 41]
# 950 ['CsBr', 'CsPb(I0.2Br0.8)3', 'Cs4PbBr6'] [16, 17, 24] [24, 16, 17]
# 951 ['PbBr2', 'MAPb(Br0.4I0.6)3', 'MAPb(Br0.2I0.8)3'] [55, 56, 64] [64, 56, 55]
# 952 ['beta-FAPbI3', 'delta-FAPbI3', 'PbI2'] [45, 46, 65] [65, 46, 44]
# 953 ['PbI2', 'delta-CsPbI3', 'alpha-CsPbI3'] [36, 37, 65] [36, 65, 37]
# 954 ['CsPb(Cl0.6Br0.4)3', 'orthorhombic-CsPbBr3', 'CsPb2Br5'] [19, 22, 33] [19, 22, 33]
# 955 ['Cs0.6MA0.4PbI3', 'tetragonal-MAPbI3', 'Cs0.4MA0.6PbI3'] [13, 14, 63] [63, 14, 13]
# 956 ['PbI2', 'alpha-FAPbI3', 'beta-FAPbI3'] [44, 45, 65] [65, 44, 45]
# 957 ['PbI2', 'alpha-FAPbI3', 'beta-FAPbI3'] [44, 45, 65] [45, 44, 65]
# 958 ['PbBr2', 'cubic-CsPbBr3', 'CsPb2Br5'] [19, 32, 64] [19, 64, 32]
# 959 ['cubic-FAPbBr3', 'MA0.8FA0.2PbBr3', 'PbBr2'] [43, 50, 64] [50, 64, 59]
# 960 ['cubic-CsPbBr3', 'CsPb2Br5', 'CsBr'] [17, 19, 32] [19, 32, 17]
# 961 ['alpha-FAPbI3', 'FAPb(Br0.8I0.2)3', 'FAPb(Br0.6I0.4)3'] [41, 42, 44] [41, 42, 44]
# 962 ['tetragonal-MAPbBr3', 'MAPb(Br0.4I0.6)3', 'MAPb(Br0.8I0.2)3'] [56, 58, 60] [60, 58, 57]
# 963 ['alpha-CsPbI3', 'CsI', 'PbI2'] [18, 36, 65] [18, 36, 65]
# 964 ['beta-FAPbI3', 'Cs0.4FA0.6PbI3', 'delta-CsPbI3'] [5, 37, 45] [5, 37, 45]
# 965 ['CsPb(I0.8Br0.2)3', 'CsPb(I0.2Br0.8)3', 'CsPb(I0.4Br0.6)3'] [24, 25, 27] [27, 25, 32]
# 966 ['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3'] [59, 60, 64] [59, 64, 60]
# 967 ['MA0.2FA0.8PbBr3', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3'] [47, 59, 60] [47, 59, 48]
# 968 ['CsBr', 'Cs4PbBr6', 'CsPb2Br5'] [16, 17, 19] [19, 16, 17]
# 969 ['Cs0.6MA0.4PbI3', 'alpha-MAPbI3', 'tetragonal-MAPbI3'] [14, 62, 63] [63, 12, 62]
# 970 ['cubic-MAPbBr3', 'MA0.6FA0.4PbBr3', 'tetragonal-MAPbBr3'] [49, 59, 60] [59, 48, 49]
# 971 ['CsBr', 'Pnma-CsPbCl3', 'CsPb2Br5'] [17, 19, 34] [34, 19, 64]
# 972 ['Cs0.4MA0.6PbBr3', 'CsBr', 'orthorhombic-CsPbBr3'] [9, 17, 33] [9, 33, 17]
# 973 ['FAPb(Br0.8I0.2)3', 'PbBr2', 'delta-FAPbI3'] [42, 46, 64] [42, 64, 40]
# 974 ['PbI2', 'Cs0.6MA0.4PbI3', 'Cs0.4MA0.6PbI3'] [13, 14, 65] [65, 14, 12]
# 975 ['tetragonal-MAPbBr3', 'MA0.4FA0.6PbBr3', 'MA0.2FA0.8PbBr3'] [47, 48, 60] [48, 47, 49]
# 976 ['Cs0.6MA0.4PbBr3', 'Cs0.8MA0.2PbBr3', 'orthorhombic-CsPbBr3'] [10, 11, 33] [11, 33, 9]
# 977 ['Cs0.6MA0.4PbI3', 'alpha-MAPbI3', 'Cs0.2MA0.8PbI3'] [12, 14, 62] [12, 62, 13]
# 978 ['orthorhombic-CsPbBr3', 'cubic-MAPbBr3', 'cubic-CsPbBr3'] [32, 33, 59] [33, 60, 32]
# 979 ['CsPb(I0.4Br0.6)3', 'alpha-CsPbI3', 'CsPb(I0.6Br0.4)3'] [25, 26, 36] [36, 27, 26]
# 980 ['FAPb(Br0.6I0.4)3', 'alpha-FAPbI3', 'delta-FAPbI3'] [41, 44, 46] [41, 65, 44]
# 981 ['CsPb(I0.2Cl0.8)3', 'CsPb(I0.8Cl0.2)3', 'CsPb(I0.4Cl0.6)3'] [28, 29, 31] [29, 28, 30]
# 982 ['FAPb(Br0.2I0.8)3', 'FAPb(Br0.6I0.4)3', 'cubic-FAPbBr3'] [39, 41, 43] [39, 43, 41]
# 983 ['delta-CsPbI3', 'alpha-MAPbI3', 'PbI2'] [37, 62, 65] [65, 37, 63]
# 984 ['CsBr', 'CsPb(I0.8Br0.2)3', 'CsPb(I0.4Br0.6)3'] [17, 25, 27] [27, 25, 17]
# 985 ['delta-FAPbI3', 'FAPb(Br0.6I0.4)3', 'PbI2'] [41, 46, 65] [65, 64, 44]
# 986 ['alpha-CsPbI3', 'Cs0.8MA0.2PbI3', 'Cs0.2MA0.8PbI3'] [12, 15, 36] [36, 15, 14]
# 987 ['Cs0.4MA0.6PbBr3', 'cubic-CsPbBr3', 'orthorhombic-CsPbBr3'] [9, 32, 33] [33, 9, 60]
# 988 ['PbI2', 'beta-FAPbI3', 'alpha-FAPbI3'] [44, 45, 65] [45, 44, 46]
# 989 ['delta-CsPbI3', 'CsPb(I0.2Br0.8)3', 'cubic-CsPbBr3'] [24, 32, 37] [32, 37, 24]
# 990 ['PbI2', 'MAPb(Br0.2I0.8)3', 'MAPb(Br0.6I0.4)3'] [55, 57, 65] [65, 62, 55]
# 991 ['MAPb(Br0.8I0.2)3', 'MAPb(Br0.2I0.8)3', 'tetragonal-MAPbBr3'] [55, 58, 60] [58, 60, 55]
# 992 ['cubic-MAPbBr3', 'tetragonal-MAPbI3', 'MAPb(Br0.8I0.2)3'] [58, 59, 63] [57, 58, 63]
# 993 ['alpha-MAPbI3', 'PbBr2', 'MAPb(Br0.2I0.8)3'] [55, 62, 64] [62, 64, 55]
# 994 ['cubic-FAPbBr3', 'alpha-FAPbI3', 'PbI2'] [43, 44, 65] [43, 44, 46]
# 995 ['CsBr', 'CsPb2Br5', 'orthorhombic-CsPbBr3'] [17, 19, 33] [19, 33, 17]
# 996 ['beta-FAPbI3', 'PbI2', 'delta-FAPbI3'] [45, 46, 65] [65, 45, 46]
# 997 ['Cs0.2FA0.8PbBr3', 'CsPb2Br5', 'cubic-FAPbBr3'] [0, 19, 43] [19, 43, 0]
# 998 ['delta-FAPbI3', 'beta-FAPbI3', 'CsI'] [18, 45, 46] [18, 46, 65]
# 999 ['Cs0.6FA0.4PbBr3', 'Cs0.4FA0.6PbBr3', 'Cs0.8FA0.2PbBr3'] [1, 2, 3] [2, 3, 1]

# %%
for prompt_type in prompt_type_list:
    print(prompt_type)
    for n in n_mix:
        y_pred_full = np.array(full_result[prompt_type]['{}'.format(n)]['y_pred'])
        y_true_full = np.array(full_result[prompt_type]['{}'.format(n)]['y_true'])
        y_acc_full = np.array(full_result[prompt_type]['{}'.format(n)]['y_acc'])
        if random_phase:
            n_pred_full = np.array(full_result[prompt_type]['{}'.format(n)]['n_pred'])
            n_true_full = np.array(full_result[prompt_type]['{}'.format(n)]['n_true'])
            n_acc_full = np.array(full_result[prompt_type]['{}'.format(n)]['n_acc'])
            print(i, coverage_error(y_true_full, y_pred_full), 1-np.sum(y_acc_full)/y_acc_full.shape[0], 1-np.sum(n_acc_full)/n_acc_full.shape[0])
        else:
            print(i, coverage_error(y_true_full, y_pred_full), 1-np.sum(y_acc_full)/y_acc_full.shape[0])
# Out:
# full
# 2 2.31 0.83
# 3 3.961333333333333 0.5893333333333333
# eds
# 2 2.439 0.791
# 3 4.108666666666666 0.5613333333333334
# none
# 2 3.237 0.7050000000000001
# 3 5.817 0.473

# %%
load_plt_setting()
stat_n = 10
prompt_type_list = ['full','eds','none',]

for n_multilabel in ['2','3']:
    fig, ax = plt.subplots(figsize=(10, 4))
    x_dic = {}
    for i, (prompt_type,c) in enumerate(zip(prompt_type_list,["#ef476f","#ffd166","#118ab2"])):
        x_dic[prompt_type] = {}
        x_dic[prompt_type]['raw'] = []
        y_pred_full = np.array(full_result[prompt_type][n_multilabel]['outputs'])
        y_true_full = np.array(full_result[prompt_type][n_multilabel]['labels'])
        for j in range(y_pred_full.shape[0]):
            x_dic[prompt_type]['raw'].append(coverage_error(y_true_full[j:j+1], y_pred_full[j:j+1]))
        x_dic[prompt_type]['stat'] = [np.mean(x_dic[prompt_type]['raw'][i:i+stat_n]) for i in range(0,len(x_dic[prompt_type]['raw']),stat_n)]
        y = np.random.uniform(i-0.25+1, i+0.25+1, size=len(x_dic[prompt_type]['stat']))
        ax.scatter(x_dic[prompt_type]['stat'], y, c=c, alpha=1, s=10)
        
    print(mannwhitneyu(x_dic[prompt_type_list[2]]['stat'],x_dic[prompt_type_list[1]]['stat']))
    print(mannwhitneyu(x_dic[prompt_type_list[1]]['stat'],x_dic[prompt_type_list[0]]['stat']))
        
    boxplot = ax.boxplot([x_dic[prompt_type_list[0]]['stat'],x_dic[prompt_type_list[1]]['stat'],x_dic[prompt_type_list[2]]['stat']], 
                         notch=False, vert=False, widths=0.5, sym='', 
                         boxprops=dict(linewidth=2,c='black'), medianprops=dict(linewidth=2,c='black'),
                         whiskerprops=dict(linewidth=2,c='black'), capprops=dict(linewidth=2,c='black'))

    ax.set_ylim([0.4,3.6])
    ax.axes.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=4, integer=True, steps=[1, 2, 5, 10]))
    ax.axes.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=4, integer=False, steps=[1, 2, 3, 5, 10]))
    
    ax.tick_params(axis='x', direction='out', top=True, labeltop=True, bottom=False, 
                   labelbottom=False, length=8, width=2, pad=10, labelsize=24)
    ax.tick_params(axis='x', which='minor', top=True, labeltop=True, bottom=False, 
                   labelbottom=False, direction='out', length=4, width=2, pad=10)
    ax.tick_params(axis='y', labelsize=24)
    ax.spines['bottom'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_yticklabels(['','Precursor label ','EDS label ','No label '])
    plt.ylabel('', labelpad=20, fontsize=28)
    ax.xaxis.set_label_position('top')
    ax.axvline(x=int(n_multilabel), clip_on=False, color='grey', linestyle='--', linewidth=2, zorder=-10)
    
    if n_multilabel == '2':
        ax.set_xlim([1.68,7])
        ax.axes.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
        plt.xlabel(r'Random binary-phase coverage'.format(n_multilabel), labelpad=30, fontsize=24)

    elif n_multilabel == '3':
        ax.set_xlim([2.4,12])
        ax.axes.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(3))
        plt.xlabel(r'Random ternary-phase coverage'.format(n_multilabel), labelpad=30, fontsize=24)

        
    plt.savefig(os.path.join(folder, 'models', model_folder, 'Top-K_{}.png'.format(n_multilabel)), bbox_inches='tight',format='png', dpi=300, transparent=True)
    np.savetxt(os.path.join(folder, 'models', model_folder, 'Top-K_{}.csv'.format(n_multilabel)),  
               np.swapaxes(np.asarray([x_dic[prompt_type_list[0]]['stat'],x_dic[prompt_type_list[1]]['stat'],x_dic[prompt_type_list[2]]['stat']]),0,1), 
               header='Precursor label / EDS label / No label',)
# Out:
# MannwhitneyuResult(statistic=7908.5, pvalue=1.0599869131712735e-12)
# MannwhitneyuResult(statistic=6227.0, pvalue=0.0025314826723136946)
# MannwhitneyuResult(statistic=34567.0, pvalue=1.930812858285049e-36)
# MannwhitneyuResult(statistic=23287.5, pvalue=0.0043744427564444644)

# %%
# 860 ['CsPb2Br5', 'PbBr2', 'CsBr'] [17, 19, 64] [64, 19, 32]
# 77 ['PbI2', 'alpha-MAPbI3', 'tetragonal-MAPbI3'] [62, 63, 65] [65, 63, 62]

sample_no = 860
twotheta = np.arange(5.00, 60.01, 0.01)

load_plt_setting()

fig, (ax0, ax1, ) = plt.subplots(2,1, sharex=True, gridspec_kw=dict(height_ratios=[2, 1]),figsize=(12, 10))
mat1 = ax0.plot(twotheta, Xs[sample_no,:,0], linewidth=1, color=colors.to_rgba('#000000'))
ax0.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
ax0.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax0.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
ax0.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax0.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax0.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax0.axes.set_ylim([-0.05,1.2])

formula = []
for sample_no, c in zip(y_true[sample_no],["#ef476f","#ffd166","#118ab2"]):
    ref = dataloader.load_ref(sample_no)
    mat1 = ax1.plot(twotheta, ref/np.max(ref), linewidth=2, color=c)
    formula.append(dataloader.dataset[dataloader.sample_list[sample_no]]['formula'])
ax1.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
ax1.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax1.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
ax1.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax1.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax1.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax1.axes.set_ylim([0,1.3])
# ax2.axes.set_xlim([22.5,30])
ax1.axes.set_xlim([twotheta[0],twotheta[-1]])

plt.text(0.03, 0.86, 'Input', fontsize=30, transform=ax0.transAxes, horizontalalignment='left')
plt.text(0.03, 0.75, 'Ground truth', fontsize=30, transform=ax1.transAxes, horizontalalignment='left')

# for i, (sample_no, c, x_pos) in enumerate(zip(y_true[sample_no],["#ef476f","#ffd166","#118ab2"],[0.95,0.79,0.55])):
#     plt.text(x_pos+0.001, 0.75-0.002, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula[i])), alpha=0.4,
#          fontsize=30, transform=ax1.transAxes, horizontalalignment='right')
#     plt.text(x_pos, 0.75, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula[i])), color=c,
#          fontsize=30, transform=ax1.transAxes, horizontalalignment='right')

    
plt.subplots_adjust(hspace=.0)

sample_no = 860
ax1.set_xlabel(r'2$\Theta$ (degree)', labelpad=10, fontsize=34)
ax0.set_ylabel(r'Normalized intensity                      ', labelpad=20, fontsize=34)
plt.savefig(os.path.join(folder, 'models', model_folder, 'Multiphase_{}_{}.png'.format(max_n_mix,sample_no)), 
            format='png', dpi=300, transparent=True, bbox_inches='tight')

# %%
# sample_no = 860

order = np.linspace(0,65,66)
y_pred_full = list(full_result['full']['{}'.format(max_n_mix)]['outputs'][sample_no])
y_true_full = list(full_result['full']['{}'.format(max_n_mix)]['labels'][sample_no])

order_sort = [x for _,x in sorted(zip(y_pred_full,order))]
y_true_full_sort = [x for _,x in sorted(zip(y_pred_full,y_true_full))]
y_pred_full_sort = copy.deepcopy(y_pred_full)
y_pred_full_sort.sort()
y_pred_full_sort = y_pred_full_sort/np.max(y_pred_full_sort)

# %%
for i in range(len(y_true_full_sort)-6,len(y_true_full_sort)):
    print(y_pred_full_sort[i], y_true_full_sort[i], order_sort[i], 
          dataloader.dataset[dataloader.sample_list[int(order_sort[i])]]['formula'])
# Out:
# 0.16904745 0.0 60.0 tetragonal-MAPbBr3
# 0.18234627 0.0 46.0 delta-FAPbI3
# 0.18284322 0.0 57.0 MAPb(Br0.6I0.4)3
# 0.9952019 1.0 62.0 alpha-MAPbI3
# 0.99629223 1.0 65.0 PbI2
# 1.0 1.0 63.0 tetragonal-MAPbI3

# %%
load_plt_setting()

fig, ax = plt.subplots(figsize=(5, 8))

cmap = mpl.cm.get_cmap('viridis')
cmap_index = np.linspace(0,1,8)

# formula_
for i in range(6):
    formula = dataloader.dataset[dataloader.sample_list[int(order_sort[-i-1])]]['formula']
    if y_true_full_sort[-i-1] == 0:
        alpha = 0.4
        plt.text(0.03, 0.83-i*0.17, u'$\u2717$'+'{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula)),
                 fontsize=26, transform=ax.transAxes, horizontalalignment='left', alpha=alpha)
    else:
        alpha = 1
        plt.text(0.03, 0.83-i*0.17, u'$\u2713$'+'{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula)),
                 fontsize=26, transform=ax.transAxes, horizontalalignment='left', alpha=alpha)
    ax.barh(-i, y_pred_full_sort[-i-1], height=0.3, color=cmap(cmap_index[-i-1]), alpha=alpha)
    

ax.tick_params(axis='x', direction='out', top=True, labeltop=True, bottom=False, 
               labelbottom=False, length=8, width=2, pad=10, labelsize=24)
ax.tick_params(axis='x', which='minor', top=True, labeltop=True, bottom=False, 
               labelbottom=False, direction='out', length=4, width=2, pad=10)
plt.yticks([])

# ax.tick_params(axis='y', labelsize=24)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.xaxis.set_label_position('top')
plt.xlabel(r'Prediction score'.format(n_multilabel), labelpad=30, fontsize=24)

plt.savefig(os.path.join(folder, 'models', model_folder, 'Multiphase_{}_{}_score.png'.format(max_n_mix,sample_no)), 
            format='png', dpi=300, transparent=True, bbox_inches='tight')

# %% [markdown]
# # 3 Random phase identification

# %%
model_folder = '20241008 random phase embedding 20'
visual_embedding_dim = 20
model = VisualBertForQuestionAnswering.from_pretrained(os.path.join(folder, 'models', model_folder, '1000000')).to('cuda')

# %%
full_result = {}
prompt_type_list = ['full']

for prompt_type in prompt_type_list:
    full_result[prompt_type] = {}
    
    for i in [1,2,3]:
        full_result[prompt_type]['{}'.format(i)] = {'phase_true':[], 'phase_pred':[], 'phase_acc':[],
                                                    'n_true':[],'n_pred':[],'n_acc':[]}

# %%
n = 3
file_name = 'test_dataset_{}phase.npy'.format(n)

with open(os.path.join(cif_folder, file_name), 'rb') as handle:
    test_dataset = joblib.load(handle)

Xs, Ys, element_list, formula_list = test_dataset['Xs'], test_dataset['Ys'], test_dataset['element_list'], test_dataset['formula_list']
n_mix_list_onehot = np.zeros((Ys.shape[0], 3))
n_mix_list_onehot[:, n-1] = 1
print('test dataset loaded.')
# Out:
# test dataset loaded.

# %%
for prompt_type in prompt_type_list:

    for i in range(len(element_list)):
#     for i in range(10):

        Xs_test = Xs[i:i+1,:-1,:].reshape((1,int(Xs.shape[1]/visual_embedding_dim),visual_embedding_dim))

        X_prompts = []
        random.shuffle(element_list[i])
        if prompt_type == 'none':
            X_prompts.append('')
        elif prompt_type == 'eds':
            X_prompts.append(' '.join([element for element in element_list[i] if element not in ['FA', 'MA']]))
        elif prompt_type == 'full':
            X_prompts.append(' '.join(element_list[i]))

        visual_embeds = torch.from_numpy(Xs_test).to(dtype=torch.float32)
        visual_attention_mask = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)
        visual_token_type_ids = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)

        inputs = tokenizer(X_prompts, return_tensors="pt", padding=True)
        inputs.update(
            {
                "visual_embeds": visual_embeds,
                "visual_token_type_ids": visual_token_type_ids,
                "visual_attention_mask": visual_attention_mask,
            }
        )

        labels = torch.from_numpy(Ys[i:i+1]).to(dtype=torch.float32)
        labels = np.array(labels[0].nonzero().view(-1))
        outputs = model(**inputs.to('cuda'), output_attentions=True)
        
        phase_pred = np.array(outputs.logits.detach().cpu())[0][:-3]
        n_pred = np.array(outputs.logits.detach().cpu())[0][-3:]
        logits_phase = np.array(torch.topk(outputs.logits.detach().cpu()[0][:-3], len(labels)).indices)
        logits_n = np.array(torch.topk(outputs.logits.detach().cpu()[0][-3:], len(labels)).indices)[0]
        
        y_true.append(list(labels))
        y_pred.append(list(np.array(logits.detach().cpu())))
        
        full_result[prompt_type][str(n)]['phase_true'].append(Ys[i])
        full_result[prompt_type][str(n)]['phase_pred'].append(phase_pred)
        full_result[prompt_type][str(n)]['n_true'].append(n_mix_list_onehot[i])
        full_result[prompt_type][str(n)]['n_pred'].append(n_pred)
        
        if set(labels) == set(logits_phase):
            full_result[prompt_type][str(n)]['phase_acc'].append(0)
        else:
            full_result[prompt_type][str(n)]['phase_acc'].append(1)
            
        if n_mix_list_onehot[i].argmax()+1 == n:
            full_result[prompt_type][str(n)]['n_acc'].append(0)
        else:
            full_result[prompt_type][str(n)]['n_acc'].append(1)
            
        print('{}\t{}\t{}\t{}\t{}'.format(i,formula_list[i],n_mix_list_onehot[i].argmax()+1,labels,logits_phase))

    result = np.array(result)
# Out:
# 0	['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'MA0.4FA0.6PbBr3']	3	[48 59 60]	[59 60  9]
# 1	['tetragonal-MAPbBr3', 'PbBr2', 'cubic-MAPbBr3']	3	[59 60 64]	[64 60 59]
# 2	['Cs4PbBr6', 'CsPb2Br5', 'CsBr']	3	[16 17 19]	[19 16 17]
# 3	['alpha-CsPbI3', 'delta-CsPbI3', 'PbI2']	3	[36 37 65]	[37 65 36]
# 4	['cubic-CsPbBr3', 'CsPb(I0.8Br0.2)3', 'PbI2']	3	[27 32 65]	[65 18 12]
# 5	['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3']	3	[59 60 64]	[64 43 17]
# 6	['MA0.4FA0.6PbI3', 'MA0.2FA0.8PbI3', 'delta-FAPbI3']	3	[46 51 52]	[64 16 47]
# 7	['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'PbBr2']	3	[59 60 64]	[59 64 60]
# 8	['PbI2', 'MAPb(Br0.8I0.2)3', 'tetragonal-MAPbBr3']	3	[58 60 65]	[59 60 32]
# 9	['beta-FAPbI3', 'PbI2', 'MA0.4FA0.6PbI3']	3	[45 52 65]	[65 45 46]
# 10	['CsPb(Cl0.8Br0.2)3', 'cubic-CsPbBr3', 'CsPb(Cl0.2Br0.8)3']	3	[20 23 32]	[32 17 60]
# 11	['cubic-CsPbBr3', 'Cs0.6MA0.4PbBr3', 'orthorhombic-CsPbBr3']	3	[10 32 33]	[33 32  9]
# 12	['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3']	3	[59 60 64]	[64 59 60]
# 13	['gamma-CsPbI3', 'Cs0.4MA0.6PbI3', 'PbI2']	3	[13 38 65]	[16 60 59]
# 14	['beta-FAPbI3', 'PbI2', 'alpha-FAPbI3']	3	[44 45 65]	[64 17 32]
# 15	['beta-FAPbI3', 'PbI2', 'alpha-FAPbI3']	3	[44 45 65]	[64 60 59]
# 16	['beta-FAPbI3', 'cubic-FAPbBr3', 'PbI2']	3	[43 45 65]	[65 64 44]
# 17	['Cs4PbBr6', 'CsBr', 'Cs0.8MA0.2PbBr3']	3	[11 16 17]	[64 16 11]
# 18	['alpha-CsPbI3', 'Cs0.6FA0.4PbI3', 'delta-CsPbI3']	3	[ 6 36 37]	[33 64 16]
# 19	['alpha-CsPbI3', 'Cs4PbBr6', 'PbBr2']	3	[16 36 64]	[64 16 11]
# 20	['Cs0.2MA0.8PbI3', 'Cs0.4MA0.6PbI3', 'alpha-MAPbI3']	3	[12 13 62]	[43  0 32]
# 21	['Cs0.2FA0.8PbBr3', 'Cs0.4FA0.6PbBr3', 'PbBr2']	3	[ 0  1 64]	[64  8  9]
# 22	['tetragonal-MAPbBr3', 'PbI2', 'MAPb(Br0.2I0.8)3']	3	[55 60 65]	[65 15 14]
# 23	['PbI2', 'beta-FAPbI3', 'delta-FAPbI3']	3	[45 46 65]	[64 65 60]
# 24	['alpha-FAPbI3', 'CsI', 'Cs0.6FA0.4PbI3']	3	[ 6 18 44]	[64 17 23]
# 25	['FAPb(Br0.4I0.6)3', 'PbI2', 'cubic-FAPbBr3']	3	[40 43 65]	[64 59 47]
# 26	['CsPb(Cl0.2Br0.8)3', 'CsPb(Cl0.6Br0.4)3', 'Pnma-CsPbCl3']	3	[20 22 34]	[34 20 22]
# 27	['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'PbBr2']	3	[59 60 64]	[64 60 59]
# 28	['gamma-CsPbI3', 'alpha-CsPbI3', 'Cs0.4FA0.6PbI3']	3	[ 5 36 38]	[38 37 65]
# 29	['cubic-CsPbBr3', 'Cs0.2FA0.8PbBr3', 'Cs0.8FA0.2PbBr3']	3	[ 0  3 32]	[32 17 23]
# 30	['alpha-CsPbI3', 'Cs0.8MA0.2PbI3', 'delta-CsPbI3']	3	[15 36 37]	[60 33 59]
# 31	['Cs0.2MA0.8PbI3', 'gamma-CsPbI3', 'Cs0.4MA0.6PbI3']	3	[12 13 38]	[38 62 12]
# 32	['cubic-MAPbBr3', 'MA0.8FA0.2PbBr3', 'cubic-FAPbBr3']	3	[43 50 59]	[43 59 47]
# 33	['FAPb(Br0.4I0.6)3', 'delta-FAPbI3', 'beta-FAPbI3']	3	[40 45 46]	[64 60 16]
# 34	['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2']	3	[62 63 65]	[34 35 64]
# 35	['cubic-CsPbBr3', 'CsPb(I0.4Br0.6)3', 'delta-CsPbI3']	3	[25 32 37]	[19 16 10]
# 36	['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3']	3	[59 60 64]	[34 35 64]
# 37	['Pnma-CsPbCl3', 'CsBr', 'CsPb(Cl0.2Br0.8)3']	3	[17 20 34]	[59 17 11]
# 38	['orthorhombic-CsPbBr3', 'CsPb(Cl0.8Br0.2)3', 'Cs4PbBr6']	3	[16 23 33]	[16 33 23]
# 39	['CsBr', 'PbBr2', 'cubic-CsPbBr3']	3	[17 32 64]	[64 17 32]
# 40	['Cs4PbBr6', 'PbBr2', 'orthorhombic-CsPbBr3']	3	[16 33 64]	[33 16 19]
# 41	['CsPb2Br5', 'PbI2', 'gamma-CsPbI3']	3	[19 38 65]	[16 33 64]
# 42	['PbI2', 'delta-CsPbI3', 'CsI']	3	[18 37 65]	[19 16 17]
# 43	['Cs4PbBr6', 'orthorhombic-CsPbBr3', 'Cs0.2MA0.8PbBr3']	3	[ 8 16 33]	[33 16 38]
# 44	['Cs4PbBr6', 'CsPb2Br5', 'CsPb(Cl0.6Br0.4)3']	3	[16 19 22]	[16 64 19]
# 45	['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2']	3	[59 60 64]	[64 60 59]
# 46	['PbBr2', 'CsBr', 'Cs4PbBr6']	3	[16 17 64]	[64 19 33]
# 47	['alpha-FAPbI3', 'delta-FAPbI3', 'PbI2']	3	[44 46 65]	[43 64 60]
# 48	['PbI2', 'tetragonal-MAPbI3', 'alpha-MAPbI3']	3	[62 63 65]	[64 59 60]
# 49	['cubic-FAPbBr3', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3']	3	[43 59 60]	[59 60 43]
# 50	['Cs0.2FA0.8PbBr3', 'CsBr', 'CsPb2Br5']	3	[ 0 17 19]	[19  0 43]
# 51	['PbI2', 'CsPb(I0.4Cl0.6)3', 'CsI']	3	[18 29 65]	[32 17 59]
# 52	['PbBr2', 'cubic-CsPbBr3', 'orthorhombic-CsPbBr3']	3	[32 33 64]	[33 32 17]
# 53	['orthorhombic-CsPbBr3', 'alpha-CsPbI3', 'delta-CsPbI3']	3	[33 36 37]	[38 37 62]
# 54	['orthorhombic-CsPbBr3', 'Cs0.8MA0.2PbBr3', 'tetragonal-MAPbBr3']	3	[11 33 60]	[ 8 33 60]
# 55	['delta-FAPbI3', 'beta-FAPbI3', 'PbI2']	3	[45 46 65]	[65 36 37]
# 56	['CsPb(Cl0.8Br0.2)3', 'CsPb2Br5', 'cubic-CsPbBr3']	3	[19 23 32]	[19 10  8]
# 57	['CsBr', 'cubic-CsPbBr3', 'CsPb2Br5']	3	[17 19 32]	[19 32 17]
# 58	['gamma-CsPbI3', 'Cs0.8MA0.2PbI3', 'CsI']	3	[15 18 38]	[65 38 13]
# 59	['MAPb(Br0.2I0.8)3', 'MAPb(Br0.4I0.6)3', 'cubic-MAPbBr3']	3	[55 56 59]	[59 19 32]
# 60	['Cs0.2FA0.8PbI3', 'alpha-CsPbI3', 'delta-FAPbI3']	3	[ 4 36 46]	[65 38 62]
# 61	['alpha-CsPbI3', 'cubic-CsPbCl3', 'delta-CsPbI3']	3	[35 36 37]	[37 34 35]
# 62	['CsPb2Br5', 'Cs4PbBr6', 'PbBr2']	3	[16 19 64]	[33 16 64]
# 63	['MA0.8FA0.2PbI3', 'MA0.2FA0.8PbI3', 'tetragonal-MAPbI3']	3	[51 54 63]	[54 63 51]
# 64	['Cs4PbBr6', 'Cs0.4FA0.6PbBr3', 'Cs0.8FA0.2PbBr3']	3	[ 1  3 16]	[32 33 64]
# 65	['PbI2', 'delta-CsPbI3', 'gamma-CsPbI3']	3	[37 38 65]	[37 38 65]
# 66	['Cs0.6MA0.4PbBr3', 'Cs0.2MA0.8PbBr3', 'tetragonal-MAPbBr3']	3	[ 8 10 60]	[ 8 60 11]
# 67	['CsPb(Cl0.2Br0.8)3', 'PbBr2', 'Cs4PbBr6']	3	[16 20 64]	[64 16 10]
# 68	['PbBr2', 'Cs4PbBr6', 'CsBr']	3	[16 17 64]	[64 17 19]
# 69	['PbBr2', 'CsBr', 'cubic-CsPbBr3']	3	[17 32 64]	[32 64 17]
# 70	['cubic-FAPbBr3', 'PbBr2', 'FAPb(Br0.4I0.6)3']	3	[40 43 64]	[65 16 17]
# 71	['alpha-MAPbI3', 'PbI2', 'tetragonal-MAPbI3']	3	[62 63 65]	[60 64 59]
# 72	['orthorhombic-CsPbBr3', 'Cs4PbBr6', 'cubic-CsPbBr3']	3	[16 32 33]	[33 32 64]
# 73	['beta-FAPbI3', 'alpha-FAPbI3', 'delta-FAPbI3']	3	[44 45 46]	[46 45 44]
# 74	['tetragonal-MAPbBr3', 'Cs0.6MA0.4PbBr3', 'cubic-MAPbBr3']	3	[10 59 60]	[59 10 11]
# 75	['delta-CsPbI3', 'CsI', 'Cs0.8MA0.2PbI3']	3	[15 18 37]	[37 65 13]
# 76	['CsPb(Cl0.2Br0.8)3', 'orthorhombic-CsPbBr3', 'CsPb(Cl0.6Br0.4)3']	3	[20 22 33]	[23 33 35]
# 77	['PbI2', 'alpha-MAPbI3', 'tetragonal-MAPbI3']	3	[62 63 65]	[62 63 65]
# 78	['MA0.8FA0.2PbI3', 'beta-FAPbI3', 'tetragonal-MAPbI3']	3	[45 54 63]	[63 37 65]
# 79	['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2']	3	[62 63 65]	[32 35 34]
# 80	['PbI2', 'orthorhombic-CsPbBr3', 'PbBr2']	3	[33 64 65]	[33 64 59]
# 81	['CsPb(I0.8Br0.2)3', 'CsPb2Br5', 'CsBr']	3	[17 19 27]	[64 18 17]
# 82	['Pnma-CsPbCl3', 'alpha-CsPbI3', 'CsPb(I0.6Cl0.4)3']	3	[30 34 36]	[32 23 19]
# 83	['PbI2', 'delta-FAPbI3', 'FAPb(Br0.8I0.2)3']	3	[42 46 65]	[47 16 64]
# 84	['alpha-CsPbI3', 'Cs0.8MA0.2PbI3', 'tetragonal-MAPbI3']	3	[15 36 63]	[59 60  8]
# 85	['CsPb(I0.4Cl0.6)3', 'CsPb(I0.2Cl0.8)3', 'alpha-CsPbI3']	3	[28 29 36]	[32 19 43]
# 86	['beta-FAPbI3', 'delta-FAPbI3', 'alpha-FAPbI3']	3	[44 45 46]	[60 64 59]
# 87	['Cs4PbBr6', 'Cs0.2FA0.8PbBr3', 'PbBr2']	3	[ 0 16 64]	[64 16  2]
# 88	['FAPb(Br0.6I0.4)3', 'PbI2', 'PbBr2']	3	[41 64 65]	[64 16 19]
# 89	['PbI2', 'CsPb(I0.8Cl0.2)3', 'Pnma-CsPbCl3']	3	[31 34 65]	[11 19 10]
# 90	['beta-FAPbI3', 'PbI2', 'delta-FAPbI3']	3	[45 46 65]	[64 60 43]
# 91	['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2']	3	[59 60 64]	[34 35 64]
# 92	['Cs0.4FA0.6PbBr3', 'cubic-FAPbBr3', 'Cs0.2FA0.8PbBr3']	3	[ 0  1 43]	[20 32 21]
# 93	['alpha-CsPbI3', 'CsPb(I0.4Cl0.6)3', 'CsPb(I0.2Cl0.8)3']	3	[28 29 36]	[32 36 59]
# 94	['tetragonal-MAPbBr3', 'MA0.2FA0.8PbBr3', 'MA0.8FA0.2PbBr3']	3	[47 50 60]	[47 50 60]
# 95	['delta-FAPbI3', 'alpha-FAPbI3', 'FAPb(Br0.8I0.2)3']	3	[42 44 46]	[65 19 16]
# 96	['delta-CsPbI3', 'gamma-CsPbI3', 'PbI2']	3	[37 38 65]	[64 33 16]
# 97	['PbI2', 'alpha-CsPbI3', 'beta-FAPbI3']	3	[36 45 65]	[64 43 47]
# 98	['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2']	3	[62 63 65]	[64 59 60]
# 99	['CsBr', 'cubic-CsPbBr3', 'orthorhombic-CsPbBr3']	3	[17 32 33]	[33 32 17]
# 100	['CsPb(I0.6Cl0.4)3', 'delta-CsPbI3', 'CsPb(I0.2Cl0.8)3']	3	[28 30 37]	[16 64 11]
# 101	['delta-FAPbI3', 'alpha-FAPbI3', 'PbI2']	3	[44 46 65]	[64 60 59]
# 102	['alpha-FAPbI3', 'delta-FAPbI3', 'cubic-FAPbBr3']	3	[43 44 46]	[64 49 60]
# 103	['alpha-MAPbI3', 'alpha-FAPbI3', 'MA0.6FA0.4PbI3']	3	[44 53 62]	[64 60 58]
# 104	['MAPb(Br0.4I0.6)3', 'PbBr2', 'alpha-MAPbI3']	3	[56 62 64]	[18 64 35]
# 105	['CsI', 'alpha-CsPbI3', 'gamma-CsPbI3']	3	[18 36 38]	[59 60 64]
# 106	['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3']	3	[59 60 64]	[64 35 34]
# 107	['beta-FAPbI3', 'FAPb(Br0.6I0.4)3', 'delta-FAPbI3']	3	[41 45 46]	[19 64 16]
# 108	['CsPb(I0.8Cl0.2)3', 'Pnma-CsPbCl3', 'CsPb(I0.2Cl0.8)3']	3	[28 31 34]	[20 34 19]
# 109	['delta-FAPbI3', 'beta-FAPbI3', 'alpha-FAPbI3']	3	[44 45 46]	[65 45 46]
# 110	['MA0.6FA0.4PbI3', 'alpha-MAPbI3', 'PbI2']	3	[53 62 65]	[46 45 62]
# 111	['cubic-CsPbBr3', 'CsBr', 'Cs0.8FA0.2PbBr3']	3	[ 3 17 32]	[43  0 32]
# 112	['MA0.2FA0.8PbBr3', 'MA0.6FA0.4PbBr3', 'PbBr2']	3	[47 49 64]	[64  8 60]
# 113	['PbI2', 'CsI', 'Cs0.6FA0.4PbI3']	3	[ 6 18 65]	[43 17 16]
# 114	['Cs4PbBr6', 'orthorhombic-CsPbBr3', 'CsBr']	3	[16 17 33]	[17 16 64]
# 115	['CsPb(Cl0.8Br0.2)3', 'orthorhombic-CsPbBr3', 'CsPb(Cl0.6Br0.4)3']	3	[22 23 33]	[33 59  8]
# 116	['beta-FAPbI3', 'delta-FAPbI3', 'alpha-FAPbI3']	3	[44 45 46]	[64 43 45]
# 117	['PbBr2', 'CsBr', 'orthorhombic-CsPbBr3']	3	[17 33 64]	[17 33 19]
# 118	['alpha-FAPbI3', 'beta-FAPbI3', 'delta-FAPbI3']	3	[44 45 46]	[64 60 59]
# 119	['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2']	3	[59 60 64]	[64 17 35]
# 120	['FAPb(Br0.8I0.2)3', 'FAPb(Br0.4I0.6)3', 'beta-FAPbI3']	3	[40 42 45]	[40 45 46]
# 121	['tetragonal-MAPbI3', 'PbI2', 'beta-FAPbI3']	3	[45 63 65]	[45 63 44]
# 122	['PbI2', 'alpha-CsPbI3', 'delta-CsPbI3']	3	[36 37 65]	[19 17 16]
# 123	['tetragonal-MAPbBr3', 'PbBr2', 'cubic-MAPbBr3']	3	[59 60 64]	[64 60 59]
# 124	['PbI2', 'beta-FAPbI3', 'alpha-FAPbI3']	3	[44 45 65]	[64 59 60]
# 125	['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2']	3	[59 60 64]	[64 60 59]
# 126	['alpha-CsPbI3', 'cubic-CsPbCl3', 'gamma-CsPbI3']	3	[35 36 38]	[33 16 64]
# 127	['orthorhombic-CsPbBr3', 'Cs4PbBr6', 'CsBr']	3	[16 17 33]	[33 64 17]
# 128	['CsBr', 'orthorhombic-CsPbBr3', 'PbBr2']	3	[17 33 64]	[64 33 17]
# 129	['Cs0.6FA0.4PbI3', 'beta-FAPbI3', 'delta-CsPbI3']	3	[ 6 37 45]	[16 64 33]
# 130	['alpha-MAPbI3', 'MAPb(Br0.8I0.2)3', 'cubic-MAPbBr3']	3	[58 59 62]	[59 60 64]
# 131	['alpha-CsPbI3', 'PbI2', 'delta-CsPbI3']	3	[36 37 65]	[64 59 16]
# 132	['gamma-CsPbI3', 'alpha-CsPbI3', 'PbI2']	3	[36 38 65]	[38 65 18]
# 133	['cubic-CsPbBr3', 'CsPb2Br5', 'cubic-CsPbCl3']	3	[19 32 35]	[19 20 22]
# 134	['delta-CsPbI3', 'Cs0.6FA0.4PbI3', 'Cs0.2FA0.8PbI3']	3	[ 4  6 37]	[64 33 16]
# 135	['MA0.8FA0.2PbI3', 'delta-FAPbI3', 'PbI2']	3	[46 54 65]	[65 46 45]
# 136	['alpha-FAPbI3', 'beta-FAPbI3', 'PbI2']	3	[44 45 65]	[64 59 17]
# 137	['delta-FAPbI3', 'Cs0.8FA0.2PbI3', 'delta-CsPbI3']	3	[ 7 37 46]	[16 33 64]
# 138	['Pnma-CsPbCl3', 'cubic-CsPbBr3', 'CsPb2Br5']	3	[19 32 34]	[64 43 49]
# 139	['beta-FAPbI3', 'FAPb(Br0.4I0.6)3', 'delta-FAPbI3']	3	[40 45 46]	[64 16 33]
# 140	['alpha-MAPbI3', 'MAPb(Br0.4I0.6)3', 'MAPb(Br0.6I0.4)3']	3	[56 57 62]	[55 57 58]
# 141	['Cs0.8MA0.2PbBr3', 'CsPb2Br5', 'orthorhombic-CsPbBr3']	3	[11 19 33]	[32 33 11]
# 142	['Cs4PbBr6', 'cubic-CsPbBr3', 'CsPb2Br5']	3	[16 19 32]	[16 19 32]
# 143	['delta-FAPbI3', 'alpha-FAPbI3', 'beta-FAPbI3']	3	[44 45 46]	[44 45 46]
# 144	['PbI2', 'alpha-CsPbI3', 'gamma-CsPbI3']	3	[36 38 65]	[36 38 65]
# 145	['orthorhombic-CsPbBr3', 'CsBr', 'cubic-CsPbBr3']	3	[17 32 33]	[33 32 17]
# 146	['gamma-CsPbI3', 'alpha-CsPbI3', 'delta-CsPbI3']	3	[36 37 38]	[64 33 16]
# 147	['Cs0.4MA0.6PbI3', 'alpha-CsPbI3', 'CsI']	3	[13 18 36]	[59 60 17]
# 148	['tetragonal-MAPbI3', 'MA0.4FA0.6PbI3', 'MA0.8FA0.2PbI3']	3	[52 54 63]	[64 16 59]
# 149	['cubic-CsPbBr3', 'orthorhombic-CsPbBr3', 'PbBr2']	3	[32 33 64]	[32 33 64]
# 150	['CsPb2Br5', 'cubic-CsPbCl3', 'PbBr2']	3	[19 35 64]	[64 19 11]
# 151	['delta-CsPbI3', 'beta-FAPbI3', 'CsI']	3	[18 37 45]	[37 65  7]
# 152	['FAPb(Br0.6I0.4)3', 'FAPb(Br0.8I0.2)3', 'PbBr2']	3	[41 42 64]	[65 51 45]
# 153	['alpha-MAPbI3', 'MAPb(Br0.8I0.2)3', 'tetragonal-MAPbBr3']	3	[58 60 62]	[59 60 65]
# 154	['Cs4PbBr6', 'CsBr', 'CsPb2Br5']	3	[16 17 19]	[16 19 32]
# 155	['delta-FAPbI3', 'beta-FAPbI3', 'alpha-FAPbI3']	3	[44 45 46]	[43 64 60]
# 156	['CsBr', 'orthorhombic-CsPbBr3', 'cubic-CsPbBr3']	3	[17 32 33]	[32 33 17]
# 157	['beta-FAPbI3', 'alpha-FAPbI3', 'MA0.2FA0.8PbI3']	3	[44 45 51]	[64 16 19]
# 158	['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3']	3	[59 60 64]	[64 34 35]
# 159	['PbI2', 'Cs4PbBr6', 'CsPb(I0.2Br0.8)3']	3	[16 24 65]	[37 62 65]
# 160	['cubic-CsPbCl3', 'CsPb(I0.4Cl0.6)3', 'alpha-CsPbI3']	3	[29 35 36]	[65 35 30]
# 161	['Cs0.2FA0.8PbBr3', 'orthorhombic-CsPbBr3', 'CsBr']	3	[ 0 17 33]	[33 22 17]
# 162	['CsPb2Br5', 'CsPb(Cl0.2Br0.8)3', 'CsPb(Cl0.8Br0.2)3']	3	[19 20 23]	[19 21 20]
# 163	['CsBr', 'Cs0.8FA0.2PbBr3', 'cubic-FAPbBr3']	3	[ 3 17 43]	[17 32 43]
# 164	['PbI2', 'delta-CsPbI3', 'alpha-CsPbI3']	3	[36 37 65]	[32 64 16]
# 165	['CsPb(Cl0.2Br0.8)3', 'PbBr2', 'CsPb(Cl0.4Br0.6)3']	3	[20 21 64]	[10 64 60]
# 166	['cubic-MAPbBr3', 'tetragonal-MAPbI3', 'MAPb(Br0.6I0.4)3']	3	[57 59 63]	[59 65 64]
# 167	['alpha-MAPbI3', 'PbI2', 'tetragonal-MAPbI3']	3	[62 63 65]	[62 65 63]
# 168	['CsPb2Br5', 'cubic-MAPbBr3', 'Cs0.2MA0.8PbBr3']	3	[ 8 19 59]	[64  8  9]
# 169	['Cs4PbBr6', 'cubic-FAPbBr3', 'Cs0.4FA0.6PbBr3']	3	[ 1 16 43]	[16 32 64]
# 170	['CsPb2Br5', 'orthorhombic-CsPbBr3', 'CsBr']	3	[17 19 33]	[64 43 17]
# 171	['PbI2', 'gamma-CsPbI3', 'CsI']	3	[18 38 65]	[17 16 64]
# 172	['alpha-FAPbI3', 'MA0.8FA0.2PbI3', 'PbI2']	3	[44 54 65]	[65 36 44]
# 173	['CsPb(I0.4Br0.6)3', 'CsBr', 'CsPb(I0.2Br0.8)3']	3	[17 24 25]	[32 43 17]
# 174	['MAPb(Br0.2I0.8)3', 'MAPb(Br0.6I0.4)3', 'tetragonal-MAPbI3']	3	[55 57 63]	[60 64 59]
# 175	['CsPb(Cl0.6Br0.4)3', 'cubic-CsPbBr3', 'orthorhombic-CsPbBr3']	3	[22 32 33]	[33  9 60]
# 176	['cubic-FAPbBr3', 'PbBr2', 'Cs0.8FA0.2PbBr3']	3	[ 3 43 64]	[64 32 43]
# 177	['PbBr2', 'CsBr', 'Cs4PbBr6']	3	[16 17 64]	[17 16 64]
# 178	['CsI', 'delta-CsPbI3', 'alpha-CsPbI3']	3	[18 36 37]	[32 16 64]
# 179	['cubic-MAPbBr3', 'MA0.2FA0.8PbBr3', 'PbBr2']	3	[47 59 64]	[43 46 19]
# 180	['PbI2', 'alpha-MAPbI3', 'tetragonal-MAPbI3']	3	[62 63 65]	[35 34 64]
# 181	['PbI2', 'cubic-FAPbBr3', 'beta-FAPbI3']	3	[43 45 65]	[65 64 18]
# 182	['MAPb(Br0.2I0.8)3', 'PbI2', 'MAPb(Br0.8I0.2)3']	3	[55 58 65]	[64 11 10]
# 183	['Cs0.8FA0.2PbI3', 'delta-CsPbI3', 'Cs0.6FA0.4PbI3']	3	[ 6  7 37]	[16 64 60]
# 184	['PbBr2', 'MA0.6FA0.4PbBr3', 'MA0.2FA0.8PbBr3']	3	[47 49 64]	[64 32 33]
# 185	['PbI2', 'delta-CsPbI3', 'CsI']	3	[18 37 65]	[37 18 65]
# 186	['CsPb(I0.6Cl0.4)3', 'cubic-CsPbCl3', 'PbI2']	3	[30 35 65]	[65 36 15]
# 187	['CsPb(I0.2Cl0.8)3', 'CsI', 'gamma-CsPbI3']	3	[18 28 38]	[64 33 16]
# 188	['CsI', 'CsPb(I0.2Br0.8)3', 'orthorhombic-CsPbBr3']	3	[18 24 33]	[33 17 59]
# 189	['FAPb(Br0.8I0.2)3', 'FAPb(Br0.6I0.4)3', 'PbBr2']	3	[41 42 64]	[64 16 19]
# 190	['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'MA0.8FA0.2PbBr3']	3	[50 59 60]	[59 60 50]
# 191	['PbBr2', 'orthorhombic-CsPbBr3', 'cubic-CsPbBr3']	3	[32 33 64]	[64 33 32]
# 192	['CsPb(Cl0.4Br0.6)3', 'CsPb(Cl0.2Br0.8)3', 'CsPb2Br5']	3	[19 20 21]	[19 20 32]
# 193	['gamma-CsPbI3', 'PbI2', 'alpha-CsPbI3']	3	[36 38 65]	[65 38 36]
# 194	['CsI', 'Cs0.8FA0.2PbI3', 'Cs0.6FA0.4PbI3']	3	[ 6  7 18]	[37 18 62]
# 195	['Cs0.2FA0.8PbBr3', 'Cs0.6FA0.4PbBr3', 'CsBr']	3	[ 0  2 17]	[32  3 43]
# 196	['alpha-FAPbI3', 'tetragonal-MAPbI3', 'MA0.2FA0.8PbI3']	3	[44 51 63]	[64 43 50]
# 197	['Pnma-CsPbCl3', 'gamma-CsPbI3', 'PbI2']	3	[34 38 65]	[33 59 16]
# 198	['CsPb2Br5', 'cubic-CsPbBr3', 'Cs4PbBr6']	3	[16 19 32]	[64 17 19]
# 199	['beta-FAPbI3', 'alpha-FAPbI3', 'delta-FAPbI3']	3	[44 45 46]	[46 45 65]
# 200	['delta-FAPbI3', 'PbI2', 'beta-FAPbI3']	3	[45 46 65]	[64 19 60]
# 201	['gamma-CsPbI3', 'Cs0.2MA0.8PbI3', 'Cs0.4MA0.6PbI3']	3	[12 13 38]	[ 8 33 16]
# 202	['tetragonal-MAPbBr3', 'PbBr2', 'cubic-MAPbBr3']	3	[59 60 64]	[60 64 59]
# 203	['CsPb(Cl0.2Br0.8)3', 'CsPb(Cl0.4Br0.6)3', 'CsPb2Br5']	3	[19 20 21]	[64 59  8]
# 204	['MA0.8FA0.2PbBr3', 'MA0.6FA0.4PbBr3', 'MA0.4FA0.6PbBr3']	3	[48 49 50]	[60 59 49]
# 205	['tetragonal-MAPbBr3', 'MA0.6FA0.4PbBr3', 'MA0.4FA0.6PbBr3']	3	[48 49 60]	[ 0  2 60]
# 206	['CsPb(I0.4Cl0.6)3', 'alpha-CsPbI3', 'delta-CsPbI3']	3	[29 36 37]	[16 64 11]
# 207	['gamma-CsPbI3', 'PbI2', 'Cs0.4FA0.6PbI3']	3	[ 5 38 65]	[64 16 33]
# 208	['tetragonal-MAPbI3', 'PbI2', 'alpha-MAPbI3']	3	[62 63 65]	[34 35 64]
# 209	['gamma-CsPbI3', 'delta-FAPbI3', 'Cs0.2FA0.8PbI3']	3	[ 4 38 46]	[16 64 33]
# 210	['cubic-MAPbBr3', 'MA0.2FA0.8PbBr3', 'cubic-FAPbBr3']	3	[43 47 59]	[59 47 43]
# 211	['cubic-MAPbBr3', 'MAPb(Br0.4I0.6)3', 'PbBr2']	3	[56 59 64]	[64 59 17]
# 212	['PbI2', 'CsI', 'CsPb(I0.6Br0.4)3']	3	[18 26 65]	[17 60 32]
# 213	['alpha-FAPbI3', 'PbI2', 'beta-FAPbI3']	3	[44 45 65]	[65 36 18]
# 214	['gamma-CsPbI3', 'Cs0.4MA0.6PbI3', 'tetragonal-MAPbI3']	3	[13 38 63]	[64 59 16]
# 215	['PbI2', 'alpha-CsPbI3', 'CsPb(I0.4Cl0.6)3']	3	[29 36 65]	[36 65 35]
# 216	['tetragonal-MAPbI3', 'beta-FAPbI3', 'alpha-MAPbI3']	3	[45 62 63]	[45 63 62]
# 217	['cubic-FAPbBr3', 'tetragonal-MAPbBr3', 'MA0.8FA0.2PbBr3']	3	[43 50 60]	[43 60 50]
# 218	['alpha-MAPbI3', 'MA0.8FA0.2PbI3', 'beta-FAPbI3']	3	[45 54 62]	[64 40 65]
# 219	['Cs0.2MA0.8PbI3', 'alpha-CsPbI3', 'gamma-CsPbI3']	3	[12 36 38]	[34 38 35]
# 220	['orthorhombic-CsPbBr3', 'PbBr2', 'cubic-CsPbBr3']	3	[32 33 64]	[64 33 32]
# 221	['tetragonal-MAPbI3', 'MA0.6FA0.4PbI3', 'MA0.2FA0.8PbI3']	3	[51 53 63]	[64 16 19]
# 222	['PbI2', 'alpha-MAPbI3', 'beta-FAPbI3']	3	[45 62 65]	[65 64 62]
# 223	['Cs4PbBr6', 'PbBr2', 'Cs0.8MA0.2PbBr3']	3	[11 16 64]	[16 33 64]
# 224	['Pnma-CsPbCl3', 'CsBr', 'cubic-CsPbBr3']	3	[17 32 34]	[17 32 10]
# 225	['MA0.8FA0.2PbBr3', 'PbBr2', 'MA0.6FA0.4PbBr3']	3	[49 50 64]	[64 49  9]
# 226	['Cs0.4FA0.6PbI3', 'CsI', 'PbI2']	3	[ 5 18 65]	[17 16 64]
# 227	['cubic-CsPbBr3', 'CsPb(Cl0.6Br0.4)3', 'CsPb(Cl0.8Br0.2)3']	3	[22 23 32]	[32 23 22]
# 228	['cubic-CsPbBr3', 'Cs4PbBr6', 'CsBr']	3	[16 17 32]	[17 16 32]
# 229	['alpha-FAPbI3', 'beta-FAPbI3', 'PbI2']	3	[44 45 65]	[64 60 59]
# 230	['delta-CsPbI3', 'gamma-CsPbI3', 'CsPb(I0.2Cl0.8)3']	3	[28 37 38]	[33 16 34]
# 231	['cubic-CsPbCl3', 'CsPb(Cl0.6Br0.4)3', 'Pnma-CsPbCl3']	3	[22 34 35]	[11 60 17]
# 232	['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'Cs0.6MA0.4PbBr3']	3	[10 59 60]	[60 59 10]
# 233	['alpha-FAPbI3', 'delta-FAPbI3', 'PbI2']	3	[44 46 65]	[17 32 64]
# 234	['cubic-CsPbBr3', 'orthorhombic-CsPbBr3', 'Cs4PbBr6']	3	[16 32 33]	[32 33 64]
# 235	['Pnma-CsPbCl3', 'CsPb(Cl0.4Br0.6)3', 'cubic-CsPbCl3']	3	[21 34 35]	[34 35 17]
# 236	['Cs0.4MA0.6PbBr3', 'Cs0.6MA0.4PbBr3', 'CsPb2Br5']	3	[ 9 10 19]	[64 47 48]
# 237	['Cs0.2MA0.8PbI3', 'gamma-CsPbI3', 'tetragonal-MAPbI3']	3	[12 38 63]	[33 16 11]
# 238	['PbI2', 'delta-FAPbI3', 'beta-FAPbI3']	3	[45 46 65]	[43 64 16]
# 239	['cubic-CsPbBr3', 'PbBr2', 'orthorhombic-CsPbBr3']	3	[32 33 64]	[64 32 33]
# 240	['CsPb(I0.4Cl0.6)3', 'cubic-CsPbCl3', 'alpha-CsPbI3']	3	[29 35 36]	[32 10 19]
# 241	['alpha-FAPbI3', 'FAPb(Br0.4I0.6)3', 'delta-FAPbI3']	3	[40 44 46]	[47 16 64]
# 242	['cubic-CsPbBr3', 'PbBr2', 'Cs4PbBr6']	3	[16 32 64]	[64 32 16]
# 243	['cubic-CsPbBr3', 'Cs0.4FA0.6PbBr3', 'Cs4PbBr6']	3	[ 1 16 32]	[64 19  0]
# 244	['MA0.8FA0.2PbBr3', 'cubic-MAPbBr3', 'cubic-FAPbBr3']	3	[43 50 59]	[43 59 50]
# 245	['PbI2', 'CsI', 'gamma-CsPbI3']	3	[18 38 65]	[64 16 33]
# 246	['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3']	3	[59 60 64]	[64 60 59]
# 247	['PbBr2', 'MA0.6FA0.4PbBr3', 'cubic-MAPbBr3']	3	[49 59 64]	[64 47 49]
# 248	['Cs0.6MA0.4PbBr3', 'PbBr2', 'CsBr']	3	[10 17 64]	[64 17 10]
# 249	['cubic-CsPbBr3', 'CsBr', 'orthorhombic-CsPbBr3']	3	[17 32 33]	[33 32 17]
# 250	['Cs4PbBr6', 'cubic-FAPbBr3', 'orthorhombic-CsPbBr3']	3	[16 33 43]	[43 16 64]
# 251	['PbBr2', 'orthorhombic-CsPbBr3', 'CsBr']	3	[17 33 64]	[64 17 32]
# 252	['alpha-CsPbI3', 'delta-CsPbI3', 'gamma-CsPbI3']	3	[36 37 38]	[37 38 36]
# 253	['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3']	3	[59 60 64]	[60 64 59]
# 254	['MAPb(Br0.4I0.6)3', 'cubic-MAPbBr3', 'MAPb(Br0.8I0.2)3']	3	[56 58 59]	[65 36 35]
# 255	['PbI2', 'delta-FAPbI3', 'alpha-FAPbI3']	3	[44 46 65]	[43 64 60]
# 256	['MA0.4FA0.6PbBr3', 'MA0.2FA0.8PbBr3', 'tetragonal-MAPbBr3']	3	[47 48 60]	[60 59 49]
# 257	['gamma-CsPbI3', 'PbI2', 'delta-CsPbI3']	3	[37 38 65]	[38 65 37]
# 258	['alpha-CsPbI3', 'gamma-CsPbI3', 'CsI']	3	[18 36 38]	[64 59 60]
# 259	['CsBr', 'Cs4PbBr6', 'orthorhombic-CsPbBr3']	3	[16 17 33]	[33 16 17]
# 260	['Cs0.2FA0.8PbBr3', 'Cs4PbBr6', 'Cs0.8FA0.2PbBr3']	3	[ 0  3 16]	[16 32 43]
# 261	['beta-FAPbI3', 'delta-FAPbI3', 'alpha-FAPbI3']	3	[44 45 46]	[46 44 45]
# 262	['orthorhombic-CsPbBr3', 'cubic-CsPbCl3', 'cubic-CsPbBr3']	3	[32 33 35]	[33 35 32]
# 263	['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3']	3	[59 60 64]	[60 64 59]
# 264	['CsPb(Cl0.2Br0.8)3', 'CsBr', 'CsPb2Br5']	3	[17 19 20]	[19 20 22]
# 265	['alpha-FAPbI3', 'CsI', 'Cs0.8FA0.2PbI3']	3	[ 7 18 44]	[18 65 36]
# 266	['cubic-CsPbCl3', 'CsPb(I0.6Cl0.4)3', 'PbI2']	3	[30 35 65]	[60 32 49]
# 267	['alpha-CsPbI3', 'delta-CsPbI3', 'gamma-CsPbI3']	3	[36 37 38]	[64 33 16]
# 268	['orthorhombic-CsPbBr3', 'cubic-CsPbBr3', 'Cs0.2MA0.8PbBr3']	3	[ 8 32 33]	[50 49 59]
# 269	['MA0.2FA0.8PbBr3', 'MA0.8FA0.2PbBr3', 'MA0.6FA0.4PbBr3']	3	[47 49 50]	[ 1 35 43]
# 270	['CsBr', 'Cs0.2MA0.8PbBr3', 'Cs0.6MA0.4PbBr3']	3	[ 8 10 17]	[ 9 17 60]
# 271	['CsPb(I0.6Cl0.4)3', 'CsI', 'alpha-CsPbI3']	3	[18 30 36]	[36 31 18]
# 272	['Cs0.8FA0.2PbBr3', 'cubic-FAPbBr3', 'Cs0.4FA0.6PbBr3']	3	[ 1  3 43]	[43  1  3]
# 273	['cubic-CsPbBr3', 'orthorhombic-CsPbBr3', 'Cs4PbBr6']	3	[16 32 33]	[33 32 16]
# 274	['PbBr2', 'cubic-CsPbBr3', 'CsBr']	3	[17 32 64]	[32 64 17]
# 275	['Cs4PbBr6', 'Cs0.4FA0.6PbBr3', 'cubic-CsPbBr3']	3	[ 1 16 32]	[16 32 43]
# 276	['alpha-FAPbI3', 'delta-FAPbI3', 'beta-FAPbI3']	3	[44 45 46]	[64 43 59]
# 277	['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3']	3	[59 60 64]	[59 60 64]
# 278	['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2']	3	[62 63 65]	[65 63 62]
# 279	['CsI', 'Pnma-CsPbCl3', 'CsPb(I0.4Cl0.6)3']	3	[18 29 34]	[18 36 63]
# 280	['delta-FAPbI3', 'PbI2', 'MA0.2FA0.8PbI3']	3	[46 51 65]	[64 16 33]
# 281	['CsPb(Cl0.8Br0.2)3', 'Pnma-CsPbCl3', 'Cs4PbBr6']	3	[16 23 34]	[16 64  8]
# 282	['CsPb2Br5', 'cubic-CsPbBr3', 'PbBr2']	3	[19 32 64]	[64 32 19]
# 283	['delta-FAPbI3', 'beta-FAPbI3', 'alpha-FAPbI3']	3	[44 45 46]	[43 64 16]
# 284	['PbBr2', 'Cs0.6MA0.4PbBr3', 'CsBr']	3	[10 17 64]	[17 64 10]
# 285	['alpha-FAPbI3', 'PbI2', 'beta-FAPbI3']	3	[44 45 65]	[64 43 60]
# 286	['PbI2', 'Cs0.8FA0.2PbI3', 'Cs0.6FA0.4PbI3']	3	[ 6  7 65]	[64 11 16]
# 287	['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2']	3	[62 63 65]	[65 63 62]
# 288	['cubic-CsPbCl3', 'orthorhombic-CsPbBr3', 'Pnma-CsPbCl3']	3	[33 34 35]	[33 35 20]
# 289	['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3']	3	[59 60 64]	[60 64 59]
# 290	['CsI', 'tetragonal-MAPbI3', 'gamma-CsPbI3']	3	[18 38 63]	[59 33 16]
# 291	['cubic-FAPbBr3', 'MA0.8FA0.2PbBr3', 'PbBr2']	3	[43 50 64]	[59 64 60]
# 292	['CsPb(I0.8Cl0.2)3', 'cubic-CsPbCl3', 'PbI2']	3	[31 35 65]	[65 62 18]
# 293	['CsPb(I0.6Br0.4)3', 'delta-CsPbI3', 'orthorhombic-CsPbBr3']	3	[26 33 37]	[16 19 33]
# 294	['CsPb(I0.4Cl0.6)3', 'gamma-CsPbI3', 'Pnma-CsPbCl3']	3	[29 34 38]	[38 34 36]
# 295	['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2']	3	[62 63 65]	[64 60 59]
# 296	['cubic-CsPbCl3', 'CsPb(I0.8Cl0.2)3', 'CsPb(I0.6Cl0.4)3']	3	[30 31 35]	[32 60 36]
# 297	['CsPb(I0.6Br0.4)3', 'PbBr2', 'CsPb(I0.4Br0.6)3']	3	[25 26 64]	[64 43 32]
# 298	['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3']	3	[59 60 64]	[64 59 60]
# 299	['cubic-CsPbCl3', 'CsI', 'CsPb(I0.2Cl0.8)3']	3	[18 28 35]	[10 60 32]
# 300	['Cs0.8MA0.2PbI3', 'alpha-MAPbI3', 'alpha-CsPbI3']	3	[15 36 62]	[ 9  8 60]
# 301	['MA0.8FA0.2PbI3', 'tetragonal-MAPbI3', 'MA0.6FA0.4PbI3']	3	[53 54 63]	[64 16 37]
# 302	['CsBr', 'CsPb2Br5', 'Cs4PbBr6']	3	[16 17 19]	[19 16 17]
# 303	['Cs0.8FA0.2PbBr3', 'cubic-CsPbBr3', 'CsBr']	3	[ 3 17 32]	[32 17 35]
# 304	['Cs4PbBr6', 'CsBr', 'CsPb2Br5']	3	[16 17 19]	[17 16 19]
# 305	['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3']	3	[59 60 64]	[60 64 59]
# 306	['Cs4PbBr6', 'Cs0.6FA0.4PbBr3', 'PbBr2']	3	[ 2 16 64]	[16 19  2]
# 307	['PbBr2', 'Cs4PbBr6', 'CsBr']	3	[16 17 64]	[16 64 32]
# 308	['PbI2', 'alpha-MAPbI3', 'tetragonal-MAPbI3']	3	[62 63 65]	[62 63 65]
# 309	['delta-CsPbI3', 'CsPb(I0.6Br0.4)3', 'alpha-CsPbI3']	3	[26 36 37]	[37 36 15]
# 310	['CsI', 'delta-CsPbI3', 'alpha-CsPbI3']	3	[18 36 37]	[64 59 60]
# 311	['PbBr2', 'FAPb(Br0.4I0.6)3', 'delta-FAPbI3']	3	[40 46 64]	[64 16  3]
# 312	['PbI2', 'beta-FAPbI3', 'delta-FAPbI3']	3	[45 46 65]	[65 45 46]
# 313	['CsPb2Br5', 'orthorhombic-CsPbBr3', 'CsBr']	3	[17 19 33]	[17 33 19]
# 314	['PbBr2', 'tetragonal-MAPbBr3', 'cubic-FAPbBr3']	3	[43 60 64]	[64 59 32]
# 315	['cubic-CsPbBr3', 'Cs0.2FA0.8PbBr3', 'Cs4PbBr6']	3	[ 0 16 32]	[32 16 43]
# 316	['cubic-MAPbBr3', 'cubic-FAPbBr3', 'PbBr2']	3	[43 59 64]	[64 32 22]
# 317	['delta-CsPbI3', 'alpha-MAPbI3', 'Cs0.2MA0.8PbI3']	3	[12 37 62]	[64 16  1]
# 318	['MA0.8FA0.2PbBr3', 'cubic-FAPbBr3', 'MA0.2FA0.8PbBr3']	3	[43 47 50]	[ 1 17 43]
# 319	['MA0.8FA0.2PbBr3', 'PbBr2', 'cubic-FAPbBr3']	3	[43 50 64]	[64 60 32]
# 320	['Cs0.6MA0.4PbBr3', 'Cs0.8MA0.2PbBr3', 'Cs0.4MA0.6PbBr3']	3	[ 9 10 11]	[32  1  0]
# 321	['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3']	3	[59 60 64]	[64 59 60]
# 322	['MA0.8FA0.2PbBr3', 'MA0.2FA0.8PbBr3', 'cubic-MAPbBr3']	3	[47 50 59]	[ 1  0 44]
# 323	['orthorhombic-CsPbBr3', 'CsPb2Br5', 'PbBr2']	3	[19 33 64]	[33 64 17]
# 324	['CsBr', 'Cs0.8FA0.2PbBr3', 'orthorhombic-CsPbBr3']	3	[ 3 17 33]	[33 17 43]
# 325	['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3']	3	[59 60 64]	[64 34 35]
# 326	['PbBr2', 'Cs4PbBr6', 'CsPb(Cl0.6Br0.4)3']	3	[16 22 64]	[64 16 37]
# 327	['Cs0.4MA0.6PbBr3', 'Cs0.8MA0.2PbBr3', 'CsBr']	3	[ 9 11 17]	[59 49 60]
# 328	['MA0.8FA0.2PbBr3', 'tetragonal-MAPbBr3', 'MA0.2FA0.8PbBr3']	3	[47 50 60]	[59 60 50]
# 329	['alpha-CsPbI3', 'CsPb(I0.4Cl0.6)3', 'PbI2']	3	[29 36 65]	[64 19  9]
# 330	['orthorhombic-CsPbBr3', 'CsPb2Br5', 'Cs0.8FA0.2PbBr3']	3	[ 3 19 33]	[33 19  3]
# 331	['CsPb(I0.2Cl0.8)3', 'CsPb(I0.6Cl0.4)3', 'CsI']	3	[18 28 30]	[23 32 17]
# 332	['Cs0.4MA0.6PbBr3', 'Cs0.2MA0.8PbBr3', 'CsPb2Br5']	3	[ 8  9 19]	[64  8 60]
# 333	['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3']	3	[59 60 64]	[64 60 59]
# 334	['alpha-CsPbI3', 'PbI2', 'gamma-CsPbI3']	3	[36 38 65]	[17 64 33]
# 335	['PbI2', 'delta-FAPbI3', 'alpha-FAPbI3']	3	[44 46 65]	[65 62 36]
# 336	['CsI', 'gamma-CsPbI3', 'alpha-CsPbI3']	3	[18 36 38]	[36 65 38]
# 337	['PbBr2', 'Cs0.8MA0.2PbBr3', 'cubic-MAPbBr3']	3	[11 59 64]	[11  8 19]
# 338	['alpha-MAPbI3', 'MA0.4FA0.6PbI3', 'MA0.6FA0.4PbI3']	3	[52 53 62]	[64 16 11]
# 339	['tetragonal-MAPbI3', 'PbI2', 'alpha-MAPbI3']	3	[62 63 65]	[35 34 32]
# 340	['Cs4PbBr6', 'tetragonal-MAPbBr3', 'CsBr']	3	[16 17 60]	[16 17 64]
# 341	['CsPb(I0.8Cl0.2)3', 'PbI2', 'Pnma-CsPbCl3']	3	[31 34 65]	[19 11  8]
# 342	['Cs0.4FA0.6PbI3', 'Cs0.8FA0.2PbI3', 'alpha-FAPbI3']	3	[ 5  7 44]	[16 19 64]
# 343	['alpha-CsPbI3', 'gamma-CsPbI3', 'PbI2']	3	[36 38 65]	[59 64 60]
# 344	['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'alpha-MAPbI3']	3	[59 60 62]	[32 34 27]
# 345	['PbBr2', 'Cs0.8MA0.2PbBr3', 'Cs4PbBr6']	3	[11 16 64]	[64 16 11]
# 346	['PbI2', 'beta-FAPbI3', 'alpha-FAPbI3']	3	[44 45 65]	[64 43 60]
# 347	['MAPb(Br0.2I0.8)3', 'MAPb(Br0.8I0.2)3', 'MAPb(Br0.6I0.4)3']	3	[55 57 58]	[59 43 60]
# 348	['Cs4PbBr6', 'PbI2', 'CsBr']	3	[16 17 65]	[35 65 37]
# 349	['PbBr2', 'CsPb2Br5', 'cubic-CsPbCl3']	3	[19 35 64]	[64 19  9]
# 350	['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2']	3	[62 63 65]	[63 65 62]
# 351	['Cs0.4FA0.6PbBr3', 'orthorhombic-CsPbBr3', 'cubic-CsPbBr3']	3	[ 1 32 33]	[ 1 33 32]
# 352	['Cs0.4FA0.6PbI3', 'Cs0.8FA0.2PbI3', 'Cs0.6FA0.4PbI3']	3	[5 6 7]	[16 19  9]
# 353	['Cs0.4MA0.6PbBr3', 'orthorhombic-CsPbBr3', 'Cs0.2MA0.8PbBr3']	3	[ 8  9 33]	[33 32 65]
# 354	['orthorhombic-CsPbBr3', 'CsBr', 'cubic-CsPbBr3']	3	[17 32 33]	[33 32 17]
# 355	['gamma-CsPbI3', 'alpha-CsPbI3', 'PbI2']	3	[36 38 65]	[59 60 64]
# 356	['tetragonal-MAPbBr3', 'PbBr2', 'cubic-MAPbBr3']	3	[59 60 64]	[64 59 60]
# 357	['PbBr2', 'CsPb(I0.4Br0.6)3', 'CsBr']	3	[17 25 64]	[64 65 18]
# 358	['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3']	3	[59 60 64]	[64 17 32]
# 359	['PbBr2', 'cubic-CsPbCl3', 'CsPb2Br5']	3	[19 35 64]	[64 19 11]
# 360	['alpha-MAPbI3', 'PbI2', 'tetragonal-MAPbI3']	3	[62 63 65]	[62 63 65]
# 361	['MA0.6FA0.4PbI3', 'MA0.8FA0.2PbI3', 'MA0.2FA0.8PbI3']	3	[51 53 54]	[16 64 33]
# 362	['orthorhombic-CsPbBr3', 'PbBr2', 'alpha-CsPbI3']	3	[33 36 64]	[64 33 19]
# 363	['PbI2', 'alpha-FAPbI3', 'beta-FAPbI3']	3	[44 45 65]	[65 44 45]
# 364	['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2']	3	[59 60 64]	[64 34 35]
# 365	['cubic-CsPbBr3', 'PbI2', 'CsPb(I0.6Br0.4)3']	3	[26 32 65]	[19 60 10]
# 366	['CsBr', 'Cs4PbBr6', 'cubic-CsPbBr3']	3	[16 17 32]	[17 64 16]
# 367	['beta-FAPbI3', 'FAPb(Br0.4I0.6)3', 'FAPb(Br0.6I0.4)3']	3	[40 41 45]	[64 47 16]
# 368	['MA0.8FA0.2PbBr3', 'MA0.4FA0.6PbBr3', 'PbBr2']	3	[48 50 64]	[64  1 32]
# 369	['CsI', 'cubic-CsPbBr3', 'gamma-CsPbI3']	3	[18 32 38]	[64 38 33]
# 370	['CsPb2Br5', 'PbBr2', 'CsBr']	3	[17 19 64]	[64 17 19]
# 371	['CsPb(I0.2Br0.8)3', 'CsBr', 'cubic-CsPbBr3']	3	[17 24 32]	[17 32 59]
# 372	['Cs0.2FA0.8PbBr3', 'CsPb2Br5', 'Cs0.6FA0.4PbBr3']	3	[ 0  2 19]	[64 32 21]
# 373	['alpha-MAPbI3', 'tetragonal-MAPbI3', 'MA0.4FA0.6PbI3']	3	[52 62 63]	[64 47 43]
# 374	['tetragonal-MAPbBr3', 'PbBr2', 'cubic-MAPbBr3']	3	[59 60 64]	[64 60 59]
# 375	['alpha-CsPbI3', 'cubic-CsPbBr3', 'CsPb2Br5']	3	[19 32 36]	[64  8  9]
# 376	['alpha-FAPbI3', 'beta-FAPbI3', 'PbI2']	3	[44 45 65]	[64 60 65]
# 377	['CsBr', 'cubic-CsPbBr3', 'orthorhombic-CsPbBr3']	3	[17 32 33]	[33 32 64]
# 378	['beta-FAPbI3', 'FAPb(Br0.4I0.6)3', 'FAPb(Br0.6I0.4)3']	3	[40 41 45]	[64 16 33]
# 379	['CsPb(Cl0.2Br0.8)3', 'CsPb(Cl0.6Br0.4)3', 'PbBr2']	3	[20 22 64]	[64 32 11]
# 380	['PbI2', 'CsPb(I0.6Cl0.4)3', 'CsPb(I0.2Cl0.8)3']	3	[28 30 65]	[32 10 60]
# 381	['CsBr', 'cubic-CsPbCl3', 'PbBr2']	3	[17 35 64]	[64 17 11]
# 382	['cubic-MAPbBr3', 'MA0.4FA0.6PbBr3', 'MA0.2FA0.8PbBr3']	3	[47 48 59]	[43  1 17]
# 383	['delta-CsPbI3', 'alpha-CsPbI3', 'PbI2']	3	[36 37 65]	[64 16 19]
# 384	['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3']	3	[59 60 64]	[64 17 32]
# 385	['alpha-MAPbI3', 'PbBr2', 'tetragonal-MAPbI3']	3	[62 63 64]	[64 10 11]
# 386	['CsBr', 'CsPb(Cl0.4Br0.6)3', 'cubic-CsPbCl3']	3	[17 21 35]	[17 60 11]
# 387	['beta-FAPbI3', 'delta-FAPbI3', 'alpha-FAPbI3']	3	[44 45 46]	[64 60 59]
# 388	['PbI2', 'MAPb(Br0.8I0.2)3', 'MAPb(Br0.6I0.4)3']	3	[57 58 65]	[59 47 60]
# 389	['alpha-CsPbI3', 'gamma-CsPbI3', 'delta-CsPbI3']	3	[36 37 38]	[64 33 16]
# 390	['CsPb2Br5', 'cubic-CsPbBr3', 'CsPb(Cl0.6Br0.4)3']	3	[19 22 32]	[64 19 32]
# 391	['PbI2', 'gamma-CsPbI3', 'Pnma-CsPbCl3']	3	[34 38 65]	[34 33 22]
# 392	['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3']	3	[59 60 64]	[64 60 59]
# 393	['PbI2', 'PbBr2', 'alpha-MAPbI3']	3	[62 64 65]	[65 62 37]
# 394	['MA0.2FA0.8PbI3', 'MA0.6FA0.4PbI3', 'delta-FAPbI3']	3	[46 51 53]	[64 39 40]
# 395	['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2']	3	[59 60 64]	[64 34 35]
# 396	['delta-FAPbI3', 'alpha-FAPbI3', 'Cs0.6FA0.4PbI3']	3	[ 6 44 46]	[46  6  7]
# 397	['cubic-CsPbBr3', 'orthorhombic-CsPbBr3', 'CsPb2Br5']	3	[19 32 33]	[32 19 33]
# 398	['delta-CsPbI3', 'PbI2', 'alpha-CsPbI3']	3	[36 37 65]	[32 16 64]
# 399	['Cs0.6FA0.4PbBr3', 'cubic-CsPbBr3', 'CsPb2Br5']	3	[ 2 19 32]	[32 64  2]
# 400	['PbI2', 'Cs0.6MA0.4PbI3', 'gamma-CsPbI3']	3	[14 38 65]	[38 65 12]
# 401	['CsI', 'PbI2', 'Cs0.8MA0.2PbI3']	3	[15 18 65]	[59 60 17]
# 402	['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3']	3	[59 60 64]	[64 32 17]
# 403	['alpha-FAPbI3', 'beta-FAPbI3', 'delta-FAPbI3']	3	[44 45 46]	[46 45 44]
# 404	['cubic-FAPbBr3', 'MA0.8FA0.2PbBr3', 'PbBr2']	3	[43 50 64]	[64 60 59]
# 405	['MA0.2FA0.8PbBr3', 'cubic-MAPbBr3', 'MA0.8FA0.2PbBr3']	3	[47 50 59]	[23 22 21]
# 406	['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2']	3	[59 60 64]	[64 17 35]
# 407	['PbBr2', 'orthorhombic-CsPbBr3', 'cubic-CsPbBr3']	3	[32 33 64]	[64 33 32]
# 408	['CsBr', 'PbBr2', 'orthorhombic-CsPbBr3']	3	[17 33 64]	[64 33 17]
# 409	['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2']	3	[62 63 65]	[34 35 32]
# 410	['gamma-CsPbI3', 'PbI2', 'CsI']	3	[18 38 65]	[64 59 17]
# 411	['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2']	3	[62 63 65]	[32 19 17]
# 412	['delta-FAPbI3', 'beta-FAPbI3', 'CsI']	3	[18 45 46]	[64 32 43]
# 413	['alpha-CsPbI3', 'CsI', 'Cs0.8MA0.2PbI3']	3	[15 18 36]	[ 8 60 17]
# 414	['cubic-CsPbCl3', 'CsPb(I0.8Cl0.2)3', 'PbI2']	3	[31 35 65]	[60 32 31]
# 415	['cubic-MAPbBr3', 'MAPb(Br0.6I0.4)3', 'alpha-MAPbI3']	3	[57 59 62]	[19 43 17]
# 416	['beta-FAPbI3', 'MA0.6FA0.4PbI3', 'MA0.2FA0.8PbI3']	3	[45 51 53]	[16 19 53]
# 417	['CsBr', 'cubic-CsPbBr3', 'Cs4PbBr6']	3	[16 17 32]	[17 16 32]
# 418	['delta-CsPbI3', 'PbI2', 'Cs0.2FA0.8PbI3']	3	[ 4 37 65]	[16 33 64]
# 419	['Cs0.6MA0.4PbBr3', 'cubic-CsPbBr3', 'CsBr']	3	[10 17 32]	[32 17 43]
# 420	['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3']	3	[59 60 64]	[64 32 35]
# 421	['Pnma-CsPbCl3', 'delta-CsPbI3', 'gamma-CsPbI3']	3	[34 37 38]	[38 37 62]
# 422	['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3']	3	[59 60 64]	[59 64 60]
# 423	['PbI2', 'alpha-MAPbI3', 'tetragonal-MAPbI3']	3	[62 63 65]	[35 34 64]
# 424	['cubic-CsPbBr3', 'CsPb2Br5', 'Cs4PbBr6']	3	[16 19 32]	[16 19 64]
# 425	['PbI2', 'PbBr2', 'tetragonal-MAPbBr3']	3	[60 64 65]	[65 63 15]
# 426	['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3']	3	[59 60 64]	[64 60 59]
# 427	['tetragonal-MAPbBr3', 'Cs0.8MA0.2PbBr3', 'CsBr']	3	[11 17 60]	[60 17 32]
# 428	['tetragonal-MAPbI3', 'PbI2', 'alpha-MAPbI3']	3	[62 63 65]	[64 32 17]
# 429	['delta-CsPbI3', 'PbI2', 'gamma-CsPbI3']	3	[37 38 65]	[33 16 19]
# 430	['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2']	3	[59 60 64]	[64 60 59]
# 431	['cubic-CsPbBr3', 'orthorhombic-CsPbBr3', 'CsPb2Br5']	3	[19 32 33]	[32 33 64]
# 432	['PbI2', 'Cs0.6MA0.4PbI3', 'Cs0.8MA0.2PbI3']	3	[14 15 65]	[65 18 15]
# 433	['PbI2', 'gamma-CsPbI3', 'CsPb(I0.4Cl0.6)3']	3	[29 38 65]	[64 16  9]
# 434	['MA0.6FA0.4PbI3', 'beta-FAPbI3', 'alpha-MAPbI3']	3	[45 53 62]	[16 64 33]
# 435	['cubic-CsPbBr3', 'PbBr2', 'CsBr']	3	[17 32 64]	[64 32 17]
# 436	['PbI2', 'alpha-MAPbI3', 'PbBr2']	3	[62 64 65]	[64 60 19]
# 437	['gamma-CsPbI3', 'PbI2', 'CsI']	3	[18 38 65]	[16 19 17]
# 438	['CsI', 'Pnma-CsPbCl3', 'CsPb(I0.8Cl0.2)3']	3	[18 31 34]	[65 18 13]
# 439	['PbI2', 'tetragonal-MAPbI3', 'alpha-MAPbI3']	3	[62 63 65]	[64 59 60]
# 440	['MAPb(Br0.4I0.6)3', 'tetragonal-MAPbI3', 'cubic-MAPbBr3']	3	[56 59 63]	[63 59 56]
# 441	['Cs0.8FA0.2PbBr3', 'Cs4PbBr6', 'CsBr']	3	[ 3 16 17]	[17 16 43]
# 442	['gamma-CsPbI3', 'delta-CsPbI3', 'CsPb(I0.6Cl0.4)3']	3	[30 37 38]	[33 16 64]
# 443	['cubic-FAPbBr3', 'delta-FAPbI3', 'FAPb(Br0.4I0.6)3']	3	[40 43 46]	[64 59 65]
# 444	['Cs0.8MA0.2PbI3', 'CsI', 'alpha-MAPbI3']	3	[15 18 62]	[18 62 65]
# 445	['PbI2', 'gamma-CsPbI3', 'delta-CsPbI3']	3	[37 38 65]	[38 37 65]
# 446	['gamma-CsPbI3', 'CsPb(I0.6Br0.4)3', 'Cs4PbBr6']	3	[16 26 38]	[64 16 59]
# 447	['delta-FAPbI3', 'beta-FAPbI3', 'PbI2']	3	[45 46 65]	[65 64 45]
# 448	['CsPb(I0.4Br0.6)3', 'CsI', 'PbBr2']	3	[18 25 64]	[18 64 62]
# 449	['delta-FAPbI3', 'beta-FAPbI3', 'alpha-FAPbI3']	3	[44 45 46]	[17 64 16]
# 450	['PbI2', 'delta-FAPbI3', 'beta-FAPbI3']	3	[45 46 65]	[64 32 19]
# 451	['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2']	3	[62 63 65]	[64 32 19]
# 452	['tetragonal-MAPbBr3', 'Cs0.6MA0.4PbBr3', 'PbBr2']	3	[10 60 64]	[64 60 50]
# 453	['PbBr2', 'cubic-CsPbBr3', 'Cs4PbBr6']	3	[16 32 64]	[32 16 64]
# 454	['cubic-FAPbBr3', 'delta-FAPbI3', 'PbI2']	3	[43 46 65]	[64 49 59]
# 455	['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2']	3	[62 63 65]	[63 62 65]
# 456	['MA0.8FA0.2PbBr3', 'MA0.4FA0.6PbBr3', 'MA0.2FA0.8PbBr3']	3	[47 48 50]	[60 59 58]
# 457	['CsPb(Cl0.4Br0.6)3', 'PbBr2', 'cubic-CsPbBr3']	3	[21 32 64]	[64 32 11]
# 458	['cubic-FAPbBr3', 'Cs0.8FA0.2PbBr3', 'cubic-CsPbBr3']	3	[ 3 32 43]	[43 32  3]
# 459	['MA0.6FA0.4PbBr3', 'MA0.8FA0.2PbBr3', 'tetragonal-MAPbBr3']	3	[49 50 60]	[59 62 43]
# 460	['CsPb2Br5', 'CsPb(Cl0.2Br0.8)3', 'Pnma-CsPbCl3']	3	[19 20 34]	[19 59 32]
# 461	['alpha-CsPbI3', 'gamma-CsPbI3', 'delta-CsPbI3']	3	[36 37 38]	[33 64 16]
# 462	['Cs4PbBr6', 'cubic-CsPbBr3', 'PbBr2']	3	[16 32 64]	[19 64 16]
# 463	['gamma-CsPbI3', 'alpha-CsPbI3', 'CsI']	3	[18 36 38]	[17 16 33]
# 464	['CsBr', 'orthorhombic-CsPbBr3', 'CsPb(Cl0.8Br0.2)3']	3	[17 23 33]	[10 33 64]
# 465	['Cs4PbBr6', 'CsBr', 'orthorhombic-CsPbBr3']	3	[16 17 33]	[64 17 33]
# 466	['CsI', 'alpha-CsPbI3', 'delta-CsPbI3']	3	[18 36 37]	[64 59 43]
# 467	['orthorhombic-CsPbBr3', 'CsBr', 'PbBr2']	3	[17 33 64]	[33 64 17]
# 468	['CsPb(Cl0.6Br0.4)3', 'Pnma-CsPbCl3', 'CsPb(Cl0.8Br0.2)3']	3	[22 23 34]	[11 10 59]
# 469	['tetragonal-MAPbI3', 'Cs0.6MA0.4PbI3', 'CsI']	3	[14 18 63]	[19 43 17]
# 470	['orthorhombic-CsPbBr3', 'Cs4PbBr6', 'CsPb2Br5']	3	[16 19 33]	[16 33 64]
# 471	['PbI2', 'delta-FAPbI3', 'beta-FAPbI3']	3	[45 46 65]	[43 64 60]
# 472	['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbI3']	3	[59 63 64]	[38 31 37]
# 473	['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3']	3	[59 60 64]	[60 64 59]
# 474	['gamma-CsPbI3', 'Cs0.8MA0.2PbI3', 'alpha-MAPbI3']	3	[15 38 62]	[38 12 13]
# 475	['MA0.8FA0.2PbI3', 'MA0.2FA0.8PbI3', 'beta-FAPbI3']	3	[45 51 54]	[16 19 64]
# 476	['PbBr2', 'orthorhombic-CsPbBr3', 'Cs4PbBr6']	3	[16 33 64]	[64 16 33]
# 477	['Cs0.6FA0.4PbI3', 'Cs0.8FA0.2PbI3', 'Cs0.4FA0.6PbI3']	3	[5 6 7]	[19 16  3]
# 478	['CsI', 'delta-CsPbI3', 'gamma-CsPbI3']	3	[18 37 38]	[17 33 16]
# 479	['tetragonal-MAPbI3', 'Cs0.4MA0.6PbI3', 'Cs0.6MA0.4PbI3']	3	[13 14 63]	[32 11 10]
# 480	['alpha-FAPbI3', 'cubic-FAPbBr3', 'FAPb(Br0.6I0.4)3']	3	[41 43 44]	[64 43 65]
# 481	['alpha-CsPbI3', 'CsI', 'PbI2']	3	[18 36 65]	[32 19 17]
# 482	['CsPb(Cl0.2Br0.8)3', 'PbBr2', 'CsPb(Cl0.8Br0.2)3']	3	[20 23 64]	[64 32 22]
# 483	['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3']	3	[59 60 64]	[64 60 59]
# 484	['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2']	3	[59 60 64]	[60 64 59]
# 485	['beta-FAPbI3', 'delta-FAPbI3', 'alpha-FAPbI3']	3	[44 45 46]	[65 36 45]
# 486	['PbI2', 'delta-FAPbI3', 'alpha-FAPbI3']	3	[44 46 65]	[64 59 60]
# 487	['orthorhombic-CsPbBr3', 'cubic-CsPbBr3', 'CsBr']	3	[17 32 33]	[33 32 17]
# 488	['Pnma-CsPbCl3', 'delta-CsPbI3', 'cubic-CsPbCl3']	3	[34 35 37]	[64 16 47]
# 489	['MAPb(Br0.6I0.4)3', 'PbBr2', 'MAPb(Br0.8I0.2)3']	3	[57 58 64]	[64 59 58]
# 490	['PbI2', 'CsI', 'Pnma-CsPbCl3']	3	[18 34 65]	[18 63 65]
# 491	['PbI2', 'MA0.6FA0.4PbI3', 'alpha-MAPbI3']	3	[53 62 65]	[65 62 46]
# 492	['FAPb(Br0.6I0.4)3', 'alpha-FAPbI3', 'FAPb(Br0.4I0.6)3']	3	[40 41 44]	[16 19  9]
# 493	['CsPb(I0.2Cl0.8)3', 'CsPb(I0.6Cl0.4)3', 'gamma-CsPbI3']	3	[28 30 38]	[16 19 22]
# 494	['cubic-FAPbBr3', 'MA0.4FA0.6PbBr3', 'PbBr2']	3	[43 48 64]	[64 47 48]
# 495	['Cs4PbBr6', 'CsBr', 'orthorhombic-CsPbBr3']	3	[16 17 33]	[17 33 16]
# 496	['cubic-CsPbBr3', 'PbBr2', 'Cs0.2FA0.8PbBr3']	3	[ 0 32 64]	[32 64  0]
# 497	['Cs0.8FA0.2PbI3', 'delta-FAPbI3', 'alpha-CsPbI3']	3	[ 7 36 46]	[64 43 32]
# 498	['CsPb(I0.8Br0.2)3', 'Cs4PbBr6', 'CsPb(I0.2Br0.8)3']	3	[16 24 27]	[16 64 19]
# 499	['cubic-MAPbBr3', 'PbBr2', 'MA0.6FA0.4PbBr3']	3	[49 59 64]	[64 59  9]
# 500	['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2']	3	[62 63 65]	[62 63 65]
# 501	['CsPb(I0.6Br0.4)3', 'Cs4PbBr6', 'CsPb(I0.2Br0.8)3']	3	[16 24 26]	[65 14 15]
# 502	['CsPb(Cl0.4Br0.6)3', 'CsBr', 'Pnma-CsPbCl3']	3	[17 21 34]	[19  8 59]
# 503	['MA0.8FA0.2PbI3', 'tetragonal-MAPbI3', 'MA0.6FA0.4PbI3']	3	[53 54 63]	[37 34 64]
# 504	['Cs0.6MA0.4PbBr3', 'tetragonal-MAPbBr3', 'CsBr']	3	[10 17 60]	[60 50 59]
# 505	['tetragonal-MAPbI3', 'alpha-FAPbI3', 'delta-FAPbI3']	3	[44 46 63]	[64 59 60]
# 506	['beta-FAPbI3', 'PbBr2', 'FAPb(Br0.4I0.6)3']	3	[40 45 64]	[16 64 33]
# 507	['beta-FAPbI3', 'MA0.8FA0.2PbI3', 'delta-FAPbI3']	3	[45 46 54]	[64 19 16]
# 508	['Cs4PbBr6', 'CsPb(Cl0.6Br0.4)3', 'orthorhombic-CsPbBr3']	3	[16 22 33]	[16 33 64]
# 509	['gamma-CsPbI3', 'delta-CsPbI3', 'alpha-CsPbI3']	3	[36 37 38]	[37 38 36]
# 510	['CsBr', 'CsPb2Br5', 'PbBr2']	3	[17 19 64]	[64 19 17]
# 511	['CsBr', 'PbI2', 'PbBr2']	3	[17 64 65]	[64 32 17]
# 512	['PbI2', 'FAPb(Br0.2I0.8)3', 'cubic-FAPbBr3']	3	[39 43 65]	[65 39 43]
# 513	['Pnma-CsPbCl3', 'CsPb(Cl0.4Br0.6)3', 'CsBr']	3	[17 21 34]	[64  8 17]
# 514	['MA0.6FA0.4PbI3', 'MA0.8FA0.2PbI3', 'beta-FAPbI3']	3	[45 53 54]	[64 16 51]
# 515	['PbBr2', 'cubic-MAPbBr3', 'MAPb(Br0.4I0.6)3']	3	[56 59 64]	[65 15 63]
# 516	['beta-FAPbI3', 'alpha-FAPbI3', 'cubic-FAPbBr3']	3	[43 44 45]	[64 59 43]
# 517	['MAPb(Br0.2I0.8)3', 'MAPb(Br0.4I0.6)3', 'cubic-MAPbBr3']	3	[55 56 59]	[59 32 17]
# 518	['PbI2', 'delta-FAPbI3', 'alpha-FAPbI3']	3	[44 46 65]	[65 45 44]
# 519	['alpha-CsPbI3', 'PbI2', 'delta-CsPbI3']	3	[36 37 65]	[64 60 59]
# 520	['Cs0.4FA0.6PbI3', 'gamma-CsPbI3', 'Cs0.2FA0.8PbI3']	3	[ 4  5 38]	[33 64 16]
# 521	['cubic-CsPbBr3', 'PbBr2', 'CsBr']	3	[17 32 64]	[17 32 64]
# 522	['PbBr2', 'CsI', 'gamma-CsPbI3']	3	[18 38 64]	[38 65 12]
# 523	['delta-FAPbI3', 'beta-FAPbI3', 'alpha-FAPbI3']	3	[44 45 46]	[65 45 44]
# 524	['PbBr2', 'MAPb(Br0.2I0.8)3', 'tetragonal-MAPbBr3']	3	[55 60 64]	[14 15 62]
# 525	['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2']	3	[62 63 65]	[34 35 19]
# 526	['PbI2', 'tetragonal-MAPbBr3', 'alpha-MAPbI3']	3	[60 62 65]	[65 62 15]
# 527	['Cs0.2FA0.8PbI3', 'alpha-CsPbI3', 'CsI']	3	[ 4 18 36]	[19 16 43]
# 528	['CsPb(I0.4Cl0.6)3', 'CsPb(I0.8Cl0.2)3', 'PbI2']	3	[29 31 65]	[65 31 29]
# 529	['cubic-MAPbBr3', 'MA0.4FA0.6PbBr3', 'MA0.8FA0.2PbBr3']	3	[48 50 59]	[59 60 48]
# 530	['beta-FAPbI3', 'delta-FAPbI3', 'Cs0.2FA0.8PbI3']	3	[ 4 45 46]	[64 16 19]
# 531	['Pnma-CsPbCl3', 'delta-CsPbI3', 'alpha-CsPbI3']	3	[34 36 37]	[64 16  9]
# 532	['Cs4PbBr6', 'Cs0.2MA0.8PbBr3', 'cubic-MAPbBr3']	3	[ 8 16 59]	[64 47 49]
# 533	['cubic-FAPbBr3', 'beta-FAPbI3', 'PbI2']	3	[43 45 65]	[64 59  8]
# 534	['orthorhombic-CsPbBr3', 'Cs4PbBr6', 'CsPb2Br5']	3	[16 19 33]	[33 16 64]
# 535	['beta-FAPbI3', 'Cs0.6FA0.4PbI3', 'PbI2']	3	[ 6 45 65]	[65 37 12]
# 536	['CsPb2Br5', 'orthorhombic-CsPbBr3', 'CsBr']	3	[17 19 33]	[64 33 17]
# 537	['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2']	3	[62 63 65]	[34 35 64]
# 538	['alpha-CsPbI3', 'Cs0.2MA0.8PbI3', 'gamma-CsPbI3']	3	[12 36 38]	[33 16 59]
# 539	['FAPb(Br0.8I0.2)3', 'FAPb(Br0.6I0.4)3', 'PbI2']	3	[41 42 65]	[16  1 43]
# 540	['gamma-CsPbI3', 'delta-CsPbI3', 'CsI']	3	[18 37 38]	[38 37 65]
# 541	['CsPb(Cl0.8Br0.2)3', 'CsPb(Cl0.4Br0.6)3', 'CsPb2Br5']	3	[19 21 23]	[19 17 32]
# 542	['tetragonal-MAPbBr3', 'MAPb(Br0.8I0.2)3', 'cubic-MAPbBr3']	3	[58 59 60]	[36 62 18]
# 543	['cubic-CsPbBr3', 'Cs0.8FA0.2PbBr3', 'Cs4PbBr6']	3	[ 3 16 32]	[16 43  1]
# 544	['alpha-MAPbI3', 'PbI2', 'tetragonal-MAPbI3']	3	[62 63 65]	[62 63 65]
# 545	['alpha-CsPbI3', 'gamma-CsPbI3', 'delta-CsPbI3']	3	[36 37 38]	[64 33 17]
# 546	['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2']	3	[62 63 65]	[62 63 65]
# 547	['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2']	3	[59 60 64]	[60 64 59]
# 548	['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'PbBr2']	3	[59 60 64]	[64 17 35]
# 549	['Cs4PbBr6', 'PbBr2', 'Cs0.4MA0.6PbBr3']	3	[ 9 16 64]	[16 64 37]
# 550	['PbBr2', 'Cs0.6FA0.4PbBr3', 'cubic-CsPbBr3']	3	[ 2 32 64]	[64 32  2]
# 551	['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'PbBr2']	3	[59 60 64]	[64 34 35]
# 552	['tetragonal-MAPbI3', 'MAPb(Br0.8I0.2)3', 'MAPb(Br0.4I0.6)3']	3	[56 58 63]	[64 43  3]
# 553	['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'PbBr2']	3	[59 60 64]	[64 60 59]
# 554	['Cs0.6MA0.4PbBr3', 'CsBr', 'cubic-MAPbBr3']	3	[10 17 59]	[32 17 59]
# 555	['Cs0.8MA0.2PbBr3', 'Cs0.4MA0.6PbBr3', 'Cs0.6MA0.4PbBr3']	3	[ 9 10 11]	[35 34  1]
# 556	['gamma-CsPbI3', 'delta-CsPbI3', 'alpha-CsPbI3']	3	[36 37 38]	[64 33 19]
# 557	['beta-FAPbI3', 'delta-FAPbI3', 'alpha-FAPbI3']	3	[44 45 46]	[64 60 43]
# 558	['MA0.8FA0.2PbI3', 'beta-FAPbI3', 'alpha-FAPbI3']	3	[44 45 54]	[16  1  3]
# 559	['beta-FAPbI3', 'delta-FAPbI3', 'alpha-FAPbI3']	3	[44 45 46]	[19 64 32]
# 560	['Pnma-CsPbCl3', 'CsI', 'CsPb(I0.6Cl0.4)3']	3	[18 30 34]	[17 60 59]
# 561	['delta-FAPbI3', 'tetragonal-MAPbI3', 'beta-FAPbI3']	3	[45 46 63]	[64 11 16]
# 562	['delta-CsPbI3', 'CsI', 'alpha-CsPbI3']	3	[18 36 37]	[18 36 38]
# 563	['MA0.2FA0.8PbBr3', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3']	3	[47 59 60]	[34 22 35]
# 564	['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'MAPb(Br0.8I0.2)3']	3	[58 59 60]	[59 60 10]
# 565	['Cs0.8MA0.2PbI3', 'PbI2', 'CsI']	3	[15 18 65]	[65 15 18]
# 566	['cubic-FAPbBr3', 'PbI2', 'delta-FAPbI3']	3	[43 46 65]	[65 43 46]
# 567	['Cs0.2FA0.8PbBr3', 'CsBr', 'Cs0.4FA0.6PbBr3']	3	[ 0  1 17]	[17 23 34]
# 568	['alpha-FAPbI3', 'beta-FAPbI3', 'delta-FAPbI3']	3	[44 45 46]	[64 59 60]
# 569	['MA0.6FA0.4PbBr3', 'cubic-FAPbBr3', 'MA0.4FA0.6PbBr3']	3	[43 48 49]	[43  1 34]
# 570	['CsPb2Br5', 'orthorhombic-CsPbBr3', 'Cs0.6FA0.4PbBr3']	3	[ 2 19 33]	[33 19 64]
# 571	['tetragonal-MAPbBr3', 'PbBr2', 'cubic-MAPbBr3']	3	[59 60 64]	[64 34 35]
# 572	['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3']	3	[59 60 64]	[64 59 60]
# 573	['CsI', 'CsPb(I0.2Br0.8)3', 'alpha-CsPbI3']	3	[18 24 36]	[32 17 43]
# 574	['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3']	3	[59 60 64]	[35 34 64]
# 575	['Cs0.4MA0.6PbI3', 'gamma-CsPbI3', 'CsI']	3	[13 18 38]	[38 62 65]
# 576	['CsPb2Br5', 'orthorhombic-CsPbBr3', 'Cs4PbBr6']	3	[16 19 33]	[33 16 64]
# 577	['Cs0.2MA0.8PbBr3', 'tetragonal-MAPbBr3', 'Cs0.6MA0.4PbBr3']	3	[ 8 10 60]	[59 60 49]
# 578	['gamma-CsPbI3', 'PbI2', 'alpha-CsPbI3']	3	[36 38 65]	[64 16 59]
# 579	['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'PbBr2']	3	[59 60 64]	[60 64 59]
# 580	['Cs0.8MA0.2PbI3', 'Cs0.6MA0.4PbI3', 'Cs0.4MA0.6PbI3']	3	[13 14 15]	[15 14 13]
# 581	['Cs4PbBr6', 'CsPb2Br5', 'Cs0.4FA0.6PbBr3']	3	[ 1 16 19]	[16 19 64]
# 582	['alpha-MAPbI3', 'PbI2', 'tetragonal-MAPbI3']	3	[62 63 65]	[65 63 62]
# 583	['Cs0.4FA0.6PbI3', 'delta-CsPbI3', 'delta-FAPbI3']	3	[ 5 37 46]	[16 64 19]
# 584	['CsPb(Cl0.4Br0.6)3', 'cubic-CsPbCl3', 'Cs4PbBr6']	3	[16 21 35]	[16 17 59]
# 585	['orthorhombic-CsPbBr3', 'delta-CsPbI3', 'CsI']	3	[18 33 37]	[37 38 63]
# 586	['gamma-CsPbI3', 'tetragonal-MAPbI3', 'CsI']	3	[18 38 63]	[38 63 65]
# 587	['tetragonal-MAPbI3', 'PbI2', 'alpha-MAPbI3']	3	[62 63 65]	[35 34 19]
# 588	['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3']	3	[59 60 64]	[60 64 59]
# 589	['tetragonal-MAPbI3', 'MAPb(Br0.4I0.6)3', 'MAPb(Br0.2I0.8)3']	3	[55 56 63]	[64 63 62]
# 590	['CsBr', 'cubic-FAPbBr3', 'cubic-CsPbBr3']	3	[17 32 43]	[32 17 43]
# 591	['PbBr2', 'delta-CsPbI3', 'CsPb(I0.8Br0.2)3']	3	[27 37 64]	[64 16 11]
# 592	['PbBr2', 'alpha-CsPbI3', 'CsI']	3	[18 36 64]	[64 17  9]
# 593	['CsPb(I0.6Cl0.4)3', 'PbI2', 'Pnma-CsPbCl3']	3	[30 34 65]	[32 19 11]
# 594	['beta-FAPbI3', 'FAPb(Br0.6I0.4)3', 'delta-FAPbI3']	3	[41 45 46]	[64 16 33]
# 595	['gamma-CsPbI3', 'PbI2', 'CsPb(I0.6Cl0.4)3']	3	[30 38 65]	[16 33  8]
# 596	['Cs4PbBr6', 'CsBr', 'cubic-MAPbBr3']	3	[16 17 59]	[64 59 16]
# 597	['alpha-CsPbI3', 'gamma-CsPbI3', 'delta-CsPbI3']	3	[36 37 38]	[64 33 32]
# 598	['delta-CsPbI3', 'CsI', 'Cs0.4MA0.6PbI3']	3	[13 18 37]	[37 29 34]
# 599	['Cs4PbBr6', 'Cs0.2MA0.8PbBr3', 'cubic-CsPbBr3']	3	[ 8 16 32]	[16 59 11]
# 600	['CsPb(I0.8Br0.2)3', 'CsI', 'Cs4PbBr6']	3	[16 18 27]	[64  9 59]
# 601	['MAPb(Br0.8I0.2)3', 'MAPb(Br0.4I0.6)3', 'MAPb(Br0.6I0.4)3']	3	[56 57 58]	[65 58 18]
# 602	['PbI2', 'alpha-MAPbI3', 'tetragonal-MAPbI3']	3	[62 63 65]	[62 63 65]
# 603	['Cs0.2FA0.8PbBr3', 'orthorhombic-CsPbBr3', 'CsBr']	3	[ 0 17 33]	[17 33 43]
# 604	['delta-FAPbI3', 'PbI2', 'beta-FAPbI3']	3	[45 46 65]	[65 45 46]
# 605	['CsPb2Br5', 'cubic-CsPbBr3', 'orthorhombic-CsPbBr3']	3	[19 32 33]	[33 32 19]
# 606	['orthorhombic-CsPbBr3', 'CsPb2Br5', 'PbBr2']	3	[19 33 64]	[64 33 16]
# 607	['PbI2', 'alpha-MAPbI3', 'tetragonal-MAPbI3']	3	[62 63 65]	[32 19 17]
# 608	['alpha-MAPbI3', 'gamma-CsPbI3', 'tetragonal-MAPbI3']	3	[38 62 63]	[33 16 11]
# 609	['cubic-CsPbBr3', 'Cs4PbBr6', 'CsPb2Br5']	3	[16 19 32]	[19 16 17]
# 610	['tetragonal-MAPbI3', 'cubic-MAPbBr3', 'alpha-MAPbI3']	3	[59 62 63]	[63 18 62]
# 611	['Cs0.8FA0.2PbI3', 'CsI', 'alpha-CsPbI3']	3	[ 7 18 36]	[43 64 32]
# 612	['PbBr2', 'orthorhombic-CsPbBr3', 'CsPb2Br5']	3	[19 33 64]	[33 64 17]
# 613	['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2']	3	[62 63 65]	[32 35 19]
# 614	['alpha-CsPbI3', 'PbI2', 'tetragonal-MAPbI3']	3	[36 63 65]	[30 34 31]
# 615	['alpha-MAPbI3', 'PbBr2', 'PbI2']	3	[62 64 65]	[64 19 59]
# 616	['alpha-FAPbI3', 'PbI2', 'delta-FAPbI3']	3	[44 46 65]	[43 64 60]
# 617	['gamma-CsPbI3', 'CsPb2Br5', 'cubic-CsPbBr3']	3	[19 32 38]	[16 33 19]
# 618	['CsPb(I0.2Br0.8)3', 'gamma-CsPbI3', 'CsBr']	3	[17 24 38]	[64 33 17]
# 619	['Cs0.8FA0.2PbBr3', 'Cs0.2FA0.8PbBr3', 'Cs0.6FA0.4PbBr3']	3	[0 2 3]	[32  3  0]
# 620	['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3']	3	[59 60 64]	[60 64 59]
# 621	['CsI', 'gamma-CsPbI3', 'alpha-CsPbI3']	3	[18 36 38]	[64 59 60]
# 622	['Cs0.6MA0.4PbBr3', 'CsPb2Br5', 'tetragonal-MAPbBr3']	3	[10 19 60]	[19 64 32]
# 623	['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2']	3	[62 63 65]	[62 63 65]
# 624	['tetragonal-MAPbBr3', 'PbBr2', 'cubic-MAPbBr3']	3	[59 60 64]	[60 64 59]
# 625	['PbI2', 'Cs0.6FA0.4PbI3', 'Cs0.2FA0.8PbI3']	3	[ 4  6 65]	[16 19 64]
# 626	['MA0.2FA0.8PbBr3', 'tetragonal-MAPbBr3', 'PbBr2']	3	[47 60 64]	[64 60 62]
# 627	['MAPb(Br0.4I0.6)3', 'MAPb(Br0.2I0.8)3', 'tetragonal-MAPbI3']	3	[55 56 63]	[64 10 59]
# 628	['CsBr', 'Cs0.2FA0.8PbBr3', 'cubic-CsPbBr3']	3	[ 0 17 32]	[17 43 32]
# 629	['CsI', 'PbI2', 'alpha-CsPbI3']	3	[18 36 65]	[32 19 17]
# 630	['PbI2', 'gamma-CsPbI3', 'delta-CsPbI3']	3	[37 38 65]	[33 16 64]
# 631	['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2']	3	[62 63 65]	[59 64 60]
# 632	['orthorhombic-CsPbBr3', 'CsPb(Cl0.6Br0.4)3', 'CsBr']	3	[17 22 33]	[64 33 48]
# 633	['PbI2', 'gamma-CsPbI3', 'CsPb(I0.4Cl0.6)3']	3	[29 38 65]	[16 64 60]
# 634	['cubic-CsPbBr3', 'CsBr', 'alpha-CsPbI3']	3	[17 32 36]	[60 32 59]
# 635	['Cs0.6MA0.4PbBr3', 'Cs0.4MA0.6PbBr3', 'Cs4PbBr6']	3	[ 9 10 16]	[16 64 10]
# 636	['Cs0.4FA0.6PbBr3', 'CsBr', 'Cs0.6FA0.4PbBr3']	3	[ 1  2 17]	[17 32 35]
# ...
# 789	['CsBr', 'CsPb2Br5', 'PbBr2']	3	[17 19 64]	[19 64 17]
# 790	['PbI2', 'MA0.4FA0.6PbI3', 'delta-FAPbI3']	3	[46 52 65]	[46 45 52]
# 791	['orthorhombic-CsPbBr3', 'PbBr2', 'alpha-CsPbI3']	3	[33 36 64]	[12 37 13]
# 792	['cubic-CsPbBr3', 'orthorhombic-CsPbBr3', 'CsBr']	3	[17 32 33]	[32 33 64]
# 793	['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3']	3	[59 60 64]	[64 60 59]
# 794	['delta-CsPbI3', 'Cs0.2MA0.8PbI3', 'Cs0.4MA0.6PbI3']	3	[12 13 37]	[37 34 65]
# 795	['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2']	3	[62 63 65]	[32 35 34]
# 796	['Cs0.6MA0.4PbI3', 'Cs0.2MA0.8PbI3', 'delta-CsPbI3']	3	[12 14 37]	[37 15 36]
# 797	['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3']	3	[59 60 64]	[64 60 59]
# 798	['MA0.4FA0.6PbBr3', 'MA0.6FA0.4PbBr3', 'cubic-MAPbBr3']	3	[48 49 59]	[60 59 58]
# 799	['delta-FAPbI3', 'PbI2', 'beta-FAPbI3']	3	[45 46 65]	[64 60 59]
# 800	['cubic-FAPbBr3', 'MA0.6FA0.4PbBr3', 'PbBr2']	3	[43 49 64]	[64  1 32]
# 801	['alpha-CsPbI3', 'CsPb(I0.2Cl0.8)3', 'PbI2']	3	[28 36 65]	[36 32 60]
# 802	['tetragonal-MAPbI3', 'PbI2', 'alpha-MAPbI3']	3	[62 63 65]	[65 63 62]
# 803	['alpha-FAPbI3', 'delta-FAPbI3', 'FAPb(Br0.8I0.2)3']	3	[42 44 46]	[19 16 43]
# 804	['beta-FAPbI3', 'MA0.4FA0.6PbI3', 'PbI2']	3	[45 52 65]	[16 17 22]
# 805	['PbI2', 'CsPb(I0.6Cl0.4)3', 'gamma-CsPbI3']	3	[30 38 65]	[65 34 38]
# 806	['CsI', 'PbI2', 'delta-CsPbI3']	3	[18 37 65]	[65 18 37]
# 807	['tetragonal-MAPbI3', 'alpha-MAPbI3', 'delta-FAPbI3']	3	[46 62 63]	[64 50 47]
# 808	['CsI', 'Cs0.6MA0.4PbI3', 'Cs0.2MA0.8PbI3']	3	[12 14 18]	[18 30 28]
# 809	['MA0.4FA0.6PbBr3', 'cubic-MAPbBr3', 'MA0.2FA0.8PbBr3']	3	[47 48 59]	[59 60 62]
# 810	['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2']	3	[62 63 65]	[34 35 32]
# 811	['orthorhombic-CsPbBr3', 'Cs4PbBr6', 'CsPb(Cl0.6Br0.4)3']	3	[16 22 33]	[33 64 10]
# 812	['beta-FAPbI3', 'alpha-FAPbI3', 'cubic-FAPbBr3']	3	[43 44 45]	[64 32 43]
# 813	['Cs4PbBr6', 'CsBr', 'CsPb2Br5']	3	[16 17 19]	[16 17 19]
# 814	['PbI2', 'tetragonal-MAPbI3', 'alpha-MAPbI3']	3	[62 63 65]	[35 34 64]
# 815	['MA0.8FA0.2PbBr3', 'MA0.6FA0.4PbBr3', 'cubic-MAPbBr3']	3	[49 50 59]	[50 59 36]
# 816	['orthorhombic-CsPbBr3', 'cubic-CsPbBr3', 'PbBr2']	3	[32 33 64]	[64 32 33]
# 817	['alpha-MAPbI3', 'PbI2', 'tetragonal-MAPbI3']	3	[62 63 65]	[63 62 65]
# 818	['PbBr2', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3']	3	[59 60 64]	[64 32 34]
# 819	['PbI2', 'CsPb(I0.6Cl0.4)3', 'CsI']	3	[18 30 65]	[ 8 17 59]
# 820	['alpha-FAPbI3', 'beta-FAPbI3', 'delta-FAPbI3']	3	[44 45 46]	[64 16 17]
# 821	['alpha-MAPbI3', 'tetragonal-MAPbI3', 'PbI2']	3	[62 63 65]	[32 19 17]
# 822	['MAPb(Br0.6I0.4)3', 'PbBr2', 'tetragonal-MAPbBr3']	3	[57 60 64]	[65 63 18]
# 823	['delta-FAPbI3', 'Cs0.2FA0.8PbI3', 'CsI']	3	[ 4 18 46]	[46  4 65]
# 824	['delta-CsPbI3', 'CsI', 'alpha-CsPbI3']	3	[18 36 37]	[33 32 17]
# 825	['cubic-FAPbBr3', 'delta-FAPbI3', 'FAPb(Br0.2I0.8)3']	3	[39 43 46]	[16 19 64]
# 826	['alpha-MAPbI3', 'PbI2', 'tetragonal-MAPbI3']	3	[62 63 65]	[64 60 59]
# 827	['PbBr2', 'MA0.4FA0.6PbBr3', 'tetragonal-MAPbBr3']	3	[48 60 64]	[64 60 59]
# 828	['alpha-CsPbI3', 'delta-CsPbI3', 'gamma-CsPbI3']	3	[36 37 38]	[38 37 65]
# 829	['Cs4PbBr6', 'orthorhombic-CsPbBr3', 'CsBr']	3	[16 17 33]	[16 33 17]
# 830	['PbI2', 'Cs0.8FA0.2PbI3', 'Cs0.4FA0.6PbI3']	3	[ 5  7 65]	[45  5 65]
# 831	['cubic-CsPbBr3', 'orthorhombic-CsPbBr3', 'CsBr']	3	[17 32 33]	[33 32 17]
# 832	['Cs0.4FA0.6PbBr3', 'cubic-FAPbBr3', 'Cs4PbBr6']	3	[ 1 16 43]	[16 43  1]
# 833	['alpha-FAPbI3', 'CsI', 'alpha-CsPbI3']	3	[18 36 44]	[65 35 36]
# 834	['MA0.4FA0.6PbI3', 'PbI2', 'MA0.8FA0.2PbI3']	3	[52 54 65]	[44 52 53]
# 835	['CsPb2Br5', 'cubic-CsPbBr3', 'cubic-MAPbBr3']	3	[19 32 59]	[64 60  9]
# 836	['PbBr2', 'MA0.4FA0.6PbBr3', 'cubic-FAPbBr3']	3	[43 48 64]	[64 60 47]
# 837	['MA0.2FA0.8PbI3', 'MA0.6FA0.4PbI3', 'beta-FAPbI3']	3	[45 51 53]	[40 64 39]
# 838	['delta-CsPbI3', 'CsI', 'delta-FAPbI3']	3	[18 37 46]	[64 16  0]
# 839	['FAPb(Br0.4I0.6)3', 'PbBr2', 'cubic-FAPbBr3']	3	[40 43 64]	[64 16 47]
# 840	['Cs4PbBr6', 'orthorhombic-CsPbBr3', 'cubic-CsPbBr3']	3	[16 32 33]	[16 33 32]
# 841	['MA0.4FA0.6PbI3', 'MA0.8FA0.2PbI3', 'beta-FAPbI3']	3	[45 52 54]	[65 37 62]
# 842	['CsBr', 'Cs0.2FA0.8PbBr3', 'cubic-CsPbBr3']	3	[ 0 17 32]	[32 17 43]
# 843	['FAPb(Br0.6I0.4)3', 'PbI2', 'PbBr2']	3	[41 64 65]	[41 64 65]
# 844	['alpha-CsPbI3', 'delta-CsPbI3', 'PbI2']	3	[36 37 65]	[36 65 37]
# 845	['MA0.2FA0.8PbBr3', 'cubic-FAPbBr3', 'PbBr2']	3	[43 47 64]	[64 43 35]
# 846	['Cs0.6MA0.4PbBr3', 'PbBr2', 'CsPb2Br5']	3	[10 19 64]	[64 19 10]
# 847	['beta-FAPbI3', 'delta-FAPbI3', 'PbBr2']	3	[45 46 64]	[64 33 16]
# 848	['delta-CsPbI3', 'CsI', 'gamma-CsPbI3']	3	[18 37 38]	[33 64 16]
# 849	['Cs0.6MA0.4PbBr3', 'Cs4PbBr6', 'Cs0.8MA0.2PbBr3']	3	[10 11 16]	[16 32 17]
# 850	['Cs4PbBr6', 'orthorhombic-CsPbBr3', 'CsBr']	3	[16 17 33]	[33 17 16]
# 851	['orthorhombic-CsPbBr3', 'CsPb(Cl0.8Br0.2)3', 'cubic-CsPbBr3']	3	[23 32 33]	[32 59 11]
# 852	['beta-FAPbI3', 'alpha-MAPbI3', 'MA0.8FA0.2PbI3']	3	[45 54 62]	[47 64 43]
# 853	['delta-CsPbI3', 'CsPb(I0.6Cl0.4)3', 'alpha-CsPbI3']	3	[30 36 37]	[64 16 11]
# 854	['PbI2', 'CsPb(I0.2Cl0.8)3', 'CsI']	3	[18 28 65]	[18 65 36]
# 855	['gamma-CsPbI3', 'CsI', 'Pnma-CsPbCl3']	3	[18 34 38]	[33 59 64]
# 856	['Cs4PbBr6', 'CsPb2Br5', 'PbBr2']	3	[16 19 64]	[16 64 19]
# 857	['MAPb(Br0.4I0.6)3', 'tetragonal-MAPbI3', 'tetragonal-MAPbBr3']	3	[56 60 63]	[59 64  9]
# 858	['delta-FAPbI3', 'FAPb(Br0.4I0.6)3', 'PbI2']	3	[40 46 65]	[64 49 48]
# 859	['CsI', 'PbI2', 'gamma-CsPbI3']	3	[18 38 65]	[17 16 64]
# 860	['CsPb2Br5', 'PbBr2', 'CsBr']	3	[17 19 64]	[19 64 32]
# 861	['MA0.4FA0.6PbBr3', 'PbBr2', 'MA0.6FA0.4PbBr3']	3	[48 49 64]	[64 32 20]
# 862	['delta-FAPbI3', 'beta-FAPbI3', 'PbI2']	3	[45 46 65]	[46 45 65]
# 863	['CsBr', 'Cs4PbBr6', 'cubic-CsPbBr3']	3	[16 17 32]	[17 64 32]
# 864	['cubic-CsPbBr3', 'Cs4PbBr6', 'CsBr']	3	[16 17 32]	[16 64 17]
# 865	['CsPb(I0.6Cl0.4)3', 'Pnma-CsPbCl3', 'CsI']	3	[18 30 34]	[60 18 17]
# 866	['PbBr2', 'CsPb(I0.4Br0.6)3', 'gamma-CsPbI3']	3	[25 38 64]	[33 16 64]
# 867	['PbI2', 'delta-CsPbI3', 'CsI']	3	[18 37 65]	[64 59 60]
# 868	['alpha-CsPbI3', 'Pnma-CsPbCl3', 'CsI']	3	[18 34 36]	[ 8 60 10]
# 869	['PbI2', 'MA0.2FA0.8PbI3', 'beta-FAPbI3']	3	[45 51 65]	[64 63 16]
# 870	['CsBr', 'Cs0.4FA0.6PbBr3', 'CsPb2Br5']	3	[ 1 17 19]	[64 17  3]
# 871	['tetragonal-MAPbBr3', 'cubic-MAPbBr3', 'PbBr2']	3	[59 60 64]	[60 64 59]
# 872	['alpha-FAPbI3', 'Cs0.6FA0.4PbI3', 'delta-FAPbI3']	3	[ 6 44 46]	[28 64 29]
# 873	['CsPb2Br5', 'CsPb(Cl0.6Br0.4)3', 'cubic-CsPbBr3']	3	[19 22 32]	[19  8 59]
# 874	['alpha-MAPbI3', 'MAPb(Br0.8I0.2)3', 'tetragonal-MAPbI3']	3	[58 62 63]	[62 63 59]
# 875	['delta-CsPbI3', 'Cs0.4FA0.6PbI3', 'Cs0.2FA0.8PbI3']	3	[ 4  5 37]	[16 33 64]
# 876	['CsPb(Cl0.6Br0.4)3', 'cubic-CsPbCl3', 'Cs4PbBr6']	3	[16 22 35]	[19 22 21]
# 877	['delta-CsPbI3', 'Cs0.8MA0.2PbI3', 'gamma-CsPbI3']	3	[15 37 38]	[38 37 33]
# 878	['PbI2', 'delta-FAPbI3', 'beta-FAPbI3']	3	[45 46 65]	[64 32 19]
# 879	['CsPb(Cl0.6Br0.4)3', 'PbBr2', 'CsBr']	3	[17 22 64]	[19 60 17]
# 880	['delta-FAPbI3', 'alpha-FAPbI3', 'Cs0.6FA0.4PbI3']	3	[ 6 44 46]	[16 19  2]
# 881	['CsPb(I0.8Cl0.2)3', 'CsPb(I0.4Cl0.6)3', 'PbI2']	3	[29 31 65]	[11 32 59]
# 882	['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2']	3	[62 63 65]	[64 59 60]
# 883	['MA0.6FA0.4PbBr3', 'MA0.8FA0.2PbBr3', 'MA0.2FA0.8PbBr3']	3	[47 49 50]	[60 11  9]
# 884	['CsPb2Br5', 'orthorhombic-CsPbBr3', 'CsBr']	3	[17 19 33]	[64 33 19]
# 885	['alpha-FAPbI3', 'PbI2', 'beta-FAPbI3']	3	[44 45 65]	[44 65 45]
# 886	['tetragonal-MAPbI3', 'alpha-MAPbI3', 'PbI2']	3	[62 63 65]	[59 64 60]
# 887	['Pnma-CsPbCl3', 'cubic-CsPbBr3', 'orthorhombic-CsPbBr3']	3	[32 33 34]	[33 32 60]
# 888	['delta-CsPbI3', 'gamma-CsPbI3', 'CsPb(I0.6Cl0.4)3']	3	[30 37 38]	[37 34 38]
# 889	['delta-FAPbI3', 'beta-FAPbI3', 'PbI2']	3	[45 46 65]	[65 36 64]
# 890	['PbBr2', 'Cs4PbBr6', 'CsPb2Br5']	3	[16 19 64]	[64 19 16]
# 891	['cubic-CsPbBr3', 'Cs0.6MA0.4PbBr3', 'CsPb2Br5']	3	[10 19 32]	[32 64 33]
# 892	['alpha-FAPbI3', 'Cs0.4FA0.6PbI3', 'PbI2']	3	[ 5 44 65]	[65 37 38]
# 893	['tetragonal-MAPbI3', 'PbI2', 'alpha-MAPbI3']	3	[62 63 65]	[64 35 43]
# 894	['orthorhombic-CsPbBr3', 'Cs0.4FA0.6PbBr3', 'PbBr2']	3	[ 1 33 64]	[33 64 21]
# 895	['CsPb2Br5', 'CsBr', 'delta-CsPbI3']	3	[17 19 37]	[16 64 33]
# 896	['cubic-FAPbBr3', 'alpha-FAPbI3', 'PbI2']	3	[43 44 65]	[32 43 65]
# 897	['delta-CsPbI3', 'CsI', 'CsPb(I0.2Cl0.8)3']	3	[18 28 37]	[16 19 11]
# 898	['cubic-FAPbBr3', 'Cs0.8FA0.2PbBr3', 'cubic-CsPbBr3']	3	[ 3 32 43]	[32  3  1]
# 899	['beta-FAPbI3', 'delta-FAPbI3', 'FAPb(Br0.4I0.6)3']	3	[40 45 46]	[33 16 64]
# 900	['alpha-MAPbI3', 'tetragonal-MAPbI3', 'MA0.2FA0.8PbI3']	3	[51 62 63]	[59 33 64]
# 901	['PbBr2', 'CsPb(I0.2Br0.8)3', 'CsPb(I0.6Br0.4)3']	3	[24 26 64]	[64 65 18]
# 902	['MA0.6FA0.4PbBr3', 'MA0.8FA0.2PbBr3', 'MA0.4FA0.6PbBr3']	3	[48 49 50]	[49 60 48]
# 903	['cubic-CsPbBr3', 'orthorhombic-CsPbBr3', 'CsBr']	3	[17 32 33]	[17 33 32]
# 904	['CsPb2Br5', 'tetragonal-MAPbBr3', 'cubic-CsPbBr3']	3	[19 32 60]	[19  8 64]
# 905	['Cs0.2FA0.8PbI3', 'delta-CsPbI3', 'delta-FAPbI3']	3	[ 4 37 46]	[64 33 16]
# 906	['MA0.2FA0.8PbI3', 'delta-FAPbI3', 'MA0.6FA0.4PbI3']	3	[46 51 53]	[37 65 38]
# 907	['tetragonal-MAPbBr3', 'PbBr2', 'cubic-MAPbBr3']	3	[59 60 64]	[60 64 59]
# 908	['Cs0.4MA0.6PbI3', 'CsI', 'Cs0.2MA0.8PbI3']	3	[12 13 18]	[35 34 30]
# 909	['Cs0.8FA0.2PbI3', 'Cs0.6FA0.4PbI3', 'Cs0.4FA0.6PbI3']	3	[5 6 7]	[37 65 12]
# 910	['CsI', 'CsPb(I0.2Cl0.8)3', 'cubic-CsPbCl3']	3	[18 28 35]	[36 65 18]
# 911	['CsBr', 'Cs4PbBr6', 'Cs0.2MA0.8PbBr3']	3	[ 8 16 17]	[17 16  8]
# 912	['Cs4PbBr6', 'PbBr2', 'cubic-CsPbBr3']	3	[16 32 64]	[32 16 33]
# 913	['CsPb2Br5', 'orthorhombic-CsPbBr3', 'PbBr2']	3	[19 33 64]	[33 19 64]
# 914	['beta-FAPbI3', 'FAPb(Br0.4I0.6)3', 'FAPb(Br0.6I0.4)3']	3	[40 41 45]	[64 16 40]
# 915	['Cs4PbBr6', 'cubic-CsPbBr3', 'CsBr']	3	[16 17 32]	[17 64 16]
# 916	['CsBr', 'Cs0.6FA0.4PbBr3', 'orthorhombic-CsPbBr3']	3	[ 2 17 33]	[33 17  3]
# 917	['CsPb(Cl0.4Br0.6)3', 'cubic-CsPbCl3', 'PbBr2']	3	[21 35 64]	[64 21 22]
# 918	['PbBr2', 'cubic-FAPbBr3', 'Cs0.6FA0.4PbBr3']	3	[ 2 43 64]	[64 17 32]
# 919	['PbBr2', 'tetragonal-MAPbBr3', 'cubic-MAPbBr3']	3	[59 60 64]	[60 64 59]
# 920	['beta-FAPbI3', 'PbI2', 'delta-FAPbI3']	3	[45 46 65]	[65 36 38]
# 921	['CsBr', 'cubic-CsPbBr3', 'cubic-CsPbCl3']	3	[17 32 35]	[17 10 32]
# 922	['CsI', 'delta-CsPbI3', 'alpha-CsPbI3']	3	[18 36 37]	[18 37 38]
# 923	['alpha-FAPbI3', 'gamma-CsPbI3', 'beta-FAPbI3']	3	[38 44 45]	[16 33 19]
# 924	['PbI2', 'delta-FAPbI3', 'alpha-FAPbI3']	3	[44 46 65]	[46 44 65]
# 925	['MAPb(Br0.6I0.4)3', 'PbI2', 'PbBr2']	3	[57 64 65]	[64 10 11]
# 926	['Pnma-CsPbCl3', 'CsPb(I0.2Cl0.8)3', 'alpha-CsPbI3']	3	[28 34 36]	[65 36 15]
# 927	['gamma-CsPbI3', 'Cs0.2MA0.8PbI3', 'Cs0.4MA0.6PbI3']	3	[12 13 38]	[38 13 14]
# 928	['Cs0.2FA0.8PbBr3', 'cubic-CsPbBr3', 'Cs0.8FA0.2PbBr3']	3	[ 0  3 32]	[32 19 43]
# 929	['orthorhombic-CsPbBr3', 'CsPb(Cl0.2Br0.8)3', 'Pnma-CsPbCl3']	3	[20 33 34]	[33 10 17]
# 930	['FAPb(Br0.8I0.2)3', 'FAPb(Br0.4I0.6)3', 'delta-FAPbI3']	3	[40 42 46]	[46 41 40]
# 931	['CsI', 'gamma-CsPbI3', 'tetragonal-MAPbI3']	3	[18 38 63]	[38 36 63]
# 932	['alpha-CsPbI3', 'CsPb(I0.6Cl0.4)3', 'CsPb(I0.4Cl0.6)3']	3	[29 30 36]	[30 29 28]
# 933	['PbI2', 'delta-FAPbI3', 'alpha-FAPbI3']	3	[44 46 65]	[64 60 59]
# 934	['MA0.4FA0.6PbI3', 'PbI2', 'MA0.8FA0.2PbI3']	3	[52 54 65]	[52 44 65]
# 935	['Cs0.6MA0.4PbI3', 'Cs0.2MA0.8PbI3', 'tetragonal-MAPbI3']	3	[12 14 63]	[63 12 62]
# 936	['MAPb(Br0.6I0.4)3', 'PbI2', 'tetragonal-MAPbI3']	3	[57 63 65]	[32 19  1]
# 937	['cubic-CsPbBr3', 'CsPb(I0.2Br0.8)3', 'CsBr']	3	[17 24 32]	[32 60 17]
# 938	['Cs0.8MA0.2PbI3', 'CsI', 'alpha-CsPbI3']	3	[15 18 36]	[59 60 17]
# 939	['MA0.4FA0.6PbI3', 'tetragonal-MAPbI3', 'alpha-MAPbI3']	3	[52 62 63]	[64 19 11]
# 940	['cubic-FAPbBr3', 'tetragonal-MAPbBr3', 'MA0.2FA0.8PbBr3']	3	[43 47 60]	[59 60 32]
# 941	['tetragonal-MAPbBr3', 'PbBr2', 'CsPb2Br5']	3	[19 60 64]	[19 64 11]
# 942	['Cs0.2FA0.8PbI3', 'PbI2', 'alpha-FAPbI3']	3	[ 4 44 65]	[64 16 22]
# 943	['PbI2', 'FAPb(Br0.4I0.6)3', 'FAPb(Br0.6I0.4)3']	3	[40 41 65]	[64 16 19]
# 944	['cubic-MAPbBr3', 'tetragonal-MAPbBr3', 'PbBr2']	3	[59 60 64]	[64 43 34]
# 945	['gamma-CsPbI3', 'Cs0.2FA0.8PbI3', 'delta-CsPbI3']	3	[ 4 37 38]	[33 64 16]
# 946	['MAPb(Br0.6I0.4)3', 'tetragonal-MAPbBr3', 'alpha-MAPbI3']	3	[57 60 62]	[59 60 64]
# 947	['PbBr2', 'FAPb(Br0.4I0.6)3', 'beta-FAPbI3']	3	[40 45 64]	[64 16 33]
# 948	['PbBr2', 'MA0.4FA0.6PbBr3', 'cubic-FAPbBr3']	3	[43 48 64]	[64 43 32]
# 949	['FAPb(Br0.6I0.4)3', 'PbBr2', 'beta-FAPbI3']	3	[41 45 64]	[64 16 37]
# 950	['CsBr', 'CsPb(I0.2Br0.8)3', 'Cs4PbBr6']	3	[16 17 24]	[16 59 17]
# 951	['PbBr2', 'MAPb(Br0.4I0.6)3', 'MAPb(Br0.2I0.8)3']	3	[55 56 64]	[64 16 25]
# 952	['beta-FAPbI3', 'delta-FAPbI3', 'PbI2']	3	[45 46 65]	[43 64 60]
# 953	['PbI2', 'delta-CsPbI3', 'alpha-CsPbI3']	3	[36 37 65]	[19 16 33]
# 954	['CsPb(Cl0.6Br0.4)3', 'orthorhombic-CsPbBr3', 'CsPb2Br5']	3	[19 22 33]	[33 19 64]
# 955	['Cs0.6MA0.4PbI3', 'tetragonal-MAPbI3', 'Cs0.4MA0.6PbI3']	3	[13 14 63]	[32  3  0]
# 956	['PbI2', 'alpha-FAPbI3', 'beta-FAPbI3']	3	[44 45 65]	[64 60 59]
# 957	['PbI2', 'alpha-FAPbI3', 'beta-FAPbI3']	3	[44 45 65]	[65 45 18]
# 958	['PbBr2', 'cubic-CsPbBr3', 'CsPb2Br5']	3	[19 32 64]	[64 33 32]
# 959	['cubic-FAPbBr3', 'MA0.8FA0.2PbBr3', 'PbBr2']	3	[43 50 64]	[59 64 60]
# 960	['cubic-CsPbBr3', 'CsPb2Br5', 'CsBr']	3	[17 19 32]	[17 32 19]
# 961	['alpha-FAPbI3', 'FAPb(Br0.8I0.2)3', 'FAPb(Br0.6I0.4)3']	3	[41 42 44]	[19 16 64]
# 962	['tetragonal-MAPbBr3', 'MAPb(Br0.4I0.6)3', 'MAPb(Br0.8I0.2)3']	3	[56 58 60]	[63 36 18]
# 963	['alpha-CsPbI3', 'CsI', 'PbI2']	3	[18 36 65]	[32 17 19]
# 964	['beta-FAPbI3', 'Cs0.4FA0.6PbI3', 'delta-CsPbI3']	3	[ 5 37 45]	[ 5 45  6]
# 965	['CsPb(I0.8Br0.2)3', 'CsPb(I0.2Br0.8)3', 'CsPb(I0.4Br0.6)3']	3	[24 25 27]	[65 36 15]
# 966	['cubic-MAPbBr3', 'PbBr2', 'tetragonal-MAPbBr3']	3	[59 60 64]	[64 60 59]
# 967	['MA0.2FA0.8PbBr3', 'cubic-MAPbBr3', 'tetragonal-MAPbBr3']	3	[47 59 60]	[59 60  9]
# 968	['CsBr', 'Cs4PbBr6', 'CsPb2Br5']	3	[16 17 19]	[19 16 17]
# 969	['Cs0.6MA0.4PbI3', 'alpha-MAPbI3', 'tetragonal-MAPbI3']	3	[14 62 63]	[63 13 12]
# 970	['cubic-MAPbBr3', 'MA0.6FA0.4PbBr3', 'tetragonal-MAPbBr3']	3	[49 59 60]	[59  9 11]
# 971	['CsBr', 'Pnma-CsPbCl3', 'CsPb2Br5']	3	[17 19 34]	[34 64 17]
# 972	['Cs0.4MA0.6PbBr3', 'CsBr', 'orthorhombic-CsPbBr3']	3	[ 9 17 33]	[33 43 59]
# 973	['FAPb(Br0.8I0.2)3', 'PbBr2', 'delta-FAPbI3']	3	[42 46 64]	[30 35 37]
# 974	['PbI2', 'Cs0.6MA0.4PbI3', 'Cs0.4MA0.6PbI3']	3	[13 14 65]	[59 47 60]
# 975	['tetragonal-MAPbBr3', 'MA0.4FA0.6PbBr3', 'MA0.2FA0.8PbBr3']	3	[47 48 60]	[60 59 58]
# 976	['Cs0.6MA0.4PbBr3', 'Cs0.8MA0.2PbBr3', 'orthorhombic-CsPbBr3']	3	[10 11 33]	[33 11 10]
# 977	['Cs0.6MA0.4PbI3', 'alpha-MAPbI3', 'Cs0.2MA0.8PbI3']	3	[12 14 62]	[43 47 48]
# 978	['orthorhombic-CsPbBr3', 'cubic-MAPbBr3', 'cubic-CsPbBr3']	3	[32 33 59]	[33 32 59]
# 979	['CsPb(I0.4Br0.6)3', 'alpha-CsPbI3', 'CsPb(I0.6Br0.4)3']	3	[25 26 36]	[19 32 64]
# 980	['FAPb(Br0.6I0.4)3', 'alpha-FAPbI3', 'delta-FAPbI3']	3	[41 44 46]	[19 64 16]
# 981	['CsPb(I0.2Cl0.8)3', 'CsPb(I0.8Cl0.2)3', 'CsPb(I0.4Cl0.6)3']	3	[28 29 31]	[65 31 29]
# 982	['FAPb(Br0.2I0.8)3', 'FAPb(Br0.6I0.4)3', 'cubic-FAPbBr3']	3	[39 41 43]	[37 38 19]
# 983	['delta-CsPbI3', 'alpha-MAPbI3', 'PbI2']	3	[37 62 65]	[16 64 11]
# 984	['CsBr', 'CsPb(I0.8Br0.2)3', 'CsPb(I0.4Br0.6)3']	3	[17 25 27]	[27 17 25]
# 985	['delta-FAPbI3', 'FAPb(Br0.6I0.4)3', 'PbI2']	3	[41 46 65]	[64  1  2]
# 986	['alpha-CsPbI3', 'Cs0.8MA0.2PbI3', 'Cs0.2MA0.8PbI3']	3	[12 15 36]	[59 60 49]
# 987	['Cs0.4MA0.6PbBr3', 'cubic-CsPbBr3', 'orthorhombic-CsPbBr3']	3	[ 9 32 33]	[33 60  9]
# 988	['PbI2', 'beta-FAPbI3', 'alpha-FAPbI3']	3	[44 45 65]	[64 43 60]
# 989	['delta-CsPbI3', 'CsPb(I0.2Br0.8)3', 'cubic-CsPbBr3']	3	[24 32 37]	[16 19 32]
# 990	['PbI2', 'MAPb(Br0.2I0.8)3', 'MAPb(Br0.6I0.4)3']	3	[55 57 65]	[19 65 32]
# 991	['MAPb(Br0.8I0.2)3', 'MAPb(Br0.2I0.8)3', 'tetragonal-MAPbBr3']	3	[55 58 60]	[59 65 43]
# 992	['cubic-MAPbBr3', 'tetragonal-MAPbI3', 'MAPb(Br0.8I0.2)3']	3	[58 59 63]	[59 64 10]
# 993	['alpha-MAPbI3', 'PbBr2', 'MAPb(Br0.2I0.8)3']	3	[55 62 64]	[64 62 65]
# 994	['cubic-FAPbBr3', 'alpha-FAPbI3', 'PbI2']	3	[43 44 65]	[59 60 10]
# 995	['CsBr', 'CsPb2Br5', 'orthorhombic-CsPbBr3']	3	[17 19 33]	[19 33 17]
# 996	['beta-FAPbI3', 'PbI2', 'delta-FAPbI3']	3	[45 46 65]	[17 16 32]
# 997	['Cs0.2FA0.8PbBr3', 'CsPb2Br5', 'cubic-FAPbBr3']	3	[ 0 19 43]	[43 19 32]
# 998	['delta-FAPbI3', 'beta-FAPbI3', 'CsI']	3	[18 45 46]	[43 33 64]
# 999	['Cs0.6FA0.4PbBr3', 'Cs0.4FA0.6PbBr3', 'Cs0.8FA0.2PbBr3']	3	[1 2 3]	[2 1 3]

# %%
for prompt_type in prompt_type_list:
    print(prompt_type)
    for i in [1,2,3]:
        phase_pred = np.array(full_result[prompt_type][str(i)]['phase_pred'])
        phase_true = np.array(full_result[prompt_type][str(i)]['phase_true'])
        phase_acc = np.array(full_result[prompt_type][str(i)]['phase_acc'])
        phase_acc_full = 1-np.sum(phase_acc)/phase_acc.shape[0]
        n_pred = np.array(full_result[prompt_type][str(i)]['n_pred'])
        n_true = np.array(full_result[prompt_type][str(i)]['n_true'])
        n_acc = np.array(full_result[prompt_type][str(i)]['n_acc'])
        n_acc_full = 1-np.sum(n_acc)/n_acc.shape[0]
        print(i, coverage_error(phase_true, phase_pred), phase_acc_full, n_acc_full)
# Out:
# full
# 1 9.335 0.367 1.0
# 2 11.669 0.29800000000000004 1.0
# 3 16.628 0.20099999999999996 1.0

# %% [markdown]
# # 4 Attention

# %%
for i in range(20):
# for i in [9]:

    Xs_test = Xs[i:i+1,:-1,:].reshape((1,int(Xs.shape[1]/visual_embedding_dim),visual_embedding_dim))

    X_prompts = []
    random.shuffle(element_list[i])
    X_prompts.append(' '.join(element_list[i]))

    visual_embeds = torch.from_numpy(Xs_test).to(dtype=torch.float32)
    visual_attention_mask = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)
    visual_token_type_ids = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)

    inputs = tokenizer(X_prompts, return_tensors="pt", padding=True)
    inputs.update(
        {
            "visual_embeds": visual_embeds,
            "visual_token_type_ids": visual_token_type_ids,
            "visual_attention_mask": visual_attention_mask,
        }
    )

    labels = torch.from_numpy(np.array(Ys[i:i+1])).to(dtype=torch.float32)

    outputs = model(**inputs.to('cuda'), output_attentions=True, labels=labels.to('cuda'))

    
    Y = np.array(outputs.attentions[0].detach().cpu())[0,0,1:len(inputs['input_ids'][0])-1,len(inputs['input_ids'][0]):]

    load_plt_setting()

    fig, (ax0, ax1) = plt.subplots(2,1, sharex=True, gridspec_kw=dict(height_ratios=[1, 1]),figsize=(12, 4.5))

    ax0.plot(np.arange(5.00, 60.01, 0.01)[:-1], Xs_test.reshape(-1), color=colors.to_rgba('#118ab2'))
    ax0.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
    ax0.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax0.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=1, steps=[1, 2, 5, 10]))
#     ax0.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax0.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax0.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax0.axes.set_ylim([-0.05,1.25])
    ax0.set_ylabel(f'XRD', labelpad=20, fontsize=32)
    
    ax1.plot(np.arange(5.00, 60.01, 0.01*20)[:-1], np.sum(Y, axis=0)/np.max(np.sum(Y, axis=0)), color=colors.to_rgba('#fb6f6f'))
    ax1.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
    ax1.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax1.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax1.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax1.axes.set_xlim([5,60])
    ax1.axes.set_ylim([-0.05,1.25])

    ax1.set_xlabel(r'2$\Theta$ (degree)', labelpad=15, fontsize=32)
    ax1.set_ylabel(f'Text-XRD\nattention', labelpad=20, fontsize=32)

#     plt.text(0.95, 0.64, r'$\gamma$'+'-'+r'CsPbI$_{3}$', fontsize=28, transform=ax0.transAxes, color='#000000', horizontalalignment='right')
    plt.text(0.95, 0.64, re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula_list[i][0]), fontsize=28, transform=ax0.transAxes, color='#000000', horizontalalignment='right')
    plt.text(0.95, 0.64, '"'+X_prompts[0]+'" label', fontsize=28, transform=ax1.transAxes, color='#000000', horizontalalignment='right')

    plt.subplots_adjust(hspace=.0)
    plt.savefig(os.path.join(folder, 'models',model_folder,'{}.png'.format(formula_list[i][0])), 
                format='png', dpi=300, transparent=True, bbox_inches='tight')

# %%
twotheta = np.arange(5.00, 60.01, 0.01)[:-1]

for i in range(30):

    Xs_test = Xs[i:i+1,:-1,:].reshape((1,int(Xs.shape[1]/visual_embedding_dim),visual_embedding_dim))

    X_prompts = []
    random.shuffle(element_list[i])
    X_prompts.append(' '.join(element_list[i]))

    visual_embeds = torch.from_numpy(Xs_test).to(dtype=torch.float32)
    visual_attention_mask = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)
    visual_token_type_ids = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)

    inputs = tokenizer(X_prompts, return_tensors="pt", padding=True)
    inputs.update(
        {
            "visual_embeds": visual_embeds,
            "visual_token_type_ids": visual_token_type_ids,
            "visual_attention_mask": visual_attention_mask,
        }
    )

    labels = torch.from_numpy(np.array(Ys[i:i+1])).to(dtype=torch.float32)

    outputs = model(**inputs.to('cuda'), output_attentions=True, labels=labels.to('cuda'))
    
    
    Y = np.array(outputs.attentions[0].detach().cpu())[0,0,1:len(inputs['input_ids'][0])-1,len(inputs['input_ids'][0]):]
    extent = [0.5,0.5+len(inputs['input_ids'][0])-2,twotheta[0],twotheta[-1]]

    load_plt_setting()

    fig, ax = plt.subplots(figsize=(12, 10))

    mat = ax.matshow(np.rot90(Y), extent=extent, aspect=(extent[1]-extent[0])/(extent[3]-extent[2]), cmap='viridis', vmin=0)
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticklabels(['',]+tokenizer.convert_ids_to_tokens(inputs.input_ids[0])[1:-1], rotation=35)
    ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=len(inputs['input_ids'][0])-2, steps=[1, 2, 5, 10]))
#     ax.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
    ax.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax.tick_params(axis='both',direction='out',length=8,width=2,pad=10,color='black',labelsize=28)
    ax.tick_params(axis='both',which='minor',direction='out',length=4,width=2,pad=10,color='black',labelsize=28)
    ax.axes.set_xlim([0.5,0.5+len(inputs['input_ids'][0])-2])
    ax.axes.set_ylim([5,60])

    cbar = plt.colorbar(mat)
    cbar.ax.tick_params(axis='y', direction='out',length=8,width=3,pad=5,labelsize=26)
    cbar.ax.set_ylabel('Text-XRD attention (a.u.)',labelpad=50, rotation=-90)
    cbar.ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=4, integer=True, steps=[1, 2, 5, 10]))
    cbar.ax.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    cbar.ax.tick_params(axis='both',which='minor',direction='out',length=4,width=3,pad=5)

    ax.set_xlabel(r'Text label', labelpad=20, fontsize=34)
    ax.set_ylabel(r'2$\Theta$ (degree)', labelpad=20, fontsize=34)
    plt.text(0.95, 0.91, re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula_list[i][0]), 
             fontsize=28, transform=ax.transAxes, color='#FFFFFF', horizontalalignment='right')

    plt.savefig(os.path.join(folder, 'models', model_folder,'{}_attention.png'.format(formula_list[i][0])), 
                format='png', dpi=300, transparent=True, bbox_inches='tight')

# %%
for i in range(30):

    Xs_test = Xs[i:i+1,:-1,:].reshape((1,int(Xs.shape[1]/visual_embedding_dim),visual_embedding_dim))

    X_prompts = []
    random.shuffle(element_list[i])
    X_prompts.append(' '.join(element_list[i]))

    visual_embeds = torch.from_numpy(Xs_test).to(dtype=torch.float32)
    visual_attention_mask = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)
    visual_token_type_ids = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)

    inputs = tokenizer(X_prompts, return_tensors="pt", padding=True)
    inputs.update(
        {
            "visual_embeds": visual_embeds,
            "visual_token_type_ids": visual_token_type_ids,
            "visual_attention_mask": visual_attention_mask,
        }
    )

    labels = torch.from_numpy(np.array(Ys[i:i+1])).to(dtype=torch.float32)

    outputs = model(**inputs.to('cuda'), output_attentions=True, labels=labels.to('cuda'))
    
    Y = np.sum(np.array(outputs.attentions[0].detach().cpu())[0,:,1:len(inputs['input_ids'][0])-1,1:len(inputs['input_ids'][0])-1],axis=0)
    extent = [0.5,0.5+len(inputs['input_ids'][0])-2,0.5,0.5+len(inputs['input_ids'][0])-2]

    load_plt_setting()

    fig, ax = plt.subplots(figsize=(12, 10))

    mat = ax.matshow(np.rot90(Y), extent=extent, aspect=(extent[1]-extent[0])/(extent[3]-extent[2]), cmap='hot', vmin=0)
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticklabels(['',]+tokenizer.convert_ids_to_tokens(inputs.input_ids[0])[1:-1], rotation=35)
    ax.set_yticklabels(['',]+tokenizer.convert_ids_to_tokens(inputs.input_ids[0])[1:-1])
    ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=len(inputs['input_ids'][0])-2, steps=[1, 2, 5, 10]))
    ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=len(inputs['input_ids'][0])-2, steps=[1, 2, 5, 10]))
    ax.tick_params(axis='both',direction='out',length=8,width=2,pad=10,color='black',labelsize=28)
    ax.tick_params(axis='both',which='minor',direction='out',length=4,width=2,pad=10,color='black',labelsize=28)

    cbar = plt.colorbar(mat)
    cbar.ax.tick_params(axis='y', direction='out',length=8,width=3,pad=5,labelsize=26)
    cbar.ax.set_ylabel('Text-text attention (a.u.)',labelpad=50, rotation=-90)
    cbar.ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=4, integer=True, steps=[1, 2, 5, 10]))
    cbar.ax.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    cbar.ax.tick_params(axis='both',which='minor',direction='out',length=4,width=3,pad=5)

    ax.set_xlabel(r'Text input', labelpad=20, fontsize=34)
    ax.set_ylabel(r'Text input', labelpad=20, fontsize=34)

    plt.text(0.95, 0.91, re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula_list[i][0]), 
             fontsize=28, transform=ax.transAxes, color='#FFFFFF', horizontalalignment='right')
    
    plt.savefig(os.path.join(folder, 'models', model_folder,'{}_attention_text.png'.format(formula_list[i][0])), 
                format='png', dpi=300, transparent=True, bbox_inches='tight')

# %%
tokenizer.convert_ids_to_tokens(inputs.input_ids[0])
# Out:
# ['[CLS]', 'pb', 'fa', 'br', 'i', '[SEP]']

# %% [markdown]
# # 5 Experimental single phase

# %%
model_folder = '20240906 single phase'
# model_folder = '20240921 single phase diverse prompt embedding 20'
visual_embedding_dim = 20
model = VisualBertForQuestionAnswering.from_pretrained(os.path.join(folder, 'models', model_folder,'100000')).to('cuda')

# %%
# data = np.genfromtxt(r'G:\Materials\MIT\=Projects\XRD\20240516 OT\CsPbBr\4 CsPb1Br3_Theta_2-Theta_fit.xy', delimiter=" ", unpack=False)
# data = np.genfromtxt(r'G:\Materials\MIT\=Projects\XRD\20240516 OT\CsPbBr\1 CsPb2Br5_Theta_2-Theta_fit.xy', delimiter=" ", unpack=False)

data = np.genfromtxt(r'G:\Materials\MIT\=Projects\XRD\20240516 OT\CsPbBr\0 Cs2Pb5Br12_Theta_2-Theta.xy', delimiter=" ", unpack=False)

twotheta = np.arange(5.00, 60.01, 0.01)
X = data[:,1]
X = (X-np.min(X))/(np.max(X)-np.min(X))
Xs = np.zeros(twotheta.shape)
Xs[-X.shape[0]:] = X
Xs = np.expand_dims(Xs,axis=(0,-1))

plt.plot(Xs[0,:,0])

# %%
y_true, y_pred, y_formula = [], [], []

Xs_test = Xs[0,:-1,:].reshape((1,int(Xs.shape[1]/visual_embedding_dim),visual_embedding_dim))

X_prompts = ['FA Pb I',]

visual_embeds = torch.from_numpy(Xs_test).to(dtype=torch.float32)
visual_attention_mask = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)
visual_token_type_ids = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)

inputs = tokenizer(X_prompts, return_tensors="pt", padding=True)
inputs.update(
    {
        "visual_embeds": visual_embeds,
        "visual_token_type_ids": visual_token_type_ids,
        "visual_attention_mask": visual_attention_mask,
    }
)

outputs = model(**inputs.to('cuda'), output_attentions=True)
logits = torch.topk(outputs.logits[0], 1).indices
y_pred = list(np.array(logits.detach().cpu()))

# %%
softmax = torch.nn.Softmax(dim=1)

# %%
for idx in y_pred:
    print(idx, np.array(softmax(outputs.logits)[0,idx].detach().cpu()), dataloader.dataset[dataloader.sample_list[idx]]['formula'])

# %%
twotheta = np.arange(5.00, 60.01, 0.01)[:-1]

for i in range(1):

    Xs_test = Xs[i:i+1,:-1,:].reshape((1,int(Xs.shape[1]/visual_embedding_dim),visual_embedding_dim))
    
    XRD_token_length = -Xs_test.shape[1]
    X_prompts = ['FA Pb I',]
    
    visual_embeds = torch.from_numpy(Xs_test).to(dtype=torch.float32)
    visual_attention_mask = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)
    visual_token_type_ids = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)

    inputs = tokenizer(X_prompts, return_tensors="pt", padding=True)
    prompt_token_length = len(inputs['input_ids'][0])
    inputs.update(
        {
            "visual_embeds": visual_embeds,
            "visual_token_type_ids": visual_token_type_ids,
            "visual_attention_mask": visual_attention_mask,
        }
    )

    outputs = model(**inputs.to('cuda'), output_attentions=True)
    pred_index = np.array(torch.topk(outputs.logits[0], 1).indices.detach().cpu())[0]
    formula = dataloader.dataset[dataloader.sample_list[pred_index]]['formula']
    
    Y = np.zeros((outputs.attentions[0].shape[-1],outputs.attentions[0].shape[-1]-prompt_token_length))

    for attention_head in outputs.attentions:
        Y += np.array(attention_head.detach().cpu())[0,0,:,prompt_token_length:]
    
    load_plt_setting()

    fig, (ax0, ax1, ax2) = plt.subplots(3,1, sharex=True, gridspec_kw=dict(height_ratios=[2,1,1]),figsize=(12, 10))

    ax0.plot(twotheta, Xs_test.reshape(-1), color=colors.to_rgba('#118ab2'))
    ax0.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
    ax0.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax0.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
    ax0.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax0.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax0.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax0.axes.set_ylim([-0.05,1.1])
    ax0.set_ylabel(f'Norm.\nintensity', labelpad=20, fontsize=34)
    
    ax1.plot(np.arange(5.00, 60.01, 0.01*20)[:-1], np.mean(Y, axis=0)/np.max(np.mean(Y, axis=0)), color=colors.to_rgba('#ffd166'))
    ax1.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
    ax1.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax1.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax1.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax1.set_ylabel(f'Norm.\nattention', labelpad=20, fontsize=34)
    ax1.axes.set_ylim([-0.05,1.2])

    ax2.plot(twotheta, dataloader.load_ref(pred_index)[:-1], color=colors.to_rgba('#fb6f6f'))
#     ax2.plot(twotheta, dataloader.load_ref(19)[:-1], color=colors.to_rgba('#fb6f6f'))
    ax2.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
    ax2.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax2.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax2.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax2.axes.set_ylim([-0.05,1.2])
    ax2.axes.set_xlim([5,60])

    ax2.set_xlabel(r'2$\Theta$ (degree)', labelpad=20, fontsize=34)
    ax2.set_ylabel(f'Norm.\nintensity', labelpad=20, fontsize=34)
    plt.text(0.03, 0.85, 'Experimental', fontsize=30, transform=ax0.transAxes, color='#000000', horizontalalignment='left')
    plt.text(0.96, 0.85, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', 'FAPbI3')), fontsize=30, transform=ax0.transAxes, color='#000000', horizontalalignment='right')
    plt.text(0.03, 0.72, 'Prediction', fontsize=30, transform=ax1.transAxes, color='#000000', horizontalalignment='left')
    plt.text(0.96, 0.72, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula)), fontsize=30, transform=ax1.transAxes, color='#000000', horizontalalignment='right')
    plt.text(0.03, 0.72, 'Reference', fontsize=30, transform=ax2.transAxes, color='#000000', horizontalalignment='left')
    plt.text(0.96, 0.72, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula)), fontsize=30, transform=ax2.transAxes, color='#000000', horizontalalignment='right')

    plt.subplots_adjust(hspace=.0)
    plt.savefig(os.path.join(folder, 'models', model_folder,'Exp {}.png'.format(formula)), format='png', dpi=300, transparent=True, bbox_inches='tight')
#     plt.savefig(folder+r"\SelfAttention_{}_linear.png".format(i), format='png', dpi=300, transparent=True, bbox_inches='tight')

# %%
# data = np.genfromtxt(r'G:\Materials\MIT\=Projects\XRD\20240912 Chem-XRD ViT\Air_3.csv', delimiter=",", unpack=False)
data = np.genfromtxt(r'G:\Materials\MIT\=Projects\XRD\20240912 Chem-XRD ViT\Air_3_fit.xy', delimiter=" ", unpack=False)

twotheta = np.arange(5.00, 60.01, 0.01)
X = CubicSpline(data[:,0], data[:,1]-data[:,4])(np.arange(5.00, 45.01, 0.01))
X = (X-np.min(X))/(np.max(X)-np.min(X))
Xs = np.zeros(twotheta.shape)
Xs[:X.shape[0]] = X
Xs = np.expand_dims(Xs,axis=(0,-1))

plt.plot(twotheta,Xs[0,:,0])

# %%
data = np.genfromtxt(r'G:\Materials\MIT\=Projects\XRD\20240912 Chem-XRD ViT\GB_3.csv', delimiter=",", unpack=False)
# data = np.genfromtxt(r'G:\Materials\MIT\=Projects\XRD\20240912 Chem-XRD ViT\Air_3_fit.xy', delimiter=" ", unpack=False)

twotheta = np.arange(5.00, 60.01, 0.01)
X = CubicSpline(data[:,0], data[:,1])(np.arange(5.00, 45.01, 0.01))
X = (X-np.min(X))/(np.max(X)-np.min(X))
Xs = np.zeros(twotheta.shape)
Xs[:X.shape[0]] = X
Xs = np.expand_dims(Xs,axis=(0,-1))

plt.plot(Xs[0,:,0])

# %%
y_true, y_pred, y_formula = [], [], []

Xs_test = Xs[0,:-1,:].reshape((1,int(Xs.shape[1]/visual_embedding_dim),visual_embedding_dim))

X_prompts = ['FA Pb I',]

visual_embeds = torch.from_numpy(Xs_test).to(dtype=torch.float32)
visual_attention_mask = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)
visual_token_type_ids = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)

inputs = tokenizer(X_prompts, return_tensors="pt", padding=True)
inputs.update(
    {
        "visual_embeds": visual_embeds,
        "visual_token_type_ids": visual_token_type_ids,
        "visual_attention_mask": visual_attention_mask,
    }
)

outputs = model(**inputs.to('cuda'), output_attentions=True)
logits = torch.topk(outputs.logits[0], 20).indices
y_pred = list(np.array(logits.detach().cpu()))

# %%
for idx in y_pred:
    print(idx, dataloader.dataset[dataloader.sample_list[idx]]['formula'],np.array(outputs.logits[0].detach().cpu())[idx])
# Out:
# 44 alpha-FAPbI3 9.33871
# 46 delta-FAPbI3 8.099103
# 60 tetragonal-MAPbBr3 2.465374
# 4 Cs0.2FA0.8PbI3 2.0282676
# 65 PbI2 1.7740173
# 62 alpha-MAPbI3 1.7330676
# 7 Cs0.8FA0.2PbI3 1.3109987
# 32 cubic-CsPbBr3 1.1496482
# 45 beta-FAPbI3 1.0594403
# 2 Cs0.6FA0.4PbBr3 0.9458855
# 54 MA0.8FA0.2PbI3 0.91527843
# 16 Cs4PbBr6 0.85488844
# 42 FAPb(Br0.8I0.2)3 0.83029073
# 29 CsPb(I0.4Cl0.6)3 0.7844297
# 3 Cs0.8FA0.2PbBr3 0.742192
# 39 FAPb(Br0.2I0.8)3 0.70042056
# 34 Pnma-CsPbCl3 0.59099156
# 20 CsPb(Cl0.2Br0.8)3 0.56310356
# 50 MA0.8FA0.2PbBr3 0.515597
# 27 CsPb(I0.8Br0.2)3 0.5009957

# %% [markdown]
# ## MAPbBr3

# %%
data = np.genfromtxt(r'G:\Materials\MIT\=Projects\XRD\20240926 MAPbI-MAPbBr XRD\MAPbBr3_Theta_2-Theta.xy', 
                     delimiter=" ", unpack=False)

twotheta = np.arange(5.00, 60.01, 0.01)
twotheta_corrected = np.arange(5.00, 70.01, 0.01)
X = np.zeros(twotheta_corrected.shape)
X[:len(data[:,1])] = data[:,1]
sample_height_displacement = -0.003458*1000

for i in range(len(twotheta_corrected)):
    twotheta_corrected[i] += math.degrees(math.atan(sample_height_displacement*math.sin(math.radians(2*twotheta_corrected[i]))/
                    (2*(110+sample_height_displacement*(math.radians(twotheta_corrected[i]))**2))))
print(twotheta_corrected)

X = interp1d(twotheta_corrected, X)(twotheta)
X = (X-np.min(X))/(np.max(X)-np.min(X))
Xs = np.zeros(twotheta.shape)
Xs[-X.shape[0]:] = X
Xs = np.expand_dims(Xs,axis=(0,-1))

plt.plot(Xs[0,:,0])
# Out:
# [ 4.84357791  4.85326811  4.86295833 ... 69.37214935 69.38239333
#  69.39263739]

# %%
twotheta = np.arange(5.00, 60.01, 0.01)[:-1]

for i in range(1):

    Xs_test = Xs[i:i+1,:-1,:].reshape((1,int(Xs.shape[1]/visual_embedding_dim),visual_embedding_dim))
    
    XRD_token_length = -Xs_test.shape[1]
    X_prompts = ['MA Pb Br',]
    
    visual_embeds = torch.from_numpy(Xs_test).to(dtype=torch.float32)
    visual_attention_mask = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)
    visual_token_type_ids = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)

    inputs = tokenizer(X_prompts, return_tensors="pt", padding=True)
    prompt_token_length = len(inputs['input_ids'][0])
    inputs.update(
        {
            "visual_embeds": visual_embeds,
            "visual_token_type_ids": visual_token_type_ids,
            "visual_attention_mask": visual_attention_mask,
        }
    )

    outputs = model(**inputs.to('cuda'), output_attentions=True)
    pred_index = np.array(torch.topk(outputs.logits[0], 1).indices.detach().cpu())[0]
    formula = dataloader.dataset[dataloader.sample_list[pred_index]]['formula']
    
    Y = np.zeros((outputs.attentions[0].shape[-1],outputs.attentions[0].shape[-1]-prompt_token_length))

    for attention_head in outputs.attentions:
        Y += np.array(attention_head.detach().cpu())[0,0,:,prompt_token_length:]
    
    load_plt_setting()

    fig, (ax0, ax1, ax2) = plt.subplots(3,1, sharex=True, gridspec_kw=dict(height_ratios=[2,1,1]),figsize=(12, 10))

    ax0.plot(twotheta, Xs_test.reshape(-1), color=colors.to_rgba('#118ab2'))
    ax0.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
    ax0.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax0.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
    ax0.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax0.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax0.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax0.axes.set_ylim([-0.05,1.1])
    ax0.set_ylabel(f'Norm.\nintensity', labelpad=20, fontsize=34)
    
    ax1.plot(np.arange(5.00, 60.01, 0.01*20)[:-1], np.mean(Y, axis=0)/np.max(np.mean(Y, axis=0)), color=colors.to_rgba('#ffd166'))
    ax1.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
    ax1.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax1.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax1.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax1.set_ylabel(f'Norm.\nattention', labelpad=20, fontsize=34)
    ax1.axes.set_ylim([-0.05,1.2])

    ax2.plot(twotheta, dataloader.load_ref(pred_index)[:-1], color=colors.to_rgba('#fb6f6f'))
#     ax2.plot(twotheta, dataloader.load_ref(19)[:-1], color=colors.to_rgba('#fb6f6f'))
    ax2.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
    ax2.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax2.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax2.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax2.axes.set_ylim([-0.05,1.2])
    ax2.axes.set_xlim([5,60])

    ax2.set_xlabel(r'2$\Theta$ (degree)', labelpad=20, fontsize=34)
    ax2.set_ylabel(f'Norm.\nintensity', labelpad=20, fontsize=34)
    plt.text(0.03, 0.85, 'Experimental', fontsize=30, transform=ax0.transAxes, color='#000000', horizontalalignment='left')
    plt.text(0.96, 0.85, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', 'MAPbBr3')), fontsize=30, transform=ax0.transAxes, color='#000000', horizontalalignment='right')
    plt.text(0.03, 0.72, 'Prediction', fontsize=30, transform=ax1.transAxes, color='#000000', horizontalalignment='left')
    plt.text(0.96, 0.72, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula)), fontsize=30, transform=ax1.transAxes, color='#000000', horizontalalignment='right')
    plt.text(0.03, 0.72, 'Reference', fontsize=30, transform=ax2.transAxes, color='#000000', horizontalalignment='left')
    plt.text(0.96, 0.72, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula)), fontsize=30, transform=ax2.transAxes, color='#000000', horizontalalignment='right')

    plt.subplots_adjust(hspace=.0)
    plt.savefig(os.path.join(folder, 'models', model_folder,'Exp {}.png'.format(formula)), format='png', dpi=300, transparent=True, bbox_inches='tight')
#     plt.savefig(folder+r"\SelfAttention_{}_linear.png".format(i), format='png', dpi=300, transparent=True, bbox_inches='tight')

# %% [markdown]
# ## MAPbI3

# %%
data = np.genfromtxt(r'G:\Materials\MIT\=Projects\XRD\20240926 MAPbI-MAPbBr XRD\MAPbI3_Theta_2-Theta.xy', 
                     delimiter=" ", unpack=False)

twotheta = np.arange(5.00, 60.01, 0.01)
twotheta_corrected = np.arange(5.00, 70.01, 0.01)
X = np.zeros(twotheta_corrected.shape)
X[:len(data[:,1])] = data[:,1]
sample_height_displacement = -0.003136*1000

for i in range(len(twotheta_corrected)):
    twotheta_corrected[i] += math.degrees(math.atan(sample_height_displacement*math.sin(math.radians(2*twotheta_corrected[i]))/
                    (2*(110+sample_height_displacement*(math.radians(twotheta_corrected[i]))**2))))
print(twotheta_corrected)

X = interp1d(twotheta_corrected, X)(twotheta)
X = (X-np.min(X))/(np.max(X)-np.min(X))
Xs = np.zeros(twotheta.shape)
Xs[-X.shape[0]:] = X
Xs = np.expand_dims(Xs,axis=(0,-1))

plt.plot(Xs[0,:,0])
# Out:
# [ 4.85814663  4.8678657   4.87758478 ... 69.43126115 69.44148216
#  69.45170324]

# %%
twotheta = np.arange(5.00, 60.01, 0.01)[:-1]

for i in range(1):

    Xs_test = Xs[i:i+1,:-1,:].reshape((1,int(Xs.shape[1]/visual_embedding_dim),visual_embedding_dim))
    
    XRD_token_length = -Xs_test.shape[1]
    X_prompts = ['MA Pb I',]
    
    visual_embeds = torch.from_numpy(Xs_test).to(dtype=torch.float32)
    visual_attention_mask = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)
    visual_token_type_ids = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)

    inputs = tokenizer(X_prompts, return_tensors="pt", padding=True)
    prompt_token_length = len(inputs['input_ids'][0])
    inputs.update(
        {
            "visual_embeds": visual_embeds,
            "visual_token_type_ids": visual_token_type_ids,
            "visual_attention_mask": visual_attention_mask,
        }
    )

    outputs = model(**inputs.to('cuda'), output_attentions=True)
    pred_index = np.array(torch.topk(outputs.logits[0], 1).indices.detach().cpu())[0]
    formula = dataloader.dataset[dataloader.sample_list[pred_index]]['formula']
    
    Y = np.zeros((outputs.attentions[0].shape[-1],outputs.attentions[0].shape[-1]-prompt_token_length))

    for attention_head in outputs.attentions:
        Y += np.array(attention_head.detach().cpu())[0,0,:,prompt_token_length:]
    
    load_plt_setting()

    fig, (ax0, ax1, ax2) = plt.subplots(3,1, sharex=True, gridspec_kw=dict(height_ratios=[2,1,1]),figsize=(12, 10))

    ax0.plot(twotheta, Xs_test.reshape(-1), color=colors.to_rgba('#118ab2'))
    ax0.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
    ax0.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax0.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
    ax0.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax0.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax0.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax0.axes.set_ylim([-0.05,1.1])
    ax0.set_ylabel(f'Norm.\nintensity', labelpad=20, fontsize=34)
    
    ax1.plot(np.arange(5.00, 60.01, 0.01*20)[:-1], np.mean(Y, axis=0)/np.max(np.mean(Y, axis=0)), color=colors.to_rgba('#ffd166'))
    ax1.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
    ax1.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax1.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax1.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax1.set_ylabel(f'Norm.\nattention', labelpad=20, fontsize=34)
    ax1.axes.set_ylim([-0.05,1.2])

    ax2.plot(twotheta, dataloader.load_ref(pred_index)[:-1], color=colors.to_rgba('#fb6f6f'))
#     ax2.plot(twotheta, dataloader.load_ref(19)[:-1], color=colors.to_rgba('#fb6f6f'))
    ax2.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
    ax2.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax2.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax2.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax2.axes.set_ylim([-0.05,1.2])
    ax2.axes.set_xlim([5,60])

    ax2.set_xlabel(r'2$\Theta$ (degree)', labelpad=20, fontsize=34)
    ax2.set_ylabel(f'Norm.\nintensity', labelpad=20, fontsize=34)
    plt.text(0.03, 0.85, 'Experimental', fontsize=30, transform=ax0.transAxes, color='#000000', horizontalalignment='left')
    plt.text(0.96, 0.85, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', 'MAPbI3')), fontsize=30, transform=ax0.transAxes, color='#000000', horizontalalignment='right')
    plt.text(0.03, 0.72, 'Prediction', fontsize=30, transform=ax1.transAxes, color='#000000', horizontalalignment='left')
    plt.text(0.96, 0.72, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula)), fontsize=30, transform=ax1.transAxes, color='#000000', horizontalalignment='right')
    plt.text(0.03, 0.72, 'Reference', fontsize=30, transform=ax2.transAxes, color='#000000', horizontalalignment='left')
    plt.text(0.96, 0.72, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula)), fontsize=30, transform=ax2.transAxes, color='#000000', horizontalalignment='right')

    plt.subplots_adjust(hspace=.0)
    plt.savefig(os.path.join(folder, 'models', model_folder,'Exp {}.png'.format(formula)), format='png', dpi=300, transparent=True, bbox_inches='tight')
#     plt.savefig(folder+r"\SelfAttention_{}_linear.png".format(i), format='png', dpi=300, transparent=True, bbox_inches='tight')

# %% [markdown]
# ## MAPbI2.4Br0.6

# %%
data = np.genfromtxt(r'G:\Materials\MIT\=Projects\XRD\20240926 MAPbI-MAPbBr XRD\MAPbI2.4Br0.6_Theta_2-Theta.xy', 
                     delimiter=" ", unpack=False)

twotheta = np.arange(5.00, 60.01, 0.01)
twotheta_corrected = np.arange(5.00, 70.01, 0.01)
X = np.zeros(twotheta_corrected.shape)
X[:len(data[:,1])] = data[:,1]
sample_height_displacement = -0.003918*1000

for i in range(len(twotheta_corrected)):
    twotheta_corrected[i] += math.degrees(math.atan(sample_height_displacement*math.sin(math.radians(2*twotheta_corrected[i]))/
                    (2*(110+sample_height_displacement*(math.radians(twotheta_corrected[i]))**2))))
print(twotheta_corrected)

X = interp1d(twotheta_corrected, X)(twotheta)
X = (X-np.min(X))/(np.max(X)-np.min(X))
Xs = np.zeros(twotheta.shape)
Xs[-X.shape[0]:] = X
Xs = np.expand_dims(Xs,axis=(0,-1))

plt.plot(Xs[0,:,0])
# Out:
# [ 4.82276437  4.83241332  4.8420623  ... 69.28676043 69.29703731
#  69.30731428]

# %%
twotheta = np.arange(5.00, 60.01, 0.01)[:-1]

for i in range(1):

    Xs_test = Xs[i:i+1,:-1,:].reshape((1,int(Xs.shape[1]/visual_embedding_dim),visual_embedding_dim))
    
    XRD_token_length = -Xs_test.shape[1]
    X_prompts = ['MA Pb I Br',]
    
    visual_embeds = torch.from_numpy(Xs_test).to(dtype=torch.float32)
    visual_attention_mask = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)
    visual_token_type_ids = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)

    inputs = tokenizer(X_prompts, return_tensors="pt", padding=True)
    prompt_token_length = len(inputs['input_ids'][0])
    inputs.update(
        {
            "visual_embeds": visual_embeds,
            "visual_token_type_ids": visual_token_type_ids,
            "visual_attention_mask": visual_attention_mask,
        }
    )

    outputs = model(**inputs.to('cuda'), output_attentions=True)
    pred_index = np.array(torch.topk(outputs.logits[0], 1).indices.detach().cpu())[0]
    formula = dataloader.dataset[dataloader.sample_list[pred_index]]['formula']
    
    Y = np.zeros((outputs.attentions[0].shape[-1],outputs.attentions[0].shape[-1]-prompt_token_length))

    for attention_head in outputs.attentions:
        Y += np.array(attention_head.detach().cpu())[0,0,:,prompt_token_length:]
    
    load_plt_setting()

    fig, (ax0, ax1, ax2) = plt.subplots(3,1, sharex=True, gridspec_kw=dict(height_ratios=[2,1,1]),figsize=(12, 10))

    ax0.plot(twotheta, Xs_test.reshape(-1), color=colors.to_rgba('#118ab2'))
    ax0.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
    ax0.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax0.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
    ax0.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax0.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax0.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax0.axes.set_ylim([-0.05,1.1])
    ax0.set_ylabel(f'Norm.\nintensity', labelpad=20, fontsize=34)
    
    ax1.plot(np.arange(5.00, 60.01, 0.01*20)[:-1], np.mean(Y, axis=0)/np.max(np.mean(Y, axis=0)), color=colors.to_rgba('#ffd166'))
    ax1.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
    ax1.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax1.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax1.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax1.set_ylabel(f'Norm.\nattention', labelpad=20, fontsize=34)
    ax1.axes.set_ylim([-0.05,1.2])

    ax2.plot(twotheta, dataloader.load_ref(pred_index)[:-1], color=colors.to_rgba('#fb6f6f'))
#     ax2.plot(twotheta, dataloader.load_ref(19)[:-1], color=colors.to_rgba('#fb6f6f'))
    ax2.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
    ax2.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax2.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax2.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax2.axes.set_ylim([-0.05,1.2])
    ax2.axes.set_xlim([5,60])

    ax2.set_xlabel(r'2$\Theta$ (degree)', labelpad=20, fontsize=34)
    ax2.set_ylabel(f'Norm.\nintensity', labelpad=20, fontsize=34)
    plt.text(0.03, 0.85, 'Experimental', fontsize=30, transform=ax0.transAxes, color='#000000', horizontalalignment='left')
    plt.text(0.96, 0.85, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', 'MAPbI2.4Br0.6')), fontsize=30, transform=ax0.transAxes, color='#000000', horizontalalignment='right')
    plt.text(0.03, 0.72, 'Prediction', fontsize=30, transform=ax1.transAxes, color='#000000', horizontalalignment='left')
    plt.text(0.96, 0.72, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula)), fontsize=30, transform=ax1.transAxes, color='#000000', horizontalalignment='right')
    plt.text(0.03, 0.72, 'Reference', fontsize=30, transform=ax2.transAxes, color='#000000', horizontalalignment='left')
    plt.text(0.96, 0.72, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula)), fontsize=30, transform=ax2.transAxes, color='#000000', horizontalalignment='right')

    plt.subplots_adjust(hspace=.0)
    plt.savefig(os.path.join(folder, 'models', model_folder,'Exp {}.png'.format(formula)), format='png', dpi=300, transparent=True, bbox_inches='tight')
#     plt.savefig(folder+r"\SelfAttention_{}_linear.png".format(i), format='png', dpi=300, transparent=True, bbox_inches='tight')

# %% [markdown]
# ## MAPbI1.8Br1.2

# %%
data = np.genfromtxt(r'G:\Materials\MIT\=Projects\XRD\20240926 MAPbI-MAPbBr XRD\MAPbI1.8Br1.2_Theta_2-Theta.xy', 
                     delimiter=" ", unpack=False)

twotheta = np.arange(5.00, 60.01, 0.01)
twotheta_corrected = np.arange(5.00, 70.01, 0.01)
X = np.zeros(twotheta_corrected.shape)
X[:len(data[:,1])] = data[:,1]
sample_height_displacement = -0.003908*1000

for i in range(len(twotheta_corrected)):
    twotheta_corrected[i] += math.degrees(math.atan(sample_height_displacement*math.sin(math.radians(2*twotheta_corrected[i]))/
                    (2*(110+sample_height_displacement*(math.radians(twotheta_corrected[i]))**2))))
print(twotheta_corrected)

X = interp1d(twotheta_corrected, X)(twotheta)
X = (X-np.min(X))/(np.max(X)-np.min(X))
Xs = np.zeros(twotheta.shape)
Xs[-X.shape[0]:] = X
Xs = np.expand_dims(Xs,axis=(0,-1))

plt.plot(X)
# Out:
# [ 4.82321685  4.8328667   4.84251657 ... 69.28862864 69.2989048
#  69.30918106]

# %%
twotheta = np.arange(5.00, 60.01, 0.01)[:-1]

for i in range(1):

    Xs_test = Xs[i:i+1,:-1,:].reshape((1,int(Xs.shape[1]/visual_embedding_dim),visual_embedding_dim))
    
    XRD_token_length = -Xs_test.shape[1]
    X_prompts = ['MA Pb I Br',]
    
    visual_embeds = torch.from_numpy(Xs_test).to(dtype=torch.float32)
    visual_attention_mask = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)
    visual_token_type_ids = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)

    inputs = tokenizer(X_prompts, return_tensors="pt", padding=True)
    prompt_token_length = len(inputs['input_ids'][0])
    inputs.update(
        {
            "visual_embeds": visual_embeds,
            "visual_token_type_ids": visual_token_type_ids,
            "visual_attention_mask": visual_attention_mask,
        }
    )

    outputs = model(**inputs.to('cuda'), output_attentions=True)
    pred_index = np.array(torch.topk(outputs.logits[0], 1).indices.detach().cpu())[0]
    formula = dataloader.dataset[dataloader.sample_list[pred_index]]['formula']
    
    Y = np.zeros((outputs.attentions[0].shape[-1],outputs.attentions[0].shape[-1]-prompt_token_length))

    for attention_head in outputs.attentions:
        Y += np.array(attention_head.detach().cpu())[0,0,:,prompt_token_length:]
    
    load_plt_setting()

    fig, (ax0, ax1, ax2) = plt.subplots(3,1, sharex=True, gridspec_kw=dict(height_ratios=[2,1,1]),figsize=(12, 10))

    ax0.plot(twotheta, Xs_test.reshape(-1), color=colors.to_rgba('#118ab2'))
    ax0.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
    ax0.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax0.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
    ax0.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax0.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax0.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax0.axes.set_ylim([-0.05,1.1])
    ax0.set_ylabel(f'Norm.\nintensity', labelpad=20, fontsize=34)
    
    ax1.plot(np.arange(5.00, 60.01, 0.01*visual_embedding_dim)[:-1], np.mean(Y, axis=0)/np.max(np.mean(Y, axis=0)), color=colors.to_rgba('#ffd166'))
    ax1.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
    ax1.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax1.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax1.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax1.set_ylabel(f'Norm.\nattention', labelpad=20, fontsize=34)
    ax1.axes.set_ylim([-0.05,1.2])

    ax2.plot(twotheta, dataloader.load_ref(pred_index)[:-1], color=colors.to_rgba('#fb6f6f'))
#     ax2.plot(twotheta, dataloader.load_ref(19)[:-1], color=colors.to_rgba('#fb6f6f'))
    ax2.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
    ax2.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
    ax2.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax2.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
    ax2.axes.set_ylim([-0.05,1.2])
    ax2.axes.set_xlim([5,60])

    ax2.set_xlabel(r'2$\Theta$ (degree)', labelpad=20, fontsize=34)
    ax2.set_ylabel(f'Norm.\nintensity', labelpad=20, fontsize=34)
    plt.text(0.03, 0.85, 'Experimental', fontsize=30, transform=ax0.transAxes, color='#000000', horizontalalignment='left')
    plt.text(0.96, 0.85, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', 'MAPbI1.8Br1.2')), fontsize=30, transform=ax0.transAxes, color='#000000', horizontalalignment='right')
    plt.text(0.03, 0.72, 'Prediction', fontsize=30, transform=ax1.transAxes, color='#000000', horizontalalignment='left')
    plt.text(0.96, 0.72, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula)), fontsize=30, transform=ax1.transAxes, color='#000000', horizontalalignment='right')
    plt.text(0.03, 0.72, 'Reference', fontsize=30, transform=ax2.transAxes, color='#000000', horizontalalignment='left')
    plt.text(0.96, 0.72, '{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula)), fontsize=30, transform=ax2.transAxes, color='#000000', horizontalalignment='right')

    plt.subplots_adjust(hspace=.0)
    plt.savefig(os.path.join(folder, 'models', model_folder,'Exp {}.png'.format(formula)), format='png', dpi=300, transparent=True, bbox_inches='tight')
#     plt.savefig(folder+r"\SelfAttention_{}_linear.png".format(i), format='png', dpi=300, transparent=True, bbox_inches='tight')

# %% [markdown]
# # 7 Experimental multiphase

# %%
model_folder = '20240909 multi phase reasonable mixing'
num_of_epochs = 100000
cif_folder = os.path.join(folder, 'cif')
visual_embedding_dim = 20
model = VisualBertForQuestionAnswering.from_pretrained(os.path.join(folder, 'models', 
                                                                    model_folder, '{}'.format(num_of_epochs))).to('cuda')

# %%
# model_folder = '20240906 single phase'
model_folder = '20241004 multi phase embedding 20 2theta 10-30'
visual_embedding_dim = 20
model = VisualBertForQuestionAnswering.from_pretrained(os.path.join(folder, 'models', model_folder,'1000000')).to('cuda')

# %%
data = np.genfromtxt(r'G:\Materials\MIT\=Projects\XRD\20240926 FAPbI XRD\1FAPbI_Theta_2-Theta.xy', 
                     delimiter=" ", unpack=False)

twotheta = np.arange(5.00, 60.01, 0.01)
twotheta_corrected = np.arange(5.00, 70.01, 0.01)
X = np.zeros(twotheta_corrected.shape)
X[:len(data[:,1])] = data[:,1]
sample_height_displacement = -0.000329*1000
# sample_height_displacement = 0

for i in range(len(twotheta_corrected)):
    twotheta_corrected[i] += math.degrees(math.atan(sample_height_displacement*math.sin(math.radians(2*twotheta_corrected[i]))/
                    (2*(110+sample_height_displacement*(math.radians(twotheta_corrected[i]))**2))))
print(twotheta_corrected)

X = interp1d(twotheta_corrected, X)(twotheta)
X = (X-np.min(X))/(np.max(X)-np.min(X))
Xs = np.zeros(twotheta.shape)
Xs[-X.shape[0]:] = X
Xs = np.expand_dims(Xs,axis=(0,-1))

# twotheta = twotheta[500:2501]
# Xs = Xs[:,500:2501,:]

plt.plot(twotheta,Xs[0,:,0])
# Out:
# [ 4.98512092  4.99509147  5.00506201 ... 69.92463104 69.93465398
#  69.94467692]

# %%
load_plt_setting()

fig, (ax0, ax1, ) = plt.subplots(2,1, sharex=True, gridspec_kw=dict(height_ratios=[2, 1]),figsize=(12, 10))
mat = ax0.plot(twotheta, Xs[0,:,0], linewidth=1, color=colors.to_rgba('#000000'))
ax0.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
ax0.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax0.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
ax0.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax0.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax0.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax0.axes.set_ylim([-0.05,1.2])

formula = []
# for sample_no, c in zip([44,46],["#ef476f","#ffd166"]):
for sample_no, c in zip([44,46,65],["#ef476f","#ffd166","#118ab2"]):
    ref = dataloader.load_ref(sample_no)
    mat = ax1.plot(twotheta, ref/np.max(ref), linewidth=2, color=c)
    formula.append(dataloader.dataset[dataloader.sample_list[sample_no]]['formula'])
ax1.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=7, steps=[1, 2, 5, 10]))
ax1.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax1.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=2, steps=[1, 2, 5, 10]))
ax1.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax1.tick_params(axis='both',direction='in',length=8,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax1.tick_params(axis='both',which='minor',direction='in',length=4,width=2,pad=10,color='black',right='on',top='on',labelsize=28)
ax1.axes.set_ylim([0,1.3])
# ax2.axes.set_xlim([22.5,30])
ax1.axes.set_xlim([twotheta[0],twotheta[-1]])

plt.text(0.03, 0.86, 'Input', fontsize=30, transform=ax0.transAxes, horizontalalignment='left')
plt.text(0.03, 0.75, 'Ground truth', fontsize=30, transform=ax1.transAxes, horizontalalignment='left')
    
plt.subplots_adjust(hspace=.0)

sample_no = 860
ax1.set_xlabel(r'2$\Theta$ (degree)', labelpad=10, fontsize=34)
ax0.set_ylabel(r'Normalized intensity                      ', labelpad=20, fontsize=34)
# plt.savefig(os.path.join(folder, 'models', model_folder, 'Multiphase_{}_{}.png'.format(max_n_mix,sample_no)), 
#             format='png', dpi=300, transparent=True, bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Normalized intensity                      ')

# %%
Xs_test = Xs[:1,:-1,:].reshape((1,int(Xs.shape[1]/visual_embedding_dim),visual_embedding_dim))

XRD_token_length = -Xs_test.shape[1]
X_prompts = ['FA Pb I',]

visual_embeds = torch.from_numpy(Xs_test).to(dtype=torch.float32)
visual_attention_mask = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)
visual_token_type_ids = torch.ones(visual_embeds.shape[:-1], dtype=torch.long)

inputs = tokenizer(X_prompts, return_tensors="pt", padding=True)
prompt_token_length = len(inputs['input_ids'][0])
inputs.update(
    {
        "visual_embeds": visual_embeds,
        "visual_token_type_ids": visual_token_type_ids,
        "visual_attention_mask": visual_attention_mask,
    }
)

outputs = model(**inputs.to('cuda'), output_attentions=True)

# %%
order = np.linspace(0,65,66)
y_pred_full = list(np.array(outputs.logits.detach().cpu())[0])
y_true_full = np.zeros(order.shape)
y_true_full[44] += 1
y_true_full[46] += 1
y_true_full[65] += 1

order_sort = [x for _,x in sorted(zip(y_pred_full,order))]
y_true_full_sort = [x for _,x in sorted(zip(y_pred_full,y_true_full))]
y_pred_full_sort = copy.deepcopy(y_pred_full)
y_pred_full_sort.sort()
y_pred_full_sort = y_pred_full_sort/np.max(y_pred_full_sort)

for i in range(len(y_true_full_sort)-20,len(y_true_full_sort)):
    print(y_pred_full_sort[i], y_true_full_sort[i], order_sort[i], 
          dataloader.dataset[dataloader.sample_list[int(order_sort[i])]]['formula'])
# Out:
# -0.13863377 0.0 24.0 CsPb(I0.2Br0.8)3
# -0.13016954 0.0 13.0 Cs0.4MA0.6PbI3
# -0.12737411 0.0 34.0 Pnma-CsPbCl3
# -0.09532744 0.0 27.0 CsPb(I0.8Br0.2)3
# -0.094834566 0.0 4.0 Cs0.2FA0.8PbI3
# -0.08478543 0.0 14.0 Cs0.6MA0.4PbI3
# -0.083946325 0.0 19.0 CsPb2Br5
# -0.08276009 0.0 15.0 Cs0.8MA0.2PbI3
# -0.047577202 0.0 5.0 Cs0.4FA0.6PbI3
# -0.024015192 0.0 45.0 beta-FAPbI3
# -0.009716054 0.0 63.0 tetragonal-MAPbI3
# 0.027859647 0.0 7.0 Cs0.8FA0.2PbI3
# 0.028487397 0.0 30.0 CsPb(I0.6Cl0.4)3
# 0.030709308 0.0 31.0 CsPb(I0.8Cl0.2)3
# 0.08498871 1.0 44.0 alpha-FAPbI3
# 0.71167463 1.0 65.0 PbI2
# 0.7685004 0.0 38.0 gamma-CsPbI3
# 0.9324156 0.0 18.0 CsI
# 0.95185006 0.0 36.0 alpha-CsPbI3
# 1.0 0.0 37.0 delta-CsPbI3

# %%
load_plt_setting()

fig, ax = plt.subplots(figsize=(5, 8))

cmap = mpl.cm.get_cmap('viridis')
cmap_index = np.linspace(0,1,8)

# formula_
for i in range(6):
    formula = dataloader.dataset[dataloader.sample_list[int(order_sort[-i-1])]]['formula']
    if y_true_full_sort[-i-1] == 0:
        alpha = 0.4
        plt.text(0.03, 0.83-i*0.17, u'$\u2717$'+'{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula)),
                 fontsize=26, transform=ax.transAxes, horizontalalignment='left', alpha=alpha)
    else:
        alpha = 1
        plt.text(0.03, 0.83-i*0.17, u'$\u2713$'+'{}'.format(re.sub(r'(\d+(\.\d+)?)', r'$_{\1}$', formula)),
                 fontsize=26, transform=ax.transAxes, horizontalalignment='left', alpha=alpha)
    ax.barh(-i, y_pred_full_sort[-i-1], height=0.3, color=cmap(cmap_index[-i-1]), alpha=alpha)
    

ax.tick_params(axis='x', direction='out', top=True, labeltop=True, bottom=False, 
               labelbottom=False, length=8, width=2, pad=10, labelsize=24)
ax.tick_params(axis='x', which='minor', top=True, labeltop=True, bottom=False, 
               labelbottom=False, direction='out', length=4, width=2, pad=10)
plt.yticks([])

# ax.tick_params(axis='y', labelsize=24)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.xaxis.set_label_position('top')
plt.xlabel(r'Prediction score', labelpad=30, fontsize=24)

# plt.savefig(os.path.join(folder, 'models', model_folder, 'Multiphase_{}_{}_score.png'.format(max_n_mix,sample_no)), 
#             format='png', dpi=300, transparent=True, bbox_inches='tight')
# Out:
# Text(0.5, 0, 'Prediction score')
